# %% [markdown]
# ### [房价预测：进阶回归技术](https://www.kaggle.com/c/house-prices-advanced-regression-techniques)

# %% [markdown]
# - **看看数据长什么样**<br>
# 用pandas加载数据<br>
# 看看列名

# %%
import pandas as pd #数据分析
import numpy as np #科学计算

data_train = pd.read_csv("test.csv")
data_train.columns
# Out:
# Index([u'Id', u'MSSubClass', u'MSZoning', u'LotFrontage', u'LotArea',
#        u'Street', u'Alley', u'LotShape', u'LandContour', u'Utilities',
#        u'LotConfig', u'LandSlope', u'Neighborhood', u'Condition1',
#        u'Condition2', u'BldgType', u'HouseStyle', u'OverallQual',
#        u'OverallCond', u'YearBuilt', u'YearRemodAdd', u'RoofStyle',
#        u'RoofMatl', u'Exterior1st', u'Exterior2nd', u'MasVnrType',
#        u'MasVnrArea', u'ExterQual', u'ExterCond', u'Foundation', u'BsmtQual',
#        u'BsmtCond', u'BsmtExposure', u'BsmtFinType1', u'BsmtFinSF1',
#        u'BsmtFinType2', u'BsmtFinSF2', u'BsmtUnfSF', u'TotalBsmtSF',
#        u'Heating', u'HeatingQC', u'CentralAir', u'Electrical', u'1stFlrSF',
#        u'2ndFlrSF', u'LowQualFinSF', u'GrLivArea', u'BsmtFullBath',
#        u'BsmtHalfBath', u'FullBath', u'HalfBath', u'BedroomAbvGr',
#        u'KitchenAbvGr', u'KitchenQual', u'TotRmsAbvGrd', u'Functional',
#        u'Fireplaces', u'FireplaceQu', u'GarageType', u'GarageYrBlt',
#        u'GarageFinish', u'GarageCars', u'GarageArea', u'GarageQual',
#        u'GarageCond', u'PavedDrive', u'WoodDeckSF', u'OpenPorchSF',
#        u'EnclosedPorch', u'3SsnPorch', u'ScreenPorch', u'PoolArea', u'PoolQC',
#        u'Fence', u'MiscFeature', u'MiscVal', u'MoSold', u'YrSold', u'SaleType',
#        u'SaleCondition'],
#       dtype='object')

# %% [markdown]
# - **<font color=red>把列名换成中文</font>**<br>
# 英文简称看着不舒服，先创建个副本，替换中文列名<br>

# %%
data_train1 = data_train.copy()
data_train1.columns = ['id','建筑信息','用途分类','临街距离','地块面积','街道铺设','门口铺设','房屋形状','地面平整','水电煤气','位置细节','物业平整','地理位置','周边条件1','周边条件2','住宅类型','住宅样式','材料外观','整体评价','起建时间','重建时间','屋顶类型','屋顶材料','外墙覆盖材料1','外墙覆盖材料2','砌体类型','胶合板面积','外墙材料质量','外墙状态','地基类型','地下室高度','地下室状况','地下室光照','地下室评级','地下室面积','第二地下室评级','第二地下室面积','地下室未完工面积','基底总面积','取暖类型','取暖设施质量','中央空调','电气系统','一楼面积','二楼面积','低质量装修面积','生活区域面积','地下室全套卫浴','地下室半套卫浴','地面全套卫浴','地面半套卫浴','地面卧室','地面厨房','厨房质量','地面房间数','家庭功能','壁炉数量','壁炉质量','车库类型','车库建成时间','车库装饰','车库容量','车库面积','车库质量','车库条件','铺设车道','木地板面积','开放式门廊面积','封闭式门廊面积','三季门廊面积','露天门廊面积','游泳池面积','游泳池质量','栅栏质量','杂项功能','杂项功能价值','出售月份','出售年份','销售类型','销售条件']
data_train1.head()
# Out:
#      id  建筑信息 用途分类  临街距离   地块面积  街道铺设 门口铺设 房屋形状 地面平整    水电煤气   ...   露天门廊面积  \
# 0  1461    20   RH  80.0  11622  Pave  NaN  Reg  Lvl  AllPub   ...      120
# 1  1462    20   RL  81.0  14267  Pave  NaN  IR1  Lvl  AllPub   ...        0
# 2  1463    60   RL  74.0  13830  Pave  NaN  IR1  Lvl  AllPub   ...        0
# 3  1464    60   RL  78.0   9978  Pave  NaN  IR1  Lvl  AllPub   ...        0
# 4  1465   120   RL  43.0   5005  Pave  NaN  IR1  HLS  AllPub   ...      144
#
#   游泳池面积 游泳池质量   栅栏质量  杂项功能 杂项功能价值 出售月份  出售年份  销售类型    销售条件
# 0     0   NaN  MnPrv   NaN      0    6  2010    WD  Normal
# 1     0   NaN    NaN  Gar2  12500    6  2010    WD  Normal
# 2     0   NaN  MnPrv   NaN      0    3  2010    WD  Normal
# 3     0   NaN    NaN   NaN      0    6  2010    WD  Normal
# 4     0   NaN    NaN   NaN      0    1  2010    WD  Normal
#
# [5 rows x 80 columns]

# %% [markdown]
# - **看下各列的类型和值**<br>
# 各列信息:3个浮点型，35个整型，43个字符型<br>
# 数值型字段的分布<br>
# 缺失值：19个字段有缺失值，但是都有用，应逐个处理

# %%
data_train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
# id          1459 non-null int64
# 建筑信息        1459 non-null int64
# 用途分类        1455 non-null object
# 临街距离        1232 non-null float64
# 地块面积        1459 non-null int64
# 街道铺设        1459 non-null object
# 门口铺设        107 non-null object
# 房屋形状        1459 non-null object
# 地面平整        1459 non-null object
# 水电煤气        1457 non-null object
# 位置细节        1459 non-null object
# 物业平整        1459 non-null object
# 地理位置        1459 non-null object
# 周边条件1       1459 non-null object
# 周边条件2       1459 non-null object
# 住宅类型        1459 non-null object
# 住宅样式        1459 non-null object
# 材料外观        1459 non-null int64
# 整体评价        1459 non-null int64
# 起建时间        1459 non-null int64
# 重建时间        1459 non-null int64
# 屋顶类型        1459 non-null object
# 屋顶材料        1459 non-null object
# 外墙覆盖材料1     1458 non-null object
# 外墙覆盖材料2     1458 non-null object
# 砌体类型        1443 non-null object
# 胶合板面积       1444 non-null float64
# 外墙材料质量      1459 non-null object
# 外墙状态        1459 non-null object
# 地基类型        1459 non-null object
# 地下室高度       1415 non-null object
# 地下室状况       1414 non-null object
# 地下室光照       1415 non-null object
# 地下室评级       1417 non-null object
# 地下室面积       1458 non-null float64
# 第二地下室评级     1417 non-null object
# 第二地下室面积     1458 non-null float64
# 地下室未完工面积    1458 non-null float64
# 基底总面积       1458 non-null float64
# 取暖类型        1459 non-null object
# 取暖设施质量      1459 non-null object
# 中央空调        1459 non-null object
# 电气系统        1459 non-null object
# 一楼面积        1459 non-null int64
# 二楼面积        1459 non-null int64
# 低质量装修面积     1459 non-null int64
# 生活区域面积      1459 non-null int64
# 地下室全套卫浴     1457 non-null float64
# 地下室半套卫浴     1457 non-null float64
# 地面全套卫浴      1459 non-null int64
# 地面半套卫浴      1459 non-null int64
# 地面卧室        1459 non-null int64
# 地面厨房        1459 non-null int64
# 厨房质量        1458 non-null object
# 地面房间数       1459 non-null int64
# 家庭功能        1457 non-null object
# 壁炉数量        1459 non-null int64
# 壁炉质量        729 non-null object
# 车库类型        1383 non-null object
# 车库建成时间      1381 non-null float64
# 车库装饰        1381 non-null object
# 车库容量        1458 non-null float64
# 车库面积        1458 non-null float64
# 车库质量        1381 non-null object
# 车库条件        1381 non-null object
# 铺设车道        1459 non-null object
# 木地板面积       1459 non-null int64
# 开放式门廊面积     1459 non-null int64
# 封闭式门廊面积     1459 non-null int64
# 三季门廊面积      1459 non-null int64
# 露天门廊面积      1459 non-null int64
# 游泳池面积       1459 non-null int64
# 游泳池质量       3 non-null object
# 栅栏质量        290 non-null object
# 杂项功能        51 non-null object
# 杂项功能价值      1459 non-null int64
# 出售月份        1459 non-null int64
# 出售年份        1459 non-null int64
# 销售类型        1458 non-null object
# 销售条件        1459 non-null object
# dtypes: float64(11), int64(26), object(43)
# memory usage: 911.9+ KB

# %%
data_train1.describe()
# Out:
# /Users/mahui/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                 id         建筑信息         临街距离          地块面积         材料外观  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000          NaN   7391.000000     5.000000
# 50%    2190.000000    50.000000          NaN   9399.000000     6.000000
# 75%    2554.500000    70.000000          NaN  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#               整体评价         起建时间         重建时间        胶合板面积        地下室面积  \
# count  1459.000000  1459.000000  1459.000000  1444.000000  1458.000000
# mean      5.553804  1971.357779  1983.662783   100.709141   439.203704
# std       1.113740    30.390071    21.130467   177.625900   455.268042
# min       1.000000  1879.000000  1950.000000     0.000000     0.000000
# 25%       5.000000  1953.000000  1963.000000          NaN          NaN
# 50%       5.000000  1973.000000  1992.000000          NaN          NaN
# 75%       6.000000  2001.000000  2004.000000          NaN          NaN
# max       9.000000  2010.000000  2010.000000  1290.000000  4010.000000
#
#           ...              车库面积        木地板面积      开放式门廊面积      封闭式门廊面积  \
# count     ...       1458.000000  1459.000000  1459.000000  1459.000000
# mean      ...        472.768861    93.174777    48.313914    24.243317
# std       ...        217.048611   127.744882    68.883364    67.227765
# min       ...          0.000000     0.000000     0.000000     0.000000
# 25%       ...               NaN     0.000000     0.000000     0.000000
# 50%       ...               NaN     0.000000    28.000000     0.000000
# 75%       ...               NaN   168.000000    72.000000     0.000000
# max       ...       1488.000000  1424.000000   742.000000  1012.000000
#
#             三季门廊面积       露天门廊面积        游泳池面积        杂项功能价值         出售月份  \
# count  1459.000000  1459.000000  1459.000000   1459.000000  1459.000000
# mean      1.794380    17.064428     1.744345     58.167923     6.104181
# std      20.207842    56.609763    30.491646    630.806978     2.722432
# min       0.000000     0.000000     0.000000      0.000000     1.000000
# 25%       0.000000     0.000000     0.000000      0.000000     4.000000
# 50%       0.000000     0.000000     0.000000      0.000000     6.000000
# 75%       0.000000     0.000000     0.000000      0.000000     8.000000
# max     360.000000   576.000000   800.000000  17000.000000    12.000000
#
#               出售年份
# count  1459.000000
# mean   2007.769705
# std       1.301740
# min    2006.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2010.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# - **处理缺失值**<br>
# 鉴于该数据集质量较高，缺失值不做drop，分为数值型和字段型分别补齐<br>
# - 字段型：用一个字段替换
# - 数值型：替换成一个值

# %%
#查看有缺失的列
df1 = data_train1.isnull()
df2 = df1.apply(lambda x: x.sum(), axis=0)
df2[df2 > 0]
# Out:
# 用途分类           4
# 临街距离         227
# 门口铺设        1352
# 水电煤气           2
# 外墙覆盖材料1        1
# 外墙覆盖材料2        1
# 砌体类型          16
# 胶合板面积         15
# 地下室高度         44
# 地下室状况         45
# 地下室光照         44
# 地下室评级         42
# 地下室面积          1
# 第二地下室评级       42
# 第二地下室面积        1
# 地下室未完工面积       1
# 基底总面积          1
# 地下室全套卫浴        2
# 地下室半套卫浴        2
# 厨房质量           1
# 家庭功能           2
# 壁炉质量         730
# 车库类型          76
# 车库建成时间        78
# 车库装饰          78
# 车库容量           1
# 车库面积           1
# 车库质量          78
# 车库条件          78
# 游泳池质量       1456
# 栅栏质量        1169
# 杂项功能        1408
# 销售类型           1
# dtype: int64

# %%
#字符型处理较为简单，用一个新特征代表缺失
#门口铺设，Alley，NaN 代表 No alley access，替换为 NoAlley
#砌体类型，MasVnrType，NaN代表无砌体
#地下室高度、状况、光照、评级、第二地下室评级，BsmtQual、BsmtCond、BsmtExposure、BsmtFinType1、BsmtFinType2，NaN 代表 No Basement，替换为 NoBasement
#游泳池质量，PoolQC，NA 代表 No Pool
#栅栏质量，Fence，NA 代表 No Fence
#杂项功能，MiscFeature，NA 代表 None
#车库类型 、建成时间 、装饰、质量、条件，GarageType、GarageFinish、GarageCars、GarageArea、GarageQual NA代表No Garage
#壁炉质量，FireplaceQu，NA 代表 No Fireplace


data_train1.loc[ (data_train1['门口铺设'].isnull()), '门口铺设' ] = 'NoAlley'
print '门口铺设修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['Alley'].isnull().sum(),data_train1['门口铺设'].isnull().sum())

data_train1.loc[ (data_train1['砌体类型'].isnull()), '砌体类型' ] = 'NoMas'
print '砌体类型修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['MasVnrType'].isnull().sum(),data_train1['砌体类型'].isnull().sum())

data_train1.loc[ (data_train1['地下室高度'].isnull()), '地下室高度' ] = 'NoBasement'
print '地下室高度修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['BsmtQual'].isnull().sum(),data_train1['地下室高度'].isnull().sum())

data_train1.loc[ (data_train1['地下室状况'].isnull()), '地下室状况' ] = 'NoBasement'
print '地下室状况修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['BsmtCond'].isnull().sum(),data_train1['地下室状况'].isnull().sum())

data_train1.loc[ (data_train1['地下室光照'].isnull()), '地下室光照' ] = 'NoBasement'
print '地下室光照修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['BsmtExposure'].isnull().sum(),data_train1['地下室光照'].isnull().sum())

data_train1.loc[ (data_train1['地下室评级'].isnull()), '地下室评级' ] = 'NoBasement'
print '地下室评级修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['BsmtFinType1'].isnull().sum(),data_train1['地下室评级'].isnull().sum())

data_train1.loc[ (data_train1['第二地下室评级'].isnull()), '第二地下室评级' ] = 'NoBasement'
print '第二地下室评级修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['BsmtFinType2'].isnull().sum(),data_train1['第二地下室评级'].isnull().sum())

data_train1.loc[ (data_train1['游泳池质量'].isnull()), '游泳池质量' ] = 'NoPool'
print '游泳池质量修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['PoolQC'].isnull().sum(),data_train1['游泳池质量'].isnull().sum())

data_train1.loc[ (data_train1['栅栏质量'].isnull()), '栅栏质量' ] = 'NoFence'
print '栅栏质量修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['Fence'].isnull().sum(),data_train1['栅栏质量'].isnull().sum())

data_train1.loc[ (data_train1['杂项功能'].isnull()), '杂项功能' ] = 'NoMisc'
print '杂项功能修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['MiscFeature'].isnull().sum(),data_train1['杂项功能'].isnull().sum())

data_train1.loc[ (data_train1['车库类型'].isnull()), '车库类型' ] = 'NoGarage'
print '车库类型修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['GarageType'].isnull().sum(),data_train1['车库类型'].isnull().sum())

data_train1.loc[ (data_train1['车库建成时间'].isnull()), '车库建成时间' ] = 'NoGarage'
print '车库建成时间修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['GarageFinish'].isnull().sum(),data_train1['车库建成时间'].isnull().sum())

data_train1.loc[ (data_train1['车库装饰'].isnull()), '车库装饰' ] = 'NoGarage'
print '车库装饰修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['GarageCars'].isnull().sum(),data_train1['车库装饰'].isnull().sum())

data_train1.loc[ (data_train1['车库质量'].isnull()), '车库质量' ] = 'NoGarage'
print '车库质量修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['GarageArea'].isnull().sum(),data_train1['车库质量'].isnull().sum())

data_train1.loc[ (data_train1['车库条件'].isnull()), '车库条件' ] = 'NoGarage'
print '车库条件修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['GarageQual'].isnull().sum(),data_train1['车库条件'].isnull().sum())

data_train1.loc[ (data_train1['壁炉质量'].isnull()), '壁炉质量' ] = 'NoFire'
print '壁炉质量修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['FireplaceQu'].isnull().sum(),data_train1['壁炉质量'].isnull().sum())
# Out:
# 门口铺设修改前NaN值为1352个,修改后NaN值为0个
# 砌体类型修改前NaN值为16个,修改后NaN值为0个
# 地下室高度修改前NaN值为44个,修改后NaN值为0个
# 地下室状况修改前NaN值为45个,修改后NaN值为0个
# 地下室光照修改前NaN值为44个,修改后NaN值为0个
# 地下室评级修改前NaN值为42个,修改后NaN值为0个
# 第二地下室评级修改前NaN值为42个,修改后NaN值为0个
# 游泳池质量修改前NaN值为1456个,修改后NaN值为0个
# 栅栏质量修改前NaN值为1169个,修改后NaN值为0个
# 杂项功能修改前NaN值为1408个,修改后NaN值为0个
# 车库类型修改前NaN值为76个,修改后NaN值为0个
# 车库建成时间修改前NaN值为78个,修改后NaN值为0个
# 车库装饰修改前NaN值为1个,修改后NaN值为0个
# 车库质量修改前NaN值为1个,修改后NaN值为0个
# 车库条件修改前NaN值为78个,修改后NaN值为0个
# 壁炉质量修改前NaN值为730个,修改后NaN值为0个

# %%
#数值型处理需要对照字段一一处理
#临街距离，LotFrontage，说明文件中未描述，但是根据分布，猜测小于20的都是NaN，所以全部补0
data_train1.loc[ (data_train1['临街距离'].isnull()), '临街距离' ] = 0
print '修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['LotFrontage'].isnull().sum(),data_train1['临街距离'].isnull().sum())

#胶合板面积，MasVnrArea，明文件中未描述，猜测全部补0
data_train1.loc[ (data_train1['胶合板面积'].isnull()), '胶合板面积' ] = 0
print '修改前NaN值为%s个,修改后NaN值为%s个' % (data_train['MasVnrArea'].isnull().sum(),data_train1['胶合板面积'].isnull().sum())
# Out:
# 修改前NaN值为227个,修改后NaN值为0个
# 修改前NaN值为15个,修改后NaN值为0个

# %%
#电气系统，Electrical，只有1个缺失，丢弃

# %%
data_train1 = data_train1.fillna(method='ffill')

# %%
#查看处理完缺失后的情况
df1 = data_train1.isnull()
df2 = df1.apply(lambda x: x.sum(), axis=0)
print '处理完毕，缺失值为%s' % df2[df2 > 0].count()
# Out:
# 处理完毕，缺失值为0

# %%
#处理完的数据备份下，换回英文缩写columns
df = data_train1.copy()
df.columns = data_train.columns
df.to_csv('2.csv',index=None)
