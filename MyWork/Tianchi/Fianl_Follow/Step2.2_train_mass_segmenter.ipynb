# %%
from utils.imports import *
MEAN_FRAME_COUNT = 1
CHANNEL_COUNT = 1
# Out:
# Using TensorFlow backend.

# %%
def random_scale_img(img, xy_range, lock_xy=False):
    if random.random() > xy_range.chance:
        return img

    if not isinstance(img, list):
        img = [img]

    import cv2
    scale_x = random.uniform(xy_range.x_min, xy_range.x_max)
    scale_y = random.uniform(xy_range.y_min, xy_range.y_max)
    if lock_xy:
        scale_y = scale_x

    org_height, org_width = img[0].shape[:2]
    xy_range.last_x = scale_x
    xy_range.last_y = scale_y

    res = []
    for img_inst in img:
        scaled_width = int(org_width * scale_x)
        scaled_height = int(org_height * scale_y)
        scaled_img = cv2.resize(img_inst, (scaled_width, scaled_height), interpolation=cv2.INTER_CUBIC)
        if scaled_width < org_width:
            extend_left = (org_width - scaled_width) / 2
            extend_right = org_width - extend_left - scaled_width
            scaled_img = cv2.copyMakeBorder(scaled_img, 0, 0, extend_left, extend_right, borderType=cv2.BORDER_CONSTANT)
            scaled_width = org_width

        if scaled_height < org_height:
            extend_top = (org_height - scaled_height) / 2
            extend_bottom = org_height - extend_top - scaled_height
            scaled_img = cv2.copyMakeBorder(scaled_img, extend_top, extend_bottom, 0, 0,  borderType=cv2.BORDER_CONSTANT)
            scaled_height = org_height

        start_x = (scaled_width - org_width) / 2
        start_y = (scaled_height - org_height) / 2
        tmp = scaled_img[start_y: start_y + org_height, start_x: start_x + org_width]
        res.append(tmp)

    return res


class XYRange:
    def __init__(self, x_min, x_max, y_min, y_max, chance=1.0):
        self.chance = chance
        self.x_min = x_min
        self.x_max = x_max
        self.y_min = y_min
        self.y_max = y_max
        self.last_x = 0
        self.last_y = 0

    def get_last_xy_txt(self):
        res = "x_" + str(int(self.last_x * 100)).replace("-", "m") + "-" + "y_" + str(int(self.last_y * 100)).replace("-", "m")
        return res


def random_translate_img(img, xy_range, border_mode="constant"):
    if random.random() > xy_range.chance:
        return img
    import cv2
    if not isinstance(img, list):
        img = [img]

    org_height, org_width = img[0].shape[:2]
    translate_x = random.randint(xy_range.x_min, xy_range.x_max)
    translate_y = random.randint(xy_range.y_min, xy_range.y_max)
    trans_matrix = numpy.float32([[1, 0, translate_x], [0, 1, translate_y]])

    border_const = cv2.BORDER_CONSTANT
    if border_mode == "reflect":
        border_const = cv2.BORDER_REFLECT

    res = []
    for img_inst in img:
        img_inst = cv2.warpAffine(img_inst, trans_matrix, (org_width, org_height), borderMode=border_const)
        res.append(img_inst)
    if len(res) == 1:
        res = res[0]
    xy_range.last_x = translate_x
    xy_range.last_y = translate_y
    return res


def random_rotate_img(img, chance, min_angle, max_angle):
    import cv2
    if random.random() > chance:
        return img
    if not isinstance(img, list):
        img = [img]

    angle = random.randint(min_angle, max_angle)
    center = (img[0].shape[0] / 2, img[0].shape[1] / 2)
    rot_matrix = cv2.getRotationMatrix2D(center, angle, scale=1.0)

    res = []
    for img_inst in img:
        img_inst = cv2.warpAffine(img_inst, rot_matrix, dsize=img_inst.shape[:2], borderMode=cv2.BORDER_CONSTANT)
        res.append(img_inst)
    if len(res) == 0:
        res = res[0]
    return res


def random_flip_img(img, horizontal_chance=0, vertical_chance=0):
    import cv2
    flip_horizontal = False
    if random.random() < horizontal_chance:
        flip_horizontal = True

    flip_vertical = False
    if random.random() < vertical_chance:
        flip_vertical = True

    if not flip_horizontal and not flip_vertical:
        return img

    flip_val = 1
    if flip_vertical:
        flip_val = -1 if flip_horizontal else 0

    if not isinstance(img, list):
        res = cv2.flip(img, flip_val) # 0 = X axis, 1 = Y axis,  -1 = both
    else:
        res = []
        for img_item in img:
            img_flip = cv2.flip(img_item, flip_val)
            res.append(img_flip)
    return res


ELASTIC_INDICES = None  # needed to make it faster to fix elastic deformation per epoch.
def elastic_transform(image, alpha, sigma, random_state=None):
    global ELASTIC_INDICES
    shape = image.shape

    if ELASTIC_INDICES == None:
        if random_state is None:
            random_state = numpy.random.RandomState(1301)

        dx = gaussian_filter((random_state.rand(*shape) * 2 - 1), sigma, mode="constant", cval=0) * alpha
        dy = gaussian_filter((random_state.rand(*shape) * 2 - 1), sigma, mode="constant", cval=0) * alpha
        x, y = numpy.meshgrid(numpy.arange(shape[0]), numpy.arange(shape[1]))
        ELASTIC_INDICES = numpy.reshape(y + dy, (-1, 1)), numpy.reshape(x + dx, (-1, 1))
    return map_coordinates(image, ELASTIC_INDICES, order=1).reshape(shape)


def prepare_image_for_net(img):
    img = img.astype(numpy.float)
    img /= 255.
    if len(img.shape) == 3:
        img = img.reshape(img.shape[-3], img.shape[-2], img.shape[-1])
    else:
        img = img.reshape(1, img.shape[-2], img.shape[-1], 1)
    return img


def get_train_holdout_files(model_type, generated_path, csv_path,holdout, train_percentage=80, frame_count=8):
    print("Get train/holdout files.")
    file_paths = glob.glob(generated_path + "*_1_pos.png")
    file_paths.sort()
    train_res = []
    holdout_res = []
    for index, file_path in enumerate(file_paths):
        file_name = ntpath.basename(file_path)
        overlay_path = file_path.replace("_1.png", "_o.png")
        train_set = False
        if "1.3.6.1.4" in file_name or "spie" in file_name or "TIME" in file_name:
            train_set = True
        else:
            patient_id = file_name.split("_")[0]
            if helpers.get_patient_fold(csv_path,patient_id) % 3 != holdout:
                train_set = True

        if train_set:
            train_res.append((file_path, overlay_path))
        else:
            holdout_res.append((file_path, overlay_path))
    print("Train count: ", len(train_res), ", holdout count: ", len(holdout_res))
    return train_res, holdout_res


def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 100) / (K.sum(y_true_f) + K.sum(y_pred_f) + 100)


def dice_coef_np(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = numpy.sum(y_true_f * y_pred_f)
    return (2. * intersection + 100) / (numpy.sum(y_true_f) + numpy.sum(y_pred_f) + 100)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)


class DumpPredictions(Callback):

    def __init__(self, dump_filelist : List[Tuple[str, str]], model_type):
        super(DumpPredictions, self).__init__()
        self.dump_filelist = dump_filelist
        self.batch_count = 0
        self.model_type = model_type

    def on_epoch_end(self, epoch, logs=None):
        model = self.model  # type: Model
        generator = image_generator(self.dump_filelist, 1, train_set=False, model_type=self.model_type)
        for i in range(0, 10):
            x, y = next(generator)
            y_pred = model.predict(x, batch_size=1)

            x = x.swapaxes(0, 3)
            x = x[0]
            # print(x.shape, y.shape, y_pred.shape)
            x *= 255.
            x = x.reshape((x.shape[0], x.shape[0])).astype(numpy.uint8)
            y *= 255.
            y = y.reshape((y.shape[1], y.shape[2])).astype(numpy.uint8)
            y_pred *= 255.
            y_pred = y_pred.reshape((y_pred.shape[1], y_pred.shape[2])).astype(numpy.uint8)
            # cv2.imwrite("workdir/segmenter/img_{0:03d}_{1:02d}_i.png".format(epoch, i), x)
            # cv2.imwrite("workdit/segmenter/img_{0:03d}_{1:02d}_o.png".format(epoch, i), y)
            # cv2.imwrite("workdit/segmenter/img_{0:03d}_{1:02d}_p.png".format(epoch, i), y_pred)


def image_generator(batch_files, batch_size, train_set, model_type):
    global ELASTIC_INDICES
    while True:
        if train_set:
            random.shuffle(batch_files)

        img_list = []
        overlay_list = []
        ELASTIC_INDICES = None
        for batch_file_idx, batch_file in enumerate(batch_files):
            images = []
            img = cv2.imread(batch_file[0], cv2.IMREAD_GRAYSCALE)
            images.append(img)
            overlay = cv2.imread(batch_file[1], cv2.IMREAD_GRAYSCALE)

            if train_set:
                if random.randint(0, 100) > 50:
                    for img_index, img in enumerate(images):
                        images[img_index] = elastic_transform(img, 128, 15)
                    overlay = elastic_transform(overlay, 128, 15)

                if True:
                    augmented = images + [overlay]
                    augmented = random_rotate_img(augmented, 0.8, -20, 20)
                    augmented = random_flip_img(augmented, 0.5, 0.5)

                    # processed = helpers_augmentation.random_flip_img(processed, horizontal_chance=0.5, vertical_chance=0)
                    # processed = helpers_augmentation.random_scale_img(processed, xy_range=helpers_augmentation.XYRange(x_min=0.8, x_max=1.2, y_min=0.8, y_max=1.2, chance=1.0))
                    augmented = random_translate_img(augmented, XYRange(-30, 30, -30, 30, 0.8))
                    images = augmented[:-1]
                    overlay = augmented[-1]

            for index, img in enumerate(images):
                # img = img[crop_y: crop_y + settings.TRAIN_IMG_HEIGHT3D, crop_x: crop_x + settings.TRAIN_IMG_WIDTH3D]
                img = prepare_image_for_net(img)
                images[index] = img

            # helpers_augmentation.dump_augmented_image(img, mean_img=None, target_path="c:\\tmp\\" + batch_file[0])
            # overlay = overlay[crop_y: crop_y + settings.TRAIN_IMG_HEIGHT3D, crop_x: crop_x + settings.TRAIN_IMG_WIDTH3D]
            overlay = prepare_image_for_net(overlay)
            # overlay = overlay.reshape(1, overlay.shape[-3] * overlay.shape[-2])
            # overlay *= settings.OVERLAY_MULTIPLIER
            images3d = numpy.vstack(images)
            images3d = images3d.swapaxes(0, 3)

            img_list.append(images3d)
            overlay_list.append(overlay)
            if len(img_list) >= batch_size:
                x = numpy.vstack(img_list)
                y = numpy.vstack(overlay_list)
                # if len(img_list) >= batch_size:
                yield x, y
                img_list = []
                overlay_list = []


def get_unet(learn_rate, load_weights_path=None) -> Model:
    inputs = Input((SEGMENTER_IMG_SIZE, SEGMENTER_IMG_SIZE, CHANNEL_COUNT))
    filter_size = 32
    growth_step = 32
    x = BatchNormalization()(inputs)
    conv1 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(x)
    conv1 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    pool1 = BatchNormalization()(pool1)
    filter_size += growth_step
    conv2 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(pool1)
    conv2 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    pool2 = BatchNormalization()(pool2)

    filter_size += growth_step
    conv3 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(pool2)
    conv3 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = BatchNormalization()(pool3)

    filter_size += growth_step
    conv4 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(pool3)
    conv4 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    pool4 = BatchNormalization()(pool4)

    conv5 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(pool4)
    conv5 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same', name="conv5b")(conv5)
    pool5 = MaxPooling2D(pool_size=(2, 2), name="pool5")(conv5)
    pool5 = BatchNormalization()(pool5)

    conv6 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(pool5)
    conv6 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same', name="conv6b")(conv6)

    up6 = UpSampling2D(size=(2, 2), name="up6")(conv6)
    up6 = merge([up6, conv5], mode='concat', concat_axis=3)
    up6 = BatchNormalization()(up6)

    # up6 = SpatialDropout2D(0.1)(up6)
    filter_size -= growth_step
    conv66 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(up6)
    conv66 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(conv66)

    up7 = merge([UpSampling2D(size=(2, 2))(conv66), conv4], mode='concat', concat_axis=3)
    up7 = BatchNormalization()(up7)
    # up7 = SpatialDropout2D(0.1)(up7)

    filter_size -= growth_step
    conv7 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(up7)
    conv7 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(conv7)

    up8 = merge([UpSampling2D(size=(2, 2))(conv7), conv3], mode='concat', concat_axis=3)
    up8 = BatchNormalization()(up8)
    filter_size -= growth_step
    conv8 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(up8)
    conv8 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(conv8)


    up9 = merge([UpSampling2D(size=(2, 2))(conv8), conv2], mode='concat', concat_axis=3)
    up9 = BatchNormalization()(up9)
    conv9 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(up9)
    conv9 = Convolution2D(filter_size, 3, 3, activation='relu', border_mode='same')(conv9)
    # conv9 = BatchNormalization()(conv9)

    up10 = UpSampling2D(size=(2, 2))(conv9)
    conv10 = Convolution2D(1, 1, 1, activation='sigmoid')(up10)

    model = Model(input=inputs, output=conv10)
    # model.load_weights(load_weights_path)
    # model.compile(optimizer=Adam(lr=1.0e-5), loss=dice_coef_loss, metrics=[dice_coef])
    model.compile(optimizer=SGD(lr=learn_rate, momentum=0.9, nesterov=True), loss=dice_coef_loss, metrics=[dice_coef])

    model.summary()
    return model


def train_model(model_paths, model_paths_temp, holdout, model_type, continue_from=None):
    batch_size = 4
    train_percentage = 80 if model_type == "masses" else 90
    train_files, holdout_files = get_train_holdout_files( model_type,generated_path, csv_path, holdout, train_percentage, frame_count=CHANNEL_COUNT)
    # train_files = train_files[:100]
    # holdout_files = train_files[:10]

    tmp_gen = image_generator(train_files[:2], 2, True, model_type)
    for i in range(10):
        x = next(tmp_gen)
        img = x[0][0].reshape((SEGMENTER_IMG_SIZE, SEGMENTER_IMG_SIZE))
        img *= 255
        # cv2.imwrite("c:/tmp/img_" + str(i).rjust(3, '0') + "i.png", img)
        img = x[1][0].reshape((SEGMENTER_IMG_SIZE, SEGMENTER_IMG_SIZE))
        img *= 255
        # cv2.imwrite("c:/tmp/img_" + str(i).rjust(3, '0') + "o.png", img)
        # print(x.shape)

    train_gen = image_generator(train_files, batch_size, True, model_type)
    holdout_gen = image_generator(holdout_files, batch_size, False, model_type)

    if continue_from is None:
        model = get_unet(0.001)
    else:
        model = get_unet(0.0001)
        model.load_weights(continue_from)

    checkpoint1 = ModelCheckpoint(model_paths_temp + model_type +"_model_h" + str(holdout) + "_{epoch:02d}-{val_loss:.2f}.hd5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
    checkpoint2 = ModelCheckpoint(model_paths_temp + model_type +"_model_h" + str(holdout) + "_best.hd5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
    files = []
    idx = 0
    while (idx < (len(holdout_files))):
        files.append(holdout_files[idx])
        idx += 5
    dumper = DumpPredictions(holdout_files[::10], model_type)
    epoch_div = 1
    epoch_count = 200 if model_type == "masses" else 50 
    #epoch_count = 200 if model_type == "masses" else 50 
    model.fit_generator(train_gen, len(train_files) / epoch_div, epoch_count, validation_data=holdout_gen, nb_val_samples=len(holdout_files) / epoch_div, callbacks=[checkpoint1, checkpoint2, dumper])
    shutil.copy(model_paths_temp + model_type +"_model_h" + str(holdout) + "_best.hd5", model_paths + model_type +"_model_h" + str(holdout) + "_best.hd5")

def predict_patients(csv_path, patients_dir,  model_path, holdout, patient_predictions, model_type):
    model = get_unet(0.001)
    model.load_weights(model_path)
    for item_name in os.listdir(patients_dir):
        if not os.path.isdir(patients_dir + item_name):
            continue
        patient_id = item_name

        if holdout >= 0:
            patient_fold = helpers.get_patient_fold(csv_path,patient_id, submission_set_neg=True)
            if patient_fold < 0:
                if holdout != 0:
                    continue
            else:
                patient_fold %= 3
                if patient_fold != holdout:
                    continue

        # if "100953483028192176989979435275" not in patient_id:
        #     continue
        print(patient_id)
        patient_dir = patients_dir + patient_id + "/"
        mass = 0
        img_type = "_i" if model_type == "masses" else "_c"
        slices = glob.glob(patient_dir + "*" + img_type + ".png")
        if model_type == "emphysema":
            slices = slices[int(len(slices) / 2):]
        for img_path in slices:
            src_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            src_img = cv2.resize(src_img, dsize=(SEGMENTER_IMG_SIZE, SEGMENTER_IMG_SIZE))
            src_img = prepare_image_for_net(src_img)
            p = model.predict(src_img, batch_size=1)
            p[p < 0.5] = 0
            mass += p.sum()
            p = p[0, :, :, 0] * 255
            # cv2.imwrite(img_path.replace("_i.png", "_mass.png"), p)
            src_img = src_img.reshape((SEGMENTER_IMG_SIZE, SEGMENTER_IMG_SIZE))
            src_img *= 255
            # src_img = cv2.cvtColor(src_img.astype(numpy.uint8), cv2.COLOR_GRAY2BGR)
            # p = cv2.cvtColor(p.astype(numpy.uint8), cv2.COLOR_GRAY2BGRA)
            src_img = cv2.addWeighted(p.astype(numpy.uint8), 0.2, src_img.astype(numpy.uint8), 1 - 0.2, 0)
            cv2.imwrite(img_path.replace(img_type + ".png", "_" + model_type + "o.png"), src_img)

        if mass > 1:
            print(model_type + ": ", mass)
        patient_predictions.append((patient_id, mass))
        df = pandas.DataFrame(patient_predictions, columns=["patient_id", "prediction"])
        df.to_csv(csv_path + model_type + "_predictions.csv", index=False)

# %%
csv_path = PATH['annotations_train']
generated_path = PATH['generated_train']
model_paths = PATH['model_paths']
model_paths_temp = PATH['model_paths_temp']
pred_path = PATH['pic_test']
#pred_path = PATH['label_test']

# %%
model0 = model_paths+'masses_model_h0_best.hd5'

# %% [markdown]
# ## 训练

# %%
continue_from = None
if True:
    for model_type_name in ["masses"]:
        train_model(model_paths, model_paths_temp, holdout=0, model_type=model_type_name, continue_from=model_paths+'masses_model_h0_best.hd5')
        train_model(model_paths, model_paths_temp, holdout=1, model_type=model_type_name, continue_from=model_paths+'masses_model_h1_best.hd5')
        train_model(model_paths, model_paths_temp, holdout=2, model_type=model_type_name, continue_from=model_paths+'masses_model_h2_best.hd5')
# Out:
# Get train/holdout files.
# Train count:  650 , holdout count:  315
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_8 (InputLayer)             (None, 512, 512, 1)   0
# ____________________________________________________________________________________________________
# batch_normalization_71 (BatchNor (None, 512, 512, 1)   4           input_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_134 (Conv2D)              (None, 512, 512, 32)  320         batch_normalization_71[0][0]
# ____________________________________________________________________________________________________
# conv2d_135 (Conv2D)              (None, 512, 512, 32)  9248        conv2d_134[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D)  (None, 256, 256, 32)  0           conv2d_135[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_72 (BatchNor (None, 256, 256, 32)  128         max_pooling2d_29[0][0]
# ____________________________________________________________________________________________________
# conv2d_136 (Conv2D)              (None, 256, 256, 64)  18496       batch_normalization_72[0][0]
# ____________________________________________________________________________________________________
# conv2d_137 (Conv2D)              (None, 256, 256, 64)  36928       conv2d_136[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D)  (None, 128, 128, 64)  0           conv2d_137[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_73 (BatchNor (None, 128, 128, 64)  256         max_pooling2d_30[0][0]
# ____________________________________________________________________________________________________
# conv2d_138 (Conv2D)              (None, 128, 128, 96)  55392       batch_normalization_73[0][0]
# ____________________________________________________________________________________________________
# conv2d_139 (Conv2D)              (None, 128, 128, 96)  83040       conv2d_138[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D)  (None, 64, 64, 96)    0           conv2d_139[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_74 (BatchNor (None, 64, 64, 96)    384         max_pooling2d_31[0][0]
# ____________________________________________________________________________________________________
# conv2d_140 (Conv2D)              (None, 64, 64, 128)   110720      batch_normalization_74[0][0]
# ____________________________________________________________________________________________________
# conv2d_141 (Conv2D)              (None, 64, 64, 128)   147584      conv2d_140[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D)  (None, 32, 32, 128)   0           conv2d_141[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_75 (BatchNor (None, 32, 32, 128)   512         max_pooling2d_32[0][0]
# ____________________________________________________________________________________________________
# conv2d_142 (Conv2D)              (None, 32, 32, 128)   147584      batch_normalization_75[0][0]
# ____________________________________________________________________________________________________
# conv5b (Conv2D)                  (None, 32, 32, 128)   147584      conv2d_142[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)             (None, 16, 16, 128)   0           conv5b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_76 (BatchNor (None, 16, 16, 128)   512         pool5[0][0]
# ____________________________________________________________________________________________________
# conv2d_143 (Conv2D)              (None, 16, 16, 128)   147584      batch_normalization_76[0][0]
# ____________________________________________________________________________________________________
# conv6b (Conv2D)                  (None, 16, 16, 128)   147584      conv2d_143[0][0]
# ____________________________________________________________________________________________________
# up6 (UpSampling2D)               (None, 32, 32, 128)   0           conv6b[0][0]
# ____________________________________________________________________________________________________
# merge_29 (Merge)                 (None, 32, 32, 256)   0           up6[0][0]
#                                                                    conv5b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_77 (BatchNor (None, 32, 32, 256)   1024        merge_29[0][0]
# ____________________________________________________________________________________________________
# conv2d_144 (Conv2D)              (None, 32, 32, 96)    221280      batch_normalization_77[0][0]
# ____________________________________________________________________________________________________
# conv2d_145 (Conv2D)              (None, 32, 32, 96)    83040       conv2d_144[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_29 (UpSampling2D)  (None, 64, 64, 96)    0           conv2d_145[0][0]
# ____________________________________________________________________________________________________
# merge_30 (Merge)                 (None, 64, 64, 224)   0           up_sampling2d_29[0][0]
#                                                                    conv2d_141[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_78 (BatchNor (None, 64, 64, 224)   896         merge_30[0][0]
# ____________________________________________________________________________________________________
# conv2d_146 (Conv2D)              (None, 64, 64, 64)    129088      batch_normalization_78[0][0]
# ____________________________________________________________________________________________________
# conv2d_147 (Conv2D)              (None, 64, 64, 64)    36928       conv2d_146[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_30 (UpSampling2D)  (None, 128, 128, 64)  0           conv2d_147[0][0]
# ____________________________________________________________________________________________________
# merge_31 (Merge)                 (None, 128, 128, 160) 0           up_sampling2d_30[0][0]
#                                                                    conv2d_139[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_79 (BatchNor (None, 128, 128, 160) 640         merge_31[0][0]
# ____________________________________________________________________________________________________
# conv2d_148 (Conv2D)              (None, 128, 128, 32)  46112       batch_normalization_79[0][0]
# ____________________________________________________________________________________________________
# conv2d_149 (Conv2D)              (None, 128, 128, 32)  9248        conv2d_148[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_31 (UpSampling2D)  (None, 256, 256, 32)  0           conv2d_149[0][0]
# ____________________________________________________________________________________________________
# merge_32 (Merge)                 (None, 256, 256, 96)  0           up_sampling2d_31[0][0]
#                                                                    conv2d_137[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_80 (BatchNor (None, 256, 256, 96)  384         merge_32[0][0]
# ____________________________________________________________________________________________________
# conv2d_150 (Conv2D)              (None, 256, 256, 32)  27680       batch_normalization_80[0][0]
# ____________________________________________________________________________________________________
# conv2d_151 (Conv2D)              (None, 256, 256, 32)  9248        conv2d_150[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_32 (UpSampling2D)  (None, 512, 512, 32)  0           conv2d_151[0][0]
# ____________________________________________________________________________________________________
# conv2d_152 (Conv2D)              (None, 512, 512, 1)   33          up_sampling2d_32[0][0]
# ====================================================================================================
# Total params: 1,619,461
# Trainable params: 1,617,091
# Non-trainable params: 2,370
# ____________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-e10ebee6586b> in <module>()
#       2 if True:
#       3     for model_type_name in ["masses"]:
# ----> 4         train_model(model_paths, model_paths_temp, holdout=0, model_type=model_type_name, continue_from=model_paths+'masses_model_h0_best.hd5')
#       5         train_model(model_paths, model_paths_temp, holdout=1, model_type=model_type_name, continue_from=model_paths+'masses_model_h1_best.hd5')
#       6         train_model(model_paths, model_paths_temp, holdout=2, model_type=model_type_name, continue_from=model_paths+'masses_model_h2_best.hd5')
#
# <ipython-input-11-1ded3013354d> in train_model(model_paths, model_paths_temp, holdout, model_type, continue_from)
#     400     epoch_count = 200 if model_type == "masses" else 50
#     401     #epoch_count = 200 if model_type == "masses" else 50
# --> 402     model.fit_generator(train_gen, len(train_files) / epoch_div, epoch_count, validation_data=holdout_gen, nb_val_samples=len(holdout_files) / epoch_div, callbacks=[checkpoint1, checkpoint2, dumper])
#     403     shutil.copy(model_paths_temp + model_type +"_model_h" + str(holdout) + "_best.hd5", model_paths + model_type +"_model_h" + str(holdout) + "_best.hd5")
#     404
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      86                 warnings.warn('Update your `' + object_name +
#      87                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 88             return func(*args, **kwargs)
#      89         wrapper._legacy_support_signature = inspect.getargspec(func)
#      90         return wrapper
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1785
#    1786         do_validation = bool(validation_data)
# -> 1787         self._make_train_function()
#    1788         if do_validation:
#    1789             self._make_test_function()
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/keras/engine/training.py in _make_train_function(self)
#    1011                 self._collected_trainable_weights,
#    1012                 self.constraints,
# -> 1013                 self.total_loss)
#    1014             updates = self.updates + training_updates
#    1015             # Gets loss and metrics. Updates weights at each call.
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/keras/optimizers.py in get_updates(self, params, constraints, loss)
#     143
#     144             if self.nesterov:
# --> 145                 new_p = p + self.momentum * v - lr * g
#     146             else:
#     147                 new_p = p + v
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in _run_op(a, *args)
#     665     def _run_op(a, *args):
#     666       # pylint: disable=protected-access
# --> 667       return getattr(ops.Tensor, operator)(a._AsTensor(), *args)
#     668     # Propagate __doc__ to wrapper
#     669     try:
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#     819       if not isinstance(y, sparse_tensor.SparseTensor):
#     820         y = ops.convert_to_tensor(y, dtype=x.dtype.base_dtype, name="y")
# --> 821       return func(x, y, name=name)
#     822
#     823   def binary_op_wrapper_sparse(sp_x, y):
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in add(x, y, name)
#      71     A `Tensor`. Has the same type as `x`.
#      72   """
# ---> 73   result = _op_def_lib.apply_op("Add", x=x, y=y, name=name)
#      74   return result
#      75
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     766         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     767                          input_types=input_types, attrs=attr_protos,
# --> 768                          op_def=op_def)
#     769         if output_structure:
#     770           outputs = op.outputs
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2334     ret = Operation(node_def, self, inputs=inputs, output_types=dtypes,
#    2335                     control_inputs=control_inputs, input_types=input_types,
# -> 2336                     original_op=self._default_original_op, op_def=op_def)
#    2337     if compute_shapes:
#    2338       set_shapes_for_outputs(ret)
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1178     if not isinstance(node_def, node_def_pb2.NodeDef):
#    1179       raise TypeError("node_def needs to be a NodeDef: %s" % node_def)
# -> 1180     if node_def.ByteSize() >= (1 << 31) or node_def.ByteSize() < 0:
#    1181       raise ValueError(
#    1182           "Cannot create a tensor proto whose content is larger than 2GB.")
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/google/protobuf/internal/python_message.py in ByteSize(self)
#    1011     size = 0
#    1012     for field_descriptor, field_value in self.ListFields():
# -> 1013       size += field_descriptor._sizer(field_value)
#    1014
#    1015     for tag_bytes, value_bytes in self._unknown_fields:
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/google/protobuf/internal/encoder.py in FieldSize(map_value)
#     358       # duplication. For message map, value.ByteSize() should be called to
#     359       # update the status.
# --> 360       entry_msg = message_type._concrete_class(key=key, value=value)
#     361       total += message_sizer(entry_msg)
#     362       if is_message_map:
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/google/protobuf/internal/python_message.py in init(self, **kwargs)
#     510         self._fields[field] = copy
#     511       elif field.cpp_type == _FieldDescriptor.CPPTYPE_MESSAGE:
# --> 512         copy = field._default_constructor(self)
#     513         new_val = field_value
#     514         if isinstance(field_value, dict):
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/google/protobuf/internal/python_message.py in MakeSubMessageDefault(message)
#     422     message_type = field.message_type
#     423     def MakeSubMessageDefault(message):
# --> 424       result = message_type._concrete_class()
#     425       result._SetListener(
#     426           _OneofListener(message, field)
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/google/protobuf/internal/python_message.py in init(self, **kwargs)
#     479     self._is_present_in_parent = False
#     480     self._listener = message_listener_mod.NullMessageListener()
# --> 481     self._listener_for_children = _Listener(self)
#     482     for field_name, field_value in list(kwargs.items()):
#     483       field = _GetFieldByName(message_descriptor, field_name)
#
# /Users/mahui/anaconda/envs/python36/lib/python3.6/site-packages/google/protobuf/internal/python_message.py in __init__(self, parent_message)
#    1376     # creating cyclic garbage when the client finishes with the 'parent' object
#    1377     # in the tree.
# -> 1378     if isinstance(parent_message, weakref.ProxyType):
#    1379       self._parent_message_weakref = parent_message
#    1380     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 预测

# %%
if True:
    for model_type_name in ["masses"]:
        patient_predictions_global = []
        for holdout_no in [0, 1, 2]:
            predict_patients(csv_path, patients_dir=pred_path, model_path=model_paths + model_type_name + "_model_h" + str(holdout_no) + "_best.hd5", holdout=holdout_no, patient_predictions=patient_predictions_global, model_type=model_type_name)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_12 (InputLayer)            (None, 512, 512, 1)   0
# ____________________________________________________________________________________________________
# batch_normalization_111 (BatchNo (None, 512, 512, 1)   4           input_12[0][0]
# ____________________________________________________________________________________________________
# conv2d_210 (Conv2D)              (None, 512, 512, 32)  320         batch_normalization_111[0][0]
# ____________________________________________________________________________________________________
# conv2d_211 (Conv2D)              (None, 512, 512, 32)  9248        conv2d_210[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_45 (MaxPooling2D)  (None, 256, 256, 32)  0           conv2d_211[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_112 (BatchNo (None, 256, 256, 32)  128         max_pooling2d_45[0][0]
# ____________________________________________________________________________________________________
# conv2d_212 (Conv2D)              (None, 256, 256, 64)  18496       batch_normalization_112[0][0]
# ____________________________________________________________________________________________________
# conv2d_213 (Conv2D)              (None, 256, 256, 64)  36928       conv2d_212[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_46 (MaxPooling2D)  (None, 128, 128, 64)  0           conv2d_213[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_113 (BatchNo (None, 128, 128, 64)  256         max_pooling2d_46[0][0]
# ____________________________________________________________________________________________________
# conv2d_214 (Conv2D)              (None, 128, 128, 96)  55392       batch_normalization_113[0][0]
# ____________________________________________________________________________________________________
# conv2d_215 (Conv2D)              (None, 128, 128, 96)  83040       conv2d_214[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_47 (MaxPooling2D)  (None, 64, 64, 96)    0           conv2d_215[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_114 (BatchNo (None, 64, 64, 96)    384         max_pooling2d_47[0][0]
# ____________________________________________________________________________________________________
# conv2d_216 (Conv2D)              (None, 64, 64, 128)   110720      batch_normalization_114[0][0]
# ____________________________________________________________________________________________________
# conv2d_217 (Conv2D)              (None, 64, 64, 128)   147584      conv2d_216[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_48 (MaxPooling2D)  (None, 32, 32, 128)   0           conv2d_217[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_115 (BatchNo (None, 32, 32, 128)   512         max_pooling2d_48[0][0]
# ____________________________________________________________________________________________________
# conv2d_218 (Conv2D)              (None, 32, 32, 128)   147584      batch_normalization_115[0][0]
# ____________________________________________________________________________________________________
# conv5b (Conv2D)                  (None, 32, 32, 128)   147584      conv2d_218[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)             (None, 16, 16, 128)   0           conv5b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_116 (BatchNo (None, 16, 16, 128)   512         pool5[0][0]
# ____________________________________________________________________________________________________
# conv2d_219 (Conv2D)              (None, 16, 16, 128)   147584      batch_normalization_116[0][0]
# ____________________________________________________________________________________________________
# conv6b (Conv2D)                  (None, 16, 16, 128)   147584      conv2d_219[0][0]
# ____________________________________________________________________________________________________
# up6 (UpSampling2D)               (None, 32, 32, 128)   0           conv6b[0][0]
# ____________________________________________________________________________________________________
# merge_45 (Merge)                 (None, 32, 32, 256)   0           up6[0][0]
#                                                                    conv5b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_117 (BatchNo (None, 32, 32, 256)   1024        merge_45[0][0]
# ____________________________________________________________________________________________________
# conv2d_220 (Conv2D)              (None, 32, 32, 96)    221280      batch_normalization_117[0][0]
# ____________________________________________________________________________________________________
# conv2d_221 (Conv2D)              (None, 32, 32, 96)    83040       conv2d_220[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_45 (UpSampling2D)  (None, 64, 64, 96)    0           conv2d_221[0][0]
# ____________________________________________________________________________________________________
# merge_46 (Merge)                 (None, 64, 64, 224)   0           up_sampling2d_45[0][0]
#                                                                    conv2d_217[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_118 (BatchNo (None, 64, 64, 224)   896         merge_46[0][0]
# ____________________________________________________________________________________________________
# conv2d_222 (Conv2D)              (None, 64, 64, 64)    129088      batch_normalization_118[0][0]
# ____________________________________________________________________________________________________
# conv2d_223 (Conv2D)              (None, 64, 64, 64)    36928       conv2d_222[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_46 (UpSampling2D)  (None, 128, 128, 64)  0           conv2d_223[0][0]
# ____________________________________________________________________________________________________
# merge_47 (Merge)                 (None, 128, 128, 160) 0           up_sampling2d_46[0][0]
#                                                                    conv2d_215[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_119 (BatchNo (None, 128, 128, 160) 640         merge_47[0][0]
# ____________________________________________________________________________________________________
# conv2d_224 (Conv2D)              (None, 128, 128, 32)  46112       batch_normalization_119[0][0]
# ____________________________________________________________________________________________________
# conv2d_225 (Conv2D)              (None, 128, 128, 32)  9248        conv2d_224[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_47 (UpSampling2D)  (None, 256, 256, 32)  0           conv2d_225[0][0]
# ____________________________________________________________________________________________________
# merge_48 (Merge)                 (None, 256, 256, 96)  0           up_sampling2d_47[0][0]
#                                                                    conv2d_213[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_120 (BatchNo (None, 256, 256, 96)  384         merge_48[0][0]
# ____________________________________________________________________________________________________
# conv2d_226 (Conv2D)              (None, 256, 256, 32)  27680       batch_normalization_120[0][0]
# ____________________________________________________________________________________________________
# conv2d_227 (Conv2D)              (None, 256, 256, 32)  9248        conv2d_226[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_48 (UpSampling2D)  (None, 512, 512, 32)  0           conv2d_227[0][0]
# ____________________________________________________________________________________________________
# conv2d_228 (Conv2D)              (None, 512, 512, 1)   33          up_sampling2d_48[0][0]
# ====================================================================================================
# Total params: 1,619,461
# Trainable params: 1,617,091
# Non-trainable params: 2,370
# ____________________________________________________________________________________________________
# _labels
# LKDS-00012
# masses:  29673007.1953
# LKDS-00022
# masses:  27160277.3594
# LKDS-00027
# masses:  27144975.5391
# LKDS-00031
# masses:  28653298.5469
# LKDS-00033
# masses:  53418162.9141
# LKDS-00037
# masses:  25981863.6406
# LKDS-00046
# masses:  36411956.5859
# LKDS-00049
# masses:  38623157.5859
# LKDS-00056
# masses:  24994331.6328
# LKDS-00057
# masses:  28489042.1367
# LKDS-00063
# masses:  31831430.5156
# LKDS-00082
# masses:  30091881.8984
# LKDS-00087
# masses:  20794603.1133
# LKDS-00094
# masses:  29431000.5
# LKDS-00097
# masses:  35198641.8203
# LKDS-00098
# masses:  22958751.7891
# LKDS-00103
# masses:  35629021.9219
# LKDS-00106
# masses:  29999677.5234
# LKDS-00124
# masses:  36652285.2031
# LKDS-00131
# masses:  30879251.4609
# LKDS-00132
# masses:  25038975.7383
# LKDS-00139
# masses:  25944901.8594
# LKDS-00143
# masses:  30128976.7578
# LKDS-00155
# masses:  30858808.332
# LKDS-00158
# masses:  32185622.2266
# LKDS-00159
# masses:  30707398.7266
# LKDS-00164
# masses:  36313003.6562
# LKDS-00167
# masses:  27456236.9297
# LKDS-00174
# masses:  32796586.1875
# LKDS-00179
# masses:  29327174.3984
# LKDS-00182
# masses:  26669252.0898
# LKDS-00186
# LKDS-00199
# masses:  28578401.168
# LKDS-00205
# masses:  20935623.4805
# LKDS-00206
# masses:  37305960.7969
# LKDS-00209
# masses:  30820194.5938
# LKDS-00211
# masses:  27171349.2422
# LKDS-00215
# masses:  38602511.0547
# LKDS-00221
# masses:  42971774.4297
# LKDS-00222
# masses:  32979306.1406
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_13 (InputLayer)            (None, 512, 512, 1)   0
# ____________________________________________________________________________________________________
# batch_normalization_121 (BatchNo (None, 512, 512, 1)   4           input_13[0][0]
# ____________________________________________________________________________________________________
# conv2d_229 (Conv2D)              (None, 512, 512, 32)  320         batch_normalization_121[0][0]
# ____________________________________________________________________________________________________
# conv2d_230 (Conv2D)              (None, 512, 512, 32)  9248        conv2d_229[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_49 (MaxPooling2D)  (None, 256, 256, 32)  0           conv2d_230[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_122 (BatchNo (None, 256, 256, 32)  128         max_pooling2d_49[0][0]
# ____________________________________________________________________________________________________
# conv2d_231 (Conv2D)              (None, 256, 256, 64)  18496       batch_normalization_122[0][0]
# ____________________________________________________________________________________________________
# conv2d_232 (Conv2D)              (None, 256, 256, 64)  36928       conv2d_231[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_50 (MaxPooling2D)  (None, 128, 128, 64)  0           conv2d_232[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_123 (BatchNo (None, 128, 128, 64)  256         max_pooling2d_50[0][0]
# ____________________________________________________________________________________________________
# conv2d_233 (Conv2D)              (None, 128, 128, 96)  55392       batch_normalization_123[0][0]
# ____________________________________________________________________________________________________
# conv2d_234 (Conv2D)              (None, 128, 128, 96)  83040       conv2d_233[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_51 (MaxPooling2D)  (None, 64, 64, 96)    0           conv2d_234[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_124 (BatchNo (None, 64, 64, 96)    384         max_pooling2d_51[0][0]
# ____________________________________________________________________________________________________
# conv2d_235 (Conv2D)              (None, 64, 64, 128)   110720      batch_normalization_124[0][0]
# ____________________________________________________________________________________________________
# conv2d_236 (Conv2D)              (None, 64, 64, 128)   147584      conv2d_235[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_52 (MaxPooling2D)  (None, 32, 32, 128)   0           conv2d_236[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_125 (BatchNo (None, 32, 32, 128)   512         max_pooling2d_52[0][0]
# ____________________________________________________________________________________________________
# conv2d_237 (Conv2D)              (None, 32, 32, 128)   147584      batch_normalization_125[0][0]
# ____________________________________________________________________________________________________
# conv5b (Conv2D)                  (None, 32, 32, 128)   147584      conv2d_237[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)             (None, 16, 16, 128)   0           conv5b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_126 (BatchNo (None, 16, 16, 128)   512         pool5[0][0]
# ____________________________________________________________________________________________________
# conv2d_238 (Conv2D)              (None, 16, 16, 128)   147584      batch_normalization_126[0][0]
# ____________________________________________________________________________________________________
# conv6b (Conv2D)                  (None, 16, 16, 128)   147584      conv2d_238[0][0]
# ____________________________________________________________________________________________________
# up6 (UpSampling2D)               (None, 32, 32, 128)   0           conv6b[0][0]
# ____________________________________________________________________________________________________
# merge_49 (Merge)                 (None, 32, 32, 256)   0           up6[0][0]
#                                                                    conv5b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_127 (BatchNo (None, 32, 32, 256)   1024        merge_49[0][0]
# ____________________________________________________________________________________________________
# conv2d_239 (Conv2D)              (None, 32, 32, 96)    221280      batch_normalization_127[0][0]
# ____________________________________________________________________________________________________
# conv2d_240 (Conv2D)              (None, 32, 32, 96)    83040       conv2d_239[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_49 (UpSampling2D)  (None, 64, 64, 96)    0           conv2d_240[0][0]
# ____________________________________________________________________________________________________
# merge_50 (Merge)                 (None, 64, 64, 224)   0           up_sampling2d_49[0][0]
#                                                                    conv2d_236[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_128 (BatchNo (None, 64, 64, 224)   896         merge_50[0][0]
# ____________________________________________________________________________________________________
# conv2d_241 (Conv2D)              (None, 64, 64, 64)    129088      batch_normalization_128[0][0]
# ____________________________________________________________________________________________________
# conv2d_242 (Conv2D)              (None, 64, 64, 64)    36928       conv2d_241[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_50 (UpSampling2D)  (None, 128, 128, 64)  0           conv2d_242[0][0]
# ____________________________________________________________________________________________________
# merge_51 (Merge)                 (None, 128, 128, 160) 0           up_sampling2d_50[0][0]
#                                                                    conv2d_234[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_129 (BatchNo (None, 128, 128, 160) 640         merge_51[0][0]
# ____________________________________________________________________________________________________
# conv2d_243 (Conv2D)              (None, 128, 128, 32)  46112       batch_normalization_129[0][0]
# ____________________________________________________________________________________________________
# conv2d_244 (Conv2D)              (None, 128, 128, 32)  9248        conv2d_243[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_51 (UpSampling2D)  (None, 256, 256, 32)  0           conv2d_244[0][0]
# ____________________________________________________________________________________________________
# merge_52 (Merge)                 (None, 256, 256, 96)  0           up_sampling2d_51[0][0]
#                                                                    conv2d_232[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_130 (BatchNo (None, 256, 256, 96)  384         merge_52[0][0]
# ____________________________________________________________________________________________________
# conv2d_245 (Conv2D)              (None, 256, 256, 32)  27680       batch_normalization_130[0][0]
# ____________________________________________________________________________________________________
# conv2d_246 (Conv2D)              (None, 256, 256, 32)  9248        conv2d_245[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_52 (UpSampling2D)  (None, 512, 512, 32)  0           conv2d_246[0][0]
# ____________________________________________________________________________________________________
# conv2d_247 (Conv2D)              (None, 512, 512, 1)   33          up_sampling2d_52[0][0]
# ====================================================================================================
# Total params: 1,619,461
# Trainable params: 1,617,091
# Non-trainable params: 2,370
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_14 (InputLayer)            (None, 512, 512, 1)   0
# ____________________________________________________________________________________________________
# batch_normalization_131 (BatchNo (None, 512, 512, 1)   4           input_14[0][0]
# ____________________________________________________________________________________________________
# conv2d_248 (Conv2D)              (None, 512, 512, 32)  320         batch_normalization_131[0][0]
# ____________________________________________________________________________________________________
# conv2d_249 (Conv2D)              (None, 512, 512, 32)  9248        conv2d_248[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_53 (MaxPooling2D)  (None, 256, 256, 32)  0           conv2d_249[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_132 (BatchNo (None, 256, 256, 32)  128         max_pooling2d_53[0][0]
# ____________________________________________________________________________________________________
# conv2d_250 (Conv2D)              (None, 256, 256, 64)  18496       batch_normalization_132[0][0]
# ____________________________________________________________________________________________________
# conv2d_251 (Conv2D)              (None, 256, 256, 64)  36928       conv2d_250[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_54 (MaxPooling2D)  (None, 128, 128, 64)  0           conv2d_251[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_133 (BatchNo (None, 128, 128, 64)  256         max_pooling2d_54[0][0]
# ____________________________________________________________________________________________________
# conv2d_252 (Conv2D)              (None, 128, 128, 96)  55392       batch_normalization_133[0][0]
# ____________________________________________________________________________________________________
# conv2d_253 (Conv2D)              (None, 128, 128, 96)  83040       conv2d_252[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_55 (MaxPooling2D)  (None, 64, 64, 96)    0           conv2d_253[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_134 (BatchNo (None, 64, 64, 96)    384         max_pooling2d_55[0][0]
# ____________________________________________________________________________________________________
# conv2d_254 (Conv2D)              (None, 64, 64, 128)   110720      batch_normalization_134[0][0]
# ____________________________________________________________________________________________________
# conv2d_255 (Conv2D)              (None, 64, 64, 128)   147584      conv2d_254[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_56 (MaxPooling2D)  (None, 32, 32, 128)   0           conv2d_255[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_135 (BatchNo (None, 32, 32, 128)   512         max_pooling2d_56[0][0]
# ____________________________________________________________________________________________________
# conv2d_256 (Conv2D)              (None, 32, 32, 128)   147584      batch_normalization_135[0][0]
# ____________________________________________________________________________________________________
# conv5b (Conv2D)                  (None, 32, 32, 128)   147584      conv2d_256[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)             (None, 16, 16, 128)   0           conv5b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_136 (BatchNo (None, 16, 16, 128)   512         pool5[0][0]
# ____________________________________________________________________________________________________
# conv2d_257 (Conv2D)              (None, 16, 16, 128)   147584      batch_normalization_136[0][0]
# ____________________________________________________________________________________________________
# conv6b (Conv2D)                  (None, 16, 16, 128)   147584      conv2d_257[0][0]
# ____________________________________________________________________________________________________
# up6 (UpSampling2D)               (None, 32, 32, 128)   0           conv6b[0][0]
# ____________________________________________________________________________________________________
# merge_53 (Merge)                 (None, 32, 32, 256)   0           up6[0][0]
#                                                                    conv5b[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_137 (BatchNo (None, 32, 32, 256)   1024        merge_53[0][0]
# ____________________________________________________________________________________________________
# conv2d_258 (Conv2D)              (None, 32, 32, 96)    221280      batch_normalization_137[0][0]
# ____________________________________________________________________________________________________
# conv2d_259 (Conv2D)              (None, 32, 32, 96)    83040       conv2d_258[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_53 (UpSampling2D)  (None, 64, 64, 96)    0           conv2d_259[0][0]
# ____________________________________________________________________________________________________
# merge_54 (Merge)                 (None, 64, 64, 224)   0           up_sampling2d_53[0][0]
#                                                                    conv2d_255[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_138 (BatchNo (None, 64, 64, 224)   896         merge_54[0][0]
# ____________________________________________________________________________________________________
# conv2d_260 (Conv2D)              (None, 64, 64, 64)    129088      batch_normalization_138[0][0]
# ____________________________________________________________________________________________________
# conv2d_261 (Conv2D)              (None, 64, 64, 64)    36928       conv2d_260[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_54 (UpSampling2D)  (None, 128, 128, 64)  0           conv2d_261[0][0]
# ____________________________________________________________________________________________________
# merge_55 (Merge)                 (None, 128, 128, 160) 0           up_sampling2d_54[0][0]
#                                                                    conv2d_253[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_139 (BatchNo (None, 128, 128, 160) 640         merge_55[0][0]
# ____________________________________________________________________________________________________
# conv2d_262 (Conv2D)              (None, 128, 128, 32)  46112       batch_normalization_139[0][0]
# ____________________________________________________________________________________________________
# conv2d_263 (Conv2D)              (None, 128, 128, 32)  9248        conv2d_262[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_55 (UpSampling2D)  (None, 256, 256, 32)  0           conv2d_263[0][0]
# ____________________________________________________________________________________________________
# merge_56 (Merge)                 (None, 256, 256, 96)  0           up_sampling2d_55[0][0]
#                                                                    conv2d_251[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_140 (BatchNo (None, 256, 256, 96)  384         merge_56[0][0]
# ____________________________________________________________________________________________________
# conv2d_264 (Conv2D)              (None, 256, 256, 32)  27680       batch_normalization_140[0][0]
# ____________________________________________________________________________________________________
# conv2d_265 (Conv2D)              (None, 256, 256, 32)  9248        conv2d_264[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_56 (UpSampling2D)  (None, 512, 512, 32)  0           conv2d_265[0][0]
# ____________________________________________________________________________________________________
# conv2d_266 (Conv2D)              (None, 512, 512, 1)   33          up_sampling2d_56[0][0]
# ====================================================================================================
# Total params: 1,619,461
# Trainable params: 1,617,091
# Non-trainable params: 2,370
# ____________________________________________________________________________________________________

# %%
os.listdir(csv_path)
# Out:
# ['.DS_Store',
#  'annotations.csv',
#  'annotations_excluded.csv',
#  'annotations_final1.csv',
#  'annotations_final2cls.csv',
#  'annotations_full.csv',
#  'annotations_pred.csv',
#  'masses_predictions.csv',
#  'seriesuids.csv']

# %%
cc = pandas.read_csv(csv_path+'masses_predictions.csv')

# %%
cc
# Out:
#     patient_id    prediction
# 0      _labels  0.000000e+00
# 1   LKDS-00012  2.967301e+07
# 2   LKDS-00022  2.716028e+07
# 3   LKDS-00027  2.714498e+07
# 4   LKDS-00031  2.865330e+07
# 5   LKDS-00033  5.341816e+07
# 6   LKDS-00037  2.598186e+07
# 7   LKDS-00046  3.641196e+07
# 8   LKDS-00049  3.862316e+07
# 9   LKDS-00056  2.499433e+07
# 10  LKDS-00057  2.848904e+07
# 11  LKDS-00063  3.183143e+07
# 12  LKDS-00082  3.009188e+07
# 13  LKDS-00087  2.079460e+07
# 14  LKDS-00094  2.943100e+07
# 15  LKDS-00097  3.519864e+07
# 16  LKDS-00098  2.295875e+07
# 17  LKDS-00103  3.562902e+07
# 18  LKDS-00106  2.999968e+07
# 19  LKDS-00124  3.665229e+07
# 20  LKDS-00131  3.087925e+07
# 21  LKDS-00132  2.503898e+07
# 22  LKDS-00139  2.594490e+07
# 23  LKDS-00143  3.012898e+07
# 24  LKDS-00155  3.085881e+07
# 25  LKDS-00158  3.218562e+07
# 26  LKDS-00159  3.070740e+07
# 27  LKDS-00164  3.631300e+07
# 28  LKDS-00167  2.745624e+07
# 29  LKDS-00174  3.279659e+07
# 30  LKDS-00179  2.932717e+07
# 31  LKDS-00182  2.666925e+07
# 32  LKDS-00186  0.000000e+00
# 33  LKDS-00199  2.857840e+07
# 34  LKDS-00205  2.093562e+07
# 35  LKDS-00206  3.730596e+07
# 36  LKDS-00209  3.082019e+07
# 37  LKDS-00211  2.717135e+07
# 38  LKDS-00215  3.860251e+07
# 39  LKDS-00221  4.297177e+07
# 40  LKDS-00222  3.297931e+07
