# %%
from utils.imports import *
# Out:
# Using TensorFlow backend.

# %%
def classifier(input_shape, kernel_size, pool_size):
    model = Sequential()

    model.add(Convolution3D(16, kernel_size[0], kernel_size[1], kernel_size[2],
                            border_mode='valid',
                            input_shape=input_shape))
    model.add(Activation('elu'))
    model.add(MaxPooling3D(pool_size=pool_size))
    model.add(Convolution3D(32, kernel_size[0], kernel_size[1], kernel_size[2]))
    model.add(Activation('elu'))
    model.add(MaxPooling3D(pool_size=pool_size))
    model.add(Convolution3D(64, kernel_size[0], kernel_size[1], kernel_size[2]))
    model.add(Activation('elu'))
    model.add(MaxPooling3D(pool_size=pool_size))
    model.add(Dropout(0.2))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('elu'))
    model.add(Dropout(0.2))
    model.add(Dense(128))
    model.add(Activation('elu'))
    model.add(Dropout(0.2))
    model.add(Dense(2))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy',
          optimizer='adadelta',
          metrics=['accuracy'])
    return model

def train_classifier(input_shape):
    model = classifier(input_shape, (3, 3, 3), (2, 2, 2))
    model.compile(loss='categorical_crossentropy',
          optimizer=Adam(lr=1e-5),
          metrics=['accuracy'])

# %%
output_path = PATH['cls_train_20']
output_true = PATH['cls_train_20_true']
output_false = PATH['cls_train_20_false']
model_paths = PATH['model_paths']
model_final = PATH['model_final']

# %%
def get_dirfiles(dir):
    file_list = []
    subset_path = os.listdir(dir)
    for _ in range(len(subset_path)):
        if subset_path[_] != '.DS_Store':
            file_list.append(dir + subset_path[_])
    return file_list

def train_generator(output_true,output_false):
    file_list_true = get_dirfiles(output_true)[0:10000]
    file_list_false = get_dirfiles(output_false)[0:10000]
    
    #file_list_true = shuffle(file_list_true)
    #file_list_false = shuffle(file_list_false)
    
    nb_true = len(file_list_true) + len(file_list_false)
    sample = np.zeros([nb_true,36,36,36])
    labels = np.zeros([nb_true,2])
    for i in tqdm(range(len(file_list_true))):       
        cc= np.load(file_list_true[i])
        sample[i] = cc
        labels[i] = [0.,1.]
    for j in tqdm(range(len(file_list_false))):
        bb= np.load(file_list_false[j])
        sample[j+len(file_list_true)] = bb 
        labels[j+len(file_list_true)] = [1.,0.]
    sample = np.expand_dims(sample, axis=1)        
    return sample,labels

def valid_generator(output_true,output_false):
    file_list_true = get_dirfiles(output_true)[-1000:]
    file_list_false = get_dirfiles(output_false)[-1000:]
    
    #file_list_true = shuffle(file_list_true)
    #file_list_false = shuffle(file_list_false)

    nb_true = len(file_list_true) + len(file_list_false)
    sample = np.zeros([nb_true,36,36,36])
    labels = np.zeros([nb_true,2])
  
    for i in tqdm(range(len(file_list_true))):       
        cc= np.load(file_list_true[i])
        sample[i] = cc
        labels[i] = [0.,1.]
    for j in tqdm(range(len(file_list_false))):
        bb= np.load(file_list_false[j])
        sample[j+len(file_list_true)] = bb 
        labels[j+len(file_list_true)] = [1.,0.]
    sample = np.expand_dims(sample, axis=1)        
    return sample,labels


def fenlei_fit(name, load_check = False,batch_size=2, epochs=100,check_name = None):

    t = time.time()
    callbacks = [EarlyStopping(monitor='val_loss', patience = 8, verbose = 1),
                 ModelCheckpoint((model_paths + '{}.h5').format(name),
                                 monitor='val_loss',
                                 verbose = 0,
                                 save_best_only = True)]
    if load_check:
        check_model = (model_paths + '{}.h5').format(check_name)
        model = load_model(check_model)
    else:
        #model = model_20()
        #model = preds3d_dense(48)
        model = classifier((1, 36, 36, 36), (3, 3, 3), (2, 2, 2))
    x,y = train_generator(output_true,output_false)
    model.fit(x=x, y=y, batch_size=batch_size, epochs=epochs,
              validation_data=valid_generator(output_true,output_false),verbose=1, callbacks=callbacks, shuffle=True)
    
 
    return model

# %%
fenlei_fit('Fenge_36_36_36_0615_2', load_check = True, batch_size=128, epochs=100, check_name = 'Fenge_36_36_36_0615')
# Out:
# 100%|██████████| 10000/10000 [00:56<00:00, 178.12it/s]
# 100%|██████████| 10000/10000 [01:12<00:00, 137.20it/s]
# 100%|██████████| 1000/1000 [00:17<00:00, 56.53it/s]
# 100%|██████████| 1000/1000 [00:17<00:00, 57.13it/s]
# Train on 20000 samples, validate on 2000 samples
# Epoch 1/100
# 20000/20000 [==============================] - 95s - loss: 0.1063 - acc: 0.9623 - val_loss: 0.2002 - val_acc: 0.9295
# Epoch 2/100
# 20000/20000 [==============================] - 94s - loss: 0.0999 - acc: 0.9646 - val_loss: 0.2426 - val_acc: 0.9160
# Epoch 3/100
# 20000/20000 [==============================] - 94s - loss: 0.0911 - acc: 0.9675 - val_loss: 0.2510 - val_acc: 0.9165
# Epoch 4/100
# 20000/20000 [==============================] - 95s - loss: 0.0810 - acc: 0.9715 - val_loss: 0.2041 - val_acc: 0.9340
# Epoch 5/100
# 20000/20000 [==============================] - 95s - loss: 0.0793 - acc: 0.9722 - val_loss: 0.1968 - val_acc: 0.9300
# Epoch 6/100
# 20000/20000 [==============================] - 95s - loss: 0.0709 - acc: 0.9751 - val_loss: 0.2720 - val_acc: 0.9185
# Epoch 7/100
# 20000/20000 [==============================] - 94s - loss: 0.0643 - acc: 0.9754 - val_loss: 0.2531 - val_acc: 0.9135
# Epoch 8/100
# 20000/20000 [==============================] - 95s - loss: 0.0593 - acc: 0.9797 - val_loss: 0.2291 - val_acc: 0.9295
# Epoch 9/100
# 20000/20000 [==============================] - 95s - loss: 0.0569 - acc: 0.9802 - val_loss: 0.2126 - val_acc: 0.9400
# Epoch 10/100
# 20000/20000 [==============================] - 95s - loss: 0.0487 - acc: 0.9829 - val_loss: 0.2421 - val_acc: 0.9335
# Epoch 11/100
# 20000/20000 [==============================] - 95s - loss: 0.0453 - acc: 0.9845 - val_loss: 0.3754 - val_acc: 0.9085
# Epoch 12/100
# 20000/20000 [==============================] - 94s - loss: 0.0414 - acc: 0.9859 - val_loss: 0.2960 - val_acc: 0.9255
# Epoch 13/100
# 20000/20000 [==============================] - 94s - loss: 0.0401 - acc: 0.9863 - val_loss: 0.2502 - val_acc: 0.9330
# Epoch 14/100
# 20000/20000 [==============================] - 94s - loss: 0.0363 - acc: 0.9878 - val_loss: 0.2048 - val_acc: 0.9350
# Epoch 00013: early stopping

# %%
file_list_true = get_dirfiles(output_true)
file_list_false = get_dirfiles(output_false)

# %%
#model_pred = classifier((1, 36, 36, 36), (3, 3, 3), (2, 2, 2))
model_pred = load_model(model_paths + 'Fenge_36_36_36_0615_2.h5')

# %%
#model_pred.load_weights(model_paths + 'Fenge_0613_2.h5')

# %%
cc = []
for i in file_list_false[0:200]:
    a=np.load(i)
    a=np.expand_dims(a,0)
    a=np.expand_dims(a,0)
    cc.append(model_pred.predict(a))
count = 0
for i in cc:
    if i[0][0] > 0.9:
        count += 1
print count*1.0/len(cc)
# Out:
# 0.915

# %%
cc
# Out:
# [array([[  9.99556720e-01,   4.43242490e-04]], dtype=float32),
#  array([[  9.99976993e-01,   2.29570214e-05]], dtype=float32),
#  array([[  9.99997497e-01,   2.49775417e-06]], dtype=float32),
#  array([[ 0.9984681 ,  0.00153191]], dtype=float32),
#  array([[ 0.98336619,  0.0166338 ]], dtype=float32),
#  array([[  1.00000000e+00,   7.01240443e-09]], dtype=float32),
#  array([[ 0.09757512,  0.90242493]], dtype=float32),
#  array([[  9.99999762e-01,   2.77694369e-07]], dtype=float32),
#  array([[ 0.93818074,  0.06181921]], dtype=float32),
#  array([[ 0.60454047,  0.3954595 ]], dtype=float32),
#  array([[  1.00000000e+00,   9.85118792e-11]], dtype=float32),
#  array([[  9.99993920e-01,   6.05189553e-06]], dtype=float32),
#  array([[ 0.93996555,  0.06003443]], dtype=float32),
#  array([[ 0.99651873,  0.00348132]], dtype=float32),
#  array([[  9.99994397e-01,   5.56863324e-06]], dtype=float32),
#  array([[  9.99999881e-01,   1.71908809e-07]], dtype=float32),
#  array([[  9.99999523e-01,   4.47063201e-07]], dtype=float32),
#  array([[  9.99981523e-01,   1.85022600e-05]], dtype=float32),
#  array([[  9.99996543e-01,   3.45104559e-06]], dtype=float32),
#  array([[  9.99999642e-01,   3.60786174e-07]], dtype=float32),
#  array([[  1.00000000e+00,   4.34149383e-10]], dtype=float32),
#  array([[  9.99893904e-01,   1.06049469e-04]], dtype=float32),
#  array([[  9.99996662e-01,   3.29398472e-06]], dtype=float32),
#  array([[  1.00000000e+00,   1.90223926e-08]], dtype=float32),
#  array([[  9.99936581e-01,   6.33865784e-05]], dtype=float32),
#  array([[  9.99688625e-01,   3.11395619e-04]], dtype=float32),
#  array([[  9.99999762e-01,   2.13472106e-07]], dtype=float32),
#  array([[  9.99983788e-01,   1.62523320e-05]], dtype=float32),
#  array([[  9.99999523e-01,   4.52081139e-07]], dtype=float32),
#  array([[  1.00000000e+00,   3.57349457e-08]], dtype=float32),
#  array([[ 0.99601316,  0.00398688]], dtype=float32),
#  array([[  9.99999762e-01,   2.73715216e-07]], dtype=float32),
#  array([[  9.99990582e-01,   9.40299924e-06]], dtype=float32),
#  array([[ 0.88473493,  0.11526506]], dtype=float32),
#  array([[ 0.94442832,  0.05557167]], dtype=float32),
#  array([[ 0.96940416,  0.03059584]], dtype=float32),
#  array([[  9.99797761e-01,   2.02258612e-04]], dtype=float32),
#  array([[  9.99961495e-01,   3.84744453e-05]], dtype=float32),
#  array([[ 0.94931376,  0.05068627]], dtype=float32),
#  array([[ 0.9852019 ,  0.01479804]], dtype=float32),
#  array([[ 0.99781394,  0.00218603]], dtype=float32),
#  array([[  9.99528527e-01,   4.71438514e-04]], dtype=float32),
#  array([[  9.99975562e-01,   2.44337189e-05]], dtype=float32),
#  array([[  9.99997854e-01,   2.09786367e-06]], dtype=float32),
#  array([[ 0.9745335 ,  0.02546655]], dtype=float32),
#  array([[  9.99982834e-01,   1.71720894e-05]], dtype=float32),
#  array([[  9.99999166e-01,   8.63422940e-07]], dtype=float32),
#  array([[  9.99999166e-01,   8.14533848e-07]], dtype=float32),
#  array([[  9.99262631e-01,   7.37341761e-04]], dtype=float32),
#  array([[ 0.9988122 ,  0.00118787]], dtype=float32),
#  array([[  9.99842167e-01,   1.57803574e-04]], dtype=float32),
#  array([[  9.99182284e-01,   8.17696680e-04]], dtype=float32),
#  array([[ 0.99502963,  0.00497045]], dtype=float32),
#  array([[ 0.95775551,  0.04224449]], dtype=float32),
#  array([[ 0.9569062 ,  0.04309387]], dtype=float32),
#  array([[  9.99984145e-01,   1.58789135e-05]], dtype=float32),
#  array([[ 0.94851565,  0.05148432]], dtype=float32),
#  array([[  9.99877095e-01,   1.22921192e-04]], dtype=float32),
#  array([[  9.99997139e-01,   2.81144048e-06]], dtype=float32),
#  array([[  9.99920249e-01,   7.97447647e-05]], dtype=float32),
#  array([[ 0.99835664,  0.00164333]], dtype=float32),
#  array([[ 0.99722785,  0.00277214]], dtype=float32),
#  array([[  9.99628901e-01,   3.71129892e-04]], dtype=float32),
#  array([[ 0.99654949,  0.00345054]], dtype=float32),
#  array([[ 0.99649495,  0.00350506]], dtype=float32),
#  array([[ 0.79845887,  0.20154114]], dtype=float32),
#  array([[  9.99999762e-01,   2.16375028e-07]], dtype=float32),
#  array([[ 0.99682271,  0.00317732]], dtype=float32),
#  array([[ 0.97149682,  0.02850316]], dtype=float32),
#  array([[  9.99959230e-01,   4.07476982e-05]], dtype=float32),
#  array([[ 0.99805117,  0.00194879]], dtype=float32),
#  array([[ 0.98639792,  0.01360204]], dtype=float32),
#  array([[  9.99921083e-01,   7.89408732e-05]], dtype=float32),
#  array([[  9.99879241e-01,   1.20704171e-04]], dtype=float32),
#  array([[ 0.96525431,  0.03474577]], dtype=float32),
#  array([[ 0.99444383,  0.00555618]], dtype=float32),
#  array([[ 0.96062994,  0.03937001]], dtype=float32),
#  array([[ 0.99639291,  0.00360714]], dtype=float32),
#  array([[  9.99767721e-01,   2.32287144e-04]], dtype=float32),
#  array([[ 0.98875612,  0.01124391]], dtype=float32),
#  array([[ 0.88250285,  0.11749714]], dtype=float32),
#  array([[ 0.80752063,  0.19247937]], dtype=float32),
#  array([[ 0.69380653,  0.30619347]], dtype=float32),
#  array([[ 0.96851593,  0.0314841 ]], dtype=float32),
#  array([[  9.99634266e-01,   3.65754910e-04]], dtype=float32),
#  array([[  9.99916434e-01,   8.35711544e-05]], dtype=float32),
#  array([[ 0.92544937,  0.07455068]], dtype=float32),
#  array([[ 0.99783957,  0.00216041]], dtype=float32),
#  array([[  1.00000000e+00,   3.07967407e-09]], dtype=float32),
#  array([[  9.99997735e-01,   2.21034020e-06]], dtype=float32),
#  array([[  9.99211192e-01,   7.88825331e-04]], dtype=float32),
#  array([[ 0.97660363,  0.02339644]], dtype=float32),
#  array([[  9.99934554e-01,   6.54120959e-05]], dtype=float32),
#  array([[ 0.99841356,  0.00158642]], dtype=float32),
#  array([[ 0.99751151,  0.00248848]], dtype=float32),
#  array([[ 0.98468208,  0.01531795]], dtype=float32),
#  array([[  1.00000000e+00,   2.38702363e-10]], dtype=float32),
#  array([[  9.99969602e-01,   3.03723627e-05]], dtype=float32),
#  array([[ 0.99897158,  0.00102847]], dtype=float32),
#  array([[  9.99999881e-01,   9.20660028e-08]], dtype=float32),
#  array([[ 0.97609949,  0.02390045]], dtype=float32),
#  array([[  9.99983907e-01,   1.60442960e-05]], dtype=float32),
#  array([[  9.99766171e-01,   2.33873448e-04]], dtype=float32),
#  array([[  9.99439061e-01,   5.60966902e-04]], dtype=float32),
#  array([[ 0.98751408,  0.012486  ]], dtype=float32),
#  array([[ 0.96864241,  0.03135762]], dtype=float32),
#  array([[ 0.99852931,  0.00147072]], dtype=float32),
#  array([[ 0.99355245,  0.00644758]], dtype=float32),
#  array([[ 0.99718225,  0.00281774]], dtype=float32),
#  array([[  9.99998331e-01,   1.72164573e-06]], dtype=float32),
#  array([[ 0.89005822,  0.10994185]], dtype=float32),
#  array([[  1.00000000e+00,   3.00337399e-09]], dtype=float32),
#  array([[  9.99983072e-01,   1.68690003e-05]], dtype=float32),
#  array([[  9.99853373e-01,   1.46567894e-04]], dtype=float32),
#  array([[ 0.98111147,  0.0188885 ]], dtype=float32),
#  array([[ 0.9649474 ,  0.03505262]], dtype=float32),
#  array([[ 0.76694405,  0.23305595]], dtype=float32),
#  array([[ 0.91258937,  0.08741066]], dtype=float32),
#  array([[ 0.69344878,  0.30655128]], dtype=float32),
#  array([[ 0.99076802,  0.00923199]], dtype=float32),
#  array([[ 0.87335366,  0.12664637]], dtype=float32),
#  array([[ 0.85280824,  0.14719179]], dtype=float32),
#  array([[ 0.94795293,  0.05204712]], dtype=float32),
#  array([[ 0.91349053,  0.0865095 ]], dtype=float32),
#  array([[ 0.97651082,  0.02348913]], dtype=float32),
#  array([[ 0.9974426 ,  0.00255745]], dtype=float32),
#  array([[ 0.52986884,  0.47013116]], dtype=float32),
#  array([[  9.99982715e-01,   1.72721939e-05]], dtype=float32),
#  array([[  9.99430835e-01,   5.69141412e-04]], dtype=float32),
#  array([[  9.99908924e-01,   9.10465533e-05]], dtype=float32),
#  array([[  9.99998689e-01,   1.26338739e-06]], dtype=float32),
#  array([[  9.99974966e-01,   2.50358989e-05]], dtype=float32),
#  array([[  9.99995589e-01,   4.35496077e-06]], dtype=float32),
#  array([[  1.00000000e+00,   2.42962983e-08]], dtype=float32),
#  array([[ 0.99745148,  0.00254849]], dtype=float32),
#  array([[ 0.99418962,  0.00581045]], dtype=float32),
#  array([[  9.99994516e-01,   5.46687261e-06]], dtype=float32),
#  array([[  9.99265969e-01,   7.33997615e-04]], dtype=float32),
#  array([[  9.99975204e-01,   2.47558182e-05]], dtype=float32),
#  array([[  9.99996066e-01,   3.97062695e-06]], dtype=float32),
#  array([[ 0.99884808,  0.00115191]], dtype=float32),
#  array([[  9.99870181e-01,   1.29815278e-04]], dtype=float32),
#  array([[ 0.99849963,  0.00150041]], dtype=float32),
#  array([[ 0.99847907,  0.00152094]], dtype=float32),
#  array([[  9.99999523e-01,   4.46484563e-07]], dtype=float32),
#  array([[  9.99235749e-01,   7.64237717e-04]], dtype=float32),
#  array([[  9.99991417e-01,   8.59707689e-06]], dtype=float32),
#  array([[  9.99982834e-01,   1.71804440e-05]], dtype=float32),
#  array([[  9.99992132e-01,   7.87721820e-06]], dtype=float32),
#  array([[  9.99992013e-01,   8.02255363e-06]], dtype=float32),
#  array([[  9.99982834e-01,   1.71336960e-05]], dtype=float32),
#  array([[  9.99179780e-01,   8.20247806e-04]], dtype=float32),
#  array([[  9.99996901e-01,   3.07981600e-06]], dtype=float32),
#  array([[ 0.99278331,  0.00721668]], dtype=float32),
#  array([[ 0.98034751,  0.01965245]], dtype=float32),
#  array([[  9.99817789e-01,   1.82223725e-04]], dtype=float32),
#  array([[ 0.99736363,  0.00263636]], dtype=float32),
#  array([[  9.99999762e-01,   2.05417720e-07]], dtype=float32),
#  array([[ 0.67259628,  0.32740372]], dtype=float32),
#  array([[  9.99999523e-01,   5.35721711e-07]], dtype=float32),
#  array([[ 0.99881566,  0.0011844 ]], dtype=float32),
#  array([[ 0.99771726,  0.00228271]], dtype=float32),
#  array([[ 0.98015869,  0.01984124]], dtype=float32),
#  array([[ 0.91467541,  0.08532463]], dtype=float32),
#  array([[ 0.33498886,  0.66501111]], dtype=float32),
#  array([[ 0.9971289,  0.0028711]], dtype=float32),
#  array([[ 0.93718964,  0.06281036]], dtype=float32),
#  array([[ 0.93413222,  0.06586782]], dtype=float32),
#  array([[ 0.99566662,  0.00433339]], dtype=float32),
#  array([[ 0.97148031,  0.02851976]], dtype=float32),
#  array([[ 0.98053211,  0.01946788]], dtype=float32),
#  array([[  9.99778688e-01,   2.21309572e-04]], dtype=float32),
#  array([[  9.99454200e-01,   5.45848685e-04]], dtype=float32),
#  array([[ 0.42752549,  0.57247448]], dtype=float32),
#  array([[ 0.99689353,  0.00310645]], dtype=float32),
#  array([[  9.99999762e-01,   1.91689622e-07]], dtype=float32),
#  array([[  9.99870420e-01,   1.29590684e-04]], dtype=float32),
#  array([[ 0.99498773,  0.00501231]], dtype=float32),
#  array([[  9.99450982e-01,   5.48960583e-04]], dtype=float32),
#  array([[  9.99115169e-01,   8.84804351e-04]], dtype=float32),
#  array([[  9.99649167e-01,   3.50880582e-04]], dtype=float32),
#  array([[ 0.97028649,  0.02971346]], dtype=float32),
#  array([[  9.99974251e-01,   2.57465417e-05]], dtype=float32),
#  array([[ 0.97632784,  0.02367211]], dtype=float32),
#  array([[ 0.99859983,  0.00140019]], dtype=float32),
#  array([[ 0.99745148,  0.00254849]], dtype=float32),
#  array([[ 0.99800342,  0.00199661]], dtype=float32),
#  array([[ 0.99755609,  0.00244383]], dtype=float32),
#  array([[  9.99944806e-01,   5.52057572e-05]], dtype=float32),
#  array([[ 0.99550807,  0.00449195]], dtype=float32),
#  array([[ 0.99736542,  0.0026346 ]], dtype=float32),
#  array([[  9.99599993e-01,   4.00072226e-04]], dtype=float32),
#  array([[ 0.96873528,  0.03126474]], dtype=float32),
#  array([[ 0.99794644,  0.00205361]], dtype=float32),
#  array([[  9.99793112e-01,   2.06923403e-04]], dtype=float32),
#  array([[ 0.99319649,  0.00680355]], dtype=float32),
#  array([[  9.99561369e-01,   4.38581803e-04]], dtype=float32),
#  array([[ 0.82409984,  0.17590018]], dtype=float32),
#  array([[ 0.99529135,  0.00470871]], dtype=float32),
#  array([[ 0.99827659,  0.00172339]], dtype=float32)]

# %%
cc = []
for i in file_list_true[0:200]:
    a=np.load(i)
    a=np.expand_dims(a,0)
    a=np.expand_dims(a,0)
    cc.append(model_pred.predict(a))
count = 0

# %%
for i in cc:
    if i[0][1] > 0.9:
        count += 1
print count*1.0/len(cc)
# Out:
# 0.895

# %%
cc
# Out:
# [array([[ 0.00952823,  0.99047184]], dtype=float32),
#  array([[ 0.01247467,  0.98752534]], dtype=float32),
#  array([[ 0.01927673,  0.98072332]], dtype=float32),
#  array([[ 0.0515774 ,  0.94842255]], dtype=float32),
#  array([[ 0.04482401,  0.955176  ]], dtype=float32),
#  array([[ 0.11076933,  0.88923067]], dtype=float32),
#  array([[ 0.01137028,  0.9886297 ]], dtype=float32),
#  array([[ 0.007959  ,  0.99204093]], dtype=float32),
#  array([[ 0.01829937,  0.9817006 ]], dtype=float32),
#  array([[ 0.0325457 ,  0.96745437]], dtype=float32),
#  array([[ 0.00209781,  0.99790215]], dtype=float32),
#  array([[ 0.02772187,  0.97227818]], dtype=float32),
#  array([[ 0.00217554,  0.99782443]], dtype=float32),
#  array([[ 0.00256138,  0.99743855]], dtype=float32),
#  array([[  4.27666906e-04,   9.99572337e-01]], dtype=float32),
#  array([[ 0.00400219,  0.99599779]], dtype=float32),
#  array([[ 0.0061254 ,  0.99387461]], dtype=float32),
#  array([[ 0.0130633 ,  0.98693675]], dtype=float32),
#  array([[ 0.01761521,  0.98238474]], dtype=float32),
#  array([[ 0.01464197,  0.985358  ]], dtype=float32),
#  array([[ 0.00550007,  0.99449992]], dtype=float32),
#  array([[  1.37157178e-06,   9.99998569e-01]], dtype=float32),
#  array([[  4.32483830e-06,   9.99995708e-01]], dtype=float32),
#  array([[  6.37132942e-08,   9.99999881e-01]], dtype=float32),
#  array([[ 0.10365023,  0.89634979]], dtype=float32),
#  array([[ 0.05840794,  0.9415921 ]], dtype=float32),
#  array([[ 0.00445026,  0.9955498 ]], dtype=float32),
#  array([[ 0.10108637,  0.89891362]], dtype=float32),
#  array([[ 0.15828174,  0.84171826]], dtype=float32),
#  array([[ 0.01796676,  0.98203319]], dtype=float32),
#  array([[ 0.09304062,  0.90695941]], dtype=float32),
#  array([[ 0.00210181,  0.99789822]], dtype=float32),
#  array([[ 0.00851234,  0.99148762]], dtype=float32),
#  array([[ 0.01277832,  0.98722166]], dtype=float32),
#  array([[ 0.01062692,  0.98937303]], dtype=float32),
#  array([[ 0.0234288,  0.9765712]], dtype=float32),
#  array([[ 0.040139  ,  0.95986098]], dtype=float32),
#  array([[ 0.08255077,  0.91744924]], dtype=float32),
#  array([[ 0.12152302,  0.87847698]], dtype=float32),
#  array([[ 0.02056749,  0.97943246]], dtype=float32),
#  array([[ 0.0463168,  0.9536832]], dtype=float32),
#  array([[ 0.07259653,  0.92740345]], dtype=float32),
#  array([[ 0.19129063,  0.80870938]], dtype=float32),
#  array([[ 0.14745663,  0.85254335]], dtype=float32),
#  array([[ 0.07975984,  0.9202401 ]], dtype=float32),
#  array([[ 0.10425313,  0.89574689]], dtype=float32),
#  array([[ 0.04589498,  0.95410508]], dtype=float32),
#  array([[ 0.5745914 ,  0.42540857]], dtype=float32),
#  array([[ 0.01291656,  0.98708344]], dtype=float32),
#  array([[ 0.02766599,  0.97233397]], dtype=float32),
#  array([[ 0.11164587,  0.88835412]], dtype=float32),
#  array([[ 0.01291656,  0.98708344]], dtype=float32),
#  array([[ 0.02766599,  0.97233397]], dtype=float32),
#  array([[ 0.11164587,  0.88835412]], dtype=float32),
#  array([[ 0.00130643,  0.99869365]], dtype=float32),
#  array([[ 0.0019298 ,  0.99807018]], dtype=float32),
#  array([[  8.18782020e-04,   9.99181211e-01]], dtype=float32),
#  array([[ 0.00219752,  0.99780244]], dtype=float32),
#  array([[ 0.00648068,  0.99351937]], dtype=float32),
#  array([[  9.89517430e-04,   9.99010444e-01]], dtype=float32),
#  array([[ 0.00235432,  0.99764568]], dtype=float32),
#  array([[  8.92803946e-04,   9.99107182e-01]], dtype=float32),
#  array([[ 0.00213546,  0.99786454]], dtype=float32),
#  array([[ 0.01058362,  0.9894163 ]], dtype=float32),
#  array([[  2.47794291e-04,   9.99752223e-01]], dtype=float32),
#  array([[  9.57918935e-04,   9.99042094e-01]], dtype=float32),
#  array([[  7.96756882e-04,   9.99203265e-01]], dtype=float32),
#  array([[ 0.00367872,  0.99632132]], dtype=float32),
#  array([[ 0.01342921,  0.98657078]], dtype=float32),
#  array([[  5.43657843e-05,   9.99945641e-01]], dtype=float32),
#  array([[  4.24984843e-04,   9.99574959e-01]], dtype=float32),
#  array([[  1.08234250e-04,   9.99891758e-01]], dtype=float32),
#  array([[  7.30722328e-04,   9.99269307e-01]], dtype=float32),
#  array([[  6.45548280e-04,   9.99354422e-01]], dtype=float32),
#  array([[ 0.00691162,  0.99308842]], dtype=float32),
#  array([[  4.77999391e-04,   9.99521971e-01]], dtype=float32),
#  array([[ 0.00353348,  0.99646652]], dtype=float32),
#  array([[ 0.0064    ,  0.99360001]], dtype=float32),
#  array([[ 0.00231859,  0.99768138]], dtype=float32),
#  array([[ 0.00688849,  0.99311149]], dtype=float32),
#  array([[ 0.00140017,  0.99859983]], dtype=float32),
#  array([[ 0.08417939,  0.9158206 ]], dtype=float32),
#  array([[ 0.04271483,  0.95728523]], dtype=float32),
#  array([[ 0.07933322,  0.92066681]], dtype=float32),
#  array([[ 0.0199143 ,  0.98008567]], dtype=float32),
#  array([[ 0.00657228,  0.99342769]], dtype=float32),
#  array([[ 0.01889148,  0.98110849]], dtype=float32),
#  array([[ 0.03164977,  0.96835023]], dtype=float32),
#  array([[ 0.01952011,  0.98047996]], dtype=float32),
#  array([[ 0.06680769,  0.93319237]], dtype=float32),
#  array([[  7.96980923e-04,   9.99203026e-01]], dtype=float32),
#  array([[ 0.04148026,  0.9585197 ]], dtype=float32),
#  array([[ 0.00286843,  0.99713159]], dtype=float32),
#  array([[  1.71184744e-04,   9.99828815e-01]], dtype=float32),
#  array([[ 0.02360699,  0.97639298]], dtype=float32),
#  array([[  9.27146291e-04,   9.99072790e-01]], dtype=float32),
#  array([[  6.02856104e-04,   9.99397159e-01]], dtype=float32),
#  array([[ 0.02665629,  0.97334373]], dtype=float32),
#  array([[ 0.0017489 ,  0.99825102]], dtype=float32),
#  array([[ 0.01322443,  0.98677558]], dtype=float32),
#  array([[ 0.03259756,  0.96740246]], dtype=float32),
#  array([[ 0.02307738,  0.97692263]], dtype=float32),
#  array([[ 0.01549445,  0.98450559]], dtype=float32),
#  array([[ 0.01893989,  0.98106009]], dtype=float32),
#  array([[ 0.01210385,  0.9878962 ]], dtype=float32),
#  array([[ 0.00298559,  0.9970144 ]], dtype=float32),
#  array([[ 0.00189526,  0.99810469]], dtype=float32),
#  array([[ 0.002134  ,  0.99786597]], dtype=float32),
#  array([[ 0.0070256,  0.9929744]], dtype=float32),
#  array([[ 0.00563424,  0.99436581]], dtype=float32),
#  array([[ 0.00613957,  0.99386036]], dtype=float32),
#  array([[ 0.01670884,  0.98329115]], dtype=float32),
#  array([[ 0.00779905,  0.99220097]], dtype=float32),
#  array([[ 0.06867339,  0.93132663]], dtype=float32),
#  array([[ 0.02569162,  0.97430837]], dtype=float32),
#  array([[ 0.00367258,  0.99632746]], dtype=float32),
#  array([[ 0.00339522,  0.9966048 ]], dtype=float32),
#  array([[ 0.05449609,  0.94550389]], dtype=float32),
#  array([[ 0.02081979,  0.97918016]], dtype=float32),
#  array([[ 0.01076174,  0.98923826]], dtype=float32),
#  array([[ 0.0853849 ,  0.91461509]], dtype=float32),
#  array([[ 0.04728259,  0.95271736]], dtype=float32),
#  array([[ 0.00872134,  0.99127859]], dtype=float32),
#  array([[ 0.08707425,  0.91292572]], dtype=float32),
#  array([[ 0.01936661,  0.98063344]], dtype=float32),
#  array([[ 0.00960131,  0.99039876]], dtype=float32),
#  array([[ 0.07728564,  0.92271441]], dtype=float32),
#  array([[ 0.00498961,  0.99501038]], dtype=float32),
#  array([[ 0.02990294,  0.97009706]], dtype=float32),
#  array([[ 0.00917207,  0.99082792]], dtype=float32),
#  array([[  5.75961953e-04,   9.99424100e-01]], dtype=float32),
#  array([[ 0.01454431,  0.98545569]], dtype=float32),
#  array([[  4.54153109e-04,   9.99545872e-01]], dtype=float32),
#  array([[  4.60452051e-04,   9.99539614e-01]], dtype=float32),
#  array([[  2.06010562e-04,   9.99794066e-01]], dtype=float32),
#  array([[ 0.01741974,  0.98258024]], dtype=float32),
#  array([[ 0.00898607,  0.99101394]], dtype=float32),
#  array([[ 0.00230835,  0.99769163]], dtype=float32),
#  array([[ 0.00376151,  0.99623847]], dtype=float32),
#  array([[ 0.00188737,  0.99811268]], dtype=float32),
#  array([[  4.26584855e-04,   9.99573410e-01]], dtype=float32),
#  array([[ 0.01161552,  0.98838449]], dtype=float32),
#  array([[  1.65258505e-04,   9.99834657e-01]], dtype=float32),
#  array([[ 0.00162876,  0.9983713 ]], dtype=float32),
#  array([[ 0.10155325,  0.8984468 ]], dtype=float32),
#  array([[ 0.13091677,  0.86908329]], dtype=float32),
#  array([[ 0.19270533,  0.80729467]], dtype=float32),
#  array([[ 0.00695773,  0.99304223]], dtype=float32),
#  array([[ 0.00564608,  0.99435389]], dtype=float32),
#  array([[  6.66276726e-04,   9.99333680e-01]], dtype=float32),
#  array([[  2.85056885e-04,   9.99714911e-01]], dtype=float32),
#  array([[  1.03799357e-04,   9.99896169e-01]], dtype=float32),
#  array([[  4.84926044e-04,   9.99515057e-01]], dtype=float32),
#  array([[ 0.04924419,  0.95075583]], dtype=float32),
#  array([[ 0.04706543,  0.95293462]], dtype=float32),
#  array([[ 0.07796364,  0.92203641]], dtype=float32),
#  array([[ 0.12199914,  0.87800086]], dtype=float32),
#  array([[ 0.07142556,  0.92857444]], dtype=float32),
#  array([[ 0.12764463,  0.8723554 ]], dtype=float32),
#  array([[ 0.01133829,  0.98866177]], dtype=float32),
#  array([[ 0.02712419,  0.97287583]], dtype=float32),
#  array([[ 0.03937386,  0.96062613]], dtype=float32),
#  array([[ 0.05175929,  0.94824076]], dtype=float32),
#  array([[ 0.07179195,  0.92820805]], dtype=float32),
#  array([[ 0.06566434,  0.93433571]], dtype=float32),
#  array([[ 0.07784819,  0.92215174]], dtype=float32),
#  array([[ 0.07567332,  0.92432672]], dtype=float32),
#  array([[ 0.02640987,  0.97359008]], dtype=float32),
#  array([[ 0.01553635,  0.98446369]], dtype=float32),
#  array([[ 0.0132413 ,  0.98675865]], dtype=float32),
#  array([[ 0.21683629,  0.78316367]], dtype=float32),
#  array([[ 0.07377928,  0.92622072]], dtype=float32),
#  array([[ 0.08734623,  0.9126538 ]], dtype=float32),
#  array([[ 0.10670402,  0.89329594]], dtype=float32),
#  array([[ 0.15194312,  0.84805685]], dtype=float32),
#  array([[ 0.11030756,  0.88969243]], dtype=float32),
#  array([[ 0.11788431,  0.88211572]], dtype=float32),
#  array([[ 0.07696857,  0.92303139]], dtype=float32),
#  array([[ 0.03888401,  0.96111602]], dtype=float32),
#  array([[ 0.06459351,  0.93540657]], dtype=float32),
#  array([[ 0.00152418,  0.99847585]], dtype=float32),
#  array([[ 0.00623878,  0.99376124]], dtype=float32),
#  array([[ 0.00397826,  0.99602181]], dtype=float32),
#  array([[  5.96306636e-04,   9.99403715e-01]], dtype=float32),
#  array([[  4.63690340e-05,   9.99953628e-01]], dtype=float32),
#  array([[  4.32899193e-04,   9.99567091e-01]], dtype=float32),
#  array([[  8.48143918e-06,   9.99991536e-01]], dtype=float32),
#  array([[  6.16068792e-05,   9.99938369e-01]], dtype=float32),
#  array([[ 0.00236624,  0.9976337 ]], dtype=float32),
#  array([[  1.48559149e-04,   9.99851465e-01]], dtype=float32),
#  array([[ 0.0011381 ,  0.99886191]], dtype=float32),
#  array([[  3.16054909e-04,   9.99683976e-01]], dtype=float32),
#  array([[  1.22775219e-07,   9.99999881e-01]], dtype=float32),
#  array([[  4.30921391e-05,   9.99956965e-01]], dtype=float32),
#  array([[  2.11112225e-10,   1.00000000e+00]], dtype=float32),
#  array([[  1.31449701e-06,   9.99998689e-01]], dtype=float32),
#  array([[  2.25651893e-05,   9.99977469e-01]], dtype=float32),
#  array([[  6.32128705e-09,   1.00000000e+00]], dtype=float32),
#  array([[ 0.00537226,  0.99462777]], dtype=float32),
#  array([[ 0.00141421,  0.99858582]], dtype=float32)]

# %%
len(file_list_false)
# Out:
# 12370

# %%
# %matplotlib inline
plt.hist(trainX[20].tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-53fe2dfb9bc0> in <module>()
#       1 get_ipython().magic(u'matplotlib inline')
# ----> 2 plt.hist(trainX[20].tolist())
#
# NameError: name 'trainX' is not defined

# %%
bb= np.load(file_list_false[0])

# %%
bb.shape
