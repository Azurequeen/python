# %% [markdown]
# ## 加载常用库

# %%
from __future__ import print_function, division
import SimpleITK as sitk
import numpy as np
import csv
from glob import glob
import pandas as pd
import os
from tqdm import tqdm #进度条
    
import warnings #不显示乱七八糟的warning
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 定义文件夹

# %% [markdown]
# - 数据和csv的位置，根据需要修改

# %%
luna_path = './'
luna_subset_path = luna_path + 'sample_patients/'
file_list = glob(luna_subset_path + "*.mhd")
df_node = pd.read_csv(luna_path + 'csv_files/' + 'annotations.csv')

# %% [markdown]
# - 临时文件和输出文件的位置

# %%
output_path = luna_path + 'npy/'
working_path = luna_path + 'output/'

# %% [markdown]
# - 检查下文件夹，如果没有的话新建

# %%
if os.path.isdir('./npy'):
    pass
else:
    os.mkdir('./npy')
    
if os.path.isdir('./output'):
    pass
else:
    os.mkdir('./output')

# %% [markdown]
# ## 定义一些函数

# %%
def make_mask(center,diam,z,width,height,spacing,origin): #只显示结节
    '''
Center : 圆的中心 px -- list of coordinates x,y,z
diam : 圆的直径 px -- diameter
widthXheight : pixel dim of image
spacing = mm/px conversion rate np array x,y,z
origin = x,y,z mm np.array
z = z position of slice in world coordinates mm
    '''
    mask = np.zeros([height,width]) # 0's everywhere except nodule swapping x,y to match img
    #convert to nodule space from world coordinates

    # Defining the voxel range in which the nodule falls
    v_center = (center-origin)/spacing
    v_diam = int(diam/spacing[0]+5)
    v_xmin = np.max([0,int(v_center[0]-v_diam)-5])
    v_xmax = np.min([width-1,int(v_center[0]+v_diam)+5])
    v_ymin = np.max([0,int(v_center[1]-v_diam)-5]) 
    v_ymax = np.min([height-1,int(v_center[1]+v_diam)+5])

    v_xrange = range(v_xmin,v_xmax+1)
    v_yrange = range(v_ymin,v_ymax+1)

    # Convert back to world coordinates for distance calculation
    x_data = [x*spacing[0]+origin[0] for x in range(width)]
    y_data = [x*spacing[1]+origin[1] for x in range(height)]

    # Fill in 1 within sphere around nodule
    for v_x in v_xrange:
        for v_y in v_yrange:
            p_x = spacing[0]*v_x + origin[0]
            p_y = spacing[1]*v_y + origin[1]
            if np.linalg.norm(center-np.array([p_x,p_y,z]))<=diam:
                mask[int((p_y-origin[1])/spacing[1]),int((p_x-origin[0])/spacing[0])] = 1.0
    return(mask)

def matrix2int16(matrix):
    ''' 
matrix must be a numpy array NXN
Returns uint16 version
    '''
    m_min= np.min(matrix)
    m_max= np.max(matrix)
    matrix = matrix-m_min
    return(np.array(np.rint( (matrix-m_min)/float(m_max-m_min) * 65535.0),dtype=np.uint16))


#
# Helper function to get rows in data frame associated 
# with each file
def get_filename(file_list, case):
    for f in file_list:
        if case in f:
            return(f)
#
# The locations of the nodes

# %% [markdown]
# ## 处理数据

# %% [markdown]
# - 将数据关联至csv

# %%
df_node["file"] = df_node["seriesuid"].map(lambda file_name: get_filename(file_list, file_name))
df_node = df_node.dropna()
df_node.head(5)
# Out:
#                                               seriesuid      coordX  \
# 1002  1.3.6.1.4.1.14519.5.2.1.6279.6001.487268565754...  119.208776
# 1003  1.3.6.1.4.1.14519.5.2.1.6279.6001.487268565754...  -37.901617
# 1145  1.3.6.1.4.1.14519.5.2.1.6279.6001.910435939545...   68.243850
# 1146  1.3.6.1.4.1.14519.5.2.1.6279.6001.910435939545...   53.469331
# 1147  1.3.6.1.4.1.14519.5.2.1.6279.6001.910435939545...  -91.369924
#
#          coordY      coordZ  diameter_mm  \
# 1002  11.450374 -165.039862    26.837081
# 1003  55.027912  -80.002605    17.718729
# 1145  83.940751 -296.892458     7.068564
# 1146  86.958564 -244.223244     8.704938
# 1147  -6.167830 -218.833869     6.162973
#
#                                                    file
# 1002  ./sample_patients/1.3.6.1.4.1.14519.5.2.1.6279...
# 1003  ./sample_patients/1.3.6.1.4.1.14519.5.2.1.6279...
# 1145  ./sample_patients/1.3.6.1.4.1.14519.5.2.1.6279...
# 1146  ./sample_patients/1.3.6.1.4.1.14519.5.2.1.6279...
# 1147  ./sample_patients/1.3.6.1.4.1.14519.5.2.1.6279...

# %% [markdown]
# - 查看下数据量

# %%
print ('数据条数：%d' % df_node.shape[0])
# Out:
# 数据条数：9

# %% [markdown]
# - 一大坨函数

# %%
for fcount, img_file in enumerate(tqdm(file_list)):
    mini_df = df_node[df_node["file"]==img_file] #get all nodules associate with file
    if mini_df.shape[0]>0: # some files may not have a nodule--skipping those 
        # load the data once
        itk_img = sitk.ReadImage(img_file) 
        img_array = sitk.GetArrayFromImage(itk_img) # indexes are z,y,x (notice the ordering)
        num_z, height, width = img_array.shape        #heightXwidth constitute the transverse plane
        origin = np.array(itk_img.GetOrigin())      # x,y,z  Origin in world coordinates (mm)
        spacing = np.array(itk_img.GetSpacing())    # spacing of voxels in world coor. (mm)
        # go through all nodes (why just the biggest?)
        for node_idx, cur_row in mini_df.iterrows():       
            node_x = cur_row["coordX"]
            node_y = cur_row["coordY"]
            node_z = cur_row["coordZ"]
            diam = cur_row["diameter_mm"]
            # just keep 3 slices
            imgs = np.ndarray([3,height,width],dtype=np.float32)
            masks = np.ndarray([3,height,width],dtype=np.uint8)
            center = np.array([node_x, node_y, node_z])   # nodule center
            v_center = np.rint((center-origin)/spacing)  # nodule center in voxel space (still x,y,z ordering)
            for i, i_z in enumerate(np.arange(int(v_center[2])-1,
                             int(v_center[2])+2).clip(0, num_z-1)): # clip prevents going out of bounds in Z
                mask = make_mask(center, diam, i_z*spacing[2]+origin[2],
                                 width, height, spacing, origin)
                masks[i] = mask
                imgs[i] = img_array[i_z]
            np.save(os.path.join(output_path,"images_%04d_%04d.npy" % (fcount, node_idx)),imgs)
            np.save(os.path.join(output_path,"masks_%04d_%04d.npy" % (fcount, node_idx)),masks)
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  2.82it/s]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

imgs = np.load(output_path+'images_0000_1002.npy')
masks = np.load(output_path+'masks_0000_1002.npy')


for i in range(len(imgs)):
    print ("图片的第 %d 层" % i)
    fig,ax = plt.subplots(2,2,figsize=[8,8])
    ax[0,0].imshow(imgs[i],cmap='gray')#如果要看彩图，删除‘,cmap='gray'’
    ax[0,0].set_title(u'扫描切片')
    ax[0,1].imshow(masks[i],cmap='gray')
    ax[0,1].set_title(u'节点')
    ax[1,0].imshow(imgs[i]*masks[i],cmap='gray')
    ax[1,0].set_title(u'节点切片')
    plt.show()
    print ('\n\n')
#    raw_input("hit enter to cont : ")
# Out:
# 图片的第 0 层
# 图片的第 1 层
# 图片的第 2 层

# %%
f, plots = plt.subplots(11, 10, sharex='all', sharey='all', figsize=(10, 11))
# matplotlib is drunk

for i in range(110):
    plots[i // 10, i % 10].axis('off')
    plots[i // 10, i % 10].imshow(img_array[i], cmap=plt.cm.bone)

# %%
import matplotlib.animation as animation
from IPython.display import HTML


fig = plt.figure()
anim = plt.imshow(img_array[0], cmap=plt.cm.bone)
def update(i):
    anim.set_array(img_array[i])
    return anim
    
a = animation.FuncAnimation(fig, update, frames=range(len(img_array)), interval=50, blit=True)   


#HTML(a.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-f25b70de99f3> in <module>()
#       9     return anim
#      10
# ---> 11 a = animation.FuncAnimation(fig, update, frames=range(len(img_array)), interval=50, blit=True)
#      12
#      13
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/animation.pyc in __init__(self, fig, func, frames, init_func, fargs, save_count, **kwargs)
#    1460         self._save_seq = []
#    1461
# -> 1462         TimedAnimation.__init__(self, fig, **kwargs)
#    1463
#    1464         # Need to reset the saved seq, since right now it will contain data
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/animation.pyc in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1227
#    1228         Animation.__init__(self, fig, event_source=event_source,
# -> 1229                            *args, **kwargs)
#    1230
#    1231     def _step(self, *args):
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/animation.pyc in __init__(self, fig, event_source, blit)
#     817                                                       self._stop)
#     818         if self._blit:
# --> 819             self._setup_blit()
#     820
#     821     def _start(self, *args):
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/animation.pyc in _setup_blit(self)
#    1109         self._resize_id = self._fig.canvas.mpl_connect('resize_event',
#    1110                                                        self._handle_resize)
# -> 1111         self._post_draw(None, self._blit)
#    1112
#    1113     def _handle_resize(self, *args):
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/animation.pyc in _post_draw(self, framedata, blit)
#    1073             self._blit_draw(self._drawn_artists, self._blit_cache)
#    1074         else:
# -> 1075             self._fig.canvas.draw_idle()
#    1076
#    1077     # The rest of the code in this class is to facilitate easy blitting
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in draw_idle(self, *args, **kwargs)
#    2030         if not self._is_idle_drawing:
#    2031             with self._idle_draw_cntx():
# -> 2032                 self.draw(*args, **kwargs)
#    2033
#    2034     def draw_cursor(self, event):
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1148
#    1149         self._cachedRenderer = renderer
# -> 1150         self.canvas.draw_event(renderer)
#    1151
#    1152     def draw_artist(self, a):
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in draw_event(self, renderer)
#    1813         s = 'draw_event'
#    1814         event = DrawEvent(s, self, renderer)
# -> 1815         self.callbacks.process(s, event)
#    1816
#    1817     def resize_event(self):
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/cbook.pyc in process(self, s, *args, **kwargs)
#     547             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     548                 try:
# --> 549                     proxy(*args, **kwargs)
#     550                 except ReferenceError:
#     551                     self._remove_proxy(proxy)
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/cbook.pyc in __call__(self, *args, **kwargs)
#     414             mtd = self.func
#     415         # invoke the callable and return the result
# --> 416         return mtd(*args, **kwargs)
#     417
#     418     def __eq__(self, other):
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/animation.pyc in _start(self, *args)
#     829
#     830         # Now do any initial draw
# --> 831         self._init_draw()
#     832
#     833         # Add our callback for stepping the animation and
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/animation.pyc in _init_draw(self)
#    1488         # artists.
#    1489         if self._init_func is None:
# -> 1490             self._draw_frame(next(self.new_frame_seq()))
#    1491
#    1492         else:
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/matplotlib/animation.pyc in _draw_frame(self, framedata)
#    1515                     raise RuntimeError('The animation function must return a '
#    1516                                        'sequence of Artist objects.')
# -> 1517             for a in self._drawn_artists:
#    1518                 a.set_animated(self._blit)
#
# TypeError: 'AxesImage' object is not iterable

# %%
import matplotlib.animation as animation
def animate(pat):
    # Based on @Zombie's code
    fig = plt.figure()
    anim = plt.imshow(pat[0], cmap=plt.cm.bone)
    def update(i):
        anim.set_array(pat[i])
        return anim,
    
    a = animation.FuncAnimation(fig, update, frames=range(len(pat)), interval=50, blit=True)
    
a = animate(img_array)
HTML(a.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-94a33dee3837> in <module>()
#      11
#      12 a = animate(img_array)
# ---> 13 HTML(a.to_html5_video())
#
# AttributeError: 'NoneType' object has no attribute 'to_html5_video'
