# %%
from utils.imports import *
# Out:
# Using TensorFlow backend.

# %%
def get_net(input_shape, load_weight_path=None, features=False, mal=False):
    width = 64
    inputs = Input(shape=(1, 32, 32, 32), name="input_1")
    x = inputs
    x = AveragePooling3D(pool_size=(2, 1, 1), strides=(2, 1, 1), border_mode="same")(x)
    x = Convolution3D(width, 3, 3, 3, activation='relu', border_mode='same', name='conv1', subsample=(1, 1, 1))(x)
    x = MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2), border_mode='valid', name='pool1')(x)

    # 2nd layer group
    x = Convolution3D(width*2, 3, 3, 3, activation='relu', border_mode='same', name='conv2', subsample=(1, 1, 1))(x)
    x = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), border_mode='valid', name='pool2')(x)
    x = Dropout(p=0.3)(x)

    # 3rd layer group
    x = Convolution3D(width*4, 3, 3, 3, activation='relu', border_mode='same', name='conv3a', subsample=(1, 1, 1))(x)
    x = Convolution3D(width*4, 3, 3, 3, activation='relu', border_mode='same', name='conv3b', subsample=(1, 1, 1))(x)
    x = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), border_mode='valid', name='pool3')(x)
    x = Dropout(p=0.4)(x)

    # 4th layer group
    x = Convolution3D(width*8, 3, 3, 3, activation='relu', border_mode='same', name='conv4a', subsample=(1, 1, 1))(x)
    x = Convolution3D(width*8, 3, 3, 3, activation='relu', border_mode='same', name='conv4b', subsample=(1, 1, 1),)(x)
    x = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), border_mode='valid', name='pool4')(x)
    x = Dropout(p=0.5)(x)
       
    last64 = Convolution3D(64, 2, 2, 2, activation="relu", name="last_64")(x)
    out_class = Convolution3D(1, 1, 1, 1, activation="softmax", name="out_class_last")(last64)
    out_class = Flatten(name="out_class")(x)
    
    out_class = Dense(2)(out_class) 
    out_class = Activation('softmax')(out_class)
    
    model = Model(input=inputs, output=out_class)
    model.compile(optimizer=SGD(lr=1e-3, momentum=0.9, nesterov=True), loss='categorical_crossentropy', metrics=['accuracy'])
    #model.compile(optimizer=Adam(lr=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])   
    return model

# %%
output_path = PATH['cls_train_cube_30']
output_true = PATH['cls_train_cube_30_true']
output_false = PATH['cls_train_cube_30_false']
model_paths = PATH['model_paths']
model_final = PATH['model_final']

# %%
def get_dirfiles(dir):
    file_list = []
    subset_path = os.listdir(dir)
    for _ in range(len(subset_path)):
        if subset_path[_] != '.DS_Store':
            file_list.append(dir + subset_path[_])
    return file_list

def train_generator(output_true,output_false):
    train_nb = 28000    
    file_list_true = get_dirfiles(output_true)
    file_list_false = get_dirfiles(output_false)        
    file_list_true = np.random.choice(file_list_true, train_nb)
    file_list_false = np.random.choice(file_list_false, train_nb)    
    nb_true = len(file_list_true) + len(file_list_false)    
    sample = np.zeros([nb_true,32, 32, 32])
    labels = np.zeros([nb_true,2])
    for i in tqdm(range(len(file_list_true))):       
        cc= np.load(file_list_true[i])
        sample[i] = cc
        labels[i] = [0.,1.]
    for j in tqdm(range(len(file_list_false))):
        bb= np.load(file_list_false[j])
        sample[j+len(file_list_true)] = bb 
        labels[j+len(file_list_true)] = [1.,0.]
    sample = np.expand_dims(sample, axis=1)        
    return sample,labels


def fenlei_fit(name, load_check = False,batch_size=2, epochs=20,check_name = None):
    t = time.time()
    callbacks = [EarlyStopping(monitor='val_loss', patience = 10, verbose = 1),
                 ModelCheckpoint((model_paths + '{}.h5').format(name),
                                 monitor='val_loss',
                                 verbose = 0,
                                 save_best_only = True)]
    if load_check:
        check_model = (model_paths + '{}.h5').format(check_name)
        model = load_model(check_model)
    else:
        #model = classifier((1, 32, 32, 32),128,(3, 3, 3), (2, 2, 2))
        model = get_net((1, 32, 32, 32))
    x,y = train_generator(output_true,output_false)
    model.fit(x,y, batch_size=batch_size, epochs=epochs,
              validation_split=0.2,verbose=1, callbacks=callbacks, shuffle=True) 
    return model

# %%
fenlei_fit('Fenge_32_32_32_0703', load_check = False, batch_size=8, epochs=200, check_name = 'Fenge_32_32_32_0630')
# Out:
# 100%|██████████| 28000/28000 [08:44<00:00, 47.96it/s]
# 100%|██████████| 28000/28000 [15:38<00:00, 33.40it/s]
# Train on 44800 samples, validate on 11200 samples
# Epoch 1/200
# 44800/44800 [==============================] - 988s - loss: 0.0375 - acc: 0.9896 - val_loss: 0.0514 - val_acc: 0.9833
# Epoch 2/200
# 44800/44800 [==============================] - 991s - loss: 0.0265 - acc: 0.9925 - val_loss: 0.0470 - val_acc: 0.9864
# Epoch 3/200
# 44800/44800 [==============================] - 968s - loss: 0.0224 - acc: 0.9933 - val_loss: 0.0484 - val_acc: 0.9847
# Epoch 4/200
# 44800/44800 [==============================] - 969s - loss: 0.0180 - acc: 0.9943 - val_loss: 0.0299 - val_acc: 0.9916
# Epoch 5/200
# 44800/44800 [==============================] - 975s - loss: 0.0149 - acc: 0.9956 - val_loss: 0.0300 - val_acc: 0.9909
# Epoch 6/200
# 44800/44800 [==============================] - 931s - loss: 0.0129 - acc: 0.9958 - val_loss: 0.0457 - val_acc: 0.9900
# Epoch 7/200
# 44800/44800 [==============================] - 944s - loss: 0.0121 - acc: 0.9958 - val_loss: 0.0460 - val_acc: 0.9896
# Epoch 8/200
# 44800/44800 [==============================] - 942s - loss: 0.0105 - acc: 0.9965 - val_loss: 0.0621 - val_acc: 0.9852
# Epoch 9/200
# 44800/44800 [==============================] - 948s - loss: 0.0082 - acc: 0.9974 - val_loss: 0.0477 - val_acc: 0.9917
# Epoch 10/200
# 44800/44800 [==============================] - 957s - loss: 0.0087 - acc: 0.9970 - val_loss: 0.0510 - val_acc: 0.9878
# Epoch 00009: early stopping

# %%
file_list_true = get_dirfiles(output_true)
file_list_false = get_dirfiles(output_false)

# %%
#model_pred = classifier((1, 36, 36, 36), (3, 3, 3), (2, 2, 2))
model_pred = load_model(model_paths + 'Fenge_32_32_32_0630.h5')

# %%
file_list_true = np.random.choice(file_list_true, 1000)
file_list_false = np.random.choice(file_list_false, 1000)

# %%
cc = []
for i in file_list_false[0:200]:
    a=np.load(i)
    a=np.expand_dims(a,0)
    a=np.expand_dims(a,0)
    cc.append(model_pred.predict(a))
count = 0
for i in cc:
    if i[0][0] > 0.9:
        count += 1
print count*1.0/len(cc)
# Out:
# 0.97

# %%
cc
# Out:
# [array([[  9.99999523e-01,   4.68049279e-07]], dtype=float32),
#  array([[  9.99997258e-01,   2.72661828e-06]], dtype=float32),
#  array([[  1.00000000e+00,   8.58620819e-09]], dtype=float32),
#  array([[  1.00000000e+00,   5.55136110e-14]], dtype=float32),
#  array([[  1.00000000e+00,   2.34465358e-09]], dtype=float32),
#  array([[  9.99894023e-01,   1.06020452e-04]], dtype=float32),
#  array([[  1.00000000e+00,   7.33059746e-09]], dtype=float32),
#  array([[ 0.89103246,  0.1089676 ]], dtype=float32),
#  array([[ 0.08805914,  0.91194081]], dtype=float32),
#  array([[  9.99999881e-01,   1.50969456e-07]], dtype=float32),
#  array([[  9.99998212e-01,   1.83361919e-06]], dtype=float32),
#  array([[ 0.99725133,  0.00274861]], dtype=float32),
#  array([[  1.00000000e+00,   4.81499534e-08]], dtype=float32),
#  array([[  1.00000000e+00,   3.11621395e-09]], dtype=float32),
#  array([[  1.00000000e+00,   5.17385823e-09]], dtype=float32),
#  array([[  9.99997854e-01,   2.16580338e-06]], dtype=float32),
#  array([[ 0.9971137 ,  0.00288632]], dtype=float32),
#  array([[  1.00000000e+00,   1.59265712e-09]], dtype=float32),
#  array([[  1.00000000e+00,   2.10844835e-08]], dtype=float32),
#  array([[  1.00000000e+00,   1.42805212e-12]], dtype=float32),
#  array([[  9.99996543e-01,   3.47813534e-06]], dtype=float32),
#  array([[  9.99917746e-01,   8.22166330e-05]], dtype=float32),
#  array([[  9.99999523e-01,   4.36783637e-07]], dtype=float32),
#  array([[  9.99999523e-01,   5.11955193e-07]], dtype=float32),
#  array([[  9.99998212e-01,   1.76892593e-06]], dtype=float32),
#  array([[  9.99991298e-01,   8.66149639e-06]], dtype=float32),
#  array([[  9.99720275e-01,   2.79709726e-04]], dtype=float32),
#  array([[  9.99999881e-01,   6.53530989e-08]], dtype=float32),
#  array([[  1.00000000e+00,   1.96547448e-11]], dtype=float32),
#  array([[  1.00000000e+00,   1.46181725e-08]], dtype=float32),
#  array([[  9.99997377e-01,   2.65187600e-06]], dtype=float32),
#  array([[ 0.99331832,  0.00668163]], dtype=float32),
#  array([[  9.99999881e-01,   9.73115917e-08]], dtype=float32),
#  array([[  1.00000000e+00,   2.46286302e-09]], dtype=float32),
#  array([[  9.99999881e-01,   9.24741315e-08]], dtype=float32),
#  array([[  9.99957323e-01,   4.26463666e-05]], dtype=float32),
#  array([[  9.99994516e-01,   5.53098698e-06]], dtype=float32),
#  array([[ 0.45761743,  0.54238254]], dtype=float32),
#  array([[  1.00000000e+00,   8.83756179e-10]], dtype=float32),
#  array([[  1.00000000e+00,   1.16054111e-10]], dtype=float32),
#  array([[  9.99998212e-01,   1.75885793e-06]], dtype=float32),
#  array([[  9.99999881e-01,   1.73050367e-07]], dtype=float32),
#  array([[  9.99999762e-01,   2.94268062e-07]], dtype=float32),
#  array([[  9.99998689e-01,   1.30424519e-06]], dtype=float32),
#  array([[  1.00000000e+00,   3.82334306e-08]], dtype=float32),
#  array([[  9.99995708e-01,   4.24904283e-06]], dtype=float32),
#  array([[  1.00000000e+00,   5.08940834e-10]], dtype=float32),
#  array([[  1.00000000e+00,   2.20444352e-09]], dtype=float32),
#  array([[  9.99999285e-01,   7.18748311e-07]], dtype=float32),
#  array([[  9.99989986e-01,   1.00110956e-05]], dtype=float32),
#  array([[  1.00000000e+00,   3.03301539e-09]], dtype=float32),
#  array([[  1.00000000e+00,   9.16100529e-12]], dtype=float32),
#  array([[  9.99999285e-01,   7.56628481e-07]], dtype=float32),
#  array([[  1.00000000e+00,   4.98087349e-09]], dtype=float32),
#  array([[  9.99873877e-01,   1.26113780e-04]], dtype=float32),
#  array([[ 0.98516774,  0.01483221]], dtype=float32),
#  array([[  9.99944448e-01,   5.55863262e-05]], dtype=float32),
#  array([[  9.99993682e-01,   6.35443939e-06]], dtype=float32),
#  array([[  1.00000000e+00,   7.90314980e-10]], dtype=float32),
#  array([[  1.00000000e+00,   1.38839840e-09]], dtype=float32),
#  array([[  9.99998569e-01,   1.41856651e-06]], dtype=float32),
#  array([[  9.99986887e-01,   1.31071429e-05]], dtype=float32),
#  array([[  1.00000000e+00,   1.89336186e-10]], dtype=float32),
#  array([[  9.99999881e-01,   6.17081781e-08]], dtype=float32),
#  array([[  1.00000000e+00,   1.13535743e-11]], dtype=float32),
#  array([[  9.99966502e-01,   3.35543373e-05]], dtype=float32),
#  array([[  9.99940634e-01,   5.94160701e-05]], dtype=float32),
#  array([[  9.99999762e-01,   2.90904097e-07]], dtype=float32),
#  array([[  9.99999762e-01,   2.69109535e-07]], dtype=float32),
#  array([[  9.99994159e-01,   5.84302097e-06]], dtype=float32),
#  array([[  9.99993563e-01,   6.41394627e-06]], dtype=float32),
#  array([[  9.99993563e-01,   6.48741707e-06]], dtype=float32),
#  array([[  9.99999881e-01,   7.24153537e-08]], dtype=float32),
#  array([[  9.99999881e-01,   1.23749018e-07]], dtype=float32),
#  array([[  1.00000000e+00,   3.17576863e-08]], dtype=float32),
#  array([[  1.00000000e+00,   1.43532164e-08]], dtype=float32),
#  array([[  1.00000000e+00,   9.83574111e-10]], dtype=float32),
#  array([[  9.99989271e-01,   1.06765438e-05]], dtype=float32),
#  array([[  9.99960899e-01,   3.90576533e-05]], dtype=float32),
#  array([[ 0.99823976,  0.00176026]], dtype=float32),
#  array([[  9.99999046e-01,   9.22421009e-07]], dtype=float32),
#  array([[  1.00000000e+00,   2.13413731e-11]], dtype=float32),
#  array([[  9.99997854e-01,   2.13747853e-06]], dtype=float32),
#  array([[  9.99999642e-01,   3.69640077e-07]], dtype=float32),
#  array([[  1.00000000e+00,   1.26956978e-11]], dtype=float32),
#  array([[  1.00000000e+00,   1.05249121e-09]], dtype=float32),
#  array([[  1.00000000e+00,   3.32289964e-08]], dtype=float32),
#  array([[  9.99999762e-01,   2.20043546e-07]], dtype=float32),
#  array([[  9.99023318e-01,   9.76683921e-04]], dtype=float32),
#  array([[  9.99996901e-01,   3.08982453e-06]], dtype=float32),
#  array([[  9.99629259e-01,   3.70762456e-04]], dtype=float32),
#  array([[  9.99994993e-01,   5.00371880e-06]], dtype=float32),
#  array([[  1.00000000e+00,   2.60998889e-09]], dtype=float32),
#  array([[ 0.99834502,  0.00165504]], dtype=float32),
#  array([[  1.00000000e+00,   1.33328912e-08]], dtype=float32),
#  array([[  9.99999881e-01,   1.38979075e-07]], dtype=float32),
#  array([[  9.99891281e-01,   1.08730062e-04]], dtype=float32),
#  array([[  9.99999523e-01,   5.27027453e-07]], dtype=float32),
#  array([[  9.99968410e-01,   3.15446887e-05]], dtype=float32),
#  array([[  9.99974370e-01,   2.56609437e-05]], dtype=float32),
#  array([[ 0.99819416,  0.0018058 ]], dtype=float32),
#  array([[ 0.99855596,  0.0014441 ]], dtype=float32),
#  array([[  1.00000000e+00,   1.95759992e-10]], dtype=float32),
#  array([[  1.00000000e+00,   1.53822555e-08]], dtype=float32),
#  array([[  9.99998093e-01,   1.90836113e-06]], dtype=float32),
#  array([[  9.99997616e-01,   2.33074479e-06]], dtype=float32),
#  array([[  1.00000000e+00,   3.17347215e-09]], dtype=float32),
#  array([[  9.99997020e-01,   2.95373502e-06]], dtype=float32),
#  array([[  1.00000000e+00,   4.30211022e-09]], dtype=float32),
#  array([[  9.99998331e-01,   1.61378978e-06]], dtype=float32),
#  array([[  1.00000000e+00,   4.24086259e-08]], dtype=float32),
#  array([[ 0.99812251,  0.0018775 ]], dtype=float32),
#  array([[  1.00000000e+00,   3.38437167e-10]], dtype=float32),
#  array([[  1.00000000e+00,   2.02400222e-10]], dtype=float32),
#  array([[  1.00000000e+00,   3.82230070e-08]], dtype=float32),
#  array([[  1.00000000e+00,   1.25241355e-08]], dtype=float32),
#  array([[  1.00000000e+00,   2.26319030e-09]], dtype=float32),
#  array([[  1.00000000e+00,   2.50223078e-08]], dtype=float32),
#  array([[  9.99997973e-01,   2.05793935e-06]], dtype=float32),
#  array([[  1.00000000e+00,   6.86332491e-10]], dtype=float32),
#  array([[  9.99995947e-01,   4.00782574e-06]], dtype=float32),
#  array([[  9.99983072e-01,   1.68702391e-05]], dtype=float32),
#  array([[ 0.99823976,  0.00176024]], dtype=float32),
#  array([[  1.00000000e+00,   7.06891345e-09]], dtype=float32),
#  array([[  9.99998450e-01,   1.58867635e-06]], dtype=float32),
#  array([[  9.99999762e-01,   2.01915810e-07]], dtype=float32),
#  array([[  9.99998808e-01,   1.17317666e-06]], dtype=float32),
#  array([[  1.00000000e+00,   8.58556004e-11]], dtype=float32),
#  array([[  1.00000000e+00,   4.68071970e-10]], dtype=float32),
#  array([[  9.99739349e-01,   2.60605244e-04]], dtype=float32),
#  array([[  9.99413967e-01,   5.86037408e-04]], dtype=float32),
#  array([[  9.99997497e-01,   2.46110426e-06]], dtype=float32),
#  array([[  1.00000000e+00,   2.47987009e-09]], dtype=float32),
#  array([[  9.99415159e-01,   5.84841066e-04]], dtype=float32),
#  array([[  9.99980330e-01,   1.96565543e-05]], dtype=float32),
#  array([[  1.00000000e+00,   2.18730922e-09]], dtype=float32),
#  array([[  9.99995470e-01,   4.51792948e-06]], dtype=float32),
#  array([[  9.99999404e-01,   5.74031617e-07]], dtype=float32),
#  array([[  9.99999881e-01,   1.71832767e-07]], dtype=float32),
#  array([[  9.99945641e-01,   5.43726310e-05]], dtype=float32),
#  array([[  9.99998927e-01,   1.07465451e-06]], dtype=float32),
#  array([[  9.99925852e-01,   7.41293115e-05]], dtype=float32),
#  array([[  9.99948978e-01,   5.10529608e-05]], dtype=float32),
#  array([[  1.00000000e+00,   5.67633016e-08]], dtype=float32),
#  array([[  9.99999881e-01,   1.74477492e-07]], dtype=float32),
#  array([[  1.00000000e+00,   3.43493198e-08]], dtype=float32),
#  array([[  1.00000000e+00,   1.58438551e-09]], dtype=float32),
#  array([[  9.99997973e-01,   2.01487342e-06]], dtype=float32),
#  array([[ 0.0870072 ,  0.91299278]], dtype=float32),
#  array([[  9.99982953e-01,   1.70550720e-05]], dtype=float32),
#  array([[  9.99858379e-01,   1.41594588e-04]], dtype=float32),
#  array([[  9.99896765e-01,   1.03264967e-04]], dtype=float32),
#  array([[  9.99326468e-01,   6.73524803e-04]], dtype=float32),
#  array([[  1.00000000e+00,   3.22773492e-13]], dtype=float32),
#  array([[  9.99995351e-01,   4.61228137e-06]], dtype=float32),
#  array([[  9.99006212e-01,   9.93852271e-04]], dtype=float32),
#  array([[  9.99967456e-01,   3.25601213e-05]], dtype=float32),
#  array([[  9.99683619e-01,   3.16388643e-04]], dtype=float32),
#  array([[  9.99998569e-01,   1.43936199e-06]], dtype=float32),
#  array([[  1.00000000e+00,   2.63921884e-09]], dtype=float32),
#  array([[  9.99999523e-01,   4.46250453e-07]], dtype=float32),
#  array([[  9.99359429e-01,   6.40629791e-04]], dtype=float32),
#  array([[  1.00000000e+00,   1.71550063e-08]], dtype=float32),
#  array([[  9.99975324e-01,   2.46200871e-05]], dtype=float32),
#  array([[  1.00000000e+00,   4.40324177e-09]], dtype=float32),
#  array([[  9.99989867e-01,   1.01406422e-05]], dtype=float32),
#  array([[  1.00000000e+00,   8.40946965e-11]], dtype=float32),
#  array([[ 0.62232876,  0.3776713 ]], dtype=float32),
#  array([[  1.00000000e+00,   1.28455774e-10]], dtype=float32),
#  array([[  1.00000000e+00,   4.42536389e-11]], dtype=float32),
#  array([[  9.99999166e-01,   7.79467996e-07]], dtype=float32),
#  array([[  1.00000000e+00,   2.56507859e-09]], dtype=float32),
#  array([[  9.99953866e-01,   4.61239142e-05]], dtype=float32),
#  array([[  9.99999881e-01,   1.08701265e-07]], dtype=float32),
#  array([[  9.99999762e-01,   2.64115471e-07]], dtype=float32),
#  array([[  9.99743521e-01,   2.56423664e-04]], dtype=float32),
#  array([[  9.99513388e-01,   4.86644421e-04]], dtype=float32),
#  array([[  9.99988914e-01,   1.11408226e-05]], dtype=float32),
#  array([[  9.99999166e-01,   8.21567710e-07]], dtype=float32),
#  array([[  9.99992967e-01,   7.00127384e-06]], dtype=float32),
#  array([[  9.99999881e-01,   8.09939067e-08]], dtype=float32),
#  array([[  1.00000000e+00,   1.99071296e-13]], dtype=float32),
#  array([[  9.99996066e-01,   3.88686021e-06]], dtype=float32),
#  array([[  9.99998927e-01,   1.08326799e-06]], dtype=float32),
#  array([[  1.00000000e+00,   1.08281979e-08]], dtype=float32),
#  array([[  1.00000000e+00,   3.13883408e-09]], dtype=float32),
#  array([[  9.99999166e-01,   8.48379841e-07]], dtype=float32),
#  array([[  1.00000000e+00,   5.93240124e-09]], dtype=float32),
#  array([[  9.99974012e-01,   2.59529224e-05]], dtype=float32),
#  array([[  9.99879241e-01,   1.20794801e-04]], dtype=float32),
#  array([[  9.99989033e-01,   1.10140954e-05]], dtype=float32),
#  array([[  1.00000000e+00,   2.95261282e-09]], dtype=float32),
#  array([[ 0.99724424,  0.00275576]], dtype=float32),
#  array([[  1.00000000e+00,   9.08331022e-10]], dtype=float32),
#  array([[  1.00000000e+00,   8.48152715e-10]], dtype=float32),
#  array([[  9.99996066e-01,   3.97747954e-06]], dtype=float32),
#  array([[ 0.99842983,  0.00157008]], dtype=float32),
#  array([[  9.99999881e-01,   6.34600568e-08]], dtype=float32),
#  array([[ 0.46723923,  0.53276074]], dtype=float32),
#  array([[  9.99999881e-01,   6.01863519e-08]], dtype=float32)]

# %%
cc = []
for i in file_list_true[0:200]:
    a=np.load(i)
    a=np.expand_dims(a,0)
    a=np.expand_dims(a,0)
    cc.append(model_pred.predict(a))
count = 0

# %%
for i in cc:
    if i[0][1] > 0.9:
        count += 1
print count*1.0/len(cc)
# Out:
# 0.99

# %%
cc
# Out:
# [array([[  3.21987405e-04,   9.99678016e-01]], dtype=float32),
#  array([[  2.63426136e-05,   9.99973655e-01]], dtype=float32),
#  array([[  1.91890358e-04,   9.99808133e-01]], dtype=float32),
#  array([[ 0.01397893,  0.9860211 ]], dtype=float32),
#  array([[ 0.0345762 ,  0.96542382]], dtype=float32),
#  array([[ 0.01500209,  0.98499793]], dtype=float32),
#  array([[  5.45636158e-06,   9.99994516e-01]], dtype=float32),
#  array([[ 0.00188866,  0.99811137]], dtype=float32),
#  array([[ 0.01822281,  0.98177725]], dtype=float32),
#  array([[ 0.00660207,  0.99339795]], dtype=float32),
#  array([[  6.27507961e-06,   9.99993682e-01]], dtype=float32),
#  array([[ 0.002692  ,  0.99730802]], dtype=float32),
#  array([[ 0.0169616 ,  0.98303843]], dtype=float32),
#  array([[  3.50628207e-12,   1.00000000e+00]], dtype=float32),
#  array([[ 0.00948578,  0.99051428]], dtype=float32),
#  array([[  2.21714114e-08,   1.00000000e+00]], dtype=float32),
#  array([[ 0.07255231,  0.92744774]], dtype=float32),
#  array([[ 0.01442549,  0.98557448]], dtype=float32),
#  array([[  7.80243718e-04,   9.99219775e-01]], dtype=float32),
#  array([[ 0.02784438,  0.97215557]], dtype=float32),
#  array([[ 0.01777171,  0.98222834]], dtype=float32),
#  array([[  4.62552671e-05,   9.99953747e-01]], dtype=float32),
#  array([[  5.76664343e-06,   9.99994278e-01]], dtype=float32),
#  array([[ 0.01948255,  0.98051745]], dtype=float32),
#  array([[  5.26093529e-04,   9.99473870e-01]], dtype=float32),
#  array([[ 0.00936925,  0.99063081]], dtype=float32),
#  array([[ 0.01143399,  0.98856598]], dtype=float32),
#  array([[ 0.00544829,  0.99455172]], dtype=float32),
#  array([[  2.52013092e-06,   9.99997497e-01]], dtype=float32),
#  array([[ 0.00145316,  0.99854678]], dtype=float32),
#  array([[ 0.00132276,  0.99867719]], dtype=float32),
#  array([[  1.98536554e-06,   9.99997973e-01]], dtype=float32),
#  array([[ 0.0022728 ,  0.99772722]], dtype=float32),
#  array([[  2.84987027e-06,   9.99997139e-01]], dtype=float32),
#  array([[ 0.00806897,  0.99193102]], dtype=float32),
#  array([[  6.91081877e-05,   9.99930859e-01]], dtype=float32),
#  array([[ 0.06167548,  0.93832451]], dtype=float32),
#  array([[  6.60212754e-06,   9.99993443e-01]], dtype=float32),
#  array([[ 0.01453109,  0.98546892]], dtype=float32),
#  array([[ 0.0031288 ,  0.99687117]], dtype=float32),
#  array([[ 0.01288125,  0.98711872]], dtype=float32),
#  array([[  5.81885048e-04,   9.99418139e-01]], dtype=float32),
#  array([[ 0.00120718,  0.99879277]], dtype=float32),
#  array([[ 0.00978462,  0.99021542]], dtype=float32),
#  array([[ 0.03075329,  0.96924669]], dtype=float32),
#  array([[ 0.03873992,  0.96126008]], dtype=float32),
#  array([[ 0.11345481,  0.88654524]], dtype=float32),
#  array([[ 0.00774259,  0.99225748]], dtype=float32),
#  array([[ 0.01076353,  0.98923653]], dtype=float32),
#  array([[ 0.0254923 ,  0.97450769]], dtype=float32),
#  array([[ 0.00871348,  0.99128646]], dtype=float32),
#  array([[ 0.00277684,  0.99722314]], dtype=float32),
#  array([[  6.43120584e-05,   9.99935627e-01]], dtype=float32),
#  array([[ 0.19794796,  0.80205208]], dtype=float32),
#  array([[ 0.00808264,  0.99191731]], dtype=float32),
#  array([[ 0.03577177,  0.96422821]], dtype=float32),
#  array([[ 0.00440601,  0.99559397]], dtype=float32),
#  array([[  1.22996526e-05,   9.99987721e-01]], dtype=float32),
#  array([[ 0.0029308 ,  0.99706918]], dtype=float32),
#  array([[  9.66887397e-04,   9.99033093e-01]], dtype=float32),
#  array([[  3.56638629e-04,   9.99643326e-01]], dtype=float32),
#  array([[ 0.00314903,  0.99685103]], dtype=float32),
#  array([[  5.03727701e-04,   9.99496222e-01]], dtype=float32),
#  array([[ 0.01824458,  0.98175538]], dtype=float32),
#  array([[ 0.00177652,  0.99822348]], dtype=float32),
#  array([[ 0.01658425,  0.98341572]], dtype=float32),
#  array([[  1.59393028e-06,   9.99998450e-01]], dtype=float32),
#  array([[  1.35581449e-05,   9.99986410e-01]], dtype=float32),
#  array([[  1.50965991e-06,   9.99998450e-01]], dtype=float32),
#  array([[ 0.00226268,  0.99773729]], dtype=float32),
#  array([[ 0.006039  ,  0.99396098]], dtype=float32),
#  array([[ 0.001268  ,  0.99873203]], dtype=float32),
#  array([[ 0.01608067,  0.98391932]], dtype=float32),
#  array([[  4.87120851e-04,   9.99512911e-01]], dtype=float32),
#  array([[ 0.00992985,  0.99007016]], dtype=float32),
#  array([[ 0.00424373,  0.99575621]], dtype=float32),
#  array([[  1.86860543e-05,   9.99981284e-01]], dtype=float32),
#  array([[  3.87591572e-04,   9.99612391e-01]], dtype=float32),
#  array([[ 0.00319458,  0.99680543]], dtype=float32),
#  array([[ 0.01924232,  0.98075771]], dtype=float32),
#  array([[ 0.01110342,  0.98889661]], dtype=float32),
#  array([[ 0.01399562,  0.98600441]], dtype=float32),
#  array([[ 0.00152281,  0.99847716]], dtype=float32),
#  array([[ 0.02837547,  0.97162455]], dtype=float32),
#  array([[ 0.07300602,  0.92699403]], dtype=float32),
#  array([[ 0.00569727,  0.99430275]], dtype=float32),
#  array([[ 0.04545792,  0.95454204]], dtype=float32),
#  array([[  1.01202759e-05,   9.99989867e-01]], dtype=float32),
#  array([[ 0.00241819,  0.99758184]], dtype=float32),
#  array([[  3.75634409e-05,   9.99962449e-01]], dtype=float32),
#  array([[  4.88219521e-04,   9.99511838e-01]], dtype=float32),
#  array([[  1.10519868e-04,   9.99889493e-01]], dtype=float32),
#  array([[  4.88704572e-05,   9.99951124e-01]], dtype=float32),
#  array([[  7.76904199e-05,   9.99922276e-01]], dtype=float32),
#  array([[  6.82924816e-04,   9.99317050e-01]], dtype=float32),
#  array([[ 0.01977604,  0.98022401]], dtype=float32),
#  array([[ 0.00184515,  0.99815482]], dtype=float32),
#  array([[  7.08921114e-04,   9.99291062e-01]], dtype=float32),
#  array([[ 0.04511331,  0.95488667]], dtype=float32),
#  array([[ 0.01478828,  0.98521173]], dtype=float32),
#  array([[  3.31624295e-04,   9.99668360e-01]], dtype=float32),
#  array([[  5.13944997e-06,   9.99994874e-01]], dtype=float32),
#  array([[  5.61031513e-04,   9.99438941e-01]], dtype=float32),
#  array([[  2.14852989e-07,   9.99999762e-01]], dtype=float32),
#  array([[ 0.00151805,  0.99848193]], dtype=float32),
#  array([[ 0.00712443,  0.99287558]], dtype=float32),
#  array([[ 0.01681457,  0.98318547]], dtype=float32),
#  array([[  5.50868606e-07,   9.99999404e-01]], dtype=float32),
#  array([[ 0.00733093,  0.99266911]], dtype=float32),
#  array([[  6.15132449e-05,   9.99938488e-01]], dtype=float32),
#  array([[  8.35612736e-05,   9.99916434e-01]], dtype=float32),
#  array([[  1.06308260e-04,   9.99893665e-01]], dtype=float32),
#  array([[ 0.01004599,  0.98995399]], dtype=float32),
#  array([[ 0.04880374,  0.95119619]], dtype=float32),
#  array([[ 0.00248691,  0.99751306]], dtype=float32),
#  array([[ 0.00850914,  0.9914909 ]], dtype=float32),
#  array([[ 0.00138509,  0.99861491]], dtype=float32),
#  array([[  1.12496582e-06,   9.99998927e-01]], dtype=float32),
#  array([[ 0.0015519 ,  0.99844813]], dtype=float32),
#  array([[ 0.00284975,  0.99715024]], dtype=float32),
#  array([[  5.71476819e-04,   9.99428451e-01]], dtype=float32),
#  array([[  2.00872546e-05,   9.99979854e-01]], dtype=float32),
#  array([[ 0.02291388,  0.97708613]], dtype=float32),
#  array([[ 0.00200047,  0.99799949]], dtype=float32),
#  array([[  1.31125154e-04,   9.99868870e-01]], dtype=float32),
#  array([[ 0.03608315,  0.9639169 ]], dtype=float32),
#  array([[ 0.01450284,  0.98549718]], dtype=float32),
#  array([[  6.09376293e-05,   9.99939084e-01]], dtype=float32),
#  array([[ 0.03717741,  0.96282256]], dtype=float32),
#  array([[  3.31916749e-06,   9.99996662e-01]], dtype=float32),
#  array([[  1.38329241e-08,   1.00000000e+00]], dtype=float32),
#  array([[  1.50714215e-04,   9.99849319e-01]], dtype=float32),
#  array([[  3.69193789e-04,   9.99630809e-01]], dtype=float32),
#  array([[  6.58077042e-05,   9.99934196e-01]], dtype=float32),
#  array([[ 0.00460569,  0.99539435]], dtype=float32),
#  array([[  7.77311157e-04,   9.99222636e-01]], dtype=float32),
#  array([[ 0.05766915,  0.94233078]], dtype=float32),
#  array([[ 0.03979187,  0.96020818]], dtype=float32),
#  array([[  6.02449116e-04,   9.99397516e-01]], dtype=float32),
#  array([[  1.57118018e-04,   9.99842882e-01]], dtype=float32),
#  array([[  5.97333610e-07,   9.99999404e-01]], dtype=float32),
#  array([[ 0.00299886,  0.99700111]], dtype=float32),
#  array([[  7.36497634e-04,   9.99263465e-01]], dtype=float32),
#  array([[ 0.0024069,  0.9975931]], dtype=float32),
#  array([[ 0.01580225,  0.9841978 ]], dtype=float32),
#  array([[ 0.04222326,  0.95777673]], dtype=float32),
#  array([[ 0.00332827,  0.99667168]], dtype=float32),
#  array([[ 0.00565453,  0.99434549]], dtype=float32),
#  array([[  3.46251938e-04,   9.99653697e-01]], dtype=float32),
#  array([[ 0.03234287,  0.96765715]], dtype=float32),
#  array([[ 0.07952395,  0.92047608]], dtype=float32),
#  array([[ 0.001122  ,  0.99887794]], dtype=float32),
#  array([[  6.31152488e-07,   9.99999404e-01]], dtype=float32),
#  array([[ 0.00127123,  0.99872881]], dtype=float32),
#  array([[ 0.00118349,  0.99881649]], dtype=float32),
#  array([[ 0.01781671,  0.98218322]], dtype=float32),
#  array([[  5.48997079e-04,   9.99450982e-01]], dtype=float32),
#  array([[ 0.01242036,  0.98757964]], dtype=float32),
#  array([[  1.67825943e-04,   9.99832153e-01]], dtype=float32),
#  array([[  5.21619630e-04,   9.99478400e-01]], dtype=float32),
#  array([[  2.38247827e-04,   9.99761760e-01]], dtype=float32),
#  array([[  5.41226356e-04,   9.99458730e-01]], dtype=float32),
#  array([[ 0.00122259,  0.99877745]], dtype=float32),
#  array([[ 0.0024125 ,  0.99758756]], dtype=float32),
#  array([[  9.26250578e-08,   9.99999881e-01]], dtype=float32),
#  array([[ 0.00423756,  0.99576253]], dtype=float32),
#  array([[  1.28622778e-04,   9.99871373e-01]], dtype=float32),
#  array([[  4.68218968e-06,   9.99995351e-01]], dtype=float32),
#  array([[ 0.0029261 ,  0.99707389]], dtype=float32),
#  array([[ 0.01557451,  0.98442554]], dtype=float32),
#  array([[  6.23802293e-07,   9.99999404e-01]], dtype=float32),
#  array([[  6.99396332e-05,   9.99930024e-01]], dtype=float32),
#  array([[ 0.00495587,  0.99504411]], dtype=float32),
#  array([[  1.44593258e-07,   9.99999881e-01]], dtype=float32),
#  array([[  2.15769134e-04,   9.99784291e-01]], dtype=float32),
#  array([[  2.41219495e-05,   9.99975920e-01]], dtype=float32),
#  array([[  1.90799801e-05,   9.99980927e-01]], dtype=float32),
#  array([[ 0.00422753,  0.99577242]], dtype=float32),
#  array([[  2.91090255e-05,   9.99970913e-01]], dtype=float32),
#  array([[ 0.00621023,  0.99378973]], dtype=float32),
#  array([[  2.15660330e-04,   9.99784410e-01]], dtype=float32),
#  array([[ 0.00731886,  0.99268109]], dtype=float32),
#  array([[  1.25520382e-04,   9.99874473e-01]], dtype=float32),
#  array([[ 0.00465506,  0.99534494]], dtype=float32),
#  array([[ 0.08174589,  0.91825414]], dtype=float32),
#  array([[  2.18100979e-07,   9.99999762e-01]], dtype=float32),
#  array([[  2.95738209e-06,   9.99997020e-01]], dtype=float32),
#  array([[ 0.004551  ,  0.99544901]], dtype=float32),
#  array([[ 0.0081903 ,  0.99180967]], dtype=float32),
#  array([[  6.09962968e-04,   9.99390006e-01]], dtype=float32),
#  array([[ 0.00118848,  0.99881148]], dtype=float32),
#  array([[ 0.00421836,  0.99578166]], dtype=float32),
#  array([[ 0.00198086,  0.9980191 ]], dtype=float32),
#  array([[  5.05709759e-05,   9.99949455e-01]], dtype=float32),
#  array([[  1.51311201e-06,   9.99998450e-01]], dtype=float32),
#  array([[ 0.00260852,  0.99739146]], dtype=float32),
#  array([[  1.12765638e-05,   9.99988675e-01]], dtype=float32),
#  array([[  1.11317513e-06,   9.99998927e-01]], dtype=float32),
#  array([[  8.46678522e-05,   9.99915361e-01]], dtype=float32),
#  array([[ 0.00278887,  0.99721116]], dtype=float32)]
