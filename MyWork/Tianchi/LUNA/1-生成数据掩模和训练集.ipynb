# %%
luna_path = '/Volumes/solo/ali/'

# %% [markdown]
# # 设定模式：
#
# - nodules_2d：train_mask
#
# - valid:val_mask
#
# - test:test_mask

# %%
annotations_path = luna_path + 'csv/train/'
src = luna_path + 'Data/train/'
dst_nodules = luna_path + 'Data/train_mask/'

# %%
threshold_min = -1200
threshold_max = 600
height_mask = 512
width_mask = 512

# %%
import time
import gc
import os

import SimpleITK as sitk
import numpy as np
import csv
import scipy
from glob import glob
import pandas as pd
from scipy import ndimage
from tqdm import tqdm 
import pandas as pd

from skimage.morphology import ball, disk, dilation, binary_erosion, remove_small_objects, erosion, closing, reconstruction, binary_closing
from skimage.measure import label,regionprops, perimeter
from skimage.morphology import binary_dilation, binary_opening
from skimage.filters import roberts, sobel
from skimage import measure, feature
from skimage.segmentation import clear_border
from skimage import data
from scipy import ndimage
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import dicom
import scipy.misc
import numpy as np

import matplotlib.pyplot as plt
from joblib import Parallel, delayed
from numba import autojit
import zarr
from PIL import Image
import cv2
import scipy.spatial.distance as dist
import gc
import warnings
from solo.unet_utils import *
from solo.unet_models import *
from solo.preproc_utils import *
from solo.tianchi import *


import tensorflow as tf
from keras import backend as K
K.set_image_dim_ordering('th') 


#from inception_unet import *
np.random.seed(1337)



os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"


warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
def load_train():
    data_path = src
    folders = [x for x in os.listdir(data_path) if 'subset' in x]
    os.chdir(data_path)
    patients = []
    for i in folders:
        os.chdir(data_path + i)
        #print('Changing folder to: {}'.format(data_path + i))
        patient_ids = [x for x in os.listdir(data_path + i) if '.mhd' in x]
        for id in patient_ids:
            j = '{}/{}'.format(i, id)
            patients.append(j)
    return patients

def get_filename(file_list, case):
    for f in file_list:
        if case in f:
            return(f)
        
def plot_ct_scan(scan):
    f, plots = plt.subplots(int(scan.shape[0] / 20) + 1, 4, figsize=(25, 25))
    for i in range(0, scan.shape[0], 5):
        plots[int(i / 20), int((i % 20) / 5)].axis('off')
        plots[int(i / 20), int((i % 20) / 5)].imshow(scan[i], cmap=plt.cm.bone) 
         
def print_mask(lung_m, nodule_m):
    fig, ax = plt.subplots(1,2, figsize=(20,16))
    ax[0].imshow(lung_m, cmap = plt.cm.bone)
    ax[1].imshow(nodule_m, cmap = plt.cm.bone)
    return

def seq(start, stop, step=1):
    n = int(round((stop - start)/float(step)))
    if n > 1:
        return([start + step*i for i in range(n+1)])
    else:
        return([])
    
def load_itk(filename):
    itkimage = sitk.ReadImage(filename)
    numpyImage = sitk.GetArrayFromImage(itkimage)
    numpyOrigin = np.array(list(reversed(itkimage.GetOrigin())))
    numpySpacing = np.array(list(reversed(itkimage.GetSpacing())))
    return numpyImage, numpyOrigin, numpySpacing

def world_2_voxel(world_coordinates, origin, spacing):
    stretched_voxel_coordinates = np.absolute(world_coordinates - origin)
    voxel_coordinates = stretched_voxel_coordinates / spacing
    return voxel_coordinates

def voxel_2_world(voxel_coordinates, origin, spacing):
    stretched_voxel_coordinates = voxel_coordinates * spacing
    world_coordinates = stretched_voxel_coordinates + origin
    return world_coordinates

def get_pixels_hu(image):
    image = image.astype(np.int16)
    image[image == threshold_min] = 0
    return np.array(image, dtype=np.int16)

def get_nodule_slices(lung_mask, nodule_mask, lung_raw):
    indexes = np.unique(np.nonzero(nodule_mask)[0])
    #print('Nodule_present on slices: {}'.format(indexes))
    lung_mask_pres = lung_mask[indexes, :, :]
    nod_mask_pres = nodule_mask[indexes, :, :]
    lung_raw_pres = lung_raw[indexes, :, :]    
    return lung_mask_pres, nod_mask_pres, lung_raw_pres

def reshape_3d(image_3d):
    reshaped_img = image_3d.reshape([image_3d.shape[0], 1, 512, 512])
    #print('Reshaped image shape:', reshaped_img.shape)
    return reshaped_img



def create_masks_for_patient_watershed(img_file, save = True):
    def draw_nodule_mask(node_idx, cur_row):
        #print('Working on node: {}, row: {}'.format(node_idx, cur_row), '\n')
        coord_x = cur_row["coordX"]
        coord_y = cur_row["coordY"]
        coord_z = cur_row["coordZ"]
        diam = cur_row["diameter_mm"]
        radius = np.ceil(diam/2)
        noduleRange = seq(-radius, radius, RESIZE_SPACING[0])
        #print('Nodule range:', noduleRange)
        world_center = np.array((coord_z,coord_y,coord_x))   # nodule center
        voxel_center = world_2_voxel(world_center, origin, new_spacing)
        image_mask = np.zeros(lung_img.shape)
        for x in noduleRange:
            for y in noduleRange:
                for z in noduleRange:
                    coords = world_2_voxel(np.array((coord_z+z,coord_y+y,coord_x+x)),origin,new_spacing)
                    if (np.linalg.norm(voxel_center - coords) * RESIZE_SPACING[0]) < radius:
                        image_mask[int(np.round(coords[0])),int(np.round(coords[1])),int(np.round(coords[2]))] = int(1)
        #print(np.max(image_mask))    
      
        return image_mask

    print("Getting mask for image file {}".format(img_file))
    patient_id = img_file.split('/')[-1][:-4]
    mini_df = df_node[df_node["file"] == img_file]
    if mini_df.shape[0] > 0: # some files may not have a nodule--skipping those 
        img, origin, spacing = load_itk(src + img_file)
        height, width = img.shape[1], img.shape[2]
        #calculate resize factor
        RESIZE_SPACING = [1, 1, 1]
        resize_factor = spacing / RESIZE_SPACING
        new_real_shape = img.shape * resize_factor
        new_shape = np.round(new_real_shape)
        real_resize = new_shape / img.shape
        new_spacing = spacing / real_resize
        
        
        lung_img = scipy.ndimage.interpolation.zoom(img, real_resize)
        
        
        
        
        #print('Original image shape: {}'.format(img.shape))
        #print('Resized image shape: {}'.format(lung_img.shape))

        lung_img = get_pixels_hu(lung_img)
        #lung_mask = segment_lung_from_ct_scan(lung_img)
        #lung_mask[lung_mask >= threshold_max] = threshold_max
        #lung_img[lung_img >= threshold_max] = threshold_max
        #lung_img[lung_img == 0] = threshold_min
        
        
        
        lung_mask = lung_img.copy()
        #lung_mask[lung_mask == 0] = threshold_min
        lung_mask[lung_mask >= threshold_max] = threshold_max
        lung_img[lung_img >= threshold_max] = threshold_max
        
        lung_masks_512 = np.zeros([lung_img.shape[0], height_mask, width_mask], dtype = np.float32)
        nodule_masks_512 = np.zeros([lung_img.shape[0], height_mask, width_mask], dtype = np.float32)
        lung_masks_512[lung_masks_512 == 0] = threshold_min
        
        i = 0
        for node_idx, cur_row in mini_df.iterrows(): 
            nodule_mask = draw_nodule_mask(node_idx, cur_row)
            lung_img_512, lung_mask_512, nodule_mask_512 = np.zeros((lung_img.shape[0], 512, 512)), np.zeros((lung_mask.shape[0], 512, 512)), np.zeros((nodule_mask.shape[0], 512, 512))
            lung_mask_512[lung_mask_512 == 0] = threshold_min
            lung_img_512[lung_img_512 == 0] = threshold_min
            original_shape = lung_img.shape
            
            for z in range(lung_img.shape[0]):
                
                offset = (512 - original_shape[1])
                upper_offset = int(np.round(offset/2))
                lower_offset = int(offset - upper_offset)

                new_origin = voxel_2_world([-upper_offset,-lower_offset,0],origin,new_spacing)
                
                lung_img_512[z, upper_offset:-lower_offset,upper_offset:-lower_offset] = lung_img[z,:,:]
                lung_mask_512[z, upper_offset:-lower_offset,upper_offset:-lower_offset] = lung_mask[z,:,:]
                nodule_mask_512[z, upper_offset:-lower_offset,upper_offset:-lower_offset] = nodule_mask[z,:,:]
            nodule_masks_512 += nodule_mask_512

        #print('Offsets shape for node index {} - main: {}, upper: {}, lower: {}'.format(node_idx, offset, upper_offset, lower_offset), '\n')
      
       
        lung_mask_pres, nod_mask_pres, lung_raw_pres = get_nodule_slices(lung_mask_512, nodule_masks_512, lung_img_512)
        #print('Nodules present on slices: ', np.unique(np.nonzero(nodule_masks_512)[0]))
        
        
        
        del lung_mask_512, nodule_masks_512, lung_img_512
        gc.collect()
        
        lung_mask_pres = reshape_3d(lung_mask_pres)
        nod_mask_pres = reshape_3d(nod_mask_pres)
        lung_mask_pres[lung_mask_pres <= threshold_min] = threshold_min
        lung_mask_pres[lung_mask_pres >= threshold_max] = threshold_max
        
        lung_mask_preproc = my_PreProc(lung_mask_pres)
        lung_mask_preproc = lung_mask_preproc.astype(np.float32)
        nod_mask_pres = (nod_mask_pres > 0.0).astype(np.float32)
        nod_mask_pres[nod_mask_pres == 1.0] = 255.

        np.save('{}/lung_mask/{}.npy'.format(dst_nodules, patient_id), lung_mask_preproc)
        np.save('{}/nodule_mask/{}.npy'.format(dst_nodules, patient_id), nod_mask_pres)
        
        del lung_mask_pres, lung_mask_preproc, nod_mask_pres
        gc.collect()
            
        #return lung_mask_preproc, nod_mask_pres
        return
    else: 
        print('\n', 'No nodules found for patient: {}'.format(patient_id), '\n')
        return
        
def dir_check(luna_path):    
    if os.path.isdir(luna_path + 'Data/train_mask/'):
        pass
    else:
        os.mkdir(luna_path + 'Data/train_mask/')
        
    if os.path.isdir(luna_path + 'Data/train_mask/lung_mask/'):
        pass
    else:
        os.mkdir(luna_path + 'Data/train_mask/lung_mask/')

    if os.path.isdir(luna_path + 'Data/train_mask/nodule_mask/'):
        pass
    else:
        os.mkdir(luna_path + 'Data/train_mask/nodule_mask/')
        
    if os.path.isdir(luna_path + 'Data/test_mask/'):
        pass
    else:
        os.mkdir(luna_path + 'Data/test_mask/')

        
    if os.path.isdir(luna_path + 'Data/val_mask/lung_mask/'):
        pass
    else:
        os.mkdir(luna_path + 'Data/val_mask/lung_mask/')

    if os.path.isdir(luna_path + 'Data/val_mask/nodule_mask/'):
        pass
    else:
        os.mkdir(luna_path + 'Data/val_mask/nodule_mask/')

# %% [markdown]
# # 生成train数据

# %%
dir_check(luna_path)
patients = load_train()
df_node = pd.read_csv(annotations_path+"annotations.csv")
df_node["file"] = df_node["seriesuid"].map(lambda file_name: get_filename(patients, file_name))
df_node = df_node.dropna()

# %%
df_node
# Out:
#       seriesuid      coordX      coordY      coordZ  diameter_mm  \
# 0    LKDS-00001  -76.449879  -49.540571  229.500000    14.180405
# 1    LKDS-00003  -82.905787  106.263573  226.224976     5.200858
# 2    LKDS-00003  -92.705387  191.515214  228.724976     6.723286
# 3    LKDS-00004  -68.270833  209.412809  167.229885    22.517480
# 4    LKDS-00005 -147.952967 -164.169479 -273.434241     5.898208
# 5    LKDS-00007  -36.303583   68.367853   18.875000     6.347767
# 6    LKDS-00011   79.240951  105.062110 -170.126775     5.838910
# 7    LKDS-00013  -42.644951  -86.651939 -139.800002    15.884164
# 8    LKDS-00015  -61.142430  -93.778010   -3.200001     8.262994
# 9    LKDS-00016 -127.532989  -29.607902 -253.697616     8.269325
# 10   LKDS-00016   93.138882   -5.652615 -213.910615     6.209760
# 11   LKDS-00016   75.454504    7.903214 -194.368523     7.631709
# 12   LKDS-00019  -71.709390  -47.089729 -218.416849     4.506690
# 13   LKDS-00019   34.652929   18.541730  -79.084230     4.812693
# 14   LKDS-00020   66.590575   40.630257  127.500000     5.501401
# 15   LKDS-00020  -59.778725  -63.993566  133.750000     3.710569
# 16   LKDS-00020  -91.957005   59.896153  140.000000     9.309810
# 17   LKDS-00020 -112.355510   21.425644  161.250000     4.375346
# 18   LKDS-00020  -95.590115  -55.689101  176.250000     4.021434
# 19   LKDS-00020  117.026559   50.394807  205.000000     4.898830
# 20   LKDS-00020  -72.587675   10.522515   43.750000    22.376520
# 21   LKDS-00020  104.023240    0.912963   97.500000     4.552701
# 22   LKDS-00020   78.402520   -6.006865  100.000000     4.411916
# 23   LKDS-00020   88.982236  -25.433698  105.000000     4.293868
# 24   LKDS-00020  -87.824278  -19.166326  107.500000     5.172114
# 25   LKDS-00021  -96.106988  185.268880  544.100037     7.963035
# 26   LKDS-00023 -103.950427 -156.447323 -143.950652     5.194046
# 27   LKDS-00023   63.575350 -130.319172 -125.029684     4.387577
# 28   LKDS-00025 -124.669468   21.097098 -169.603976     6.731879
# 29   LKDS-00026   82.499680  -81.762469 -162.313272     4.206700
# ..          ...         ...         ...         ...          ...
# 945  LKDS-00964  -61.849471   15.779482 -113.597407     5.758007
# 946  LKDS-00964   55.391137   11.936578  -63.155121    13.736209
# 947  LKDS-00968   94.439356  212.116405  922.099976    24.525780
# 948  LKDS-00969  -70.260537  217.171155  315.525024     5.889871
# 949  LKDS-00970  -91.501150   -5.251185 -138.967421     5.413366
# 950  LKDS-00973   61.493255  230.315226  983.900085    26.701043
# 951  LKDS-00976  -32.108486  -30.265435 -219.578676     4.978983
# 952  LKDS-00976  -94.290183   70.674326 -253.256346     4.843420
# 953  LKDS-00976  133.983223   16.502436 -158.815894     5.674731
# 954  LKDS-00976  -16.016191   50.520947 -137.590344     4.907213
# 955  LKDS-00979  -52.501212 -167.049434 -239.900002    12.244973
# 956  LKDS-00981   42.574154   90.267552  -84.811060     5.916174
# 957  LKDS-00982  107.466107  131.220875  414.349976     5.985322
# 958  LKDS-00983  -79.247146  174.226243  981.090027    16.413009
# 959  LKDS-00984  -37.642123  212.224864  573.700012    11.006408
# 960  LKDS-00985   52.988396  199.384019 -471.099976     4.156682
# 961  LKDS-00989  -91.886719  164.785156  347.400024    10.768235
# 962  LKDS-00990   93.959583  182.810062 -519.166061     5.525559
# 963  LKDS-00990  -60.538320  148.054637 -648.371453     7.244055
# 964  LKDS-00991   61.149576   65.368350 -282.883805     8.815803
# 965  LKDS-00991  -82.509773   75.766696 -284.302722     6.765042
# 966  LKDS-00991   78.144945   84.694172 -181.038169     8.279652
# 967  LKDS-00991  129.660691   32.394915 -174.182537    11.369634
# 968  LKDS-00994  -58.644564   29.437956  -78.844092     8.742044
# 969  LKDS-00995   72.227071  -90.226588  181.499999    18.140449
# 970  LKDS-00996   97.955792   28.734844 -133.407946    12.167405
# 971  LKDS-00996   95.351139   50.214602 -139.266673    12.076178
# 972  LKDS-00997   55.340565   11.539587   61.500000    24.270031
# 973  LKDS-00998  -77.771604  -11.389945  -58.035362    16.721463
# 974  LKDS-01000  114.694950    7.839530  265.375000     4.999972
#
#                               file
# 0    train_subset00/LKDS-00001.mhd
# 1    train_subset00/LKDS-00003.mhd
# 2    train_subset00/LKDS-00003.mhd
# 3    train_subset00/LKDS-00004.mhd
# 4    train_subset00/LKDS-00005.mhd
# 5    train_subset00/LKDS-00007.mhd
# 6    train_subset00/LKDS-00011.mhd
# 7    train_subset00/LKDS-00013.mhd
# 8    train_subset00/LKDS-00015.mhd
# 9    train_subset00/LKDS-00016.mhd
# 10   train_subset00/LKDS-00016.mhd
# 11   train_subset00/LKDS-00016.mhd
# 12   train_subset00/LKDS-00019.mhd
# 13   train_subset00/LKDS-00019.mhd
# 14   train_subset00/LKDS-00020.mhd
# 15   train_subset00/LKDS-00020.mhd
# 16   train_subset00/LKDS-00020.mhd
# 17   train_subset00/LKDS-00020.mhd
# 18   train_subset00/LKDS-00020.mhd
# 19   train_subset00/LKDS-00020.mhd
# 20   train_subset00/LKDS-00020.mhd
# 21   train_subset00/LKDS-00020.mhd
# 22   train_subset00/LKDS-00020.mhd
# 23   train_subset00/LKDS-00020.mhd
# 24   train_subset00/LKDS-00020.mhd
# 25   train_subset00/LKDS-00021.mhd
# 26   train_subset00/LKDS-00023.mhd
# 27   train_subset00/LKDS-00023.mhd
# 28   train_subset00/LKDS-00025.mhd
# 29   train_subset00/LKDS-00026.mhd
# ..                             ...
# 945  train_subset14/LKDS-00964.mhd
# 946  train_subset14/LKDS-00964.mhd
# 947  train_subset14/LKDS-00968.mhd
# 948  train_subset14/LKDS-00969.mhd
# 949  train_subset14/LKDS-00970.mhd
# 950  train_subset14/LKDS-00973.mhd
# 951  train_subset14/LKDS-00976.mhd
# 952  train_subset14/LKDS-00976.mhd
# 953  train_subset14/LKDS-00976.mhd
# 954  train_subset14/LKDS-00976.mhd
# 955  train_subset14/LKDS-00979.mhd
# 956  train_subset14/LKDS-00981.mhd
# 957  train_subset14/LKDS-00982.mhd
# 958  train_subset14/LKDS-00983.mhd
# 959  train_subset14/LKDS-00984.mhd
# 960  train_subset14/LKDS-00985.mhd
# 961  train_subset14/LKDS-00989.mhd
# 962  train_subset14/LKDS-00990.mhd
# 963  train_subset14/LKDS-00990.mhd
# 964  train_subset14/LKDS-00991.mhd
# 965  train_subset14/LKDS-00991.mhd
# 966  train_subset14/LKDS-00991.mhd
# 967  train_subset14/LKDS-00991.mhd
# 968  train_subset14/LKDS-00994.mhd
# 969  train_subset14/LKDS-00995.mhd
# 970  train_subset14/LKDS-00996.mhd
# 971  train_subset14/LKDS-00996.mhd
# 972  train_subset14/LKDS-00997.mhd
# 973  train_subset14/LKDS-00998.mhd
# 974  train_subset14/LKDS-01000.mhd
#
# [975 rows x 6 columns]

# %%
patients
# Out:
# ['train_subset00/LKDS-00001.mhd',
#  'train_subset00/LKDS-00003.mhd',
#  'train_subset00/LKDS-00004.mhd',
#  'train_subset00/LKDS-00005.mhd',
#  'train_subset00/LKDS-00007.mhd',
#  'train_subset00/LKDS-00011.mhd',
#  'train_subset00/LKDS-00013.mhd',
#  'train_subset00/LKDS-00015.mhd',
#  'train_subset00/LKDS-00016.mhd',
#  'train_subset00/LKDS-00019.mhd',
#  'train_subset00/LKDS-00020.mhd',
#  'train_subset00/LKDS-00021.mhd',
#  'train_subset00/LKDS-00023.mhd',
#  'train_subset00/LKDS-00025.mhd',
#  'train_subset00/LKDS-00026.mhd',
#  'train_subset00/LKDS-00028.mhd',
#  'train_subset00/LKDS-00029.mhd',
#  'train_subset00/LKDS-00030.mhd',
#  'train_subset00/LKDS-00034.mhd',
#  'train_subset00/LKDS-00035.mhd',
#  'train_subset00/LKDS-00036.mhd',
#  'train_subset00/LKDS-00038.mhd',
#  'train_subset00/LKDS-00039.mhd',
#  'train_subset00/LKDS-00040.mhd',
#  'train_subset00/LKDS-00041.mhd',
#  'train_subset00/LKDS-00042.mhd',
#  'train_subset00/LKDS-00043.mhd',
#  'train_subset00/LKDS-00044.mhd',
#  'train_subset00/LKDS-00047.mhd',
#  'train_subset00/LKDS-00050.mhd',
#  'train_subset00/LKDS-00051.mhd',
#  'train_subset00/LKDS-00052.mhd',
#  'train_subset00/LKDS-00053.mhd',
#  'train_subset00/LKDS-00054.mhd',
#  'train_subset00/LKDS-00058.mhd',
#  'train_subset00/LKDS-00061.mhd',
#  'train_subset00/LKDS-00062.mhd',
#  'train_subset00/LKDS-00064.mhd',
#  'train_subset00/LKDS-00065.mhd',
#  'train_subset00/LKDS-00066.mhd',
#  'train_subset01/LKDS-00068.mhd',
#  'train_subset01/LKDS-00073.mhd',
#  'train_subset01/LKDS-00074.mhd',
#  'train_subset01/LKDS-00075.mhd',
#  'train_subset01/LKDS-00076.mhd',
#  'train_subset01/LKDS-00077.mhd',
#  'train_subset01/LKDS-00078.mhd',
#  'train_subset01/LKDS-00079.mhd',
#  'train_subset01/LKDS-00081.mhd',
#  'train_subset01/LKDS-00083.mhd',
#  'train_subset01/LKDS-00084.mhd',
#  'train_subset01/LKDS-00085.mhd',
#  'train_subset01/LKDS-00088.mhd',
#  'train_subset01/LKDS-00089.mhd',
#  'train_subset01/LKDS-00090.mhd',
#  'train_subset01/LKDS-00091.mhd',
#  'train_subset01/LKDS-00092.mhd',
#  'train_subset01/LKDS-00093.mhd',
#  'train_subset01/LKDS-00095.mhd',
#  'train_subset01/LKDS-00096.mhd',
#  'train_subset01/LKDS-00099.mhd',
#  'train_subset01/LKDS-00100.mhd',
#  'train_subset01/LKDS-00101.mhd',
#  'train_subset01/LKDS-00102.mhd',
#  'train_subset01/LKDS-00104.mhd',
#  'train_subset01/LKDS-00105.mhd',
#  'train_subset01/LKDS-00107.mhd',
#  'train_subset01/LKDS-00108.mhd',
#  'train_subset01/LKDS-00109.mhd',
#  'train_subset01/LKDS-00110.mhd',
#  'train_subset01/LKDS-00111.mhd',
#  'train_subset01/LKDS-00112.mhd',
#  'train_subset01/LKDS-00114.mhd',
#  'train_subset01/LKDS-00116.mhd',
#  'train_subset01/LKDS-00117.mhd',
#  'train_subset01/LKDS-00118.mhd',
#  'train_subset01/LKDS-00119.mhd',
#  'train_subset01/LKDS-00120.mhd',
#  'train_subset01/LKDS-00122.mhd',
#  'train_subset01/LKDS-00126.mhd',
#  'train_subset02/LKDS-00127.mhd',
#  'train_subset02/LKDS-00129.mhd',
#  'train_subset02/LKDS-00133.mhd',
#  'train_subset02/LKDS-00134.mhd',
#  'train_subset02/LKDS-00135.mhd',
#  'train_subset02/LKDS-00136.mhd',
#  'train_subset02/LKDS-00137.mhd',
#  'train_subset02/LKDS-00140.mhd',
#  'train_subset02/LKDS-00142.mhd',
#  'train_subset02/LKDS-00144.mhd',
#  'train_subset02/LKDS-00147.mhd',
#  'train_subset02/LKDS-00149.mhd',
#  'train_subset02/LKDS-00150.mhd',
#  'train_subset02/LKDS-00151.mhd',
#  'train_subset02/LKDS-00152.mhd',
#  'train_subset02/LKDS-00154.mhd',
#  'train_subset02/LKDS-00156.mhd',
#  'train_subset02/LKDS-00160.mhd',
#  'train_subset02/LKDS-00162.mhd',
#  'train_subset02/LKDS-00165.mhd',
#  'train_subset02/LKDS-00168.mhd',
#  'train_subset02/LKDS-00169.mhd',
#  'train_subset02/LKDS-00171.mhd',
#  'train_subset02/LKDS-00173.mhd',
#  'train_subset02/LKDS-00175.mhd',
#  'train_subset02/LKDS-00176.mhd',
#  'train_subset02/LKDS-00178.mhd',
#  'train_subset02/LKDS-00180.mhd',
#  'train_subset02/LKDS-00181.mhd',
#  'train_subset02/LKDS-00183.mhd',
#  'train_subset02/LKDS-00184.mhd',
#  'train_subset02/LKDS-00185.mhd',
#  'train_subset02/LKDS-00187.mhd',
#  'train_subset02/LKDS-00188.mhd',
#  'train_subset02/LKDS-00189.mhd',
#  'train_subset02/LKDS-00191.mhd',
#  'train_subset02/LKDS-00192.mhd',
#  'train_subset02/LKDS-00193.mhd',
#  'train_subset02/LKDS-00194.mhd',
#  'train_subset02/LKDS-00195.mhd',
#  'train_subset03/LKDS-00196.mhd',
#  'train_subset03/LKDS-00198.mhd',
#  'train_subset03/LKDS-00200.mhd',
#  'train_subset03/LKDS-00203.mhd',
#  'train_subset03/LKDS-00204.mhd',
#  'train_subset03/LKDS-00207.mhd',
#  'train_subset03/LKDS-00212.mhd',
#  'train_subset03/LKDS-00213.mhd',
#  'train_subset03/LKDS-00214.mhd',
#  'train_subset03/LKDS-00216.mhd',
#  'train_subset03/LKDS-00217.mhd',
#  'train_subset03/LKDS-00218.mhd',
#  'train_subset03/LKDS-00219.mhd',
#  'train_subset03/LKDS-00220.mhd',
#  'train_subset03/LKDS-00223.mhd',
#  'train_subset03/LKDS-00225.mhd',
#  'train_subset03/LKDS-00227.mhd',
#  'train_subset03/LKDS-00229.mhd',
#  'train_subset03/LKDS-00230.mhd',
#  'train_subset03/LKDS-00232.mhd',
#  'train_subset03/LKDS-00235.mhd',
#  'train_subset03/LKDS-00236.mhd',
#  'train_subset03/LKDS-00237.mhd',
#  'train_subset03/LKDS-00238.mhd',
#  'train_subset03/LKDS-00240.mhd',
#  'train_subset03/LKDS-00242.mhd',
#  'train_subset03/LKDS-00244.mhd',
#  'train_subset03/LKDS-00246.mhd',
#  'train_subset03/LKDS-00247.mhd',
#  'train_subset03/LKDS-00249.mhd',
#  'train_subset03/LKDS-00253.mhd',
#  'train_subset03/LKDS-00254.mhd',
#  'train_subset03/LKDS-00256.mhd',
#  'train_subset03/LKDS-00257.mhd',
#  'train_subset03/LKDS-00260.mhd',
#  'train_subset03/LKDS-00261.mhd',
#  'train_subset03/LKDS-00263.mhd',
#  'train_subset03/LKDS-00264.mhd',
#  'train_subset03/LKDS-00267.mhd',
#  'train_subset03/LKDS-00269.mhd',
#  'train_subset04/LKDS-00270.mhd',
#  'train_subset04/LKDS-00272.mhd',
#  'train_subset04/LKDS-00273.mhd',
#  'train_subset04/LKDS-00275.mhd',
#  'train_subset04/LKDS-00277.mhd',
#  'train_subset04/LKDS-00278.mhd',
#  'train_subset04/LKDS-00279.mhd',
#  'train_subset04/LKDS-00280.mhd',
#  'train_subset04/LKDS-00281.mhd',
#  'train_subset04/LKDS-00283.mhd',
#  'train_subset04/LKDS-00284.mhd',
#  'train_subset04/LKDS-00286.mhd',
#  'train_subset04/LKDS-00287.mhd',
#  'train_subset04/LKDS-00289.mhd',
#  'train_subset04/LKDS-00290.mhd',
#  'train_subset04/LKDS-00291.mhd',
#  'train_subset04/LKDS-00292.mhd',
#  'train_subset04/LKDS-00293.mhd',
#  'train_subset04/LKDS-00294.mhd',
#  'train_subset04/LKDS-00295.mhd',
#  'train_subset04/LKDS-00296.mhd',
#  'train_subset04/LKDS-00297.mhd',
#  'train_subset04/LKDS-00299.mhd',
#  'train_subset04/LKDS-00301.mhd',
#  'train_subset04/LKDS-00302.mhd',
#  'train_subset04/LKDS-00303.mhd',
#  'train_subset04/LKDS-00304.mhd',
#  'train_subset04/LKDS-00306.mhd',
#  'train_subset04/LKDS-00307.mhd',
#  'train_subset04/LKDS-00312.mhd',
#  'train_subset04/LKDS-00314.mhd',
#  'train_subset04/LKDS-00315.mhd',
#  'train_subset04/LKDS-00319.mhd',
#  'train_subset04/LKDS-00320.mhd',
#  'train_subset04/LKDS-00321.mhd',
#  'train_subset04/LKDS-00323.mhd',
#  'train_subset04/LKDS-00325.mhd',
#  'train_subset04/LKDS-00326.mhd',
#  'train_subset04/LKDS-00331.mhd',
#  'train_subset04/LKDS-00333.mhd',
#  'train_subset05/LKDS-00334.mhd',
#  'train_subset05/LKDS-00335.mhd',
#  'train_subset05/LKDS-00336.mhd',
#  'train_subset05/LKDS-00337.mhd',
#  'train_subset05/LKDS-00339.mhd',
#  'train_subset05/LKDS-00342.mhd',
#  'train_subset05/LKDS-00345.mhd',
#  'train_subset05/LKDS-00348.mhd',
#  'train_subset05/LKDS-00349.mhd',
#  'train_subset05/LKDS-00350.mhd',
#  'train_subset05/LKDS-00356.mhd',
#  'train_subset05/LKDS-00357.mhd',
#  'train_subset05/LKDS-00358.mhd',
#  'train_subset05/LKDS-00359.mhd',
#  'train_subset05/LKDS-00360.mhd',
#  'train_subset05/LKDS-00363.mhd',
#  'train_subset05/LKDS-00364.mhd',
#  'train_subset05/LKDS-00368.mhd',
#  'train_subset05/LKDS-00369.mhd',
#  'train_subset05/LKDS-00371.mhd',
#  'train_subset05/LKDS-00374.mhd',
#  'train_subset05/LKDS-00375.mhd',
#  'train_subset05/LKDS-00378.mhd',
#  'train_subset05/LKDS-00379.mhd',
#  'train_subset05/LKDS-00381.mhd',
#  'train_subset05/LKDS-00388.mhd',
#  'train_subset05/LKDS-00389.mhd',
#  'train_subset05/LKDS-00390.mhd',
#  'train_subset05/LKDS-00392.mhd',
#  'train_subset05/LKDS-00393.mhd',
#  'train_subset05/LKDS-00394.mhd',
#  'train_subset05/LKDS-00395.mhd',
#  'train_subset05/LKDS-00396.mhd',
#  'train_subset05/LKDS-00398.mhd',
#  'train_subset05/LKDS-00402.mhd',
#  'train_subset05/LKDS-00403.mhd',
#  'train_subset05/LKDS-00405.mhd',
#  'train_subset05/LKDS-00406.mhd',
#  'train_subset05/LKDS-00407.mhd',
#  'train_subset05/LKDS-00408.mhd',
#  'train_subset06/LKDS-00412.mhd',
#  'train_subset06/LKDS-00413.mhd',
#  'train_subset06/LKDS-00416.mhd',
#  'train_subset06/LKDS-00418.mhd',
#  'train_subset06/LKDS-00420.mhd',
#  'train_subset06/LKDS-00421.mhd',
#  'train_subset06/LKDS-00423.mhd',
#  'train_subset06/LKDS-00424.mhd',
#  'train_subset06/LKDS-00426.mhd',
#  'train_subset06/LKDS-00427.mhd',
#  'train_subset06/LKDS-00428.mhd',
#  'train_subset06/LKDS-00429.mhd',
#  'train_subset06/LKDS-00431.mhd',
#  'train_subset06/LKDS-00434.mhd',
#  'train_subset06/LKDS-00436.mhd',
#  'train_subset06/LKDS-00440.mhd',
#  'train_subset06/LKDS-00442.mhd',
#  'train_subset06/LKDS-00443.mhd',
#  'train_subset06/LKDS-00445.mhd',
#  'train_subset06/LKDS-00447.mhd',
#  'train_subset06/LKDS-00448.mhd',
#  'train_subset06/LKDS-00450.mhd',
#  'train_subset06/LKDS-00451.mhd',
#  'train_subset06/LKDS-00454.mhd',
#  'train_subset06/LKDS-00456.mhd',
#  'train_subset06/LKDS-00457.mhd',
#  'train_subset06/LKDS-00459.mhd',
#  'train_subset06/LKDS-00460.mhd',
#  'train_subset06/LKDS-00461.mhd',
#  'train_subset06/LKDS-00463.mhd',
#  'train_subset06/LKDS-00465.mhd',
#  'train_subset06/LKDS-00466.mhd',
#  'train_subset06/LKDS-00467.mhd',
#  'train_subset06/LKDS-00469.mhd',
#  'train_subset06/LKDS-00470.mhd',
#  'train_subset06/LKDS-00471.mhd',
#  'train_subset06/LKDS-00472.mhd',
#  'train_subset06/LKDS-00473.mhd',
#  'train_subset06/LKDS-00474.mhd',
#  'train_subset06/LKDS-00475.mhd',
#  'train_subset07/LKDS-00476.mhd',
#  'train_subset07/LKDS-00477.mhd',
#  'train_subset07/LKDS-00478.mhd',
#  'train_subset07/LKDS-00480.mhd',
#  'train_subset07/LKDS-00481.mhd',
#  'train_subset07/LKDS-00482.mhd',
#  'train_subset07/LKDS-00485.mhd',
#  'train_subset07/LKDS-00486.mhd',
#  'train_subset07/LKDS-00487.mhd',
#  'train_subset07/LKDS-00488.mhd',
#  'train_subset07/LKDS-00491.mhd',
#  'train_subset07/LKDS-00492.mhd',
#  'train_subset07/LKDS-00493.mhd',
#  'train_subset07/LKDS-00494.mhd',
#  'train_subset07/LKDS-00496.mhd',
#  'train_subset07/LKDS-00497.mhd',
#  'train_subset07/LKDS-00499.mhd',
#  'train_subset07/LKDS-00503.mhd',
#  'train_subset07/LKDS-00506.mhd',
#  'train_subset07/LKDS-00507.mhd',
#  'train_subset07/LKDS-00509.mhd',
#  'train_subset07/LKDS-00511.mhd',
#  'train_subset07/LKDS-00512.mhd',
#  'train_subset07/LKDS-00513.mhd',
#  'train_subset07/LKDS-00514.mhd',
#  'train_subset07/LKDS-00515.mhd',
#  'train_subset07/LKDS-00517.mhd',
#  'train_subset07/LKDS-00519.mhd',
#  'train_subset07/LKDS-00521.mhd',
#  'train_subset07/LKDS-00525.mhd',
#  'train_subset07/LKDS-00527.mhd',
#  'train_subset07/LKDS-00528.mhd',
#  'train_subset07/LKDS-00529.mhd',
#  'train_subset07/LKDS-00530.mhd',
#  'train_subset07/LKDS-00531.mhd',
#  'train_subset07/LKDS-00533.mhd',
#  'train_subset07/LKDS-00534.mhd',
#  'train_subset07/LKDS-00537.mhd',
#  'train_subset07/LKDS-00540.mhd',
#  'train_subset07/LKDS-00541.mhd',
#  'train_subset08/LKDS-00544.mhd',
#  'train_subset08/LKDS-00545.mhd',
#  'train_subset08/LKDS-00546.mhd',
#  'train_subset08/LKDS-00549.mhd',
#  'train_subset08/LKDS-00550.mhd',
#  'train_subset08/LKDS-00553.mhd',
#  'train_subset08/LKDS-00555.mhd',
#  'train_subset08/LKDS-00556.mhd',
#  'train_subset08/LKDS-00558.mhd',
#  'train_subset08/LKDS-00562.mhd',
#  'train_subset08/LKDS-00563.mhd',
#  'train_subset08/LKDS-00565.mhd',
#  'train_subset08/LKDS-00566.mhd',
#  'train_subset08/LKDS-00567.mhd',
#  'train_subset08/LKDS-00571.mhd',
#  'train_subset08/LKDS-00572.mhd',
#  'train_subset08/LKDS-00573.mhd',
#  'train_subset08/LKDS-00574.mhd',
#  'train_subset08/LKDS-00575.mhd',
#  'train_subset08/LKDS-00578.mhd',
#  'train_subset08/LKDS-00579.mhd',
#  'train_subset08/LKDS-00582.mhd',
#  'train_subset08/LKDS-00585.mhd',
#  'train_subset08/LKDS-00586.mhd',
#  'train_subset08/LKDS-00587.mhd',
#  'train_subset08/LKDS-00589.mhd',
#  'train_subset08/LKDS-00592.mhd',
#  'train_subset08/LKDS-00593.mhd',
#  'train_subset08/LKDS-00595.mhd',
#  'train_subset08/LKDS-00596.mhd',
#  'train_subset08/LKDS-00598.mhd',
#  'train_subset08/LKDS-00600.mhd',
#  'train_subset08/LKDS-00601.mhd',
#  'train_subset08/LKDS-00603.mhd',
#  'train_subset08/LKDS-00605.mhd',
#  'train_subset08/LKDS-00608.mhd',
#  'train_subset08/LKDS-00609.mhd',
#  'train_subset08/LKDS-00611.mhd',
#  'train_subset08/LKDS-00612.mhd',
#  'train_subset08/LKDS-00614.mhd',
#  'train_subset09/LKDS-00615.mhd',
#  'train_subset09/LKDS-00619.mhd',
#  'train_subset09/LKDS-00620.mhd',
#  'train_subset09/LKDS-00622.mhd',
#  'train_subset09/LKDS-00623.mhd',
#  'train_subset09/LKDS-00624.mhd',
#  'train_subset09/LKDS-00625.mhd',
#  'train_subset09/LKDS-00628.mhd',
#  'train_subset09/LKDS-00629.mhd',
#  'train_subset09/LKDS-00630.mhd',
#  'train_subset09/LKDS-00632.mhd',
#  'train_subset09/LKDS-00634.mhd',
#  'train_subset09/LKDS-00638.mhd',
#  'train_subset09/LKDS-00639.mhd',
#  'train_subset09/LKDS-00640.mhd',
#  'train_subset09/LKDS-00641.mhd',
#  'train_subset09/LKDS-00643.mhd',
#  'train_subset09/LKDS-00646.mhd',
#  'train_subset09/LKDS-00647.mhd',
#  'train_subset09/LKDS-00648.mhd',
#  'train_subset09/LKDS-00649.mhd',
#  'train_subset09/LKDS-00650.mhd',
#  'train_subset09/LKDS-00651.mhd',
#  'train_subset09/LKDS-00653.mhd',
#  'train_subset09/LKDS-00658.mhd',
#  'train_subset09/LKDS-00660.mhd',
#  'train_subset09/LKDS-00661.mhd',
#  'train_subset09/LKDS-00663.mhd',
#  'train_subset09/LKDS-00666.mhd',
#  'train_subset09/LKDS-00667.mhd',
#  'train_subset09/LKDS-00668.mhd',
#  'train_subset09/LKDS-00670.mhd',
#  'train_subset09/LKDS-00671.mhd',
#  'train_subset09/LKDS-00673.mhd',
#  'train_subset09/LKDS-00674.mhd',
#  'train_subset09/LKDS-00675.mhd',
#  'train_subset09/LKDS-00676.mhd',
#  'train_subset09/LKDS-00677.mhd',
#  'train_subset09/LKDS-00678.mhd',
#  'train_subset09/LKDS-00681.mhd',
#  'train_subset10/LKDS-00682.mhd',
#  'train_subset10/LKDS-00683.mhd',
#  'train_subset10/LKDS-00684.mhd',
#  'train_subset10/LKDS-00691.mhd',
#  'train_subset10/LKDS-00692.mhd',
#  'train_subset10/LKDS-00694.mhd',
#  'train_subset10/LKDS-00696.mhd',
#  'train_subset10/LKDS-00697.mhd',
#  'train_subset10/LKDS-00698.mhd',
#  'train_subset10/LKDS-00699.mhd',
#  'train_subset10/LKDS-00700.mhd',
#  'train_subset10/LKDS-00701.mhd',
#  'train_subset10/LKDS-00702.mhd',
#  'train_subset10/LKDS-00703.mhd',
#  'train_subset10/LKDS-00706.mhd',
#  'train_subset10/LKDS-00707.mhd',
#  'train_subset10/LKDS-00708.mhd',
#  'train_subset10/LKDS-00709.mhd',
#  'train_subset10/LKDS-00710.mhd',
#  'train_subset10/LKDS-00711.mhd',
#  'train_subset10/LKDS-00714.mhd',
#  'train_subset10/LKDS-00716.mhd',
#  'train_subset10/LKDS-00717.mhd',
#  'train_subset10/LKDS-00718.mhd',
#  'train_subset10/LKDS-00722.mhd',
#  'train_subset10/LKDS-00723.mhd',
#  'train_subset10/LKDS-00725.mhd',
#  'train_subset10/LKDS-00727.mhd',
#  'train_subset10/LKDS-00728.mhd',
#  'train_subset10/LKDS-00730.mhd',
#  'train_subset10/LKDS-00731.mhd',
#  'train_subset10/LKDS-00732.mhd',
#  'train_subset10/LKDS-00733.mhd',
#  'train_subset10/LKDS-00734.mhd',
#  'train_subset10/LKDS-00739.mhd',
#  'train_subset10/LKDS-00740.mhd',
#  'train_subset10/LKDS-00742.mhd',
#  'train_subset10/LKDS-00744.mhd',
#  'train_subset10/LKDS-00745.mhd',
#  'train_subset10/LKDS-00746.mhd',
#  'train_subset11/LKDS-00750.mhd',
#  'train_subset11/LKDS-00752.mhd',
#  'train_subset11/LKDS-00755.mhd',
#  'train_subset11/LKDS-00756.mhd',
#  'train_subset11/LKDS-00757.mhd',
#  'train_subset11/LKDS-00759.mhd',
#  'train_subset11/LKDS-00760.mhd',
#  'train_subset11/LKDS-00762.mhd',
#  'train_subset11/LKDS-00763.mhd',
#  'train_subset11/LKDS-00764.mhd',
#  'train_subset11/LKDS-00767.mhd',
#  'train_subset11/LKDS-00768.mhd',
#  'train_subset11/LKDS-00771.mhd',
#  'train_subset11/LKDS-00772.mhd',
#  'train_subset11/LKDS-00773.mhd',
#  'train_subset11/LKDS-00775.mhd',
#  'train_subset11/LKDS-00776.mhd',
#  'train_subset11/LKDS-00777.mhd',
#  'train_subset11/LKDS-00778.mhd',
#  'train_subset11/LKDS-00780.mhd',
#  'train_subset11/LKDS-00781.mhd',
#  'train_subset11/LKDS-00782.mhd',
#  'train_subset11/LKDS-00783.mhd',
#  'train_subset11/LKDS-00784.mhd',
#  'train_subset11/LKDS-00788.mhd',
#  'train_subset11/LKDS-00789.mhd',
#  'train_subset11/LKDS-00790.mhd',
#  'train_subset11/LKDS-00795.mhd',
#  'train_subset11/LKDS-00796.mhd',
#  'train_subset11/LKDS-00797.mhd',
#  'train_subset11/LKDS-00798.mhd',
#  'train_subset11/LKDS-00801.mhd',
#  'train_subset11/LKDS-00803.mhd',
#  'train_subset11/LKDS-00804.mhd',
#  'train_subset11/LKDS-00805.mhd',
#  'train_subset11/LKDS-00807.mhd',
#  'train_subset11/LKDS-00808.mhd',
#  'train_subset11/LKDS-00809.mhd',
#  'train_subset11/LKDS-00811.mhd',
#  'train_subset11/LKDS-00813.mhd',
#  'train_subset12/LKDS-00814.mhd',
#  'train_subset12/LKDS-00815.mhd',
#  'train_subset12/LKDS-00816.mhd',
#  'train_subset12/LKDS-00817.mhd',
#  'train_subset12/LKDS-00819.mhd',
#  'train_subset12/LKDS-00820.mhd',
#  'train_subset12/LKDS-00821.mhd',
#  'train_subset12/LKDS-00823.mhd',
#  'train_subset12/LKDS-00824.mhd',
#  'train_subset12/LKDS-00825.mhd',
#  'train_subset12/LKDS-00826.mhd',
#  'train_subset12/LKDS-00827.mhd',
#  'train_subset12/LKDS-00829.mhd',
#  'train_subset12/LKDS-00830.mhd',
#  'train_subset12/LKDS-00831.mhd',
#  'train_subset12/LKDS-00832.mhd',
#  'train_subset12/LKDS-00833.mhd',
#  'train_subset12/LKDS-00834.mhd',
#  'train_subset12/LKDS-00835.mhd',
#  'train_subset12/LKDS-00836.mhd',
#  'train_subset12/LKDS-00837.mhd',
#  'train_subset12/LKDS-00838.mhd',
#  'train_subset12/LKDS-00839.mhd',
#  'train_subset12/LKDS-00841.mhd',
#  'train_subset12/LKDS-00843.mhd',
#  'train_subset12/LKDS-00844.mhd',
#  'train_subset12/LKDS-00845.mhd',
#  'train_subset12/LKDS-00846.mhd',
#  'train_subset12/LKDS-00847.mhd',
#  'train_subset12/LKDS-00848.mhd',
#  'train_subset12/LKDS-00852.mhd',
#  'train_subset12/LKDS-00855.mhd',
#  'train_subset12/LKDS-00856.mhd',
#  'train_subset12/LKDS-00857.mhd',
#  'train_subset12/LKDS-00859.mhd',
#  'train_subset12/LKDS-00862.mhd',
#  'train_subset12/LKDS-00863.mhd',
#  'train_subset12/LKDS-00865.mhd',
#  'train_subset12/LKDS-00866.mhd',
#  'train_subset12/LKDS-00867.mhd',
#  'train_subset13/LKDS-00868.mhd',
#  'train_subset13/LKDS-00870.mhd',
#  'train_subset13/LKDS-00873.mhd',
#  'train_subset13/LKDS-00875.mhd',
#  'train_subset13/LKDS-00876.mhd',
#  'train_subset13/LKDS-00878.mhd',
#  'train_subset13/LKDS-00879.mhd',
#  'train_subset13/LKDS-00880.mhd',
#  'train_subset13/LKDS-00882.mhd',
#  'train_subset13/LKDS-00884.mhd',
#  'train_subset13/LKDS-00885.mhd',
#  'train_subset13/LKDS-00886.mhd',
#  'train_subset13/LKDS-00887.mhd',
#  'train_subset13/LKDS-00888.mhd',
#  'train_subset13/LKDS-00890.mhd',
#  'train_subset13/LKDS-00891.mhd',
#  'train_subset13/LKDS-00892.mhd',
#  'train_subset13/LKDS-00893.mhd',
#  'train_subset13/LKDS-00894.mhd',
#  'train_subset13/LKDS-00896.mhd',
#  'train_subset13/LKDS-00897.mhd',
#  'train_subset13/LKDS-00898.mhd',
#  'train_subset13/LKDS-00899.mhd',
#  'train_subset13/LKDS-00900.mhd',
#  'train_subset13/LKDS-00901.mhd',
#  'train_subset13/LKDS-00904.mhd',
#  'train_subset13/LKDS-00906.mhd',
#  'train_subset13/LKDS-00911.mhd',
#  'train_subset13/LKDS-00912.mhd',
#  'train_subset13/LKDS-00914.mhd',
#  'train_subset13/LKDS-00915.mhd',
#  'train_subset13/LKDS-00917.mhd',
#  'train_subset13/LKDS-00918.mhd',
#  'train_subset13/LKDS-00919.mhd',
#  'train_subset13/LKDS-00921.mhd',
#  'train_subset13/LKDS-00923.mhd',
#  'train_subset13/LKDS-00924.mhd',
#  'train_subset13/LKDS-00930.mhd',
#  'train_subset13/LKDS-00931.mhd',
#  'train_subset13/LKDS-00933.mhd',
#  'train_subset14/LKDS-00935.mhd',
#  'train_subset14/LKDS-00936.mhd',
#  'train_subset14/LKDS-00937.mhd',
#  'train_subset14/LKDS-00939.mhd',
#  'train_subset14/LKDS-00941.mhd',
#  'train_subset14/LKDS-00942.mhd',
#  'train_subset14/LKDS-00944.mhd',
#  'train_subset14/LKDS-00945.mhd',
#  'train_subset14/LKDS-00946.mhd',
#  'train_subset14/LKDS-00948.mhd',
#  'train_subset14/LKDS-00949.mhd',
#  'train_subset14/LKDS-00950.mhd',
#  'train_subset14/LKDS-00951.mhd',
#  'train_subset14/LKDS-00953.mhd',
#  'train_subset14/LKDS-00954.mhd',
#  'train_subset14/LKDS-00956.mhd',
#  'train_subset14/LKDS-00957.mhd',
#  'train_subset14/LKDS-00961.mhd',
#  'train_subset14/LKDS-00962.mhd',
#  'train_subset14/LKDS-00964.mhd',
#  'train_subset14/LKDS-00968.mhd',
#  'train_subset14/LKDS-00969.mhd',
#  'train_subset14/LKDS-00970.mhd',
#  'train_subset14/LKDS-00973.mhd',
#  'train_subset14/LKDS-00976.mhd',
#  'train_subset14/LKDS-00979.mhd',
#  'train_subset14/LKDS-00981.mhd',
#  'train_subset14/LKDS-00982.mhd',
#  'train_subset14/LKDS-00983.mhd',
#  'train_subset14/LKDS-00984.mhd',
#  'train_subset14/LKDS-00985.mhd',
#  'train_subset14/LKDS-00989.mhd',
#  'train_subset14/LKDS-00990.mhd',
#  'train_subset14/LKDS-00991.mhd',
#  'train_subset14/LKDS-00994.mhd',
#  'train_subset14/LKDS-00995.mhd',
#  'train_subset14/LKDS-00996.mhd',
#  'train_subset14/LKDS-00997.mhd',
#  'train_subset14/LKDS-00998.mhd',
#  'train_subset14/LKDS-01000.mhd']

# %%
Parallel(n_jobs=5)(delayed(create_masks_for_patient_watershed)(patient) for patient in sorted(patients))
print 'done'

# %% [markdown]
# # 生成valid数据

# %%
annotations_path = luna_path + 'csv/val/'
src = luna_path + 'Data/val/'
dst_nodules = luna_path + 'Data/val_mask/'

# %%
dir_check(luna_path)
patients = load_train()
df_node = pd.read_csv(annotations_path+"annotations.csv")
df_node["file"] = df_node["seriesuid"].map(lambda file_name: get_filename(patients, file_name))
df_node = df_node.dropna()

Parallel(n_jobs=5)(delayed(create_masks_for_patient_watershed)(patient) for patient in sorted(patients))
print 'done'

# %% [markdown]
# # 生成test数据

# %%
annotations_path = luna_path + 'csv/test/'
src = luna_path + 'Data/test/'
dst_nodules = luna_path + 'Data/test_mask/'
patients = load_train()

# %%
patients

# %%
coord_x = []
coord_y = []
coord_z = []
diam = []
patient_id = []

for img_file in tqdm(patients):
    patient_id_ = img_file.split('/')[-1][:-4]
    img, origin, spacing = load_itk(src + img_file)   
    
    RESIZE_SPACING = [1, 1, 1]
    resize_factor = spacing / RESIZE_SPACING
    new_real_shape = img.shape * resize_factor
    new_shape = np.round(new_real_shape)
    real_resize = new_shape / img.shape
    new_spacing = spacing / real_resize
    
    world_center = np.array((img.shape[2],img.shape[1],img.shape[0]))   # nodule center
    voxel_center = world_2_voxel(world_center, origin, new_spacing)
    
    coord_x.append(img.shape[0]/2)
    coord_y.append(img.shape[1]/2)
    coord_z.append(img.shape[2]/2)
    diam.append(voxel_center[0])
    patient_id.append(patient_id_)
    
df_node = pd.DataFrame({'seriesuid':patient_id,
             'coordX':coord_x,
             'coordY':coord_y ,
             'coordZ':coord_z,
             'diameter_mm':diam,
             'file':patients})
df_node = df_node [['seriesuid','coordX','coordY','coordZ','diameter_mm','file']]

# %%
df_node.to_csv('/Volumes/solo/ali/csv/test/temp.csv',index=None)
df_node = pd.read_csv('/Volumes/solo/ali/csv/test/temp.csv',index_col=None)

# %%
def create_masks_for_patient_watershed1(img_file, save = True):
    

    print("Getting mask for image file {}".format(img_file))
    patient_id = img_file.split('/')[-1][:-4]
    mini_df = df_node[df_node["file"] == img_file]
    if mini_df.shape[0] > 0: # some files may not have a nodule--skipping those 
        img, origin, spacing = load_itk(src + img_file)
        height, width = img.shape[1], img.shape[2]
        #calculate resize factor
        RESIZE_SPACING = [1, 1, 1]
        resize_factor = spacing / RESIZE_SPACING
        new_real_shape = img.shape * resize_factor
        new_shape = np.round(new_real_shape)
        real_resize = new_shape / img.shape
        new_spacing = spacing / real_resize
        
        
        lung_img = scipy.ndimage.interpolation.zoom(img, real_resize)
        
        
        
        
        #print('Original image shape: {}'.format(img.shape))
        #print('Resized image shape: {}'.format(lung_img.shape))

        lung_img = get_pixels_hu(lung_img)
        #lung_mask = segment_lung_from_ct_scan(lung_img)
        #lung_mask[lung_mask >= threshold_max] = threshold_max
        #lung_img[lung_img >= threshold_max] = threshold_max
        #lung_img[lung_img == 0] = threshold_min
        
        
        
        lung_mask = lung_img.copy()
        #lung_mask[lung_mask == 0] = threshold_min
        lung_mask[lung_mask >= threshold_max] = threshold_max
        lung_img[lung_img >= threshold_max] = threshold_max
        
        lung_masks_512 = np.zeros([lung_img.shape[0], height_mask, width_mask], dtype = np.float32)
        nodule_masks_512 = np.zeros([lung_img.shape[0], height_mask, width_mask], dtype = np.float32)
        lung_masks_512[lung_masks_512 == 0] = threshold_min
        
        i = 0

        nodule_mask = np.ones(lung_img.shape)
        #print('nodule_mask shape: {}'.format(nodule_mask.shape))
        lung_img_512, lung_mask_512, nodule_mask_512 = np.zeros((lung_img.shape[0], 512, 512)), np.zeros((lung_mask.shape[0], 512, 512)), np.zeros((nodule_mask.shape[0], 512, 512))
        lung_mask_512[lung_mask_512 == 0] = threshold_min
        lung_img_512[lung_img_512 == 0] = threshold_min
        original_shape = lung_img.shape
            
        for z in range(lung_img.shape[0]):
                
            offset = (512 - original_shape[1])
            upper_offset = int(np.round(offset/2))
            lower_offset = int(offset - upper_offset)

            new_origin = voxel_2_world([-upper_offset,-lower_offset,0],origin,new_spacing)
                
            lung_img_512[z, upper_offset:-lower_offset,upper_offset:-lower_offset] = lung_img[z,:,:]
            lung_mask_512[z, upper_offset:-lower_offset,upper_offset:-lower_offset] = lung_mask[z,:,:]
            nodule_mask_512[z, upper_offset:-lower_offset,upper_offset:-lower_offset] = nodule_mask[z,:,:]
        nodule_masks_512 += nodule_mask_512
        #print('Offsets shape for node index {} - main: {}, upper: {}, lower: {}'.format(node_idx, offset, upper_offset, lower_offset), '\n')
      
        #print('nodule_masks_512 shape: {}'.format(nodule_masks_512.shape))
        
        lung_mask_pres, nod_mask_pres, lung_raw_pres = get_nodule_slices(lung_mask_512, nodule_masks_512, lung_img_512)
        #print('Nodules present on slices: ', np.unique(np.nonzero(nodule_masks_512)[0]))
        
        
        
        del lung_mask_512, nodule_masks_512, lung_img_512
        gc.collect()
        
        lung_mask_pres = reshape_3d(lung_mask_pres)
        nod_mask_pres = reshape_3d(nod_mask_pres)
        lung_mask_pres[lung_mask_pres <= threshold_min] = threshold_min
        lung_mask_pres[lung_mask_pres >= threshold_max] = threshold_max
        
        lung_mask_preproc = my_PreProc(lung_mask_pres)
        lung_mask_preproc = lung_mask_preproc.astype(np.float32)
        nod_mask_pres = (nod_mask_pres > 0.0).astype(np.float32)
        nod_mask_pres[nod_mask_pres == 1.0] = 255.

        np.save('{}/pre_lung_mask/{}.npy'.format(dst_nodules, patient_id), lung_mask_preproc)
        #np.save('{}/nodule_mask/{}.npy'.format(dst_nodules, patient_id), nod_mask_pres)
        
        del lung_mask_pres, lung_mask_preproc, nod_mask_pres
        gc.collect()
            
        #return lung_mask_preproc, nod_mask_pres
        return
    else: 
        print('\n', 'No nodules found for patient: {}'.format(patient_id), '\n')
        return

# %%
Parallel(n_jobs=5)(delayed(create_masks_for_patient_watershed1)(patient) for patient in sorted(patients))
print 'done'
