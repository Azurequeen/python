# %%
luna_path = '/Volumes/solo/ali/'

annotations_path = luna_path + 'csv/train/'
src = luna_path + 'Data/train/'
dst_nodules = luna_path + 'Data/nodules_2d/'

# %%
import time
import gc
import os

import SimpleITK as sitk
import numpy as np
import csv
import scipy
from glob import glob
import pandas as pd
from scipy import ndimage
from tqdm import tqdm 
import pandas as pd

from skimage.morphology import ball, disk, dilation, binary_erosion, remove_small_objects, erosion, closing, reconstruction, binary_closing
from skimage.measure import label,regionprops, perimeter
from skimage.morphology import binary_dilation, binary_opening
from skimage.filters import roberts, sobel
from skimage import measure, feature
from skimage.segmentation import clear_border
from skimage import data
from scipy import ndimage
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import dicom
import scipy.misc
import numpy as np

import matplotlib.pyplot as plt
from joblib import Parallel, delayed
from numba import autojit
import zarr
from PIL import Image
import cv2
import scipy.spatial.distance as dist
import gc
import warnings
from solo.unet_utils import *
from solo.unet_models import *
from solo.preproc_utils import *
from solo.tianchi import *


import tensorflow as tf
from keras import backend as K
K.set_image_dim_ordering('th') 


#from inception_unet import *
np.random.seed(1337)



os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"


warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
def load_train():
    data_path = src
    folders = [x for x in os.listdir(data_path) if 'subset' in x]
    os.chdir(data_path)
    patients = []
    for i in folders:
        os.chdir(data_path + i)
        #print('Changing folder to: {}'.format(data_path + i))
        patient_ids = [x for x in os.listdir(data_path + i) if '.mhd' in x]
        for id in patient_ids:
            j = '{}/{}'.format(i, id)
            patients.append(j)
    return patients

def get_filename(file_list, case):
    for f in file_list:
        if case in f:
            return(f)
        
def plot_ct_scan(scan):
    f, plots = plt.subplots(int(scan.shape[0] / 20) + 1, 4, figsize=(25, 25))
    for i in range(0, scan.shape[0], 5):
        plots[int(i / 20), int((i % 20) / 5)].axis('off')
        plots[int(i / 20), int((i % 20) / 5)].imshow(scan[i], cmap=plt.cm.bone) 
         
def print_mask(lung_m, nodule_m):
    fig, ax = plt.subplots(1,2, figsize=(20,16))
    ax[0].imshow(lung_m, cmap = plt.cm.bone)
    ax[1].imshow(nodule_m, cmap = plt.cm.bone)
    return

def seq(start, stop, step=1):
    n = int(round((stop - start)/float(step)))
    if n > 1:
        return([start + step*i for i in range(n+1)])
    else:
        return([])
    
def load_itk(filename):
    itkimage = sitk.ReadImage(filename)
    numpyImage = sitk.GetArrayFromImage(itkimage)
    numpyOrigin = np.array(list(reversed(itkimage.GetOrigin())))
    numpySpacing = np.array(list(reversed(itkimage.GetSpacing())))
    return numpyImage, numpyOrigin, numpySpacing

def world_2_voxel(world_coordinates, origin, spacing):
    stretched_voxel_coordinates = np.absolute(world_coordinates - origin)
    voxel_coordinates = stretched_voxel_coordinates / spacing
    return voxel_coordinates

def voxel_2_world(voxel_coordinates, origin, spacing):
    stretched_voxel_coordinates = voxel_coordinates * spacing
    world_coordinates = stretched_voxel_coordinates + origin
    return world_coordinates

def get_pixels_hu(image):
    image = image.astype(np.int16)
    image[image == threshold_min] = 0
    return np.array(image, dtype=np.int16)

def get_nodule_slices(lung_mask, nodule_mask, lung_raw):
    indexes = np.unique(np.nonzero(nodule_mask)[0])
    #print('Nodule_present on slices: {}'.format(indexes))
    lung_mask_pres = lung_mask[indexes, :, :]
    nod_mask_pres = nodule_mask[indexes, :, :]
    lung_raw_pres = lung_raw[indexes, :, :]
    return lung_mask_pres, nod_mask_pres, lung_raw_pres

def reshape_3d(image_3d):
    reshaped_img = image_3d.reshape([image_3d.shape[0], 1, 512, 512])
    #print('Reshaped image shape:', reshaped_img.shape)
    return reshaped_img



def create_masks_for_patient_watershed(img_file, save = True):
    def draw_nodule_mask(node_idx, cur_row):
        #print('Working on node: {}, row: {}'.format(node_idx, cur_row), '\n')
        coord_x = cur_row["coordX"]
        coord_y = cur_row["coordY"]
        coord_z = cur_row["coordZ"]
        diam = cur_row["diameter_mm"]
        radius = np.ceil(diam/2)
        noduleRange = seq(-radius, radius, RESIZE_SPACING[0])
        #print('Nodule range:', noduleRange)
        world_center = np.array((coord_z,coord_y,coord_x))   # nodule center
        voxel_center = world_2_voxel(world_center, origin, new_spacing)
        image_mask = np.zeros(lung_img.shape)
        for x in noduleRange:
            for y in noduleRange:
                for z in noduleRange:
                    coords = world_2_voxel(np.array((coord_z+z,coord_y+y,coord_x+x)),origin,new_spacing)
                    if (np.linalg.norm(voxel_center - coords) * RESIZE_SPACING[0]) < radius:
                        image_mask[int(np.round(coords[0])),int(np.round(coords[1])),int(np.round(coords[2]))] = int(1)
        print(np.max(image_mask))                
        return image_mask

    print("Getting mask for image file {}".format(img_file))
    patient_id = img_file.split('/')[-1][:-4]
    mini_df = df_node[df_node["file"] == img_file]
    if mini_df.shape[0] > 0: # some files may not have a nodule--skipping those 
        img, origin, spacing = load_itk(src + img_file)
        height, width = img.shape[1], img.shape[2]
        #calculate resize factor
        RESIZE_SPACING = [1, 1, 1]
        resize_factor = spacing / RESIZE_SPACING
        new_real_shape = img.shape * resize_factor
        new_shape = np.round(new_real_shape)
        real_resize = new_shape / img.shape
        new_spacing = spacing / real_resize
        lung_img = scipy.ndimage.interpolation.zoom(img, real_resize)
        #print('Original image shape: {}'.format(img.shape))
        #print('Resized image shape: {}'.format(lung_img.shape))

        lung_img = get_pixels_hu(lung_img)
        #lung_mask = segment_lung_from_ct_scan(lung_img)
        #lung_mask[lung_mask >= threshold_max] = threshold_max
        #lung_img[lung_img >= threshold_max] = threshold_max
        #lung_img[lung_img == 0] = threshold_min
        
        lung_mask = lung_img.copy()
        #lung_mask[lung_mask == 0] = threshold_min
        lung_mask[lung_mask >= threshold_max] = threshold_max
        lung_img[lung_img >= threshold_max] = threshold_max
        
        lung_masks_512 = np.zeros([lung_img.shape[0], height_mask, width_mask], dtype = np.float32)
        nodule_masks_512 = np.zeros([lung_img.shape[0], height_mask, width_mask], dtype = np.float32)
        lung_masks_512[lung_masks_512 == 0] = threshold_min
        
        i = 0
        for node_idx, cur_row in mini_df.iterrows(): 
            nodule_mask = draw_nodule_mask(node_idx, cur_row)
            lung_img_512, lung_mask_512, nodule_mask_512 = np.zeros((lung_img.shape[0], 512, 512)), np.zeros((lung_mask.shape[0], 512, 512)), np.zeros((nodule_mask.shape[0], 512, 512))
            lung_mask_512[lung_mask_512 == 0] = threshold_min
            lung_img_512[lung_img_512 == 0] = threshold_min
            original_shape = lung_img.shape
            
            for z in range(lung_img.shape[0]):
                
                offset = (512 - original_shape[1])
                upper_offset = int(np.round(offset/2))
                lower_offset = int(offset - upper_offset)

                new_origin = voxel_2_world([-upper_offset,-lower_offset,0],origin,new_spacing)
                
                lung_img_512[z, upper_offset:-lower_offset,upper_offset:-lower_offset] = lung_img[z,:,:]
                lung_mask_512[z, upper_offset:-lower_offset,upper_offset:-lower_offset] = lung_mask[z,:,:]
                nodule_mask_512[z, upper_offset:-lower_offset,upper_offset:-lower_offset] = nodule_mask[z,:,:]
            nodule_masks_512 += nodule_mask_512

        #print('Offsets shape for node index {} - main: {}, upper: {}, lower: {}'.format(node_idx, offset, upper_offset, lower_offset), '\n')
      
       
        lung_mask_pres, nod_mask_pres, lung_raw_pres = get_nodule_slices(lung_mask_512, nodule_masks_512, lung_img_512)
        #print('Nodules present on slices: ', np.unique(np.nonzero(nodule_masks_512)[0]))
        
        del lung_mask_512, nodule_masks_512, lung_img_512
        gc.collect()
        
        lung_mask_pres = reshape_3d(lung_mask_pres)
        nod_mask_pres = reshape_3d(nod_mask_pres)
        lung_mask_pres[lung_mask_pres <= threshold_min] = threshold_min
        lung_mask_pres[lung_mask_pres >= threshold_max] = threshold_max
        
        lung_mask_preproc = my_PreProc(lung_mask_pres)
        lung_mask_preproc = lung_mask_preproc.astype(np.float32)
        nod_mask_pres = (nod_mask_pres > 0.0).astype(np.float32)
        nod_mask_pres[nod_mask_pres == 1.0] = 255.

        np.save('{}/lung_mask/{}.npy'.format(dst_nodules, patient_id), lung_mask_preproc)
        np.save('{}/nodule_mask/{}.npy'.format(dst_nodules, patient_id), nod_mask_pres)
        
        del lung_mask_pres, lung_mask_preproc, nod_mask_pres
        gc.collect()
            
        #return lung_mask_preproc, nod_mask_pres
        return
    else: 
        print('\n', 'No nodules found for patient: {}'.format(patient_id), '\n')
        return
        
def dir_check(luna_path):    
    if os.path.isdir(luna_path + 'Data/nodules_2d/'):
        pass
    else:
        os.mkdir(luna_path + 'Data/nodules_2d/')
        
    if os.path.isdir(luna_path + 'Data/nodules_2d/lung_mask/'):
        pass
    else:
        os.mkdir(luna_path + 'Data/nodules_2d/lung_mask/')

    if os.path.isdir(luna_path + 'Data/nodules_2d/nodule_mask/'):
        pass
    else:
        os.mkdir(luna_path + 'Data/nodules_2d/nodule_mask/')
        
def unet_fit(name, batch_size, unet_model, load_check = False, check_name = None):
    
    t = time.time()
    callbacks = [EarlyStopping(monitor='val_loss', patience = 5, 
                                   verbose = 1),
    ModelCheckpoint((luna_path + 'Data/model/{}.h5').format(name), 
                        monitor='val_loss', 
                        verbose = 0, save_best_only = True)]
    if load_check:
        check_model = (luna_path + 'Data/model/{}.h5').format(check_name)
        model = load_model(check_model, custom_objects={'dice_coef_loss': dice_coef_loss, 'dice_coef': dice_coef})
    else:
        model = unet_model()
        
    model.fit_generator(generate_train(lung_path, nodule_path, start_t, end_t, batch_size), epochs = 2, verbose = 1, 
                        validation_data = generate_val(lung_path, nodule_path, batch_size), callbacks = callbacks, 
                        steps_per_epoch = f1, validation_steps = f2)
    return model

# %% [markdown]
# # 训练模型

# %%
lung_path = luna_path +  'Data/nodules_2d/lung_mask/'
nodule_path = luna_path + 'Data/nodules_2d/nodule_mask/'

start_t, end_t = 0, 500
start_v, end_v = end_t, end_t + 200


f1 = get_max_slices(lung_path, start_t, end_t)
f2 = get_max_slices(lung_path, start_v, end_v)
f1 = f1
f2 = f2//2
print('Training samples:', f1, 'Validation samples:', f2)

smooth = 1.0
img_rows = 512
img_cols = 512
batch_size = 2

model_1 = unet_fit('Unet_fulldatagen425', batch_size, unet_model,True,'Unet_fulldatagen')
print 'done!'
# Out:
# Number of 2D slices in CT image: 7697
# Number of 2D slices in CT image: 1768
# ('Training samples:', 7697, 'Validation samples:', 884)
# Epoch 1/1
# Shuffling data
# Shuffling data
#    4/7697 [..............................] - ETA: 18104s - loss: -1.3781 - dice_coef: 1.3781    Shuffling data
#   17/7697 [..............................] - ETA: 12658s - loss: -1.5818 - dice_coef: 1.5818Shuffling data
#   22/7697 [..............................] - ETA: 12275s - loss: -1.6566 - dice_coef: 1.6566Shuffling data
#   27/7697 [..............................] - ETA: 12031s - loss: -1.7052 - dice_coef: 1.7052Shuffling data
#   32/7697 [..............................] - ETA: 11859s - loss: -1.6329 - dice_coef: 1.6329Shuffling data
#   42/7697 [..............................] - ETA: 11631s - loss: -1.6716 - dice_coef: 1.6716Shuffling data
#   47/7697 [..............................] - ETA: 11551s - loss: -1.6964 - dice_coef: 1.6964Shuffling data
#   63/7697 [..............................] - ETA: 11374s - loss: -1.7408 - dice_coef: 1.7408Shuffling data
#   69/7697 [..............................] - ETA: 11327s - loss: -1.7435 - dice_coef: 1.7435Shuffling data
#  110/7697 [..............................] - ETA: 11112s - loss: -1.7277 - dice_coef: 1.7277Shuffling data
#  115/7697 [..............................] - ETA: 11095s - loss: -1.7335 - dice_coef: 1.7335Shuffling data
#  120/7697 [..............................] - ETA: 11077s - loss: -1.7317 - dice_coef: 1.7317Shuffling data
#  126/7697 [..............................] - ETA: 11057s - loss: -1.7335 - dice_coef: 1.7335Shuffling data
#  133/7697 [..............................] - ETA: 11035s - loss: -1.7383 - dice_coef: 1.7383Shuffling data
#  137/7697 [..............................] - ETA: 11023s - loss: -1.7298 - dice_coef: 1.7298Shuffling data
#  141/7697 [..............................] - ETA: 11011s - loss: -1.7213 - dice_coef: 1.7213Shuffling data
#  147/7697 [..............................] - ETA: 10994s - loss: -1.7111 - dice_coef: 1.7111Shuffling data
#  152/7697 [..............................] - ETA: 10981s - loss: -1.7162 - dice_coef: 1.7162Shuffling data
#  165/7697 [..............................] - ETA: 10947s - loss: -1.7260 - dice_coef: 1.7260Shuffling data
#  169/7697 [..............................] - ETA: 10938s - loss: -1.7312 - dice_coef: 1.7312Shuffling data
#  175/7697 [..............................] - ETA: 10923s - loss: -1.7383 - dice_coef: 1.7383Shuffling data
#  187/7697 [..............................] - ETA: 10895s - loss: -1.7453 - dice_coef: 1.7453Shuffling data
#  194/7697 [..............................] - ETA: 10880s - loss: -1.7517 - dice_coef: 1.7517Shuffling data
#  199/7697 [..............................] - ETA: 10870s - loss: -1.7511 - dice_coef: 1.7511Shuffling data
#  204/7697 [..............................] - ETA: 10859s - loss: -1.7545 - dice_coef: 1.7545Shuffling data
#  218/7697 [..............................] - ETA: 10831s - loss: -1.7613 - dice_coef: 1.7613Shuffling data
#  222/7697 [..............................] - ETA: 10824s - loss: -1.7651 - dice_coef: 1.7651Shuffling data
#  230/7697 [..............................] - ETA: 10807s - loss: -1.7713 - dice_coef: 1.7713Shuffling data
#  243/7697 [..............................] - ETA: 10782s - loss: -1.7742 - dice_coef: 1.7742Shuffling data
#  251/7697 [..............................] - ETA: 10767s - loss: -1.7792 - dice_coef: 1.7792Shuffling data
#  276/7697 [>.............................] - ETA: 10721s - loss: -1.7861 - dice_coef: 1.7861Shuffling data
#  284/7697 [>.............................] - ETA: 10706s - loss: -1.7883 - dice_coef: 1.7883Shuffling data
#  298/7697 [>.............................] - ETA: 10681s - loss: -1.7864 - dice_coef: 1.7864Shuffling data
#  306/7697 [>.............................] - ETA: 10667s - loss: -1.7884 - dice_coef: 1.7884Shuffling data
#  316/7697 [>.............................] - ETA: 10650s - loss: -1.7890 - dice_coef: 1.7890Shuffling data
#  324/7697 [>.............................] - ETA: 10636s - loss: -1.7932 - dice_coef: 1.7932Shuffling data
#  331/7697 [>.............................] - ETA: 10624s - loss: -1.7850 - dice_coef: 1.7850Shuffling data
#  342/7697 [>.............................] - ETA: 10605s - loss: -1.7844 - dice_coef: 1.7844Shuffling data
#  347/7697 [>.............................] - ETA: 10597s - loss: -1.7870 - dice_coef: 1.7870Shuffling data
#  352/7697 [>.............................] - ETA: 10589s - loss: -1.7895 - dice_coef: 1.7895Shuffling data
#  357/7697 [>.............................] - ETA: 10580s - loss: -1.7825 - dice_coef: 1.7825Shuffling data
#  361/7697 [>.............................] - ETA: 10574s - loss: -1.7810 - dice_coef: 1.7810Shuffling data
#  374/7697 [>.............................] - ETA: 10553s - loss: -1.7772 - dice_coef: 1.7772Shuffling data
#  381/7697 [>.............................] - ETA: 10541s - loss: -1.7809 - dice_coef: 1.7809Shuffling data
#  386/7697 [>.............................] - ETA: 10533s - loss: -1.7816 - dice_coef: 1.7816Shuffling data
#  397/7697 [>.............................] - ETA: 10516s - loss: -1.7824 - dice_coef: 1.7824Shuffling data
#  407/7697 [>.............................] - ETA: 10499s - loss: -1.7755 - dice_coef: 1.7755Shuffling data
#  428/7697 [>.............................] - ETA: 10465s - loss: -1.7836 - dice_coef: 1.7836Shuffling data
#  435/7697 [>.............................] - ETA: 10454s - loss: -1.7862 - dice_coef: 1.7862Shuffling data
#  443/7697 [>.............................] - ETA: 10441s - loss: -1.7882 - dice_coef: 1.7882Shuffling data
#  454/7697 [>.............................] - ETA: 10424s - loss: -1.7865 - dice_coef: 1.7865Shuffling data
#  459/7697 [>.............................] - ETA: 10416s - loss: -1.7876 - dice_coef: 1.7876Shuffling data
#  467/7697 [>.............................] - ETA: 10404s - loss: -1.7892 - dice_coef: 1.7892Shuffling data
#  471/7697 [>.............................] - ETA: 10398s - loss: -1.7901 - dice_coef: 1.7901Shuffling data
#  476/7697 [>.............................] - ETA: 10390s - loss: -1.7902 - dice_coef: 1.7902Shuffling data
#  482/7697 [>.............................] - ETA: 10381s - loss: -1.7913 - dice_coef: 1.7913Shuffling data
#  491/7697 [>.............................] - ETA: 10367s - loss: -1.7924 - dice_coef: 1.7924Shuffling data
#  497/7697 [>.............................] - ETA: 10357s - loss: -1.7934 - dice_coef: 1.7934Shuffling data
#  510/7697 [>.............................] - ETA: 10337s - loss: -1.7941 - dice_coef: 1.7941Shuffling data
#  518/7697 [=>............................] - ETA: 10325s - loss: -1.7915 - dice_coef: 1.7915Shuffling data
#  523/7697 [=>............................] - ETA: 10317s - loss: -1.7901 - dice_coef: 1.7901Shuffling data
#  528/7697 [=>............................] - ETA: 10309s - loss: -1.7914 - dice_coef: 1.7914Shuffling data
#  533/7697 [=>............................] - ETA: 10302s - loss: -1.7908 - dice_coef: 1.7908Shuffling data
#  538/7697 [=>............................] - ETA: 10294s - loss: -1.7904 - dice_coef: 1.7904Shuffling data
#  547/7697 [=>............................] - ETA: 10280s - loss: -1.7892 - dice_coef: 1.7892Shuffling data
#  553/7697 [=>............................] - ETA: 10271s - loss: -1.7898 - dice_coef: 1.7898Shuffling data
#  564/7697 [=>............................] - ETA: 10254s - loss: -1.7887 - dice_coef: 1.7887Shuffling data
#  570/7697 [=>............................] - ETA: 10245s - loss: -1.7902 - dice_coef: 1.7902Shuffling data
#  578/7697 [=>............................] - ETA: 10233s - loss: -1.7920 - dice_coef: 1.7920Shuffling data
#  589/7697 [=>............................] - ETA: 10216s - loss: -1.7897 - dice_coef: 1.7897Shuffling data
#  597/7697 [=>............................] - ETA: 10204s - loss: -1.7916 - dice_coef: 1.7916Shuffling data
#  606/7697 [=>............................] - ETA: 10190s - loss: -1.7932 - dice_coef: 1.7932Shuffling data
#  610/7697 [=>............................] - ETA: 10184s - loss: -1.7939 - dice_coef: 1.7939Shuffling data
#  615/7697 [=>............................] - ETA: 10177s - loss: -1.7944 - dice_coef: 1.7944Shuffling data
#  621/7697 [=>............................] - ETA: 10168s - loss: -1.7950 - dice_coef: 1.7950Shuffling data
#  626/7697 [=>............................] - ETA: 10160s - loss: -1.7952 - dice_coef: 1.7952Shuffling data
#  630/7697 [=>............................] - ETA: 10154s - loss: -1.7955 - dice_coef: 1.7955Shuffling data
#  634/7697 [=>............................] - ETA: 10148s - loss: -1.7958 - dice_coef: 1.7958Shuffling data
#  640/7697 [=>............................] - ETA: 10140s - loss: -1.7940 - dice_coef: 1.7940Shuffling data
#  646/7697 [=>............................] - ETA: 10131s - loss: -1.7947 - dice_coef: 1.7947Shuffling data
#  656/7697 [=>............................] - ETA: 10115s - loss: -1.7929 - dice_coef: 1.7929Shuffling data
#  671/7697 [=>............................] - ETA: 10093s - loss: -1.7943 - dice_coef: 1.7943Shuffling data
#  689/7697 [=>............................] - ETA: 10068s - loss: -1.7945 - dice_coef: 1.7945Shuffling data
#  708/7697 [=>............................] - ETA: 10039s - loss: -1.7901 - dice_coef: 1.7901Shuffling data
#  712/7697 [=>............................] - ETA: 10033s - loss: -1.7907 - dice_coef: 1.7907Shuffling data
#  721/7697 [=>............................] - ETA: 10020s - loss: -1.7893 - dice_coef: 1.7893Shuffling data
#  725/7697 [=>............................] - ETA: 10014s - loss: -1.7898 - dice_coef: 1.7898Shuffling data
#  731/7697 [=>............................] - ETA: 10005s - loss: -1.7911 - dice_coef: 1.7911Shuffling data
#  736/7697 [=>............................] - ETA: 9998s - loss: -1.7884 - dice_coef: 1.7884Shuffling data
#  742/7697 [=>............................] - ETA: 9989s - loss: -1.7891 - dice_coef: 1.7891Shuffling data
#  746/7697 [=>............................] - ETA: 9983s - loss: -1.7895 - dice_coef: 1.7895Shuffling data
#  751/7697 [=>............................] - ETA: 9975s - loss: -1.7902 - dice_coef: 1.7902Shuffling data
#  755/7697 [=>............................] - ETA: 9970s - loss: -1.7905 - dice_coef: 1.7905Shuffling data
#  764/7697 [=>............................] - ETA: 9956s - loss: -1.7876 - dice_coef: 1.7876Shuffling data
#  772/7697 [==>...........................] - ETA: 9944s - loss: -1.7864 - dice_coef: 1.7864Shuffling data
#  776/7697 [==>...........................] - ETA: 9938s - loss: -1.7867 - dice_coef: 1.7867Shuffling data
#  795/7697 [==>...........................] - ETA: 9911s - loss: -1.7866 - dice_coef: 1.7866Shuffling data
#  808/7697 [==>...........................] - ETA: 9892s - loss: -1.7878 - dice_coef: 1.7878Shuffling data
#  819/7697 [==>...........................] - ETA: 9876s - loss: -1.7897 - dice_coef: 1.7897Shuffling data
#  830/7697 [==>...........................] - ETA: 9859s - loss: -1.7915 - dice_coef: 1.7915Shuffling data
#  835/7697 [==>...........................] - ETA: 9852s - loss: -1.7925 - dice_coef: 1.7925Shuffling data
#  847/7697 [==>...........................] - ETA: 9834s - loss: -1.7892 - dice_coef: 1.7892Shuffling data
#  859/7697 [==>...........................] - ETA: 9817s - loss: -1.7914 - dice_coef: 1.7914Shuffling data
#  871/7697 [==>...........................] - ETA: 9799s - loss: -1.7930 - dice_coef: 1.7930Shuffling data
#  877/7697 [==>...........................] - ETA: 9790s - loss: -1.7941 - dice_coef: 1.7941Shuffling data
#  885/7697 [==>...........................] - ETA: 9778s - loss: -1.7951 - dice_coef: 1.7951Shuffling data
#  895/7697 [==>...........................] - ETA: 9763s - loss: -1.7955 - dice_coef: 1.7955Shuffling data
#  901/7697 [==>...........................] - ETA: 9755s - loss: -1.7965 - dice_coef: 1.7965Shuffling data
#  909/7697 [==>...........................] - ETA: 9743s - loss: -1.7969 - dice_coef: 1.7969Shuffling data
#  916/7697 [==>...........................] - ETA: 9733s - loss: -1.7974 - dice_coef: 1.7974Shuffling data
#  921/7697 [==>...........................] - ETA: 9725s - loss: -1.7981 - dice_coef: 1.7981Shuffling data
#  927/7697 [==>...........................] - ETA: 9716s - loss: -1.7985 - dice_coef: 1.7985Shuffling data
#  936/7697 [==>...........................] - ETA: 9703s - loss: -1.7981 - dice_coef: 1.7981Shuffling data
#  944/7697 [==>...........................] - ETA: 9692s - loss: -1.7984 - dice_coef: 1.7984Shuffling data
#  962/7697 [==>...........................] - ETA: 9666s - loss: -1.8008 - dice_coef: 1.8008Shuffling data
#  968/7697 [==>...........................] - ETA: 9657s - loss: -1.8019 - dice_coef: 1.8019Shuffling data
#  981/7697 [==>...........................] - ETA: 9638s - loss: -1.8030 - dice_coef: 1.8030Shuffling data
#  988/7697 [==>...........................] - ETA: 9628s - loss: -1.8039 - dice_coef: 1.8039Shuffling data
#  996/7697 [==>...........................] - ETA: 9616s - loss: -1.8046 - dice_coef: 1.8046Shuffling data
# 1000/7697 [==>...........................] - ETA: 9610s - loss: -1.8043 - dice_coef: 1.8043Shuffling data
# 1013/7697 [==>...........................] - ETA: 9592s - loss: -1.8030 - dice_coef: 1.8030Shuffling data
# 1028/7697 [===>..........................] - ETA: 9570s - loss: -1.8051 - dice_coef: 1.8051Shuffling data
# 1034/7697 [===>..........................] - ETA: 9561s - loss: -1.8058 - dice_coef: 1.8058Shuffling data
# 1045/7697 [===>..........................] - ETA: 9545s - loss: -1.8068 - dice_coef: 1.8068Shuffling data
# 1050/7697 [===>..........................] - ETA: 9538s - loss: -1.8075 - dice_coef: 1.8075Shuffling data
# 1057/7697 [===>..........................] - ETA: 9528s - loss: -1.8048 - dice_coef: 1.8048Shuffling data
# 1062/7697 [===>..........................] - ETA: 9520s - loss: -1.7999 - dice_coef: 1.7999Shuffling data
# 1067/7697 [===>..........................] - ETA: 9513s - loss: -1.7983 - dice_coef: 1.7983Shuffling data
# 1072/7697 [===>..........................] - ETA: 9506s - loss: -1.7978 - dice_coef: 1.7978Shuffling data
# 1088/7697 [===>..........................] - ETA: 9483s - loss: -1.7956 - dice_coef: 1.7956Shuffling data
# 1091/7697 [===>..........................] - ETA: 9478s - loss: -1.7959 - dice_coef: 1.7959Shuffling data
# 1096/7697 [===>..........................] - ETA: 9471s - loss: -1.7966 - dice_coef: 1.7966Shuffling data
# 1101/7697 [===>..........................] - ETA: 9464s - loss: -1.7954 - dice_coef: 1.7954Shuffling data
# 1111/7697 [===>..........................] - ETA: 9449s - loss: -1.7928 - dice_coef: 1.7928Shuffling data
# 1116/7697 [===>..........................] - ETA: 9442s - loss: -1.7924 - dice_coef: 1.7924Shuffling data
# 1122/7697 [===>..........................] - ETA: 9433s - loss: -1.7918 - dice_coef: 1.7918Shuffling data
# 1127/7697 [===>..........................] - ETA: 9426s - loss: -1.7887 - dice_coef: 1.7887Shuffling data
# 1141/7697 [===>..........................] - ETA: 9405s - loss: -1.7843 - dice_coef: 1.7843Shuffling data
# 1147/7697 [===>..........................] - ETA: 9397s - loss: -1.7852 - dice_coef: 1.7852Shuffling data
# 1159/7697 [===>..........................] - ETA: 9379s - loss: -1.7865 - dice_coef: 1.7865Shuffling data
# 1166/7697 [===>..........................] - ETA: 9369s - loss: -1.7871 - dice_coef: 1.7871Shuffling data
# 1177/7697 [===>..........................] - ETA: 9353s - loss: -1.7881 - dice_coef: 1.7881Shuffling data
# 1184/7697 [===>..........................] - ETA: 9343s - loss: -1.7891 - dice_coef: 1.7891Shuffling data
# 1199/7697 [===>..........................] - ETA: 9321s - loss: -1.7909 - dice_coef: 1.7909Shuffling data
# 1210/7697 [===>..........................] - ETA: 9305s - loss: -1.7925 - dice_coef: 1.7925Shuffling data
# 1217/7697 [===>..........................] - ETA: 9295s - loss: -1.7928 - dice_coef: 1.7928Shuffling data
# 1224/7697 [===>..........................] - ETA: 9285s - loss: -1.7935 - dice_coef: 1.7935Shuffling data
# 1230/7697 [===>..........................] - ETA: 9276s - loss: -1.7941 - dice_coef: 1.7941Shuffling data
# 1246/7697 [===>..........................] - ETA: 9253s - loss: -1.7946 - dice_coef: 1.7946Shuffling data
# 1257/7697 [===>..........................] - ETA: 9237s - loss: -1.7960 - dice_coef: 1.7960Shuffling data
# 1264/7697 [===>..........................] - ETA: 9227s - loss: -1.7969 - dice_coef: 1.7969Shuffling data
# 1271/7697 [===>..........................] - ETA: 9217s - loss: -1.7960 - dice_coef: 1.7960Shuffling data
# 1288/7697 [====>.........................] - ETA: 9192s - loss: -1.7965 - dice_coef: 1.7965Shuffling data
# 1294/7697 [====>.........................] - ETA: 9183s - loss: -1.7971 - dice_coef: 1.7971Shuffling data
# 1306/7697 [====>.........................] - ETA: 9166s - loss: -1.7975 - dice_coef: 1.7975Shuffling data
# 1311/7697 [====>.........................] - ETA: 9159s - loss: -1.7975 - dice_coef: 1.7975Shuffling data
# 1315/7697 [====>.........................] - ETA: 9153s - loss: -1.7979 - dice_coef: 1.7979Shuffling data
# 1322/7697 [====>.........................] - ETA: 9143s - loss: -1.7963 - dice_coef: 1.7963Shuffling data
# 1329/7697 [====>.........................] - ETA: 9133s - loss: -1.7968 - dice_coef: 1.7968Shuffling data
# 1336/7697 [====>.........................] - ETA: 9122s - loss: -1.7970 - dice_coef: 1.7970Shuffling data
# 1339/7697 [====>.........................] - ETA: 9118s - loss: -1.7967 - dice_coef: 1.7967Shuffling data
# 1343/7697 [====>.........................] - ETA: 9112s - loss: -1.7971 - dice_coef: 1.7971Shuffling data
# 1354/7697 [====>.........................] - ETA: 9096s - loss: -1.7974 - dice_coef: 1.7974Shuffling data
# 1368/7697 [====>.........................] - ETA: 9076s - loss: -1.7968 - dice_coef: 1.7968Shuffling data
# 1373/7697 [====>.........................] - ETA: 9069s - loss: -1.7973 - dice_coef: 1.7973Shuffling data
# 1386/7697 [====>.........................] - ETA: 9050s - loss: -1.7976 - dice_coef: 1.7976Shuffling data
# 1398/7697 [====>.........................] - ETA: 9033s - loss: -1.7976 - dice_coef: 1.7976Shuffling data
# 1403/7697 [====>.........................] - ETA: 9025s - loss: -1.7965 - dice_coef: 1.7965Shuffling data
# 1422/7697 [====>.........................] - ETA: 8998s - loss: -1.7958 - dice_coef: 1.7958Shuffling data
# 1428/7697 [====>.........................] - ETA: 8989s - loss: -1.7959 - dice_coef: 1.7959Shuffling data
# 1433/7697 [====>.........................] - ETA: 8982s - loss: -1.7954 - dice_coef: 1.7954Shuffling data
# 1438/7697 [====>.........................] - ETA: 8975s - loss: -1.7950 - dice_coef: 1.7950Shuffling data
# 1457/7697 [====>.........................] - ETA: 8947s - loss: -1.7844 - dice_coef: 1.7844Shuffling data
# 1475/7697 [====>.........................] - ETA: 8921s - loss: -1.7839 - dice_coef: 1.7839Shuffling data
# 1483/7697 [====>.........................] - ETA: 8910s - loss: -1.7843 - dice_coef: 1.7843Shuffling data
# 1499/7697 [====>.........................] - ETA: 8887s - loss: -1.7851 - dice_coef: 1.7851Shuffling data
# 1513/7697 [====>.........................] - ETA: 8866s - loss: -1.7860 - dice_coef: 1.7860Shuffling data
# 1525/7697 [====>.........................] - ETA: 8849s - loss: -1.7862 - dice_coef: 1.7862Shuffling data
# 1530/7697 [====>.........................] - ETA: 8842s - loss: -1.7865 - dice_coef: 1.7865Shuffling data
# 1536/7697 [====>.........................] - ETA: 8833s - loss: -1.7869 - dice_coef: 1.7869Shuffling data
# 1542/7697 [=====>........................] - ETA: 8824s - loss: -1.7865 - dice_coef: 1.7865Shuffling data
# 1558/7697 [=====>........................] - ETA: 8801s - loss: -1.7878 - dice_coef: 1.7878Shuffling data
# 1565/7697 [=====>........................] - ETA: 8791s - loss: -1.7886 - dice_coef: 1.7886Shuffling data
# 1574/7697 [=====>........................] - ETA: 8778s - loss: -1.7890 - dice_coef: 1.7890Shuffling data
# 1593/7697 [=====>........................] - ETA: 8751s - loss: -1.7904 - dice_coef: 1.7904Shuffling data
# 1607/7697 [=====>........................] - ETA: 8731s - loss: -1.7916 - dice_coef: 1.7916Shuffling data
# 1614/7697 [=====>........................] - ETA: 8721s - loss: -1.7916 - dice_coef: 1.7916Shuffling data
# 1633/7697 [=====>........................] - ETA: 8693s - loss: -1.7921 - dice_coef: 1.7921Shuffling data
# 1652/7697 [=====>........................] - ETA: 8667s - loss: -1.7933 - dice_coef: 1.7933Shuffling data
# 1656/7697 [=====>........................] - ETA: 8661s - loss: -1.7934 - dice_coef: 1.7934Shuffling data
# 1661/7697 [=====>........................] - ETA: 8654s - loss: -1.7937 - dice_coef: 1.7937Shuffling data
# 1668/7697 [=====>........................] - ETA: 8643s - loss: -1.7903 - dice_coef: 1.7903Shuffling data
# 1672/7697 [=====>........................] - ETA: 8638s - loss: -1.7901 - dice_coef: 1.7901Shuffling data
# 1693/7697 [=====>........................] - ETA: 8607s - loss: -1.7914 - dice_coef: 1.7914Shuffling data
# 1697/7697 [=====>........................] - ETA: 8602s - loss: -1.7918 - dice_coef: 1.7918Shuffling data
# 1704/7697 [=====>........................] - ETA: 8592s - loss: -1.7912 - dice_coef: 1.7912Shuffling data
# 1712/7697 [=====>........................] - ETA: 8580s - loss: -1.7903 - dice_coef: 1.7903Shuffling data
# 1721/7697 [=====>........................] - ETA: 8567s - loss: -1.7903 - dice_coef: 1.7903Shuffling data
# 1726/7697 [=====>........................] - ETA: 8560s - loss: -1.7908 - dice_coef: 1.7908Shuffling data
# 1732/7697 [=====>........................] - ETA: 8551s - loss: -1.7908 - dice_coef: 1.7908Shuffling data
# 1738/7697 [=====>........................] - ETA: 8543s - loss: -1.7912 - dice_coef: 1.7912Shuffling data
# 1744/7697 [=====>........................] - ETA: 8534s - loss: -1.7904 - dice_coef: 1.7904Shuffling data
# 1759/7697 [=====>........................] - ETA: 8512s - loss: -1.7915 - dice_coef: 1.7915Shuffling data
# 1764/7697 [=====>........................] - ETA: 8505s - loss: -1.7920 - dice_coef: 1.7920Shuffling data
# 1778/7697 [=====>........................] - ETA: 8485s - loss: -1.7926 - dice_coef: 1.7926Shuffling data
# 1790/7697 [=====>........................] - ETA: 8468s - loss: -1.7922 - dice_coef: 1.7922Shuffling data
# 1815/7697 [======>.......................] - ETA: 8432s - loss: -1.7930 - dice_coef: 1.7930Shuffling data
# 1832/7697 [======>.......................] - ETA: 8407s - loss: -1.7940 - dice_coef: 1.7940Shuffling data
# 1847/7697 [======>.......................] - ETA: 8386s - loss: -1.7948 - dice_coef: 1.7948Shuffling data
# 1860/7697 [======>.......................] - ETA: 8367s - loss: -1.7957 - dice_coef: 1.7957Shuffling data
# 1866/7697 [======>.......................] - ETA: 8358s - loss: -1.7961 - dice_coef: 1.7961Shuffling data
# 1875/7697 [======>.......................] - ETA: 8345s - loss: -1.7962 - dice_coef: 1.7962Shuffling data
# 1882/7697 [======>.......................] - ETA: 8335s - loss: -1.7965 - dice_coef: 1.7965Shuffling data
# 1891/7697 [======>.......................] - ETA: 8322s - loss: -1.7965 - dice_coef: 1.7965Shuffling data
# 1903/7697 [======>.......................] - ETA: 8305s - loss: -1.7966 - dice_coef: 1.7966Shuffling data
# 1911/7697 [======>.......................] - ETA: 8293s - loss: -1.7969 - dice_coef: 1.7969Shuffling data
# 1915/7697 [======>.......................] - ETA: 8288s - loss: -1.7968 - dice_coef: 1.7968Shuffling data
# 1923/7697 [======>.......................] - ETA: 8276s - loss: -1.7958 - dice_coef: 1.7958Shuffling data
# 1930/7697 [======>.......................] - ETA: 8266s - loss: -1.7960 - dice_coef: 1.7960Shuffling data
# 1942/7697 [======>.......................] - ETA: 8249s - loss: -1.7965 - dice_coef: 1.7965Shuffling data
# 1947/7697 [======>.......................] - ETA: 8241s - loss: -1.7965 - dice_coef: 1.7965Shuffling data
# 1953/7697 [======>.......................] - ETA: 8233s - loss: -1.7968 - dice_coef: 1.7968Shuffling data
# 1971/7697 [======>.......................] - ETA: 8207s - loss: -1.7970 - dice_coef: 1.7970Shuffling data
# 1981/7697 [======>.......................] - ETA: 8193s - loss: -1.7974 - dice_coef: 1.7974Shuffling data
# 2108/7697 [=======>......................] - ETA: 8010s - loss: -1.8001 - dice_coef: 1.8001Shuffling data
# 2112/7697 [=======>......................] - ETA: 8004s - loss: -1.8003 - dice_coef: 1.8003Shuffling data
# 2123/7697 [=======>......................] - ETA: 7988s - loss: -1.7998 - dice_coef: 1.7998Shuffling data
# 2128/7697 [=======>......................] - ETA: 7981s - loss: -1.7988 - dice_coef: 1.7988Shuffling data
# 2136/7697 [=======>......................] - ETA: 7969s - loss: -1.7990 - dice_coef: 1.7990Shuffling data
# 2144/7697 [=======>......................] - ETA: 7958s - loss: -1.7991 - dice_coef: 1.7991Shuffling data
# 2158/7697 [=======>......................] - ETA: 7938s - loss: -1.7998 - dice_coef: 1.7998Shuffling data
# 2166/7697 [=======>......................] - ETA: 7926s - loss: -1.8003 - dice_coef: 1.8003Shuffling data
# 2175/7697 [=======>......................] - ETA: 7913s - loss: -1.8010 - dice_coef: 1.8010Shuffling data
# 2181/7697 [=======>......................] - ETA: 7905s - loss: -1.8013 - dice_coef: 1.8013Shuffling data
# 2185/7697 [=======>......................] - ETA: 7899s - loss: -1.8016 - dice_coef: 1.8016Shuffling data
# 2190/7697 [=======>......................] - ETA: 7892s - loss: -1.8015 - dice_coef: 1.8015Shuffling data
# 2196/7697 [=======>......................] - ETA: 7883s - loss: -1.8016 - dice_coef: 1.8016Shuffling data
# 2209/7697 [=======>......................] - ETA: 7864s - loss: -1.8013 - dice_coef: 1.8013Shuffling data
# 2215/7697 [=======>......................] - ETA: 7856s - loss: -1.8017 - dice_coef: 1.8017Shuffling data
# 2227/7697 [=======>......................] - ETA: 7839s - loss: -1.8016 - dice_coef: 1.8016Shuffling data
# 2234/7697 [=======>......................] - ETA: 7828s - loss: -1.8021 - dice_coef: 1.8021Shuffling data
# 2246/7697 [=======>......................] - ETA: 7811s - loss: -1.8027 - dice_coef: 1.8027Shuffling data
# 2250/7697 [=======>......................] - ETA: 7805s - loss: -1.8028 - dice_coef: 1.8028Shuffling data
# 2261/7697 [=======>......................] - ETA: 7790s - loss: -1.8032 - dice_coef: 1.8032Shuffling data
# 2268/7697 [=======>......................] - ETA: 7780s - loss: -1.8036 - dice_coef: 1.8036Shuffling data
# 2283/7697 [=======>......................] - ETA: 7758s - loss: -1.8043 - dice_coef: 1.8043Shuffling data
# 2307/7697 [=======>......................] - ETA: 7723s - loss: -1.8048 - dice_coef: 1.8048Shuffling data
# 2313/7697 [========>.....................] - ETA: 7715s - loss: -1.8051 - dice_coef: 1.8051Shuffling data
# 2320/7697 [========>.....................] - ETA: 7705s - loss: -1.8053 - dice_coef: 1.8053Shuffling data
# 2335/7697 [========>.....................] - ETA: 7683s - loss: -1.8056 - dice_coef: 1.8056Shuffling data
# 2345/7697 [========>.....................] - ETA: 7669s - loss: -1.8057 - dice_coef: 1.8057Shuffling data
# 2362/7697 [========>.....................] - ETA: 7645s - loss: -1.8068 - dice_coef: 1.8068Shuffling data
# 2374/7697 [========>.....................] - ETA: 7627s - loss: -1.8068 - dice_coef: 1.8068Shuffling data
# 2380/7697 [========>.....................] - ETA: 7619s - loss: -1.8070 - dice_coef: 1.8070Shuffling data
# 2386/7697 [========>.....................] - ETA: 7610s - loss: -1.8072 - dice_coef: 1.8072Shuffling data
# 2393/7697 [========>.....................] - ETA: 7600s - loss: -1.8075 - dice_coef: 1.8075Shuffling data
# 2397/7697 [========>.....................] - ETA: 7594s - loss: -1.8072 - dice_coef: 1.8072Shuffling data
# 2402/7697 [========>.....................] - ETA: 7587s - loss: -1.8070 - dice_coef: 1.8070Shuffling data
# 2410/7697 [========>.....................] - ETA: 7576s - loss: -1.8063 - dice_coef: 1.8063Shuffling data
# 2416/7697 [========>.....................] - ETA: 7567s - loss: -1.8062 - dice_coef: 1.8062Shuffling data
# 2424/7697 [========>.....................] - ETA: 7555s - loss: -1.8064 - dice_coef: 1.8064Shuffling data
# 2432/7697 [========>.....................] - ETA: 7544s - loss: -1.8062 - dice_coef: 1.8062Shuffling data
# 2438/7697 [========>.....................] - ETA: 7535s - loss: -1.8054 - dice_coef: 1.8054Shuffling data
# 2446/7697 [========>.....................] - ETA: 7524s - loss: -1.8051 - dice_coef: 1.8051Shuffling data
# 2451/7697 [========>.....................] - ETA: 7517s - loss: -1.8051 - dice_coef: 1.8051Shuffling data
# 2465/7697 [========>.....................] - ETA: 7496s - loss: -1.8051 - dice_coef: 1.8051Shuffling data
# 2473/7697 [========>.....................] - ETA: 7485s - loss: -1.8055 - dice_coef: 1.8055Shuffling data
# 2484/7697 [========>.....................] - ETA: 7469s - loss: -1.8045 - dice_coef: 1.8045Shuffling data
# 2498/7697 [========>.....................] - ETA: 7449s - loss: -1.8021 - dice_coef: 1.8021Shuffling data
# 2505/7697 [========>.....................] - ETA: 7439s - loss: -1.8021 - dice_coef: 1.8021Shuffling data
# 2511/7697 [========>.....................] - ETA: 7430s - loss: -1.8023 - dice_coef: 1.8023Shuffling data
# 2515/7697 [========>.....................] - ETA: 7425s - loss: -1.8022 - dice_coef: 1.8022Shuffling data
# 2521/7697 [========>.....................] - ETA: 7416s - loss: -1.8022 - dice_coef: 1.8022Shuffling data
# 2535/7697 [========>.....................] - ETA: 7396s - loss: -1.8004 - dice_coef: 1.8004Shuffling data
# 2545/7697 [========>.....................] - ETA: 7382s - loss: -1.8008 - dice_coef: 1.8008Shuffling data
# 2549/7697 [========>.....................] - ETA: 7376s - loss: -1.8009 - dice_coef: 1.8009Shuffling data
# 2554/7697 [========>.....................] - ETA: 7369s - loss: -1.8009 - dice_coef: 1.8009Shuffling data
# 2561/7697 [========>.....................] - ETA: 7359s - loss: -1.8000 - dice_coef: 1.8000Shuffling data
# 2568/7697 [=========>....................] - ETA: 7348s - loss: -1.8000 - dice_coef: 1.8000Shuffling data
# 2573/7697 [=========>....................] - ETA: 7341s - loss: -1.7995 - dice_coef: 1.7995Shuffling data
# 2578/7697 [=========>....................] - ETA: 7334s - loss: -1.7996 - dice_coef: 1.7996Shuffling data
# 2585/7697 [=========>....................] - ETA: 7324s - loss: -1.7998 - dice_coef: 1.7998Shuffling data
# 2597/7697 [=========>....................] - ETA: 7307s - loss: -1.7998 - dice_coef: 1.7998Shuffling data
# 2602/7697 [=========>....................] - ETA: 7300s - loss: -1.8001 - dice_coef: 1.8001Shuffling data
# 2607/7697 [=========>....................] - ETA: 7292s - loss: -1.8004 - dice_coef: 1.8004Shuffling data
# 2622/7697 [=========>....................] - ETA: 7271s - loss: -1.7996 - dice_coef: 1.7996Shuffling data
# 2635/7697 [=========>....................] - ETA: 7252s - loss: -1.7995 - dice_coef: 1.7995Shuffling data
# 2647/7697 [=========>....................] - ETA: 7235s - loss: -1.8001 - dice_coef: 1.8001Shuffling data
# 2658/7697 [=========>....................] - ETA: 7219s - loss: -1.8008 - dice_coef: 1.8008Shuffling data
# 2672/7697 [=========>....................] - ETA: 7199s - loss: -1.8015 - dice_coef: 1.8015Shuffling data
# 2686/7697 [=========>....................] - ETA: 7179s - loss: -1.8018 - dice_coef: 1.8018Shuffling data
# 2695/7697 [=========>....................] - ETA: 7166s - loss: -1.8022 - dice_coef: 1.8022Shuffling data
# 2709/7697 [=========>....................] - ETA: 7146s - loss: -1.8025 - dice_coef: 1.8025Shuffling data
# 2714/7697 [=========>....................] - ETA: 7139s - loss: -1.8025 - dice_coef: 1.8025Shuffling data
# 2723/7697 [=========>....................] - ETA: 7126s - loss: -1.8025 - dice_coef: 1.8025Shuffling data
# 2732/7697 [=========>....................] - ETA: 7113s - loss: -1.8029 - dice_coef: 1.8029Shuffling data
# 2742/7697 [=========>....................] - ETA: 7099s - loss: -1.8033 - dice_coef: 1.8033Shuffling data
# 2748/7697 [=========>....................] - ETA: 7090s - loss: -1.8036 - dice_coef: 1.8036Shuffling data
# 2758/7697 [=========>....................] - ETA: 7076s - loss: -1.8038 - dice_coef: 1.8038Shuffling data
# 2766/7697 [=========>....................] - ETA: 7064s - loss: -1.8034 - dice_coef: 1.8034Shuffling data
# 2773/7697 [=========>....................] - ETA: 7054s - loss: -1.8034 - dice_coef: 1.8034Shuffling data
# 2782/7697 [=========>....................] - ETA: 7041s - loss: -1.8035 - dice_coef: 1.8035Shuffling data
# 2788/7697 [=========>....................] - ETA: 7033s - loss: -1.8034 - dice_coef: 1.8034Shuffling data
# 2794/7697 [=========>....................] - ETA: 7024s - loss: -1.8033 - dice_coef: 1.8033Shuffling data
# 2802/7697 [=========>....................] - ETA: 7012s - loss: -1.8030 - dice_coef: 1.8030Shuffling data
# 2814/7697 [=========>....................] - ETA: 6995s - loss: -1.8032 - dice_coef: 1.8032Shuffling data
# 2828/7697 [==========>...................] - ETA: 6975s - loss: -1.8036 - dice_coef: 1.8036Shuffling data
# 2834/7697 [==========>...................] - ETA: 6967s - loss: -1.8033 - dice_coef: 1.8033Shuffling data
# 2846/7697 [==========>...................] - ETA: 6949s - loss: -1.8018 - dice_coef: 1.8018Shuffling data
# 2854/7697 [==========>...................] - ETA: 6938s - loss: -1.8022 - dice_coef: 1.8022Shuffling data
# 2864/7697 [==========>...................] - ETA: 6923s - loss: -1.8025 - dice_coef: 1.8025Shuffling data
# 2871/7697 [==========>...................] - ETA: 6913s - loss: -1.8023 - dice_coef: 1.8023Shuffling data
# 2884/7697 [==========>...................] - ETA: 6895s - loss: -1.8022 - dice_coef: 1.8022Shuffling data
# 2888/7697 [==========>...................] - ETA: 6889s - loss: -1.8019 - dice_coef: 1.8019Shuffling data
# 2898/7697 [==========>...................] - ETA: 6875s - loss: -1.8014 - dice_coef: 1.8014Shuffling data
# 2904/7697 [==========>...................] - ETA: 6866s - loss: -1.8017 - dice_coef: 1.8017Shuffling data
# 2912/7697 [==========>...................] - ETA: 6855s - loss: -1.8018 - dice_coef: 1.8018Shuffling data
# 2916/7697 [==========>...................] - ETA: 6849s - loss: -1.8018 - dice_coef: 1.8018Shuffling data
# 2922/7697 [==========>...................] - ETA: 6840s - loss: -1.8004 - dice_coef: 1.8004Shuffling data
# 2938/7697 [==========>...................] - ETA: 6817s - loss: -1.8000 - dice_coef: 1.8000Shuffling data
# 2953/7697 [==========>...................] - ETA: 6796s - loss: -1.7983 - dice_coef: 1.7983Shuffling data
# 2963/7697 [==========>...................] - ETA: 6781s - loss: -1.7988 - dice_coef: 1.7988Shuffling data
# 2970/7697 [==========>...................] - ETA: 6771s - loss: -1.7992 - dice_coef: 1.7992Shuffling data
# 2975/7697 [==========>...................] - ETA: 6764s - loss: -1.7992 - dice_coef: 1.7992Shuffling data
# 2982/7697 [==========>...................] - ETA: 6754s - loss: -1.7987 - dice_coef: 1.7987Shuffling data
# 2986/7697 [==========>...................] - ETA: 6748s - loss: -1.7986 - dice_coef: 1.7986Shuffling data
# 2990/7697 [==========>...................] - ETA: 6743s - loss: -1.7981 - dice_coef: 1.7981Shuffling data
# 3000/7697 [==========>...................] - ETA: 6728s - loss: -1.7976 - dice_coef: 1.7976Shuffling data
# 3004/7697 [==========>...................] - ETA: 6723s - loss: -1.7974 - dice_coef: 1.7974Shuffling data
# 3010/7697 [==========>...................] - ETA: 6714s - loss: -1.7973 - dice_coef: 1.7973Shuffling data
# 3025/7697 [==========>...................] - ETA: 6692s - loss: -1.7967 - dice_coef: 1.7967Shuffling data
# 3031/7697 [==========>...................] - ETA: 6684s - loss: -1.7970 - dice_coef: 1.7970Shuffling data
# 3038/7697 [==========>...................] - ETA: 6674s - loss: -1.7972 - dice_coef: 1.7972Shuffling data
# 3046/7697 [==========>...................] - ETA: 6662s - loss: -1.7973 - dice_coef: 1.7973Shuffling data
# 3057/7697 [==========>...................] - ETA: 6646s - loss: -1.7969 - dice_coef: 1.7969Shuffling data
# 3075/7697 [==========>...................] - ETA: 6621s - loss: -1.7974 - dice_coef: 1.7974Shuffling data
# 3086/7697 [===========>..................] - ETA: 6605s - loss: -1.7976 - dice_coef: 1.7976Shuffling data
# 3100/7697 [===========>..................] - ETA: 6585s - loss: -1.7967 - dice_coef: 1.7967Shuffling data
# 3106/7697 [===========>..................] - ETA: 6576s - loss: -1.7963 - dice_coef: 1.7963Shuffling data
# 3112/7697 [===========>..................] - ETA: 6568s - loss: -1.7959 - dice_coef: 1.7959Shuffling data
# 3127/7697 [===========>..................] - ETA: 6546s - loss: -1.7960 - dice_coef: 1.7960Shuffling data
# 3139/7697 [===========>..................] - ETA: 6529s - loss: -1.7964 - dice_coef: 1.7964Shuffling data
# 3146/7697 [===========>..................] - ETA: 6519s - loss: -1.7967 - dice_coef: 1.7967Shuffling data
# 3151/7697 [===========>..................] - ETA: 6512s - loss: -1.7969 - dice_coef: 1.7969Shuffling data
# 3155/7697 [===========>..................] - ETA: 6506s - loss: -1.7970 - dice_coef: 1.7970Shuffling data
# 3159/7697 [===========>..................] - ETA: 6500s - loss: -1.7966 - dice_coef: 1.7966Shuffling data
# 3168/7697 [===========>..................] - ETA: 6487s - loss: -1.7950 - dice_coef: 1.7950Shuffling data
# 3183/7697 [===========>..................] - ETA: 6466s - loss: -1.7950 - dice_coef: 1.7950Shuffling data
# 3188/7697 [===========>..................] - ETA: 6459s - loss: -1.7949 - dice_coef: 1.7949Shuffling data
# 3194/7697 [===========>..................] - ETA: 6450s - loss: -1.7952 - dice_coef: 1.7952Shuffling data
# 3200/7697 [===========>..................] - ETA: 6441s - loss: -1.7950 - dice_coef: 1.7950Shuffling data
# 3207/7697 [===========>..................] - ETA: 6431s - loss: -1.7947 - dice_coef: 1.7947Shuffling data
# 3219/7697 [===========>..................] - ETA: 6414s - loss: -1.7947 - dice_coef: 1.7947Shuffling data
# 3223/7697 [===========>..................] - ETA: 6408s - loss: -1.7949 - dice_coef: 1.7949Shuffling data
# 3227/7697 [===========>..................] - ETA: 6403s - loss: -1.7950 - dice_coef: 1.7950Shuffling data
# 3246/7697 [===========>..................] - ETA: 6376s - loss: -1.7952 - dice_coef: 1.7952Shuffling data
# 3261/7697 [===========>..................] - ETA: 6354s - loss: -1.7954 - dice_coef: 1.7954Shuffling data
# 3269/7697 [===========>..................] - ETA: 6343s - loss: -1.7958 - dice_coef: 1.7958Shuffling data
# 3280/7697 [===========>..................] - ETA: 6327s - loss: -1.7958 - dice_coef: 1.7958Shuffling data
# 3293/7697 [===========>..................] - ETA: 6308s - loss: -1.7960 - dice_coef: 1.7960Shuffling data
# 3306/7697 [===========>..................] - ETA: 6290s - loss: -1.7964 - dice_coef: 1.7964Shuffling data
# 3314/7697 [===========>..................] - ETA: 6278s - loss: -1.7967 - dice_coef: 1.7967Shuffling data
# 3320/7697 [===========>..................] - ETA: 6269s - loss: -1.7966 - dice_coef: 1.7966Shuffling data
# 3329/7697 [===========>..................] - ETA: 6257s - loss: -1.7967 - dice_coef: 1.7967Shuffling data
# 3341/7697 [============>.................] - ETA: 6239s - loss: -1.7966 - dice_coef: 1.7966Shuffling data
# 3348/7697 [============>.................] - ETA: 6229s - loss: -1.7967 - dice_coef: 1.7967Shuffling data
# 3362/7697 [============>.................] - ETA: 6209s - loss: -1.7971 - dice_coef: 1.7971Shuffling data
# 3376/7697 [============>.................] - ETA: 6189s - loss: -1.7970 - dice_coef: 1.7970Shuffling data
# 3381/7697 [============>.................] - ETA: 6182s - loss: -1.7963 - dice_coef: 1.7963Shuffling data
# 3386/7697 [============>.................] - ETA: 6175s - loss: -1.7962 - dice_coef: 1.7962Shuffling data
# 3391/7697 [============>.................] - ETA: 6168s - loss: -1.7962 - dice_coef: 1.7962Shuffling data
# 3397/7697 [============>.................] - ETA: 6159s - loss: -1.7958 - dice_coef: 1.7958Shuffling data
# 3401/7697 [============>.................] - ETA: 6153s - loss: -1.7959 - dice_coef: 1.7959Shuffling data
# 3413/7697 [============>.................] - ETA: 6136s - loss: -1.7958 - dice_coef: 1.7958Shuffling data
# 3418/7697 [============>.................] - ETA: 6129s - loss: -1.7959 - dice_coef: 1.7959Shuffling data
# 3421/7697 [============>.................] - ETA: 6125s - loss: -1.7959 - dice_coef: 1.7959Shuffling data
# 3429/7697 [============>.................] - ETA: 6113s - loss: -1.7948 - dice_coef: 1.7948Shuffling data
# 3438/7697 [============>.................] - ETA: 6100s - loss: -1.7940 - dice_coef: 1.7940Shuffling data
# 3443/7697 [============>.................] - ETA: 6093s - loss: -1.7942 - dice_coef: 1.7942Shuffling data
# 3448/7697 [============>.................] - ETA: 6086s - loss: -1.7944 - dice_coef: 1.7944Shuffling data
# 3454/7697 [============>.................] - ETA: 6077s - loss: -1.7940 - dice_coef: 1.7940Shuffling data
# 3463/7697 [============>.................] - ETA: 6064s - loss: -1.7938 - dice_coef: 1.7938Shuffling data
# 3477/7697 [============>.................] - ETA: 6044s - loss: -1.7906 - dice_coef: 1.7906Shuffling data
# 3490/7697 [============>.................] - ETA: 6026s - loss: -1.7908 - dice_coef: 1.7908Shuffling data
# 3495/7697 [============>.................] - ETA: 6018s - loss: -1.7910 - dice_coef: 1.7910Shuffling data
# 3498/7697 [============>.................] - ETA: 6014s - loss: -1.7911 - dice_coef: 1.7911Shuffling data
# 3506/7697 [============>.................] - ETA: 6003s - loss: -1.7902 - dice_coef: 1.7902Shuffling data
# 3517/7697 [============>.................] - ETA: 5987s - loss: -1.7890 - dice_coef: 1.7890Shuffling data
# 3526/7697 [============>.................] - ETA: 5974s - loss: -1.7894 - dice_coef: 1.7894Shuffling data
# 3554/7697 [============>.................] - ETA: 5934s - loss: -1.7903 - dice_coef: 1.7903Shuffling data
# 3566/7697 [============>.................] - ETA: 5917s - loss: -1.7907 - dice_coef: 1.7907Shuffling data
# 3571/7697 [============>.................] - ETA: 5909s - loss: -1.7906 - dice_coef: 1.7906Shuffling data
# 3579/7697 [============>.................] - ETA: 5898s - loss: -1.7902 - dice_coef: 1.7902Shuffling data
# 3586/7697 [============>.................] - ETA: 5888s - loss: -1.7903 - dice_coef: 1.7903Shuffling data
# 3605/7697 [=============>................] - ETA: 5861s - loss: -1.7905 - dice_coef: 1.7905Shuffling data
# 3610/7697 [=============>................] - ETA: 5854s - loss: -1.7904 - dice_coef: 1.7904Shuffling data
# 3615/7697 [=============>................] - ETA: 5847s - loss: -1.7904 - dice_coef: 1.7904Shuffling data
# 3620/7697 [=============>................] - ETA: 5839s - loss: -1.7898 - dice_coef: 1.7898Shuffling data
# 3630/7697 [=============>................] - ETA: 5825s - loss: -1.7895 - dice_coef: 1.7895Shuffling data
# 3635/7697 [=============>................] - ETA: 5818s - loss: -1.7897 - dice_coef: 1.7897Shuffling data
# 3646/7697 [=============>................] - ETA: 5802s - loss: -1.7890 - dice_coef: 1.7890Shuffling data
# 3649/7697 [=============>................] - ETA: 5798s - loss: -1.7887 - dice_coef: 1.7887Shuffling data
# 3659/7697 [=============>................] - ETA: 5784s - loss: -1.7882 - dice_coef: 1.7882Shuffling data
# 3664/7697 [=============>................] - ETA: 5776s - loss: -1.7883 - dice_coef: 1.7883Shuffling data
# 3673/7697 [=============>................] - ETA: 5763s - loss: -1.7881 - dice_coef: 1.7881Shuffling data
# 3687/7697 [=============>................] - ETA: 5743s - loss: -1.7872 - dice_coef: 1.7872Shuffling data
# 3693/7697 [=============>................] - ETA: 5735s - loss: -1.7872 - dice_coef: 1.7872Shuffling data
# 3700/7697 [=============>................] - ETA: 5725s - loss: -1.7864 - dice_coef: 1.7864Shuffling data
# 3705/7697 [=============>................] - ETA: 5718s - loss: -1.7865 - dice_coef: 1.7865Shuffling data
# 3710/7697 [=============>................] - ETA: 5710s - loss: -1.7863 - dice_coef: 1.7863Shuffling data
# 3722/7697 [=============>................] - ETA: 5693s - loss: -1.7854 - dice_coef: 1.7854Shuffling data
# 3737/7697 [=============>................] - ETA: 5672s - loss: -1.7857 - dice_coef: 1.7857Shuffling data
# 3751/7697 [=============>................] - ETA: 5652s - loss: -1.7861 - dice_coef: 1.7861Shuffling data
# 3759/7697 [=============>................] - ETA: 5640s - loss: -1.7863 - dice_coef: 1.7863Shuffling data
# 3798/7697 [=============>................] - ETA: 5584s - loss: -1.7860 - dice_coef: 1.7860Shuffling data
# 3806/7697 [=============>................] - ETA: 5573s - loss: -1.7855 - dice_coef: 1.7855Shuffling data
# 3825/7697 [=============>................] - ETA: 5545s - loss: -1.7854 - dice_coef: 1.7854Shuffling data
# 3836/7697 [=============>................] - ETA: 5530s - loss: -1.7857 - dice_coef: 1.7857Shuffling data
# 3853/7697 [==============>...............] - ETA: 5505s - loss: -1.7863 - dice_coef: 1.7863Shuffling data
# 3861/7697 [==============>...............] - ETA: 5494s - loss: -1.7866 - dice_coef: 1.7866Shuffling data
# 3866/7697 [==============>...............] - ETA: 5487s - loss: -1.7868 - dice_coef: 1.7868Shuffling data
# 3870/7697 [==============>...............] - ETA: 5481s - loss: -1.7869 - dice_coef: 1.7869Shuffling data
# 3876/7697 [==============>...............] - ETA: 5473s - loss: -1.7870 - dice_coef: 1.7870Shuffling data
# 3895/7697 [==============>...............] - ETA: 5445s - loss: -1.7863 - dice_coef: 1.7863Shuffling data
# 3907/7697 [==============>...............] - ETA: 5428s - loss: -1.7862 - dice_coef: 1.7862Shuffling data
# 3913/7697 [==============>...............] - ETA: 5419s - loss: -1.7864 - dice_coef: 1.7864Shuffling data
# 3919/7697 [==============>...............] - ETA: 5411s - loss: -1.7861 - dice_coef: 1.7861Shuffling data
# 3925/7697 [==============>...............] - ETA: 5402s - loss: -1.7859 - dice_coef: 1.7859Shuffling data
# 3946/7697 [==============>...............] - ETA: 5372s - loss: -1.7857 - dice_coef: 1.7857Shuffling data
# 3951/7697 [==============>...............] - ETA: 5365s - loss: -1.7857 - dice_coef: 1.7857Shuffling data
# 3961/7697 [==============>...............] - ETA: 5351s - loss: -1.7858 - dice_coef: 1.7858Shuffling data
# 3968/7697 [==============>...............] - ETA: 5341s - loss: -1.7857 - dice_coef: 1.7857Shuffling data
# 3980/7697 [==============>...............] - ETA: 5323s - loss: -1.7853 - dice_coef: 1.7853Shuffling data
# 3985/7697 [==============>...............] - ETA: 5316s - loss: -1.7853 - dice_coef: 1.7853Shuffling data
# 3989/7697 [==============>...............] - ETA: 5310s - loss: -1.7854 - dice_coef: 1.7854Shuffling data
# 3995/7697 [==============>...............] - ETA: 5302s - loss: -1.7850 - dice_coef: 1.7850Shuffling data
# 4000/7697 [==============>...............] - ETA: 5295s - loss: -1.7848 - dice_coef: 1.7848Shuffling data
# 4007/7697 [==============>...............] - ETA: 5285s - loss: -1.7848 - dice_coef: 1.7848Shuffling data
# 4036/7697 [==============>...............] - ETA: 5243s - loss: -1.7844 - dice_coef: 1.7844Shuffling data
# 4042/7697 [==============>...............] - ETA: 5235s - loss: -1.7846 - dice_coef: 1.7846Shuffling data
# 4053/7697 [==============>...............] - ETA: 5219s - loss: -1.7844 - dice_coef: 1.7844Shuffling data
# 4066/7697 [==============>...............] - ETA: 5200s - loss: -1.7847 - dice_coef: 1.7847Shuffling data
# 4074/7697 [==============>...............] - ETA: 5189s - loss: -1.7842 - dice_coef: 1.7842Shuffling data
# 4081/7697 [==============>...............] - ETA: 5179s - loss: -1.7838 - dice_coef: 1.7838Shuffling data
# 4089/7697 [==============>...............] - ETA: 5167s - loss: -1.7837 - dice_coef: 1.7837Shuffling data
# 4096/7697 [==============>...............] - ETA: 5157s - loss: -1.7832 - dice_coef: 1.7832Shuffling data
# 4102/7697 [==============>...............] - ETA: 5149s - loss: -1.7833 - dice_coef: 1.7833Shuffling data
# 4108/7697 [===============>..............] - ETA: 5140s - loss: -1.7835 - dice_coef: 1.7835Shuffling data
# 4113/7697 [===============>..............] - ETA: 5133s - loss: -1.7836 - dice_coef: 1.7836Shuffling data
# 4119/7697 [===============>..............] - ETA: 5124s - loss: -1.7838 - dice_coef: 1.7838Shuffling data
# ...
# 6350/7697 [=======================>......] - ETA: 1929s - loss: -1.7866 - dice_coef: 1.7866Shuffling data
# 6355/7697 [=======================>......] - ETA: 1921s - loss: -1.7867 - dice_coef: 1.7867Shuffling data
# 6361/7697 [=======================>......] - ETA: 1913s - loss: -1.7868 - dice_coef: 1.7868Shuffling data
# 6379/7697 [=======================>......] - ETA: 1887s - loss: -1.7869 - dice_coef: 1.7869Shuffling data
# 6389/7697 [=======================>......] - ETA: 1873s - loss: -1.7871 - dice_coef: 1.7871Shuffling data
# 6399/7697 [=======================>......] - ETA: 1858s - loss: -1.7873 - dice_coef: 1.7873Shuffling data
# 6409/7697 [=======================>......] - ETA: 1844s - loss: -1.7873 - dice_coef: 1.7873Shuffling data
# 6421/7697 [========================>.....] - ETA: 1827s - loss: -1.7876 - dice_coef: 1.7876Shuffling data
# 6427/7697 [========================>.....] - ETA: 1818s - loss: -1.7877 - dice_coef: 1.7877Shuffling data
# 6438/7697 [========================>.....] - ETA: 1802s - loss: -1.7871 - dice_coef: 1.7871Shuffling data
# 6445/7697 [========================>.....] - ETA: 1792s - loss: -1.7872 - dice_coef: 1.7872Shuffling data
# 6451/7697 [========================>.....] - ETA: 1784s - loss: -1.7872 - dice_coef: 1.7872Shuffling data
# 6454/7697 [========================>.....] - ETA: 1780s - loss: -1.7873 - dice_coef: 1.7873Shuffling data
# 6461/7697 [========================>.....] - ETA: 1770s - loss: -1.7873 - dice_coef: 1.7873Shuffling data
# 6469/7697 [========================>.....] - ETA: 1758s - loss: -1.7873 - dice_coef: 1.7873Shuffling data
# 6473/7697 [========================>.....] - ETA: 1752s - loss: -1.7873 - dice_coef: 1.7873Shuffling data
# 6481/7697 [========================>.....] - ETA: 1741s - loss: -1.7874 - dice_coef: 1.7874Shuffling data
# 6489/7697 [========================>.....] - ETA: 1729s - loss: -1.7875 - dice_coef: 1.7875Shuffling data
# 6495/7697 [========================>.....] - ETA: 1721s - loss: -1.7876 - dice_coef: 1.7876Shuffling data
# 6516/7697 [========================>.....] - ETA: 1691s - loss: -1.7879 - dice_coef: 1.7879Shuffling data
# 6520/7697 [========================>.....] - ETA: 1685s - loss: -1.7879 - dice_coef: 1.7879Shuffling data
# 6531/7697 [========================>.....] - ETA: 1669s - loss: -1.7879 - dice_coef: 1.7879Shuffling data
# 6536/7697 [========================>.....] - ETA: 1662s - loss: -1.7876 - dice_coef: 1.7876Shuffling data
# 6544/7697 [========================>.....] - ETA: 1651s - loss: -1.7876 - dice_coef: 1.7876Shuffling data
# 6552/7697 [========================>.....] - ETA: 1639s - loss: -1.7876 - dice_coef: 1.7876Shuffling data
# 6566/7697 [========================>.....] - ETA: 1619s - loss: -1.7878 - dice_coef: 1.7878Shuffling data
# 6574/7697 [========================>.....] - ETA: 1608s - loss: -1.7880 - dice_coef: 1.7880Shuffling data
# 6583/7697 [========================>.....] - ETA: 1595s - loss: -1.7882 - dice_coef: 1.7882Shuffling data
# 6589/7697 [========================>.....] - ETA: 1586s - loss: -1.7883 - dice_coef: 1.7883Shuffling data
# 6593/7697 [========================>.....] - ETA: 1580s - loss: -1.7882 - dice_coef: 1.7882Shuffling data
# 6598/7697 [========================>.....] - ETA: 1573s - loss: -1.7881 - dice_coef: 1.7881Shuffling data
# 6604/7697 [========================>.....] - ETA: 1565s - loss: -1.7880 - dice_coef: 1.7880Shuffling data
# 6617/7697 [========================>.....] - ETA: 1546s - loss: -1.7881 - dice_coef: 1.7881Shuffling data
# 6622/7697 [========================>.....] - ETA: 1539s - loss: -1.7882 - dice_coef: 1.7882Shuffling data
# 6635/7697 [========================>.....] - ETA: 1520s - loss: -1.7883 - dice_coef: 1.7883Shuffling data
# 6642/7697 [========================>.....] - ETA: 1510s - loss: -1.7885 - dice_coef: 1.7885Shuffling data
# 6654/7697 [========================>.....] - ETA: 1493s - loss: -1.7887 - dice_coef: 1.7887Shuffling data
# 6658/7697 [========================>.....] - ETA: 1487s - loss: -1.7887 - dice_coef: 1.7887Shuffling data
# 6669/7697 [========================>.....] - ETA: 1472s - loss: -1.7889 - dice_coef: 1.7889Shuffling data
# 6676/7697 [=========================>....] - ETA: 1462s - loss: -1.7890 - dice_coef: 1.7890Shuffling data
# 6691/7697 [=========================>....] - ETA: 1440s - loss: -1.7891 - dice_coef: 1.7891Shuffling data
# 6715/7697 [=========================>....] - ETA: 1406s - loss: -1.7896 - dice_coef: 1.7896Shuffling data
# 6721/7697 [=========================>....] - ETA: 1397s - loss: -1.7898 - dice_coef: 1.7898Shuffling data
# 6728/7697 [=========================>....] - ETA: 1387s - loss: -1.7899 - dice_coef: 1.7899Shuffling data
# 6743/7697 [=========================>....] - ETA: 1366s - loss: -1.7901 - dice_coef: 1.7901Shuffling data
# 6753/7697 [=========================>....] - ETA: 1351s - loss: -1.7903 - dice_coef: 1.7903Shuffling data
# 6770/7697 [=========================>....] - ETA: 1327s - loss: -1.7906 - dice_coef: 1.7906Shuffling data
# 6782/7697 [=========================>....] - ETA: 1310s - loss: -1.7906 - dice_coef: 1.7906Shuffling data
# 6788/7697 [=========================>....] - ETA: 1301s - loss: -1.7907 - dice_coef: 1.7907Shuffling data
# 6794/7697 [=========================>....] - ETA: 1293s - loss: -1.7908 - dice_coef: 1.7908Shuffling data
# 6801/7697 [=========================>....] - ETA: 1283s - loss: -1.7907 - dice_coef: 1.7907Shuffling data
# 6805/7697 [=========================>....] - ETA: 1277s - loss: -1.7906 - dice_coef: 1.7906Shuffling data
# 6810/7697 [=========================>....] - ETA: 1270s - loss: -1.7905 - dice_coef: 1.7905Shuffling data
# 6818/7697 [=========================>....] - ETA: 1258s - loss: -1.7903 - dice_coef: 1.7903Shuffling data
# 6824/7697 [=========================>....] - ETA: 1250s - loss: -1.7903 - dice_coef: 1.7903Shuffling data
# 6832/7697 [=========================>....] - ETA: 1238s - loss: -1.7904 - dice_coef: 1.7904Shuffling data
# 6840/7697 [=========================>....] - ETA: 1227s - loss: -1.7904 - dice_coef: 1.7904Shuffling data
# 6846/7697 [=========================>....] - ETA: 1218s - loss: -1.7901 - dice_coef: 1.7901Shuffling data
# 6854/7697 [=========================>....] - ETA: 1207s - loss: -1.7899 - dice_coef: 1.7899Shuffling data
# 6859/7697 [=========================>....] - ETA: 1200s - loss: -1.7899 - dice_coef: 1.7899Shuffling data
# 6873/7697 [=========================>....] - ETA: 1179s - loss: -1.7898 - dice_coef: 1.7898Shuffling data
# 6881/7697 [=========================>....] - ETA: 1168s - loss: -1.7900 - dice_coef: 1.7900Shuffling data
# 6892/7697 [=========================>....] - ETA: 1152s - loss: -1.7898 - dice_coef: 1.7898Shuffling data
# 6906/7697 [=========================>....] - ETA: 1132s - loss: -1.7893 - dice_coef: 1.7893Shuffling data
# 6913/7697 [=========================>....] - ETA: 1122s - loss: -1.7894 - dice_coef: 1.7894Shuffling data
# 6919/7697 [=========================>....] - ETA: 1114s - loss: -1.7895 - dice_coef: 1.7895Shuffling data
# 6923/7697 [=========================>....] - ETA: 1108s - loss: -1.7894 - dice_coef: 1.7894Shuffling data
# 6929/7697 [==========================>...] - ETA: 1099s - loss: -1.7893 - dice_coef: 1.7893Shuffling data
# 6943/7697 [==========================>...] - ETA: 1079s - loss: -1.7887 - dice_coef: 1.7887Shuffling data
# 6953/7697 [==========================>...] - ETA: 1065s - loss: -1.7887 - dice_coef: 1.7887Shuffling data
# 6957/7697 [==========================>...] - ETA: 1059s - loss: -1.7888 - dice_coef: 1.7888Shuffling data
# 6962/7697 [==========================>...] - ETA: 1052s - loss: -1.7888 - dice_coef: 1.7888Shuffling data
# 6969/7697 [==========================>...] - ETA: 1042s - loss: -1.7886 - dice_coef: 1.7886Shuffling data
# 6976/7697 [==========================>...] - ETA: 1032s - loss: -1.7887 - dice_coef: 1.7887Shuffling data
# 6981/7697 [==========================>...] - ETA: 1025s - loss: -1.7886 - dice_coef: 1.7886Shuffling data
# 6986/7697 [==========================>...] - ETA: 1018s - loss: -1.7886 - dice_coef: 1.7886Shuffling data
# 6993/7697 [==========================>...] - ETA: 1008s - loss: -1.7887 - dice_coef: 1.7887Shuffling data
# 7005/7697 [==========================>...] - ETA: 990s - loss: -1.7889 - dice_coef: 1.7889Shuffling data
# 7010/7697 [==========================>...] - ETA: 983s - loss: -1.7890 - dice_coef: 1.7890Shuffling data
# 7015/7697 [==========================>...] - ETA: 976s - loss: -1.7891 - dice_coef: 1.7891Shuffling data
# 7031/7697 [==========================>...] - ETA: 953s - loss: -1.7886 - dice_coef: 1.7886Shuffling data
# 7043/7697 [==========================>...] - ETA: 936s - loss: -1.7886 - dice_coef: 1.7886Shuffling data
# 7055/7697 [==========================>...] - ETA: 919s - loss: -1.7888 - dice_coef: 1.7888Shuffling data
# 7066/7697 [==========================>...] - ETA: 903s - loss: -1.7891 - dice_coef: 1.7891Shuffling data
# 7080/7697 [==========================>...] - ETA: 883s - loss: -1.7893 - dice_coef: 1.7893Shuffling data
# 7094/7697 [==========================>...] - ETA: 863s - loss: -1.7896 - dice_coef: 1.7896Shuffling data
# 7103/7697 [==========================>...] - ETA: 850s - loss: -1.7898 - dice_coef: 1.7898Shuffling data
# 7117/7697 [==========================>...] - ETA: 830s - loss: -1.7900 - dice_coef: 1.7900Shuffling data
# 7122/7697 [==========================>...] - ETA: 823s - loss: -1.7901 - dice_coef: 1.7901Shuffling data
# 7131/7697 [==========================>...] - ETA: 810s - loss: -1.7902 - dice_coef: 1.7902Shuffling data
# 7140/7697 [==========================>...] - ETA: 797s - loss: -1.7903 - dice_coef: 1.7903Shuffling data
# 7150/7697 [==========================>...] - ETA: 783s - loss: -1.7902 - dice_coef: 1.7902Shuffling data
# 7156/7697 [==========================>...] - ETA: 774s - loss: -1.7903 - dice_coef: 1.7903Shuffling data
# 7166/7697 [==========================>...] - ETA: 760s - loss: -1.7903 - dice_coef: 1.7903Shuffling data
# 7174/7697 [==========================>...] - ETA: 748s - loss: -1.7902 - dice_coef: 1.7902Shuffling data
# 7181/7697 [==========================>...] - ETA: 738s - loss: -1.7902 - dice_coef: 1.7902Shuffling data
# 7190/7697 [===========================>..] - ETA: 726s - loss: -1.7901 - dice_coef: 1.7901Shuffling data
# 7196/7697 [===========================>..] - ETA: 717s - loss: -1.7902 - dice_coef: 1.7902Shuffling data
# 7202/7697 [===========================>..] - ETA: 708s - loss: -1.7902 - dice_coef: 1.7902Shuffling data
# 7210/7697 [===========================>..] - ETA: 697s - loss: -1.7901 - dice_coef: 1.7901Shuffling data
# 7222/7697 [===========================>..] - ETA: 680s - loss: -1.7901 - dice_coef: 1.7901Shuffling data
# 7236/7697 [===========================>..] - ETA: 660s - loss: -1.7904 - dice_coef: 1.7904Shuffling data
# 7242/7697 [===========================>..] - ETA: 651s - loss: -1.7904 - dice_coef: 1.7904Shuffling data
# 7254/7697 [===========================>..] - ETA: 634s - loss: -1.7898 - dice_coef: 1.7898Shuffling data
# 7262/7697 [===========================>..] - ETA: 622s - loss: -1.7899 - dice_coef: 1.7899Shuffling data
# 7272/7697 [===========================>..] - ETA: 608s - loss: -1.7900 - dice_coef: 1.7900Shuffling data
# 7279/7697 [===========================>..] - ETA: 598s - loss: -1.7899 - dice_coef: 1.7899Shuffling data
# 7292/7697 [===========================>..] - ETA: 579s - loss: -1.7899 - dice_coef: 1.7899Shuffling data
# 7296/7697 [===========================>..] - ETA: 574s - loss: -1.7899 - dice_coef: 1.7899Shuffling data
# 7306/7697 [===========================>..] - ETA: 559s - loss: -1.7896 - dice_coef: 1.7896Shuffling data
# 7312/7697 [===========================>..] - ETA: 551s - loss: -1.7897 - dice_coef: 1.7897Shuffling data
# 7320/7697 [===========================>..] - ETA: 539s - loss: -1.7897 - dice_coef: 1.7897Shuffling data
# 7324/7697 [===========================>..] - ETA: 534s - loss: -1.7895 - dice_coef: 1.7895Shuffling data
# 7330/7697 [===========================>..] - ETA: 525s - loss: -1.7890 - dice_coef: 1.7890Shuffling data
# 7346/7697 [===========================>..] - ETA: 502s - loss: -1.7889 - dice_coef: 1.7889Shuffling data
# 7361/7697 [===========================>..] - ETA: 481s - loss: -1.7884 - dice_coef: 1.7884Shuffling data
# 7371/7697 [===========================>..] - ETA: 466s - loss: -1.7887 - dice_coef: 1.7887Shuffling data
# 7378/7697 [===========================>..] - ETA: 456s - loss: -1.7888 - dice_coef: 1.7888Shuffling data
# 7382/7697 [===========================>..] - ETA: 451s - loss: -1.7889 - dice_coef: 1.7889Shuffling data
# 7390/7697 [===========================>..] - ETA: 439s - loss: -1.7889 - dice_coef: 1.7889Shuffling data
# 7394/7697 [===========================>..] - ETA: 433s - loss: -1.7888 - dice_coef: 1.7888Shuffling data
# 7398/7697 [===========================>..] - ETA: 428s - loss: -1.7887 - dice_coef: 1.7887Shuffling data
# 7408/7697 [===========================>..] - ETA: 413s - loss: -1.7881 - dice_coef: 1.7881Shuffling data
# 7412/7697 [===========================>..] - ETA: 408s - loss: -1.7880 - dice_coef: 1.7880Shuffling data
# 7418/7697 [===========================>..] - ETA: 399s - loss: -1.7880 - dice_coef: 1.7880Shuffling data
# 7433/7697 [===========================>..] - ETA: 378s - loss: -1.7877 - dice_coef: 1.7877Shuffling data
# 7439/7697 [===========================>..] - ETA: 369s - loss: -1.7878 - dice_coef: 1.7878Shuffling data
# 7446/7697 [============================>.] - ETA: 359s - loss: -1.7878 - dice_coef: 1.7878Shuffling data
# 7454/7697 [============================>.] - ETA: 347s - loss: -1.7877 - dice_coef: 1.7877Shuffling data
# 7465/7697 [============================>.] - ETA: 332s - loss: -1.7876 - dice_coef: 1.7876Shuffling data
# 7483/7697 [============================>.] - ETA: 306s - loss: -1.7878 - dice_coef: 1.7878Shuffling data
# 7494/7697 [============================>.] - ETA: 290s - loss: -1.7880 - dice_coef: 1.7880Shuffling data
# 7508/7697 [============================>.] - ETA: 270s - loss: -1.7878 - dice_coef: 1.7878Shuffling data
# 7514/7697 [============================>.] - ETA: 262s - loss: -1.7878 - dice_coef: 1.7878Shuffling data
# 7520/7697 [============================>.] - ETA: 253s - loss: -1.7877 - dice_coef: 1.7877Shuffling data
# 7535/7697 [============================>.] - ETA: 231s - loss: -1.7878 - dice_coef: 1.7878Shuffling data
# 7547/7697 [============================>.] - ETA: 214s - loss: -1.7880 - dice_coef: 1.7880Shuffling data
# 7554/7697 [============================>.] - ETA: 204s - loss: -1.7881 - dice_coef: 1.7881Shuffling data
# 7559/7697 [============================>.] - ETA: 197s - loss: -1.7881 - dice_coef: 1.7881Shuffling data
# 7563/7697 [============================>.] - ETA: 191s - loss: -1.7881 - dice_coef: 1.7881Shuffling data
# 7567/7697 [============================>.] - ETA: 186s - loss: -1.7880 - dice_coef: 1.7880Shuffling data
# 7576/7697 [============================>.] - ETA: 173s - loss: -1.7874 - dice_coef: 1.7874Shuffling data
# 7591/7697 [============================>.] - ETA: 151s - loss: -1.7875 - dice_coef: 1.7875Shuffling data
# 7596/7697 [============================>.] - ETA: 144s - loss: -1.7876 - dice_coef: 1.7876Shuffling data
# 7602/7697 [============================>.] - ETA: 136s - loss: -1.7877 - dice_coef: 1.7877Shuffling data
# 7608/7697 [============================>.] - ETA: 127s - loss: -1.7874 - dice_coef: 1.7874Shuffling data
# 7615/7697 [============================>.] - ETA: 117s - loss: -1.7873 - dice_coef: 1.7873Shuffling data
# 7627/7697 [============================>.] - ETA: 100s - loss: -1.7873 - dice_coef: 1.7873Shuffling data
# 7631/7697 [============================>.] - ETA: 94s - loss: -1.7874 - dice_coef: 1.7874Shuffling data
# 7635/7697 [============================>.] - ETA: 88s - loss: -1.7875 - dice_coef: 1.7875Shuffling data
# 7648/7697 [============================>.] - ETA: 70s - loss: -1.7875 - dice_coef: 1.7875
