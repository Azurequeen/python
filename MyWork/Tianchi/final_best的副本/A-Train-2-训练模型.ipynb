# %%
from utils.imports import *
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 训练模型

# %%
src = PATH['model_train']
model_paths = PATH['model_paths']

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def dice_coef_np(y_true,y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return ((2. * intersection + 1) / (np.sum(y_true_f) + np.sum(y_pred_f) + 1))

def unet_model(dropout_rate,learn_rate, width):
    inputs = Input((1, 512, 512))
    conv1 = Convolution2D(width, (3, 3), padding="same", activation="elu")(inputs)
    conv1 = BatchNormalization(axis = 1)(conv1)
    conv1 = Convolution2D(width, (3, 3), padding="same", activation="elu")(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Convolution2D(width*2, (3, 3), padding="same", activation="elu")(pool1)
    conv2 = BatchNormalization(axis = 1)(conv2)
    conv2 = Convolution2D(width*2, (3, 3), padding="same", activation="elu")(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Convolution2D(width*4, (3, 3), padding="same", activation="elu")(pool2)
    conv3 = BatchNormalization(axis = 1)(conv3)
    conv3 = Convolution2D(width*4, (3, 3), padding="same", activation="elu")(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Convolution2D(width*8, (3, 3), padding="same", activation="elu")(pool3)
    conv4 = BatchNormalization(axis = 1)(conv4)
    conv4 = Convolution2D(width*8, (3, 3), padding="same", activation="elu")(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Convolution2D(width*16, (3, 3), padding="same", activation="elu")(pool4)
    conv5 = BatchNormalization(axis = 1)(conv5)
    conv5 = Convolution2D(width*16, (3, 3), padding="same", activation="elu")(conv5)

    up6 = merge([UpSampling2D(size=(2, 2))(conv5), conv4], mode='concat', concat_axis=1)
    conv6 = SpatialDropout2D(dropout_rate)(up6)
    conv6 = Convolution2D(width*8, (3, 3), padding="same", activation="elu")(conv6)
    conv6 = Convolution2D(width*8, (3, 3), padding="same", activation="elu")(conv6)

    up7 = merge([UpSampling2D(size=(2, 2))(conv6), conv3], mode='concat', concat_axis=1)
    conv7 = SpatialDropout2D(dropout_rate)(up7)
    conv7 = Convolution2D(width*4, (3, 3), padding="same", activation="elu")(conv7)
    conv7 = Convolution2D(width*4, (3, 3), padding="same", activation="elu")(conv7)

    up8 = merge([UpSampling2D(size=(2, 2))(conv7), conv2], mode='concat', concat_axis=1)
    conv8 = SpatialDropout2D(dropout_rate)(up8)
    conv8 = Convolution2D(width*2, (3, 3), padding="same", activation="elu")(conv8)
    conv8 = Convolution2D(width*2, (3, 3), padding="same", activation="elu")(conv8)

    up9 = merge([UpSampling2D(size=(2, 2))(conv8), conv1], mode='concat', concat_axis=1)
    conv9 = SpatialDropout2D(dropout_rate)(up9)
    conv9 = Convolution2D(width, (3, 3), padding="same", activation="elu")(conv9)
    conv9 = Convolution2D(width, (3, 3), padding="same", activation="elu")(conv9)
    conv10 = Convolution2D(1, (1, 1), activation="sigmoid")(conv9)

    model = Model(input=inputs, output=conv10)
    #model.summary()
    model.compile(optimizer=Adam(lr=learn_rate), loss=dice_coef_loss, metrics=[dice_coef])
    #model.compile(optimizer=SGD(lr=learn_rate, momentum=0.9, nesterov=True), loss=dice_coef_loss, metrics=[dice_coef])
    
    #plot_model(model, to_file='model1.png',show_shapes=True)
    return model


def unet_fit(name, check_name = None):
    data_gen_args = dict(rotation_range=90.,   
                     width_shift_range=0.3,  
                     height_shift_range=0.3,   
                     horizontal_flip=True,   
                     vertical_flip=True,  
                     )
    from keras.preprocessing.image import ImageDataGenerator
    image_datagen = ImageDataGenerator(**data_gen_args)
    mask_datagen = ImageDataGenerator(**data_gen_args)

    # Provide the same seed and keyword arguments to the fit and flow methods
    seed = 1
    
    image_generator = image_datagen.flow_from_directory(
        src,
        class_mode=None,
        classes=['lung'],
        seed=seed,
        target_size=(512,512),
        color_mode="grayscale",
        batch_size=1)

    mask_generator = mask_datagen.flow_from_directory(
        src,
        class_mode=None,
        classes=['nodule'],
        seed=seed,
        target_size=(512,512),
        color_mode="grayscale",
        batch_size=1) 
    # combine generators into one which yields image and masks
    train_generator = itertools.izip(image_generator, mask_generator)   
    t = time.time()
    callbacks = [EarlyStopping(monitor='val_loss', patience = 40, 
                                   verbose = 1),
    ModelCheckpoint(model_paths + '{}.h5'.format(name), 
                        monitor='val_loss', 
                        verbose = 0, save_best_only = True)]
    
    if check_name is not None:
        check_model = model_paths + '{}.h5'.format(check_name)
        model = load_model(check_model, 
                           custom_objects={'dice_coef_loss': dice_coef_loss, 'dice_coef': dice_coef})
    else:
        model = unet_model(dropout_rate = 0.35, learn_rate = 1e-5, width = 32)
    model.fit_generator(
        train_generator,
        epochs=300,
        verbose =1, 
        callbacks = callbacks,
        steps_per_epoch=256,
        validation_data = train_generator,
        nb_val_samples = 48)
    return

# %%
#unet_fit('final_fenge_170626')
unet_fit('final_fenge_170626','final_fenge_170626')
# Out:
# Found 3711 images belonging to 1 classes.
# Found 3711 images belonging to 1 classes.
# Epoch 1/300
# 256/256 [==============================] - 96s - loss: -1.1876 - dice_coef: 1.1876 - val_loss: -0.9817 - val_dice_coef: 0.9817
# Epoch 2/300
# 256/256 [==============================] - 92s - loss: -1.2123 - dice_coef: 1.2123 - val_loss: -0.9181 - val_dice_coef: 0.9181
# Epoch 3/300
# 256/256 [==============================] - 94s - loss: -1.1728 - dice_coef: 1.1728 - val_loss: -1.0871 - val_dice_coef: 1.0871
# Epoch 4/300
# 256/256 [==============================] - 94s - loss: -1.2254 - dice_coef: 1.2254 - val_loss: -1.3041 - val_dice_coef: 1.3041
# Epoch 5/300
# 256/256 [==============================] - 92s - loss: -1.1811 - dice_coef: 1.1811 - val_loss: -0.8569 - val_dice_coef: 0.8569
# Epoch 6/300
# 256/256 [==============================] - 92s - loss: -1.2306 - dice_coef: 1.2306 - val_loss: -0.9389 - val_dice_coef: 0.9389
# Epoch 7/300
# 256/256 [==============================] - 92s - loss: -1.2613 - dice_coef: 1.2613 - val_loss: -0.9236 - val_dice_coef: 0.9236
# Epoch 8/300
# 256/256 [==============================] - 92s - loss: -1.2486 - dice_coef: 1.2486 - val_loss: -1.1660 - val_dice_coef: 1.1660
# Epoch 9/300
# 256/256 [==============================] - 94s - loss: -1.3243 - dice_coef: 1.3243 - val_loss: -1.3463 - val_dice_coef: 1.3463
# Epoch 10/300
# 256/256 [==============================] - 92s - loss: -1.2345 - dice_coef: 1.2345 - val_loss: -1.0947 - val_dice_coef: 1.0947
# Epoch 11/300
# 256/256 [==============================] - 92s - loss: -1.2662 - dice_coef: 1.2662 - val_loss: -0.9744 - val_dice_coef: 0.9744
# Epoch 12/300
# 256/256 [==============================] - 92s - loss: -1.2919 - dice_coef: 1.2919 - val_loss: -1.2076 - val_dice_coef: 1.2076
# Epoch 13/300
# 256/256 [==============================] - 92s - loss: -1.2896 - dice_coef: 1.2896 - val_loss: -1.1158 - val_dice_coef: 1.1158
# Epoch 14/300
# 256/256 [==============================] - 92s - loss: -1.2935 - dice_coef: 1.2935 - val_loss: -1.3201 - val_dice_coef: 1.3201
# Epoch 15/300
# 256/256 [==============================] - 92s - loss: -1.2650 - dice_coef: 1.2650 - val_loss: -1.1581 - val_dice_coef: 1.1581
# Epoch 16/300
# 256/256 [==============================] - 95s - loss: -1.3182 - dice_coef: 1.3182 - val_loss: -1.3966 - val_dice_coef: 1.3966
# Epoch 17/300
# 256/256 [==============================] - 92s - loss: -1.2876 - dice_coef: 1.2876 - val_loss: -1.2278 - val_dice_coef: 1.2278
# Epoch 18/300
# 256/256 [==============================] - 92s - loss: -1.3243 - dice_coef: 1.3243 - val_loss: -1.1816 - val_dice_coef: 1.1816
# Epoch 19/300
# 256/256 [==============================] - 92s - loss: -1.2997 - dice_coef: 1.2997 - val_loss: -1.0758 - val_dice_coef: 1.0758
# Epoch 20/300
# 256/256 [==============================] - 92s - loss: -1.3987 - dice_coef: 1.3987 - val_loss: -1.1277 - val_dice_coef: 1.1277
# Epoch 21/300
# 256/256 [==============================] - 94s - loss: -1.2754 - dice_coef: 1.2754 - val_loss: -1.4142 - val_dice_coef: 1.4142
# Epoch 22/300
# 256/256 [==============================] - 92s - loss: -1.2989 - dice_coef: 1.2989 - val_loss: -1.0937 - val_dice_coef: 1.0937
# Epoch 23/300
# 256/256 [==============================] - 92s - loss: -1.3620 - dice_coef: 1.3620 - val_loss: -1.0231 - val_dice_coef: 1.0231
# Epoch 24/300
# 256/256 [==============================] - 92s - loss: -1.3533 - dice_coef: 1.3533 - val_loss: -1.2822 - val_dice_coef: 1.2822
# Epoch 25/300
# 256/256 [==============================] - 92s - loss: -1.3681 - dice_coef: 1.3681 - val_loss: -1.1737 - val_dice_coef: 1.1737
# Epoch 26/300
# 256/256 [==============================] - 92s - loss: -1.3325 - dice_coef: 1.3325 - val_loss: -1.3175 - val_dice_coef: 1.3175
# Epoch 27/300
# 256/256 [==============================] - 92s - loss: -1.3281 - dice_coef: 1.3281 - val_loss: -1.2733 - val_dice_coef: 1.2733
# Epoch 28/300
# 256/256 [==============================] - 92s - loss: -1.3826 - dice_coef: 1.3826 - val_loss: -1.1408 - val_dice_coef: 1.1408
# Epoch 29/300
# 256/256 [==============================] - 92s - loss: -1.3488 - dice_coef: 1.3488 - val_loss: -1.2776 - val_dice_coef: 1.2776
# Epoch 30/300
# 256/256 [==============================] - 92s - loss: -1.4252 - dice_coef: 1.4252 - val_loss: -1.1503 - val_dice_coef: 1.1503
# Epoch 31/300
# 256/256 [==============================] - 93s - loss: -1.3429 - dice_coef: 1.3429 - val_loss: -1.4497 - val_dice_coef: 1.4497
# Epoch 32/300
# 256/256 [==============================] - 94s - loss: -1.4544 - dice_coef: 1.4544 - val_loss: -1.5247 - val_dice_coef: 1.5247
# Epoch 33/300
# 256/256 [==============================] - 92s - loss: -1.3309 - dice_coef: 1.3309 - val_loss: -1.1062 - val_dice_coef: 1.1062
# Epoch 34/300
# 256/256 [==============================] - 92s - loss: -1.4236 - dice_coef: 1.4236 - val_loss: -1.4207 - val_dice_coef: 1.4207
# Epoch 35/300
# 256/256 [==============================] - 92s - loss: -1.3852 - dice_coef: 1.3852 - val_loss: -1.4001 - val_dice_coef: 1.4001
# Epoch 36/300
# 256/256 [==============================] - 92s - loss: -1.3857 - dice_coef: 1.3857 - val_loss: -1.3676 - val_dice_coef: 1.3676
# Epoch 37/300
# 256/256 [==============================] - 92s - loss: -1.3874 - dice_coef: 1.3874 - val_loss: -1.2752 - val_dice_coef: 1.2752
# Epoch 38/300
# 256/256 [==============================] - 92s - loss: -1.3687 - dice_coef: 1.3687 - val_loss: -1.1674 - val_dice_coef: 1.1674
# Epoch 39/300
# 256/256 [==============================] - 92s - loss: -1.3726 - dice_coef: 1.3726 - val_loss: -1.4317 - val_dice_coef: 1.4317
# Epoch 40/300
# 256/256 [==============================] - 92s - loss: -1.4578 - dice_coef: 1.4578 - val_loss: -1.2401 - val_dice_coef: 1.2401
# Epoch 41/300
# 256/256 [==============================] - 92s - loss: -1.3403 - dice_coef: 1.3403 - val_loss: -1.2811 - val_dice_coef: 1.2811
# Epoch 42/300
# 256/256 [==============================] - 92s - loss: -1.4118 - dice_coef: 1.4118 - val_loss: -1.3180 - val_dice_coef: 1.3180
# Epoch 43/300
# 256/256 [==============================] - 92s - loss: -1.4750 - dice_coef: 1.4750 - val_loss: -1.1805 - val_dice_coef: 1.1805
# Epoch 44/300
# 256/256 [==============================] - 92s - loss: -1.4509 - dice_coef: 1.4509 - val_loss: -1.4721 - val_dice_coef: 1.4721
# Epoch 45/300
# 256/256 [==============================] - 92s - loss: -1.3713 - dice_coef: 1.3713 - val_loss: -1.4471 - val_dice_coef: 1.4471
# Epoch 46/300
# 256/256 [==============================] - 92s - loss: -1.4178 - dice_coef: 1.4178 - val_loss: -1.1873 - val_dice_coef: 1.1873
# Epoch 47/300
# 256/256 [==============================] - 92s - loss: -1.4308 - dice_coef: 1.4308 - val_loss: -1.3581 - val_dice_coef: 1.3581
# Epoch 48/300
# 256/256 [==============================] - 92s - loss: -1.4581 - dice_coef: 1.4581 - val_loss: -1.2609 - val_dice_coef: 1.2609
# Epoch 49/300
# 256/256 [==============================] - 94s - loss: -1.4287 - dice_coef: 1.4287 - val_loss: -1.5766 - val_dice_coef: 1.5766
# Epoch 50/300
# 256/256 [==============================] - 92s - loss: -1.3933 - dice_coef: 1.3933 - val_loss: -1.5131 - val_dice_coef: 1.5131
# Epoch 51/300
# 256/256 [==============================] - 92s - loss: -1.5014 - dice_coef: 1.5014 - val_loss: -1.1790 - val_dice_coef: 1.1790
# Epoch 52/300
# 256/256 [==============================] - 92s - loss: -1.4341 - dice_coef: 1.4341 - val_loss: -1.3166 - val_dice_coef: 1.3166
# Epoch 53/300
# 256/256 [==============================] - 92s - loss: -1.4107 - dice_coef: 1.4107 - val_loss: -1.4426 - val_dice_coef: 1.4426
# Epoch 54/300
# 256/256 [==============================] - 92s - loss: -1.4705 - dice_coef: 1.4705 - val_loss: -1.3178 - val_dice_coef: 1.3178
# Epoch 55/300
# 256/256 [==============================] - 92s - loss: -1.3943 - dice_coef: 1.3943 - val_loss: -1.5637 - val_dice_coef: 1.5637
# Epoch 56/300
# 256/256 [==============================] - 92s - loss: -1.4964 - dice_coef: 1.4964 - val_loss: -1.3554 - val_dice_coef: 1.3554
# Epoch 57/300
# 256/256 [==============================] - 92s - loss: -1.4369 - dice_coef: 1.4369 - val_loss: -1.2841 - val_dice_coef: 1.2841
# Epoch 58/300
# 256/256 [==============================] - 92s - loss: -1.4980 - dice_coef: 1.4980 - val_loss: -1.3552 - val_dice_coef: 1.3552
# Epoch 59/300
# 256/256 [==============================] - 92s - loss: -1.4413 - dice_coef: 1.4413 - val_loss: -1.3193 - val_dice_coef: 1.3193
# Epoch 60/300
# 256/256 [==============================] - 92s - loss: -1.3510 - dice_coef: 1.3510 - val_loss: -1.3648 - val_dice_coef: 1.3648
# Epoch 61/300
# 256/256 [==============================] - 92s - loss: -1.4303 - dice_coef: 1.4303 - val_loss: -1.1269 - val_dice_coef: 1.1269
# Epoch 62/300
# 256/256 [==============================] - 92s - loss: -1.4835 - dice_coef: 1.4835 - val_loss: -1.3168 - val_dice_coef: 1.3168
# Epoch 63/300
# 256/256 [==============================] - 92s - loss: -1.4570 - dice_coef: 1.4570 - val_loss: -1.5175 - val_dice_coef: 1.5175
# Epoch 64/300
# 256/256 [==============================] - 92s - loss: -1.4738 - dice_coef: 1.4738 - val_loss: -1.4537 - val_dice_coef: 1.4537
# Epoch 65/300
# 256/256 [==============================] - 92s - loss: -1.4831 - dice_coef: 1.4831 - val_loss: -1.3779 - val_dice_coef: 1.3779
# Epoch 66/300
# 256/256 [==============================] - 92s - loss: -1.5312 - dice_coef: 1.5312 - val_loss: -1.5451 - val_dice_coef: 1.5451
# Epoch 67/300
# 256/256 [==============================] - 92s - loss: -1.4262 - dice_coef: 1.4262 - val_loss: -1.2356 - val_dice_coef: 1.2356
# Epoch 68/300
# 256/256 [==============================] - 92s - loss: -1.5617 - dice_coef: 1.5617 - val_loss: -1.4385 - val_dice_coef: 1.4385
# Epoch 69/300
# 256/256 [==============================] - 92s - loss: -1.4708 - dice_coef: 1.4708 - val_loss: -1.4628 - val_dice_coef: 1.4628
# Epoch 70/300
# 256/256 [==============================] - 92s - loss: -1.4590 - dice_coef: 1.4590 - val_loss: -1.3625 - val_dice_coef: 1.3625
# Epoch 71/300
# 256/256 [==============================] - 92s - loss: -1.4730 - dice_coef: 1.4730 - val_loss: -1.4786 - val_dice_coef: 1.4786
# Epoch 72/300
# 256/256 [==============================] - 92s - loss: -1.4605 - dice_coef: 1.4605 - val_loss: -1.4945 - val_dice_coef: 1.4945
# Epoch 73/300
# 256/256 [==============================] - 92s - loss: -1.4969 - dice_coef: 1.4969 - val_loss: -1.5725 - val_dice_coef: 1.5725
# Epoch 74/300
# 256/256 [==============================] - 92s - loss: -1.4385 - dice_coef: 1.4385 - val_loss: -1.3503 - val_dice_coef: 1.3503
# Epoch 75/300
# 256/256 [==============================] - 92s - loss: -1.5116 - dice_coef: 1.5116 - val_loss: -1.4288 - val_dice_coef: 1.4288
# Epoch 76/300
# 256/256 [==============================] - 92s - loss: -1.4995 - dice_coef: 1.4995 - val_loss: -1.5572 - val_dice_coef: 1.5572
# Epoch 77/300
# 256/256 [==============================] - 92s - loss: -1.5302 - dice_coef: 1.5302 - val_loss: -1.3514 - val_dice_coef: 1.3514
# Epoch 78/300
# 256/256 [==============================] - 92s - loss: -1.4501 - dice_coef: 1.4501 - val_loss: -1.5705 - val_dice_coef: 1.5705
# Epoch 79/300
# 256/256 [==============================] - 94s - loss: -1.5274 - dice_coef: 1.5274 - val_loss: -1.6790 - val_dice_coef: 1.6790
# Epoch 80/300
# 256/256 [==============================] - 92s - loss: -1.4440 - dice_coef: 1.4440 - val_loss: -1.3789 - val_dice_coef: 1.3789
# Epoch 81/300
# 256/256 [==============================] - 92s - loss: -1.5334 - dice_coef: 1.5334 - val_loss: -1.3541 - val_dice_coef: 1.3541
# Epoch 82/300
# 256/256 [==============================] - 92s - loss: -1.4647 - dice_coef: 1.4647 - val_loss: -1.4709 - val_dice_coef: 1.4709
# Epoch 83/300
# 256/256 [==============================] - 92s - loss: -1.4573 - dice_coef: 1.4573 - val_loss: -1.4606 - val_dice_coef: 1.4606
# Epoch 84/300
# 256/256 [==============================] - 92s - loss: -1.4855 - dice_coef: 1.4855 - val_loss: -1.5215 - val_dice_coef: 1.5215
# Epoch 85/300
# 256/256 [==============================] - 92s - loss: -1.5196 - dice_coef: 1.5196 - val_loss: -1.3075 - val_dice_coef: 1.3075
# Epoch 86/300
# 256/256 [==============================] - 92s - loss: -1.4202 - dice_coef: 1.4202 - val_loss: -1.2856 - val_dice_coef: 1.2856
# Epoch 87/300
# 256/256 [==============================] - 92s - loss: -1.4836 - dice_coef: 1.4836 - val_loss: -1.4026 - val_dice_coef: 1.4026
# Epoch 88/300
# 256/256 [==============================] - 92s - loss: -1.4959 - dice_coef: 1.4959 - val_loss: -1.4964 - val_dice_coef: 1.4964
# Epoch 89/300
# 256/256 [==============================] - 92s - loss: -1.5475 - dice_coef: 1.5475 - val_loss: -1.5711 - val_dice_coef: 1.5711
# Epoch 90/300
# 256/256 [==============================] - 92s - loss: -1.5313 - dice_coef: 1.5313 - val_loss: -1.5089 - val_dice_coef: 1.5089
# Epoch 91/300
# 256/256 [==============================] - 93s - loss: -1.3838 - dice_coef: 1.3838 - val_loss: -1.4282 - val_dice_coef: 1.4282
# Epoch 92/300
# 256/256 [==============================] - 92s - loss: -1.4962 - dice_coef: 1.4962 - val_loss: -1.3324 - val_dice_coef: 1.3324
# Epoch 93/300
# 256/256 [==============================] - 92s - loss: -1.5061 - dice_coef: 1.5061 - val_loss: -1.4350 - val_dice_coef: 1.4350
# Epoch 94/300
# 256/256 [==============================] - 93s - loss: -1.5420 - dice_coef: 1.5420 - val_loss: -1.5635 - val_dice_coef: 1.5635
# Epoch 95/300
# 256/256 [==============================] - 92s - loss: -1.5984 - dice_coef: 1.5984 - val_loss: -1.4456 - val_dice_coef: 1.4456
# Epoch 96/300
# 256/256 [==============================] - 92s - loss: -1.5100 - dice_coef: 1.5100 - val_loss: -1.2377 - val_dice_coef: 1.2377
# Epoch 97/300
# 256/256 [==============================] - 92s - loss: -1.4898 - dice_coef: 1.4898 - val_loss: -1.5355 - val_dice_coef: 1.5355
# Epoch 98/300
# 256/256 [==============================] - 92s - loss: -1.5110 - dice_coef: 1.5110 - val_loss: -1.2479 - val_dice_coef: 1.2479
# Epoch 99/300
# 256/256 [==============================] - 92s - loss: -1.5011 - dice_coef: 1.5011 - val_loss: -1.2821 - val_dice_coef: 1.2821
# Epoch 100/300
# 256/256 [==============================] - 92s - loss: -1.5179 - dice_coef: 1.5179 - val_loss: -1.1306 - val_dice_coef: 1.1306
# Epoch 101/300
# 256/256 [==============================] - 92s - loss: -1.5499 - dice_coef: 1.5499 - val_loss: -1.4302 - val_dice_coef: 1.4302
# Epoch 102/300
# 256/256 [==============================] - 92s - loss: -1.5695 - dice_coef: 1.5695 - val_loss: -1.5180 - val_dice_coef: 1.5180
# Epoch 103/300
# 256/256 [==============================] - 92s - loss: -1.5765 - dice_coef: 1.5765 - val_loss: -1.4702 - val_dice_coef: 1.4702
# Epoch 104/300
# 256/256 [==============================] - 93s - loss: -1.4770 - dice_coef: 1.4770 - val_loss: -1.4911 - val_dice_coef: 1.4911
# Epoch 105/300
#  65/256 [======>.......................] - ETA: 65s - loss: -1.4744 - dice_coef: 1.4744
