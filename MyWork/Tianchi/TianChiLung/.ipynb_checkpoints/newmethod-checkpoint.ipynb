# %%
from utils.imports import *
from utils.functions import *
from utils.paths import *

# %matplotlib inline

from sklearn.cluster import KMeans
dropout_rate = 0.35
width = 32
# Out:
# Using TensorFlow backend.

# %%
PATH = {'src' : full_lung_train,
       'annotations_path' : annotations_train_path,}

# %%
patients = get_dirfiles(PATH['src'])
img = np.load('/Volumes/solo/ali/Data/train_mask/train_full_lung/LKDS-00001.npy')
df = pd.read_csv(PATH['annotations_path'] + 'annotations_final2cls.csv')

# %%
patient_id = patients[0].split('/')[-1][:-4]

# %%
for idx,row in df.iterrows():
    if row['seriesuid'] == patient_id:
        origin = np.array([row['origin1'],row['origin2'],row['origin3']])
        new_spacing = np.array([row['new_spacing1'],row['new_spacing2'],row['new_spacing3']])

# %%
img.shape
# Out:
# (351, 1, 512, 512)

# %%
def fine(props,origin, spacing):
    patient_id_ = []
    Centroid3_ = []
    Centroid1_ = []
    Centroid2_ = []
    EquivDiameter_ = []
    var = []

    for i in tqdm(range(len(props))):
        patient_id_ = []
        if props[i]['EquivDiameter'] < 30:
            if props[i]['EquivDiameter'] > 5:
                x=props[i]['Centroid'][0]
                y=props[i]['Centroid'][1]
                z=props[i]['Centroid'][2]
                voxel_coordinates = [z,y,x]
                
                world = voxel_2_world(voxel_coordinates, origin, new_spacing)
                
                patient_id_.append(int(world[2]))
                patient_id_.append(int(world[1]))
                patient_id_.append(int(world[0]))
                patient_id_.append(int(props[i]['EquivDiameter']))
                
                var.append(patient_id_)
                print var
    return var

# %%
from skimage import data,filters
def cc(img_):
    var1 = []
    if True:
        #aa = np.load(_)
        #patient_id = _.split('/')[-1][:-4]
        img_ = np.squeeze(img_) 
        #img_[img_ >= 400] = 400
        #img_[img_ <= -2000] = 0
        #thresh = filters.threshold_otsu(img_)
        #img_ =(img_ <= thresh)*1.0
        #ball = skimage.morphology.ball(2)
        

        temp = skimage.morphology.black_tophat (img_, np.ones([5,5,5]))            
        #temp = skimage.morphology.binary_opening(img_, np.ones([5,5,5]))
        labels = measure.label(np.squeeze(temp))
        props = regionprops(labels)
        var =  fine(props,origin, new_spacing)
        print var,temp
    return

# %%
cc,temp = cc(img)

# %%
sorted(cc)

# %%
voxel_coordinates = [0,0,0]
                
world = voxel_2_world(voxel_coordinates, origin, new_spacing)

# %%
world
# Out:
# array([  49.5, -206.5, -207.5])

# %%
zz = np.zeros([3,512,512])

# %%
zz[1:2,510:512,510:512] =1

# %%
labels = measure.label(np.squeeze(zz))
props = regionprops(labels)

# %%
props[0]['Centroid'][2]
# Out:
# 510.5

# %%
temp = skimage.morphology.black_tophat (img, np.ones([5,5,5])) 
temp_ = np.squeeze(temp)
img_ = temp_[130]

plt.imshow(img_)

# %%
labels = measure.label(img)

# %%
props = regionprops(labels)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-8418791e841b> in <module>()
# ----> 1 props = regionprops(labels)
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/skimage/measure/_regionprops.pyc in regionprops(label_image, intensity_image, cache)
#     549
#     550         props = _RegionProperties(sl, label, label_image, intensity_image,
# --> 551                                   cache)
#     552         regions.append(props)
#     553
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/skimage/measure/_regionprops.pyc in __init__(self, slice, label, label_image, intensity_image, cache_active)
#     106
#     107         self._cache_active = cache_active
# --> 108         self._cache = {}
#     109         self._ndim = label_image.ndim
#     110
#
# KeyboardInterrupt:
