# %%
import numpy as np 
import pandas as pd 
import skimage, os
import SimpleITK as sitk
from scipy import ndimage
import matplotlib.pyplot as plt
import os
import glob
import zarr
from sklearn.utils import shuffle
import time

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import tensorflow as tf
from keras import backend as K
K.set_image_dim_ordering('th') 

from keras.models import Sequential,load_model,Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers import Input, merge, UpSampling2D
from keras.optimizers import Adam, SGD, RMSprop, Nadam
from keras.preprocessing.image import ImageDataGenerator

from keras.layers.convolutional import Convolution3D, MaxPooling3D, UpSampling3D
from keras.layers import BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.core import SpatialDropout3D
from keras.models import load_model

import warnings
warnings.filterwarnings('ignore')

from utils_3d import *
from paths import *

def unet_model():
    
    inputs = Input(shape=(1, max_slices, img_size, img_size))
    conv1 = Convolution3D(width, 3, 3, 3, activation = 'relu', border_mode='same')(inputs)
    conv1 = BatchNormalization(axis = 1)(conv1)
    conv1 = Convolution3D(width*2, 3, 3, 3, activation = 'relu', border_mode='same')(conv1)
    conv1 = BatchNormalization(axis = 1)(conv1)
    pool1 = MaxPooling3D(pool_size=(2, 2, 2), strides = (2, 2, 2), border_mode='same')(conv1)
    
    conv2 = Convolution3D(width*2, 3, 3, 3, activation = 'relu', border_mode='same')(pool1)
    conv2 = BatchNormalization(axis = 1)(conv2)
    conv2 = Convolution3D(width*4, 3, 3, 3, activation = 'relu', border_mode='same')(conv2)
    conv2 = BatchNormalization(axis = 1)(conv2)
    pool2 = MaxPooling3D(pool_size=(2, 2, 2), strides = (2, 2, 2), border_mode='same')(conv2)

    conv3 = Convolution3D(width*4, 3, 3, 3, activation = 'relu', border_mode='same')(pool2)
    conv3 = BatchNormalization(axis = 1)(conv3)
    conv3 = Convolution3D(width*8, 3, 3, 3, activation = 'relu', border_mode='same')(conv3)
    conv3 = BatchNormalization(axis = 1)(conv3)
    pool3 = MaxPooling3D(pool_size=(2, 2, 2), strides = (2, 2, 2), border_mode='same')(conv3)
    
    conv4 = Convolution3D(width*8, 3, 3, 3, activation = 'relu', border_mode='same')(pool3)
    conv4 = BatchNormalization(axis = 1)(conv4)
    conv4 = Convolution3D(width*8, 3, 3, 3, activation = 'relu', border_mode='same')(conv4)
    conv4 = BatchNormalization(axis = 1)(conv4)
    conv4 = Convolution3D(width*16, 3, 3, 3, activation = 'relu', border_mode='same')(conv4)
    conv4 = BatchNormalization(axis = 1)(conv4)

    up5 = merge([UpSampling3D(size=(2, 2, 2))(conv4), conv3], mode='concat', concat_axis=1)
    conv5 = SpatialDropout3D(dropout_rate)(up5)
    conv5 = Convolution3D(width*8, 3, 3, 3, activation = 'relu', border_mode='same')(conv5)
    conv5 = Convolution3D(width*8, 3, 3, 3, activation = 'relu', border_mode='same')(conv5)
    
    up6 = merge([UpSampling3D(size=(2, 2, 2))(conv5), conv2], mode='concat', concat_axis=1)
    conv6 = SpatialDropout3D(dropout_rate)(up6)
    conv6 = Convolution3D(width*4, 3, 3, 3, activation = 'relu', border_mode='same')(conv6)
    conv6 = Convolution3D(width*4, 3, 3, 3, activation = 'relu', border_mode='same')(conv6)

    up7 = merge([UpSampling3D(size=(2, 2, 2))(conv6), conv1], mode='concat', concat_axis=1)
    conv7 = SpatialDropout3D(dropout_rate)(up7)
    conv7 = Convolution3D(width*2, 3, 3, 3, activation = 'relu', border_mode='same')(conv7)
    conv7 = Convolution3D(width*2, 3, 3, 3, activation = 'relu', border_mode='same')(conv7)
    conv8 = Convolution3D(1, 1, 1, 1, activation='sigmoid')(conv7)

    model = Model(input=inputs, output=conv8)
    model.compile(optimizer=Adam(lr=1e-5), 
                  loss=dice_coef_loss, metrics=[dice_coef])

    return model


def generate_train(start, end, seed = None):
    size_3d = 128
    size = 128
    lungs = sorted(glob.glob(src + 'lung_mask/*.npy'))[start:end]
    nods = sorted(glob.glob(src + 'nodule_mask/*.npy'))[start:end]
    while True:
        print('Shuffling data')
        lungs, nods = shuffle(lungs, nods)
        for i in range(len(lungs)):
            lung_3d = np.full((1, 1, size_3d, size, size), 7.).astype('float32')
            nodule_3d = np.zeros((1, 1, size_3d, size, size)).astype('float32')
            lung = np.load(lungs[i]).astype('float32')
            nod = np.load(nods[i]).astype('float32')
            lung = lung.swapaxes(1, 0)
            nod = nod.swapaxes(1, 0)
            num_slices = lung.shape[1]
            offset = (size_3d - num_slices)
            if offset == 0:
                lung_3d[0, :, :, :, :] = lung[:, :, :, :]
                nodule_3d[0, :, :, :, :] = nod[:, :, :, :]
            if offset > 0:
                begin_offset = int(np.round(offset/2))
                end_offset = int(offset - begin_offset)
                lung_3d[0, :, begin_offset:-end_offset, :, :] = lung[:, :, :, :]
                nodule_3d[0, :, begin_offset:-end_offset, :, :] = nod[:, :, :, :]
            if offset < 0:
                print('{} slices lost due to size restrictions'.format(offset))
                offset = -(size_3d - num_slices)
                begin_offset = int(np.round(offset/2))
                end_offset = int(offset - begin_offset)
                lung_3d[0, :, :, :, :] = lung[:, begin_offset:-end_offset, :, :]
                nodule_3d[0, :, :, :, :] = nod[:, begin_offset:-end_offset, :, :]
                del lung, nod
               
            yield(lung_3d, nodule_3d)
            
def generate_val(start, end, seed = None):
    size_3d = 128
    size = 128
    lungs = sorted(glob.glob(src + 'lung_mask/*.npy'))[start:end]
    nods = sorted(glob.glob(src + 'nodule_mask/*.npy'))[start:end]
    while True:
        for i in range(len(lungs)):
            lung_3d = np.full((1, 1, size_3d, size, size), 7.).astype('float32')
            nodule_3d = np.zeros((1, 1, size_3d, size, size)).astype('float32')
            lung = np.load(lungs[i]).astype('float32')
            nod = np.load(nods[i]).astype('float32')
            lung = lung.swapaxes(1, 0)
            nod = nod.swapaxes(1, 0)
            num_slices = lung.shape[1]
            offset = (size_3d - num_slices)
            if offset == 0:
                lung_3d[0, :, :, :, :] = lung[:, :, :, :]
                nodule_3d[0, :, :, :, :] = nod[:, :, :, :]
            if offset > 0:
                begin_offset = int(np.round(offset/2))
                end_offset = int(offset - begin_offset)
                lung_3d[0, :, begin_offset:-end_offset, :, :] = lung[:, :, :, :]
                nodule_3d[0, :, begin_offset:-end_offset, :, :] = nod[:, :, :, :]
            if offset < 0:
                print('{} slices lost due to size restrictions'.format(offset))
                offset = -(size_3d - num_slices)
                begin_offset = int(np.round(offset/2))
                end_offset = int(offset - begin_offset)
                lung_3d[0, :, :, :, :] = lung[:, begin_offset:-end_offset, :, :]
                nodule_3d[0, :, :, :, :] = nod[:, begin_offset:-end_offset, :, :]
                del lung, nod
   
            yield(lung_3d, nodule_3d)


def unet_fit(name, start_t, end_t, start_v, end_v, check_name = None):
    
    t = time.time()
    callbacks = [EarlyStopping(monitor='val_loss', patience = 15, 
                                   verbose = 1),
    ModelCheckpoint('/Volumes/solo/ali/Data/model/{}.h5'.format(name), 
                        monitor='val_loss', 
                        verbose = 0, save_best_only = True)]
    
    if check_name is not None:
        check_model = '/Volumes/solo/ali/Data/model/{}.h5'.format(check_name)
        model = load_model(check_model, 
                           custom_objects={'dice_coef_loss': dice_coef_loss, 'dice_coef': dice_coef})
    else:
        model = unet_model()

    model.fit_generator(generate_train(start_t, end_t), nb_epoch = 150, verbose = 1, 
                        validation_data = generate_val(start_v, end_v), 
                        callbacks = callbacks,
                        samples_per_epoch = 551, nb_val_samples = 50)
        
    return
# Out:
# Using TensorFlow backend.

# %%
src = mask_train
max_slices = 128
img_size = 128
dropout_rate = 0.5
width = 8

img_rows = img_size
img_cols = img_size


#unet_fit('3DUNet_genfulldata_patients_merged', 0, 551, 551, 601)
unet_fit('3DUNet_genfulldata_patients_merged_cont', 0, 551, 551, 601, check_name = None)
# Out:
# Epoch 1/150
# Shuffling data
# 152/551 [=======>......................] - ETA: 597s - loss: -0.0094 - dice_coef: 0.0094-73 slices lost due to size restrictions
# 304/551 [===============>..............] - ETA: 356s - loss: -0.0101 - dice_coef: 0.0101-33 slices lost due to size restrictions
# 374/551 [===================>..........] - ETA: 255s - loss: -0.0104 - dice_coef: 0.0104-79 slices lost due to size restrictions
# 486/551 [=========================>....] - ETA: 93s - loss: -0.0098 - dice_coef: 0.0098-15 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.0105 - dice_coef: 0.0105Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.0105 - dice_coef: 0.0105-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 808s - loss: -0.0105 - dice_coef: 0.0105 - val_loss: -0.0313 - val_dice_coef: 0.0313
# Epoch 2/150
#  65/551 [==>...........................] - ETA: 673s - loss: -0.0175 - dice_coef: 0.0175-15 slices lost due to size restrictions
# 105/551 [====>.........................] - ETA: 618s - loss: -0.0203 - dice_coef: 0.0203-33 slices lost due to size restrictions
# 110/551 [====>.........................] - ETA: 611s - loss: -0.0195 - dice_coef: 0.0195-79 slices lost due to size restrictions
# 395/551 [====================>.........] - ETA: 216s - loss: -0.0257 - dice_coef: 0.0257-73 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.0317 - dice_coef: 0.0317Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.0316 - dice_coef: 0.0316-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 784s - loss: -0.0315 - dice_coef: 0.0315 - val_loss: -0.0780 - val_dice_coef: 0.0780
# Epoch 3/150
# 231/551 [===========>..................] - ETA: 446s - loss: -0.0473 - dice_coef: 0.0473-33 slices lost due to size restrictions
# 239/551 [============>.................] - ETA: 435s - loss: -0.0484 - dice_coef: 0.0484-79 slices lost due to size restrictions
# 363/551 [==================>...........] - ETA: 261s - loss: -0.0711 - dice_coef: 0.0711-73 slices lost due to size restrictions
# 389/551 [====================>.........] - ETA: 225s - loss: -0.0721 - dice_coef: 0.0721-15 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.0780 - dice_coef: 0.0780Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.0808 - dice_coef: 0.0808-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 790s - loss: -0.0806 - dice_coef: 0.0806 - val_loss: -0.1033 - val_dice_coef: 0.1033
# Epoch 4/150
# 120/551 [=====>........................] - ETA: 607s - loss: -0.1082 - dice_coef: 0.1082-73 slices lost due to size restrictions
# 327/551 [================>.............] - ETA: 314s - loss: -0.1110 - dice_coef: 0.1110-79 slices lost due to size restrictions
# 435/551 [======================>.......] - ETA: 162s - loss: -0.1152 - dice_coef: 0.1152-15 slices lost due to size restrictions
# 486/551 [=========================>....] - ETA: 91s - loss: -0.1107 - dice_coef: 0.1107-33 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.1086 - dice_coef: 0.1086Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.1087 - dice_coef: 0.1087-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# 551/551 [==============================] - 794s - loss: -0.1085 - dice_coef: 0.1085 - val_loss: -0.1176 - val_dice_coef: 0.1176
# Epoch 5/150
#  24/551 [>.............................] - ETA: 738s - loss: -0.2464 - dice_coef: 0.2464-33 slices lost due to size restrictions
# 148/551 [=======>......................] - ETA: 562s - loss: -0.1302 - dice_coef: 0.1302-15 slices lost due to size restrictions
# 385/551 [===================>..........] - ETA: 232s - loss: -0.1359 - dice_coef: 0.1359-79 slices lost due to size restrictions
# 471/551 [========================>.....] - ETA: 111s - loss: -0.1318 - dice_coef: 0.1318-73 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.1350 - dice_coef: 0.1350Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.1342 - dice_coef: 0.1342-43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 797s - loss: -0.1340 - dice_coef: 0.1340 - val_loss: -0.1295 - val_dice_coef: 0.1295
# Epoch 6/150
#  38/551 [=>............................] - ETA: 749s - loss: -0.0802 - dice_coef: 0.0802-15 slices lost due to size restrictions
# 104/551 [====>.........................] - ETA: 658s - loss: -0.1473 - dice_coef: 0.1473-73 slices lost due to size restrictions
# 214/551 [==========>...................] - ETA: 496s - loss: -0.1447 - dice_coef: 0.1447-79 slices lost due to size restrictions
# 450/551 [=======================>......] - ETA: 148s - loss: -0.1482 - dice_coef: 0.1482-33 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.1581 - dice_coef: 0.1581Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.1582 - dice_coef: 0.1582-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 831s - loss: -0.1580 - dice_coef: 0.1580 - val_loss: -0.1677 - val_dice_coef: 0.1677
# Epoch 7/150
#  81/551 [===>..........................] - ETA: 688s - loss: -0.1889 - dice_coef: 0.1889-79 slices lost due to size restrictions
# 326/551 [================>.............] - ETA: 329s - loss: -0.1530 - dice_coef: 0.1530-33 slices lost due to size restrictions
# 342/551 [=================>............] - ETA: 306s - loss: -0.1471 - dice_coef: 0.1471-73 slices lost due to size restrictions
# 371/551 [===================>..........] - ETA: 263s - loss: -0.1510 - dice_coef: 0.1510-15 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.1562 - dice_coef: 0.1562Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.1551 - dice_coef: 0.1551-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 829s - loss: -0.1572 - dice_coef: 0.1572 - val_loss: -0.1554 - val_dice_coef: 0.1554
# Epoch 8/150
# 153/551 [=======>......................] - ETA: 578s - loss: -0.1843 - dice_coef: 0.1843-73 slices lost due to size restrictions
# 202/551 [=========>....................] - ETA: 508s - loss: -0.1981 - dice_coef: 0.1981-33 slices lost due to size restrictions
# 499/551 [==========================>...] - ETA: 75s - loss: -0.1813 - dice_coef: 0.1813-79 slices lost due to size restrictions
# 524/551 [===========================>..] - ETA: 39s - loss: -0.1781 - dice_coef: 0.1781-15 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.1766 - dice_coef: 0.1766Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.1748 - dice_coef: 0.1748-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 821s - loss: -0.1745 - dice_coef: 0.1745 - val_loss: -0.1474 - val_dice_coef: 0.1474
# Epoch 9/150
# 294/551 [===============>..............] - ETA: 374s - loss: -0.1908 - dice_coef: 0.1908-33 slices lost due to size restrictions
# 308/551 [===============>..............] - ETA: 354s - loss: -0.1859 - dice_coef: 0.1859-15 slices lost due to size restrictions
# 384/551 [===================>..........] - ETA: 243s - loss: -0.1799 - dice_coef: 0.1799-79 slices lost due to size restrictions
# 483/551 [=========================>....] - ETA: 98s - loss: -0.1777 - dice_coef: 0.1777 -73 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.1766 - dice_coef: 0.1766Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.1774 - dice_coef: 0.1774-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# 551/551 [==============================] - 823s - loss: -0.1771 - dice_coef: 0.1771 - val_loss: -0.1478 - val_dice_coef: 0.1478
# Epoch 10/150
#  69/551 [==>...........................] - ETA: 698s - loss: -0.1349 - dice_coef: 0.1349-79 slices lost due to size restrictions
# 150/551 [=======>......................] - ETA: 589s - loss: -0.1692 - dice_coef: 0.1692-73 slices lost due to size restrictions
# 488/551 [=========================>....] - ETA: 92s - loss: -0.1973 - dice_coef: 0.1973-33 slices lost due to size restrictions
# 525/551 [===========================>..] - ETA: 38s - loss: -0.1995 - dice_coef: 0.1995-15 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.1990 - dice_coef: 0.1990Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.1966 - dice_coef: 0.1966-43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 831s - loss: -0.1962 - dice_coef: 0.1962 - val_loss: -0.1638 - val_dice_coef: 0.1638
# Epoch 11/150
#  23/551 [>.............................] - ETA: 769s - loss: -0.3150 - dice_coef: 0.3150-15 slices lost due to size restrictions
#  89/551 [===>..........................] - ETA: 673s - loss: -0.2307 - dice_coef: 0.2307-33 slices lost due to size restrictions
# 126/551 [=====>........................] - ETA: 624s - loss: -0.2203 - dice_coef: 0.2203-73 slices lost due to size restrictions
# 219/551 [==========>...................] - ETA: 488s - loss: -0.2175 - dice_coef: 0.2175-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.2105 - dice_coef: 0.2105Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.2086 - dice_coef: 0.2086-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 832s - loss: -0.2097 - dice_coef: 0.2097 - val_loss: -0.1580 - val_dice_coef: 0.1580
# Epoch 12/150
#  99/551 [====>.........................] - ETA: 665s - loss: -0.2482 - dice_coef: 0.2482-79 slices lost due to size restrictions
# 164/551 [=======>......................] - ETA: 570s - loss: -0.2448 - dice_coef: 0.2448-73 slices lost due to size restrictions
# 168/551 [========>.....................] - ETA: 565s - loss: -0.2405 - dice_coef: 0.2405-15 slices lost due to size restrictions
# 238/551 [===========>..................] - ETA: 462s - loss: -0.2561 - dice_coef: 0.2561-33 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.2136 - dice_coef: 0.2136Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.2119 - dice_coef: 0.2119-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 835s - loss: -0.2116 - dice_coef: 0.2116 - val_loss: -0.1656 - val_dice_coef: 0.1656
# Epoch 13/150
# 109/551 [====>.........................] - ETA: 647s - loss: -0.1747 - dice_coef: 0.1747-15 slices lost due to size restrictions
# 276/551 [==============>...............] - ETA: 402s - loss: -0.1966 - dice_coef: 0.1966-73 slices lost due to size restrictions
# 340/551 [=================>............] - ETA: 308s - loss: -0.2102 - dice_coef: 0.2102-33 slices lost due to size restrictions
# 495/551 [=========================>....] - ETA: 81s - loss: -0.2209 - dice_coef: 0.2209-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.2213 - dice_coef: 0.2213Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.2212 - dice_coef: 0.2212-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 828s - loss: -0.2208 - dice_coef: 0.2208 - val_loss: -0.1794 - val_dice_coef: 0.1794
# Epoch 14/150
# 380/551 [===================>..........] - ETA: 246s - loss: -0.2329 - dice_coef: 0.2329-15 slices lost due to size restrictions
# 384/551 [===================>..........] - ETA: 240s - loss: -0.2343 - dice_coef: 0.2343-79 slices lost due to size restrictions
# 404/551 [====================>.........] - ETA: 211s - loss: -0.2287 - dice_coef: 0.2287-33 slices lost due to size restrictions
# 473/551 [========================>.....] - ETA: 111s - loss: -0.2248 - dice_coef: 0.2248-73 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.2251 - dice_coef: 0.2251Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.2249 - dice_coef: 0.2249-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# 551/551 [==============================] - 805s - loss: -0.2267 - dice_coef: 0.2267 - val_loss: -0.1676 - val_dice_coef: 0.1676
# Epoch 15/150
#  84/551 [===>..........................] - ETA: 646s - loss: -0.2986 - dice_coef: 0.2986-73 slices lost due to size restrictions
# 302/551 [===============>..............] - ETA: 360s - loss: -0.2509 - dice_coef: 0.2509-15 slices lost due to size restrictions
# 447/551 [=======================>......] - ETA: 150s - loss: -0.2386 - dice_coef: 0.2386-79 slices lost due to size restrictions
# 461/551 [========================>.....] - ETA: 130s - loss: -0.2372 - dice_coef: 0.2372-33 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.2419 - dice_coef: 0.2419Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.2437 - dice_coef: 0.2437-43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 824s - loss: -0.2432 - dice_coef: 0.2432 - val_loss: -0.1592 - val_dice_coef: 0.1592
# Epoch 16/150
# 127/551 [=====>........................] - ETA: 632s - loss: -0.2365 - dice_coef: 0.2365-15 slices lost due to size restrictions
# 140/551 [======>.......................] - ETA: 614s - loss: -0.2307 - dice_coef: 0.2307-33 slices lost due to size restrictions
# 273/551 [=============>................] - ETA: 416s - loss: -0.2270 - dice_coef: 0.2270-73 slices lost due to size restrictions
# 341/551 [=================>............] - ETA: 314s - loss: -0.2267 - dice_coef: 0.2267-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.2477 - dice_coef: 0.2477Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.2519 - dice_coef: 0.2519-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 844s - loss: -0.2533 - dice_coef: 0.2533 - val_loss: -0.1762 - val_dice_coef: 0.1762
# Epoch 17/150
# 149/551 [=======>......................] - ETA: 594s - loss: -0.2599 - dice_coef: 0.2599-79 slices lost due to size restrictions
# 176/551 [========>.....................] - ETA: 556s - loss: -0.2617 - dice_coef: 0.2617-73 slices lost due to size restrictions
# 311/551 [===============>..............] - ETA: 359s - loss: -0.2843 - dice_coef: 0.2843-15 slices lost due to size restrictions
# 500/551 [==========================>...] - ETA: 76s - loss: -0.2611 - dice_coef: 0.2611-33 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.2536 - dice_coef: 0.2536Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.2549 - dice_coef: 0.2549-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 845s - loss: -0.2550 - dice_coef: 0.2550 - val_loss: -0.1744 - val_dice_coef: 0.1744
# Epoch 18/150
# 153/551 [=======>......................] - ETA: 587s - loss: -0.2414 - dice_coef: 0.2414-73 slices lost due to size restrictions
# 178/551 [========>.....................] - ETA: 549s - loss: -0.2191 - dice_coef: 0.2191-15 slices lost due to size restrictions
# 276/551 [==============>...............] - ETA: 404s - loss: -0.2288 - dice_coef: 0.2288-33 slices lost due to size restrictions
# 315/551 [================>.............] - ETA: 346s - loss: -0.2363 - dice_coef: 0.2363-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 14s - loss: -0.2561 - dice_coef: 0.2561Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.2562 - dice_coef: 0.2562-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 823s - loss: -0.2558 - dice_coef: 0.2558 - val_loss: -0.1810 - val_dice_coef: 0.1810
# Epoch 19/150
#  95/551 [====>.........................] - ETA: 628s - loss: -0.2798 - dice_coef: 0.2798-73 slices lost due to size restrictions
# 236/551 [===========>..................] - ETA: 433s - loss: -0.3184 - dice_coef: 0.3184-15 slices lost due to size restrictions
# 413/551 [=====================>........] - ETA: 190s - loss: -0.2753 - dice_coef: 0.2753-79 slices lost due to size restrictions
# 511/551 [==========================>...] - ETA: 55s - loss: -0.2665 - dice_coef: 0.2665-33 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.2630 - dice_coef: 0.2630Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.2647 - dice_coef: 0.2647-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.2643 - dice_coef: 0.2643 - val_loss: -0.1725 - val_dice_coef: 0.1725
# Epoch 20/150
#  69/551 [==>...........................] - ETA: 665s - loss: -0.2393 - dice_coef: 0.2393-33 slices lost due to size restrictions
#  70/551 [==>...........................] - ETA: 664s - loss: -0.2359 - dice_coef: 0.2359-79 slices lost due to size restrictions
# 214/551 [==========>...................] - ETA: 465s - loss: -0.2880 - dice_coef: 0.2880-73 slices lost due to size restrictions
# 380/551 [===================>..........] - ETA: 236s - loss: -0.2864 - dice_coef: 0.2864-15 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.2814 - dice_coef: 0.2814Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.2847 - dice_coef: 0.2847-43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 783s - loss: -0.2867 - dice_coef: 0.2867 - val_loss: -0.1763 - val_dice_coef: 0.1763
# Epoch 21/150
#  78/551 [===>..........................] - ETA: 657s - loss: -0.3537 - dice_coef: 0.3537-33 slices lost due to size restrictions
# 137/551 [======>.......................] - ETA: 573s - loss: -0.3304 - dice_coef: 0.3304-73 slices lost due to size restrictions
# 248/551 [============>.................] - ETA: 418s - loss: -0.2929 - dice_coef: 0.2929-15 slices lost due to size restrictions
# 267/551 [=============>................] - ETA: 392s - loss: -0.3139 - dice_coef: 0.3139-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.2927 - dice_coef: 0.2927Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.2915 - dice_coef: 0.2915-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 782s - loss: -0.2931 - dice_coef: 0.2931 - val_loss: -0.1514 - val_dice_coef: 0.1514
# Epoch 22/150
#  75/551 [===>..........................] - ETA: 657s - loss: -0.3662 - dice_coef: 0.3662-15 slices lost due to size restrictions
# 140/551 [======>.......................] - ETA: 567s - loss: -0.3681 - dice_coef: 0.3681-73 slices lost due to size restrictions
# 388/551 [====================>.........] - ETA: 225s - loss: -0.3209 - dice_coef: 0.3209-33 slices lost due to size restrictions
# 441/551 [=======================>......] - ETA: 151s - loss: -0.3145 - dice_coef: 0.3145-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.3012 - dice_coef: 0.3012Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.3002 - dice_coef: 0.3002-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 782s - loss: -0.2996 - dice_coef: 0.2996 - val_loss: -0.1885 - val_dice_coef: 0.1885
# Epoch 23/150
#  34/551 [>.............................] - ETA: 714s - loss: -0.2311 - dice_coef: 0.2311-73 slices lost due to size restrictions
#  83/551 [===>..........................] - ETA: 646s - loss: -0.2567 - dice_coef: 0.2567-15 slices lost due to size restrictions
# 121/551 [=====>........................] - ETA: 594s - loss: -0.3024 - dice_coef: 0.3024-33 slices lost due to size restrictions
# 164/551 [=======>......................] - ETA: 534s - loss: -0.3167 - dice_coef: 0.3167-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.3130 - dice_coef: 0.3130Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.3081 - dice_coef: 0.3081-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 782s - loss: -0.3075 - dice_coef: 0.3075 - val_loss: -0.1746 - val_dice_coef: 0.1746
# Epoch 24/150
# 166/551 [========>.....................] - ETA: 531s - loss: -0.2911 - dice_coef: 0.2911-33 slices lost due to size restrictions
# 329/551 [================>.............] - ETA: 306s - loss: -0.3072 - dice_coef: 0.3072-73 slices lost due to size restrictions
# 458/551 [=======================>......] - ETA: 128s - loss: -0.3246 - dice_coef: 0.3246-79 slices lost due to size restrictions
# 488/551 [=========================>....] - ETA: 86s - loss: -0.3222 - dice_coef: 0.3222-15 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.3325 - dice_coef: 0.3325Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.3368 - dice_coef: 0.3368-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.3391 - dice_coef: 0.3391 - val_loss: -0.1686 - val_dice_coef: 0.1686
# Epoch 25/150
# 194/551 [=========>....................] - ETA: 492s - loss: -0.3408 - dice_coef: 0.3408-15 slices lost due to size restrictions
# 204/551 [==========>...................] - ETA: 479s - loss: -0.3443 - dice_coef: 0.3443-79 slices lost due to size restrictions
# 223/551 [===========>..................] - ETA: 452s - loss: -0.3337 - dice_coef: 0.3337-73 slices lost due to size restrictions
# 516/551 [===========================>..] - ETA: 48s - loss: -0.3293 - dice_coef: 0.3293-33 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.3311 - dice_coef: 0.3311Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.3298 - dice_coef: 0.3298-43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.3300 - dice_coef: 0.3300 - val_loss: -0.1814 - val_dice_coef: 0.1814
# Epoch 26/150
#  80/551 [===>..........................] - ETA: 650s - loss: -0.3689 - dice_coef: 0.3689-73 slices lost due to size restrictions
# 137/551 [======>.......................] - ETA: 571s - loss: -0.3629 - dice_coef: 0.3629-33 slices lost due to size restrictions
# 298/551 [===============>..............] - ETA: 349s - loss: -0.3775 - dice_coef: 0.3775-15 slices lost due to size restrictions
# 455/551 [=======================>......] - ETA: 132s - loss: -0.3459 - dice_coef: 0.3459-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.3478 - dice_coef: 0.3478Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.3478 - dice_coef: 0.3478-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 782s - loss: -0.3472 - dice_coef: 0.3472 - val_loss: -0.1778 - val_dice_coef: 0.1778
# Epoch 27/150
# 116/551 [=====>........................] - ETA: 600s - loss: -0.4653 - dice_coef: 0.4653-15 slices lost due to size restrictions
# 119/551 [=====>........................] - ETA: 596s - loss: -0.4536 - dice_coef: 0.4536-33 slices lost due to size restrictions
# 199/551 [=========>....................] - ETA: 486s - loss: -0.3919 - dice_coef: 0.3919-73 slices lost due to size restrictions
# 375/551 [===================>..........] - ETA: 242s - loss: -0.3745 - dice_coef: 0.3745-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.3710 - dice_coef: 0.3710Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.3693 - dice_coef: 0.3693-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.3686 - dice_coef: 0.3686 - val_loss: -0.1735 - val_dice_coef: 0.1735
# Epoch 28/150
#  16/551 [..............................] - ETA: 738s - loss: -0.2854 - dice_coef: 0.2854-73 slices lost due to size restrictions
# 191/551 [=========>....................] - ETA: 497s - loss: -0.3358 - dice_coef: 0.3358-15 slices lost due to size restrictions
# 438/551 [======================>.......] - ETA: 155s - loss: -0.3492 - dice_coef: 0.3492-79 slices lost due to size restrictions
# 540/551 [============================>.] - ETA: 15s - loss: -0.3712 - dice_coef: 0.3712-33 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.3716 - dice_coef: 0.3716Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.3661 - dice_coef: 0.3661-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.3655 - dice_coef: 0.3655 - val_loss: -0.1848 - val_dice_coef: 0.1848
# Epoch 29/150
# 302/551 [===============>..............] - ETA: 343s - loss: -0.3617 - dice_coef: 0.3617-73 slices lost due to size restrictions
# 313/551 [================>.............] - ETA: 328s - loss: -0.3649 - dice_coef: 0.3649-33 slices lost due to size restrictions
# 374/551 [===================>..........] - ETA: 244s - loss: -0.3603 - dice_coef: 0.3603-79 slices lost due to size restrictions
# 432/551 [======================>.......] - ETA: 164s - loss: -0.3776 - dice_coef: 0.3776-15 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.3735 - dice_coef: 0.3735Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.3691 - dice_coef: 0.3691-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.3685 - dice_coef: 0.3685 - val_loss: -0.1661 - val_dice_coef: 0.1661
# Epoch 30/150
# 102/551 [====>.........................] - ETA: 619s - loss: -0.3990 - dice_coef: 0.3990-79 slices lost due to size restrictions
# 151/551 [=======>......................] - ETA: 551s - loss: -0.4010 - dice_coef: 0.4010-73 slices lost due to size restrictions
# 335/551 [=================>............] - ETA: 297s - loss: -0.4083 - dice_coef: 0.4083-15 slices lost due to size restrictions
# 467/551 [========================>.....] - ETA: 115s - loss: -0.4030 - dice_coef: 0.4030-33 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.3960 - dice_coef: 0.3960Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.3932 - dice_coef: 0.3932-43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.3936 - dice_coef: 0.3936 - val_loss: -0.1843 - val_dice_coef: 0.1843
# Epoch 31/150
# 168/551 [========>.....................] - ETA: 528s - loss: -0.3933 - dice_coef: 0.3933-73 slices lost due to size restrictions
# 306/551 [===============>..............] - ETA: 338s - loss: -0.4056 - dice_coef: 0.4056-33 slices lost due to size restrictions
# 396/551 [====================>.........] - ETA: 213s - loss: -0.4081 - dice_coef: 0.4081-15 slices lost due to size restrictions
# 509/551 [==========================>...] - ETA: 57s - loss: -0.3879 - dice_coef: 0.3879-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.3849 - dice_coef: 0.3849Shuffling data
# 543/551 [============================>.] - ETA: 11s - loss: -0.3850 - dice_coef: 0.3850-73 slices lost due to size restrictions
# 550/551 [============================>.] - ETA: 1s - loss: -0.3835 - dice_coef: 0.3835-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.3857 - dice_coef: 0.3857 - val_loss: -0.1944 - val_dice_coef: 0.1944
# Epoch 32/150
# 159/551 [=======>......................] - ETA: 541s - loss: -0.3669 - dice_coef: 0.3669-79 slices lost due to size restrictions
# 207/551 [==========>...................] - ETA: 474s - loss: -0.3824 - dice_coef: 0.3824-33 slices lost due to size restrictions
# 257/551 [============>.................] - ETA: 405s - loss: -0.3952 - dice_coef: 0.3952-15 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.4043 - dice_coef: 0.4043Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.3996 - dice_coef: 0.3996-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.4014 - dice_coef: 0.4014 - val_loss: -0.1792 - val_dice_coef: 0.1792
# Epoch 33/150
# 107/551 [====>.........................] - ETA: 612s - loss: -0.4348 - dice_coef: 0.4348-73 slices lost due to size restrictions
# 352/551 [==================>...........] - ETA: 274s - loss: -0.4397 - dice_coef: 0.4397-15 slices lost due to size restrictions
# 384/551 [===================>..........] - ETA: 230s - loss: -0.4574 - dice_coef: 0.4574-33 slices lost due to size restrictions
# 388/551 [====================>.........] - ETA: 224s - loss: -0.4578 - dice_coef: 0.4578-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.4478 - dice_coef: 0.4478Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.4474 - dice_coef: 0.4474-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.4466 - dice_coef: 0.4466 - val_loss: -0.1841 - val_dice_coef: 0.1841
# Epoch 34/150
#   2/551 [..............................] - ETA: 760s - loss: -1.1425 - dice_coef: 1.1425-73 slices lost due to size restrictions
#  67/551 [==>...........................] - ETA: 668s - loss: -0.4449 - dice_coef: 0.4449-79 slices lost due to size restrictions
# 401/551 [====================>.........] - ETA: 207s - loss: -0.4273 - dice_coef: 0.4273-33 slices lost due to size restrictions
# 446/551 [=======================>......] - ETA: 144s - loss: -0.4196 - dice_coef: 0.4196-15 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.4204 - dice_coef: 0.4204Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.4233 - dice_coef: 0.4233-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.4225 - dice_coef: 0.4225 - val_loss: -0.1453 - val_dice_coef: 0.1453
# Epoch 35/150
# 238/551 [===========>..................] - ETA: 431s - loss: -0.4576 - dice_coef: 0.4576-79 slices lost due to size restrictions
# 304/551 [===============>..............] - ETA: 340s - loss: -0.4550 - dice_coef: 0.4550-15 slices lost due to size restrictions
# 372/551 [===================>..........] - ETA: 246s - loss: -0.4343 - dice_coef: 0.4343-73 slices lost due to size restrictions
# 492/551 [=========================>....] - ETA: 81s - loss: -0.4360 - dice_coef: 0.4360-33 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.4331 - dice_coef: 0.4331Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.4334 - dice_coef: 0.4334-43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.4326 - dice_coef: 0.4326 - val_loss: -0.1639 - val_dice_coef: 0.1639
# Epoch 36/150
# 327/551 [================>.............] - ETA: 308s - loss: -0.4829 - dice_coef: 0.4829-15 slices lost due to size restrictions
# 331/551 [=================>............] - ETA: 303s - loss: -0.4850 - dice_coef: 0.4850-73 slices lost due to size restrictions
# 414/551 [=====================>........] - ETA: 188s - loss: -0.4857 - dice_coef: 0.4857-33 slices lost due to size restrictions
# 528/551 [===========================>..] - ETA: 31s - loss: -0.4667 - dice_coef: 0.4667-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.4671 - dice_coef: 0.4671Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.4656 - dice_coef: 0.4656-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.4647 - dice_coef: 0.4647 - val_loss: -0.1716 - val_dice_coef: 0.1716
# Epoch 37/150
#  90/551 [===>..........................] - ETA: 635s - loss: -0.3182 - dice_coef: 0.3182-15 slices lost due to size restrictions
#  95/551 [====>.........................] - ETA: 628s - loss: -0.3336 - dice_coef: 0.3336-79 slices lost due to size restrictions
# 375/551 [===================>..........] - ETA: 242s - loss: -0.4368 - dice_coef: 0.4368-33 slices lost due to size restrictions
# 489/551 [=========================>....] - ETA: 85s - loss: -0.4505 - dice_coef: 0.4505-73 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.4725 - dice_coef: 0.4725Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.4662 - dice_coef: 0.4662-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.4654 - dice_coef: 0.4654 - val_loss: -0.1457 - val_dice_coef: 0.1457
# Epoch 38/150
#  71/551 [==>...........................] - ETA: 661s - loss: -0.6239 - dice_coef: 0.6239-79 slices lost due to size restrictions
# 197/551 [=========>....................] - ETA: 488s - loss: -0.5041 - dice_coef: 0.5041-33 slices lost due to size restrictions
# 206/551 [==========>...................] - ETA: 475s - loss: -0.4883 - dice_coef: 0.4883-15 slices lost due to size restrictions
# 217/551 [==========>...................] - ETA: 460s - loss: -0.4767 - dice_coef: 0.4767-73 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.4679 - dice_coef: 0.4679Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.4704 - dice_coef: 0.4704-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.4695 - dice_coef: 0.4695 - val_loss: -0.1615 - val_dice_coef: 0.1615
# Epoch 39/150
# 246/551 [============>.................] - ETA: 420s - loss: -0.5090 - dice_coef: 0.5090-73 slices lost due to size restrictions
# 272/551 [=============>................] - ETA: 384s - loss: -0.5160 - dice_coef: 0.5160-79 slices lost due to size restrictions
# 459/551 [=======================>......] - ETA: 126s - loss: -0.4715 - dice_coef: 0.4715-33 slices lost due to size restrictions
# 536/551 [============================>.] - ETA: 20s - loss: -0.4776 - dice_coef: 0.4776-15 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.4800 - dice_coef: 0.4800Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.4758 - dice_coef: 0.4758-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# 551/551 [==============================] - 781s - loss: -0.4771 - dice_coef: 0.4771 - val_loss: -0.1754 - val_dice_coef: 0.1754
# Epoch 40/150
# -33 slices lost due to size restrictions
# 124/551 [=====>........................] - ETA: 588s - loss: -0.4743 - dice_coef: 0.4743-73 slices lost due to size restrictions
# 139/551 [======>.......................] - ETA: 568s - loss: -0.5064 - dice_coef: 0.5064-15 slices lost due to size restrictions
# 345/551 [=================>............] - ETA: 284s - loss: -0.5250 - dice_coef: 0.5250-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.5234 - dice_coef: 0.5234Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.5193 - dice_coef: 0.5193-43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 780s - loss: -0.5183 - dice_coef: 0.5183 - val_loss: -0.1658 - val_dice_coef: 0.1658
# Epoch 41/150
# 166/551 [========>.....................] - ETA: 530s - loss: -0.5138 - dice_coef: 0.5138-33 slices lost due to size restrictions
# 223/551 [===========>..................] - ETA: 452s - loss: -0.5477 - dice_coef: 0.5477-73 slices lost due to size restrictions
# 269/551 [=============>................] - ETA: 388s - loss: -0.5515 - dice_coef: 0.5515-15 slices lost due to size restrictions
# 458/551 [=======================>......] - ETA: 128s - loss: -0.5158 - dice_coef: 0.5158-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.5089 - dice_coef: 0.5089Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.5075 - dice_coef: 0.5075-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 780s - loss: -0.5086 - dice_coef: 0.5086 - val_loss: -0.1679 - val_dice_coef: 0.1679
# Epoch 42/150
# 100/551 [====>.........................] - ETA: 621s - loss: -0.5785 - dice_coef: 0.5785-15 slices lost due to size restrictions
# 220/551 [==========>...................] - ETA: 456s - loss: -0.5491 - dice_coef: 0.5491-79 slices lost due to size restrictions
# 282/551 [==============>...............] - ETA: 370s - loss: -0.5450 - dice_coef: 0.5450-33 slices lost due to size restrictions
# 472/551 [========================>.....] - ETA: 108s - loss: -0.5185 - dice_coef: 0.5185-73 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.5270 - dice_coef: 0.5270Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.5255 - dice_coef: 0.5255-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 780s - loss: -0.5245 - dice_coef: 0.5245 - val_loss: -0.1332 - val_dice_coef: 0.1332
# Epoch 43/150
#  48/551 [=>............................] - ETA: 693s - loss: -0.5776 - dice_coef: 0.5776-33 slices lost due to size restrictions
# 152/551 [=======>......................] - ETA: 550s - loss: -0.5277 - dice_coef: 0.5277-73 slices lost due to size restrictions
# 365/551 [==================>...........] - ETA: 256s - loss: -0.5445 - dice_coef: 0.5445-15 slices lost due to size restrictions
# 501/551 [==========================>...] - ETA: 68s - loss: -0.5349 - dice_coef: 0.5349-79 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.5367 - dice_coef: 0.5367Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.5349 - dice_coef: 0.5349-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 780s - loss: -0.5348 - dice_coef: 0.5348 - val_loss: -0.1464 - val_dice_coef: 0.1464
# Epoch 44/150
#  52/551 [=>............................] - ETA: 688s - loss: -0.4172 - dice_coef: 0.4172-33 slices lost due to size restrictions
# 273/551 [=============>................] - ETA: 383s - loss: -0.5057 - dice_coef: 0.5057-79 slices lost due to size restrictions
# 286/551 [==============>...............] - ETA: 365s - loss: -0.5127 - dice_coef: 0.5127-15 slices lost due to size restrictions
# 291/551 [==============>...............] - ETA: 358s - loss: -0.5172 - dice_coef: 0.5172-73 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.5465 - dice_coef: 0.5465Shuffling data
# 547/551 [============================>.] - ETA: 5s - loss: -0.5487 - dice_coef: 0.5487-33 slices lost due to size restrictions
# 550/551 [============================>.] - ETA: 1s - loss: -0.5504 - dice_coef: 0.5504-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# 551/551 [==============================] - 780s - loss: -0.5508 - dice_coef: 0.5508 - val_loss: -0.1649 - val_dice_coef: 0.1649
# Epoch 45/150
# 163/551 [=======>......................] - ETA: 534s - loss: -0.5650 - dice_coef: 0.5650-79 slices lost due to size restrictions
# 198/551 [=========>....................] - ETA: 486s - loss: -0.5541 - dice_coef: 0.5541-15 slices lost due to size restrictions
# 255/551 [============>.................] - ETA: 408s - loss: -0.5694 - dice_coef: 0.5694-73 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.5538 - dice_coef: 0.5538Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.5515 - dice_coef: 0.5515-43 slices lost due to size restrictions
# -38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 780s - loss: -0.5537 - dice_coef: 0.5537 - val_loss: -0.1645 - val_dice_coef: 0.1645
# Epoch 46/150
#  77/551 [===>..........................] - ETA: 653s - loss: -0.6445 - dice_coef: 0.6445-79 slices lost due to size restrictions
# 167/551 [========>.....................] - ETA: 529s - loss: -0.6068 - dice_coef: 0.6068-15 slices lost due to size restrictions
# 226/551 [===========>..................] - ETA: 448s - loss: -0.5791 - dice_coef: 0.5791-33 slices lost due to size restrictions
# 314/551 [================>.............] - ETA: 326s - loss: -0.5868 - dice_coef: 0.5868-73 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.5922 - dice_coef: 0.5922Shuffling data
# 550/551 [============================>.] - ETA: 1s - loss: -0.5959 - dice_coef: 0.5959-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 780s - loss: -0.5949 - dice_coef: 0.5949 - val_loss: -0.1705 - val_dice_coef: 0.1705
# Epoch 47/150
#  40/551 [=>............................] - ETA: 704s - loss: -0.6224 - dice_coef: 0.6224-79 slices lost due to size restrictions
# 128/551 [=====>........................] - ETA: 583s - loss: -0.6809 - dice_coef: 0.6809-73 slices lost due to size restrictions
# 388/551 [====================>.........] - ETA: 224s - loss: -0.5954 - dice_coef: 0.5954-15 slices lost due to size restrictions
# 441/551 [=======================>......] - ETA: 151s - loss: -0.5962 - dice_coef: 0.5962-33 slices lost due to size restrictions
# 541/551 [============================>.] - ETA: 13s - loss: -0.5784 - dice_coef: 0.5784Shuffling data
# 547/551 [============================>.] - ETA: 5s - loss: -0.5801 - dice_coef: 0.5801-79 slices lost due to size restrictions
# 550/551 [============================>.] - ETA: 1s - loss: -0.5769 - dice_coef: 0.5769-38 slices lost due to size restrictions
# -43 slices lost due to size restrictions
# 551/551 [==============================] - 780s - loss: -0.5758 - dice_coef: 0.5758 - val_loss: -0.1779 - val_dice_coef: 0.1779
# Epoch 00046: early stopping
