# %%
from utils.imports import *
# Out:
# Using TensorFlow backend.

# %%
def get_net(input_shape, load_weight_path=None, features=False, mal=False):
    width = 64
    inputs = Input(shape=(1, 32, 32, 32), name="input_1")
    x = inputs
    x = AveragePooling3D(pool_size=(2, 1, 1), strides=(2, 1, 1), border_mode="same")(x)
    x = Convolution3D(width, 3, 3, 3, activation='relu', border_mode='same', name='conv1', subsample=(1, 1, 1))(x)
    x = MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2), border_mode='valid', name='pool1')(x)

    # 2nd layer group
    x = Convolution3D(width*2, 3, 3, 3, activation='relu', border_mode='same', name='conv2', subsample=(1, 1, 1))(x)
    x = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), border_mode='valid', name='pool2')(x)
    x = Dropout(p=0.3)(x)

    # 3rd layer group
    x = Convolution3D(width*4, 3, 3, 3, activation='relu', border_mode='same', name='conv3a', subsample=(1, 1, 1))(x)
    x = Convolution3D(width*4, 3, 3, 3, activation='relu', border_mode='same', name='conv3b', subsample=(1, 1, 1))(x)
    x = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), border_mode='valid', name='pool3')(x)
    x = Dropout(p=0.4)(x)

    # 4th layer group
    x = Convolution3D(width*8, 3, 3, 3, activation='relu', border_mode='same', name='conv4a', subsample=(1, 1, 1))(x)
    x = Convolution3D(width*8, 3, 3, 3, activation='relu', border_mode='same', name='conv4b', subsample=(1, 1, 1),)(x)
    x = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), border_mode='valid', name='pool4')(x)
    x = Dropout(p=0.5)(x)
       
    last64 = Convolution3D(64, 2, 2, 2, activation="relu", name="last_64")(x)
    out_class = Convolution3D(1, 1, 1, 1, activation="softmax", name="out_class_last")(last64)
    out_class = Flatten(name="out_class")(x)
    
    out_class = Dense(2)(out_class) 
    out_class = Activation('softmax')(out_class)
    
    model = Model(input=inputs, output=out_class)
    model.compile(optimizer=SGD(lr=1e-3, momentum=0.9, nesterov=True), loss='categorical_crossentropy', metrics=['accuracy'])
    #model.compile(optimizer=Adam(lr=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])   
    return model

# %%
output_path = PATH['cls_train_cube_30']
output_true = PATH['cls_train_cube_30_true']
output_false = PATH['cls_train_cube_30_false']
model_paths = PATH['model_paths']
model_final = PATH['model_final']

# %%
def get_dirfiles(dir):
    file_list = []
    subset_path = os.listdir(dir)
    for _ in range(len(subset_path)):
        if subset_path[_] != '.DS_Store':
            file_list.append(dir + subset_path[_])
    return file_list

def train_generator(output_true,output_false):
    train_nb = 9000    
    file_list_true = get_dirfiles(output_true)
    file_list_false = get_dirfiles(output_false)        
    file_list_true = np.random.choice(file_list_true, train_nb)
    file_list_false = np.random.choice(file_list_false, train_nb)    
    nb_true = len(file_list_true) + len(file_list_false)    
    sample = np.zeros([nb_true,32, 32, 32])
    labels = np.zeros([nb_true,2])
    for i in tqdm(range(len(file_list_true))):       
        cc= np.load(file_list_true[i])
        sample[i] = cc
        labels[i] = [0.,1.]
    for j in tqdm(range(len(file_list_false))):
        bb= np.load(file_list_false[j])
        sample[j+len(file_list_true)] = bb 
        labels[j+len(file_list_true)] = [1.,0.]
    sample = np.expand_dims(sample, axis=1)        
    return sample,labels


def fenlei_fit(name, load_check = False,batch_size=2, epochs=100,check_name = None):
    t = time.time()
    callbacks = [EarlyStopping(monitor='val_loss', patience = 8, verbose = 1),
                 ModelCheckpoint((model_paths + '{}.h5').format(name),
                                 monitor='val_loss',
                                 verbose = 0,
                                 save_best_only = True)]
    if load_check:
        check_model = (model_paths + '{}.h5').format(check_name)
        model = load_model(check_model)
    else:
        #model = classifier((1, 32, 32, 32),128,(3, 3, 3), (2, 2, 2))
        model = get_net((1, 32, 32, 32))
    x,y = train_generator(output_true,output_false)
    model.fit(x,y, batch_size=batch_size, epochs=epochs,
              validation_split=0.2,verbose=1, callbacks=callbacks, shuffle=True) 
    return model

# %%
fenlei_fit('Fenge_32_32_32_0629', load_check = False, batch_size=8, epochs=200, check_name = 'Fenge_32_32_32_0629')
# Out:
# 100%|██████████| 9000/9000 [01:25<00:00, 104.87it/s]
# 100%|██████████| 9000/9000 [02:05<00:00, 71.99it/s]
# Train on 14400 samples, validate on 3600 samples
# Epoch 1/200
# 14400/14400 [==============================] - 256s - loss: 0.0587 - acc: 0.9780 - val_loss: 0.1689 - val_acc: 0.9536
# Epoch 2/200
# 14400/14400 [==============================] - 258s - loss: 0.0511 - acc: 0.9806 - val_loss: 0.0820 - val_acc: 0.9806
# Epoch 3/200
# 14400/14400 [==============================] - 257s - loss: 0.0445 - acc: 0.9841 - val_loss: 0.1132 - val_acc: 0.9675
# Epoch 4/200
# 14400/14400 [==============================] - 257s - loss: 0.0374 - acc: 0.9867 - val_loss: 0.1062 - val_acc: 0.9783
# Epoch 5/200
# 14400/14400 [==============================] - 256s - loss: 0.0338 - acc: 0.9865 - val_loss: 0.1310 - val_acc: 0.9661
# Epoch 6/200
# 14400/14400 [==============================] - 256s - loss: 0.0305 - acc: 0.9885 - val_loss: 0.0904 - val_acc: 0.9736
# Epoch 7/200
# 14400/14400 [==============================] - 256s - loss: 0.0300 - acc: 0.9892 - val_loss: 0.1047 - val_acc: 0.9703
# Epoch 8/200
# 14400/14400 [==============================] - 257s - loss: 0.0252 - acc: 0.9918 - val_loss: 0.1386 - val_acc: 0.9689
# Epoch 00007: early stopping

# %%
file_list_true = get_dirfiles(output_true)
file_list_false = get_dirfiles(output_false)

# %%
#model_pred = classifier((1, 36, 36, 36), (3, 3, 3), (2, 2, 2))
model_pred = load_model(model_paths + 'Fenge_32_32_32_0626.h5')

# %%
cc = []
for i in file_list_false[0:200]:
    a=np.load(i)
    a=np.expand_dims(a,0)
    a=np.expand_dims(a,0)
    cc.append(model_pred.predict(a))
count = 0
for i in cc:
    if i[0][0] > 0.9:
        count += 1
print count*1.0/len(cc)
# Out:
# 0.925

# %%
cc
# Out:
# [array([[ 0.08843933,  0.91156065]], dtype=float32),
#  array([[ 0.56332302,  0.43667698]], dtype=float32),
#  array([[ 0.895293  ,  0.10470697]], dtype=float32),
#  array([[ 0.95696002,  0.04303998]], dtype=float32),
#  array([[ 0.98198193,  0.01801805]], dtype=float32),
#  array([[ 0.99577492,  0.00422515]], dtype=float32),
#  array([[ 0.44888291,  0.55111706]], dtype=float32),
#  array([[ 0.90439427,  0.09560573]], dtype=float32),
#  array([[  9.99952316e-01,   4.77101203e-05]], dtype=float32),
#  array([[ 0.90899187,  0.09100811]], dtype=float32),
#  array([[ 0.94554162,  0.05445836]], dtype=float32),
#  array([[ 0.99226874,  0.00773125]], dtype=float32),
#  array([[ 0.03545162,  0.96454841]], dtype=float32),
#  array([[ 0.45879343,  0.5412066 ]], dtype=float32),
#  array([[ 0.99006504,  0.00993504]], dtype=float32),
#  array([[ 0.96149653,  0.03850353]], dtype=float32),
#  array([[ 0.22012223,  0.77987778]], dtype=float32),
#  array([[ 0.99604237,  0.00395761]], dtype=float32),
#  array([[ 0.99791962,  0.00208036]], dtype=float32),
#  array([[  9.99513984e-01,   4.85985220e-04]], dtype=float32),
#  array([[ 0.99809974,  0.00190022]], dtype=float32),
#  array([[ 0.98338175,  0.01661828]], dtype=float32),
#  array([[  9.99739945e-01,   2.59993743e-04]], dtype=float32),
#  array([[ 0.91124946,  0.08875055]], dtype=float32),
#  array([[  9.99932647e-01,   6.73238683e-05]], dtype=float32),
#  array([[  9.99230385e-01,   7.69672508e-04]], dtype=float32),
#  array([[ 0.99578071,  0.00421933]], dtype=float32),
#  array([[  9.99863505e-01,   1.36465605e-04]], dtype=float32),
#  array([[  9.99602854e-01,   3.97158408e-04]], dtype=float32),
#  array([[ 0.99448293,  0.00551702]], dtype=float32),
#  array([[ 0.46410483,  0.53589517]], dtype=float32),
#  array([[  9.99987483e-01,   1.24657763e-05]], dtype=float32),
#  array([[  9.99997139e-01,   2.81498183e-06]], dtype=float32),
#  array([[  9.99144197e-01,   8.55777471e-04]], dtype=float32),
#  array([[  9.99979734e-01,   2.02713818e-05]], dtype=float32),
#  array([[ 0.99318403,  0.00681597]], dtype=float32),
#  array([[  9.99323606e-01,   6.76434662e-04]], dtype=float32),
#  array([[ 0.93313193,  0.06686804]], dtype=float32),
#  array([[  9.99733627e-01,   2.66348594e-04]], dtype=float32),
#  array([[  9.99736130e-01,   2.63843860e-04]], dtype=float32),
#  array([[ 0.9966839,  0.0033161]], dtype=float32),
#  array([[ 0.9763931 ,  0.02360688]], dtype=float32),
#  array([[  9.99994636e-01,   5.32014383e-06]], dtype=float32),
#  array([[  9.99989986e-01,   1.00262114e-05]], dtype=float32),
#  array([[ 0.93521851,  0.06478152]], dtype=float32),
#  array([[  9.99907255e-01,   9.27720248e-05]], dtype=float32),
#  array([[  9.99618053e-01,   3.81902850e-04]], dtype=float32),
#  array([[ 0.9950524 ,  0.00494767]], dtype=float32),
#  array([[  9.99856353e-01,   1.43609723e-04]], dtype=float32),
#  array([[  9.99994159e-01,   5.86517399e-06]], dtype=float32),
#  array([[  9.99033570e-01,   9.66455496e-04]], dtype=float32),
#  array([[  9.99109328e-01,   8.90705734e-04]], dtype=float32),
#  array([[  9.99263227e-01,   7.36805145e-04]], dtype=float32),
#  array([[  9.99995351e-01,   4.66455867e-06]], dtype=float32),
#  array([[  9.99051988e-01,   9.47998720e-04]], dtype=float32),
#  array([[  9.99991298e-01,   8.65877064e-06]], dtype=float32),
#  array([[ 0.99863857,  0.00136146]], dtype=float32),
#  array([[  9.99547541e-01,   4.52381559e-04]], dtype=float32),
#  array([[ 0.99810827,  0.00189174]], dtype=float32),
#  array([[  9.99841571e-01,   1.58430470e-04]], dtype=float32),
#  array([[  9.99994993e-01,   5.00077977e-06]], dtype=float32),
#  array([[  9.99998689e-01,   1.34102424e-06]], dtype=float32),
#  array([[  9.99751747e-01,   2.48199533e-04]], dtype=float32),
#  array([[  9.99961376e-01,   3.86807260e-05]], dtype=float32),
#  array([[  9.99951601e-01,   4.84475931e-05]], dtype=float32),
#  array([[  9.99680758e-01,   3.19301907e-04]], dtype=float32),
#  array([[  9.99929309e-01,   7.06621795e-05]], dtype=float32),
#  array([[  9.99987721e-01,   1.22810161e-05]], dtype=float32),
#  array([[ 0.99871886,  0.00128114]], dtype=float32),
#  array([[  9.99810278e-01,   1.89708546e-04]], dtype=float32),
#  array([[ 0.84846318,  0.15153682]], dtype=float32),
#  array([[  9.99999762e-01,   2.52029622e-07]], dtype=float32),
#  array([[  9.99936581e-01,   6.34715761e-05]], dtype=float32),
#  array([[ 0.99769104,  0.002309  ]], dtype=float32),
#  array([[ 0.9987483 ,  0.00125168]], dtype=float32),
#  array([[ 0.99852645,  0.00147354]], dtype=float32),
#  array([[  9.99988198e-01,   1.18394128e-05]], dtype=float32),
#  array([[  9.99134719e-01,   8.65275739e-04]], dtype=float32),
#  array([[ 0.98913479,  0.01086521]], dtype=float32),
#  array([[  9.99919295e-01,   8.06389944e-05]], dtype=float32),
#  array([[  9.99883056e-01,   1.16934723e-04]], dtype=float32),
#  array([[  9.99341071e-01,   6.58936973e-04]], dtype=float32),
#  array([[ 0.99796742,  0.00203255]], dtype=float32),
#  array([[  9.99994636e-01,   5.36028529e-06]], dtype=float32),
#  array([[ 0.99436247,  0.00563757]], dtype=float32),
#  array([[  9.99996424e-01,   3.52054076e-06]], dtype=float32),
#  array([[ 0.87802601,  0.12197395]], dtype=float32),
#  array([[  9.99807537e-01,   1.92465188e-04]], dtype=float32),
#  array([[ 0.99137068,  0.00862933]], dtype=float32),
#  array([[ 0.99703276,  0.00296725]], dtype=float32),
#  array([[ 0.96672016,  0.03327988]], dtype=float32),
#  array([[  9.99994874e-01,   5.13617215e-06]], dtype=float32),
#  array([[  9.99994397e-01,   5.61595471e-06]], dtype=float32),
#  array([[  9.99986291e-01,   1.36511699e-05]], dtype=float32),
#  array([[  9.99135673e-01,   8.64372239e-04]], dtype=float32),
#  array([[  9.99997735e-01,   2.31283639e-06]], dtype=float32),
#  array([[  9.99997020e-01,   3.02039120e-06]], dtype=float32),
#  array([[  9.99997973e-01,   2.02687465e-06]], dtype=float32),
#  array([[ 0.97867876,  0.02132119]], dtype=float32),
#  array([[ 0.99707127,  0.00292871]], dtype=float32),
#  array([[  9.99923587e-01,   7.64251599e-05]], dtype=float32),
#  array([[ 0.99894089,  0.00105916]], dtype=float32)]

# %%
cc = []
for i in file_list_true[0:200]:
    a=np.load(i)
    a=np.expand_dims(a,0)
    a=np.expand_dims(a,0)
    cc.append(model_pred.predict(a))
count = 0

# %%
for i in cc:
    if i[0][1] > 0.9:
        count += 1
print count*1.0/len(cc)
# Out:
# 0.895

# %%
cc
# Out:
#  array([[ 0.00263278,  0.9973672 ]], dtype=float32),
#  array([[  6.35948381e-04,   9.99364078e-01]], dtype=float32),
#  array([[  9.70516354e-04,   9.99029517e-01]], dtype=float32),
#  array([[ 0.00285255,  0.9971475 ]], dtype=float32),
#  array([[ 0.00532667,  0.99467331]], dtype=float32),
#  array([[ 0.00483821,  0.99516183]], dtype=float32),
#  array([[ 0.02805032,  0.9719497 ]], dtype=float32),
#  array([[ 0.03773747,  0.96226251]], dtype=float32),
#  array([[ 0.00492738,  0.99507254]], dtype=float32),
#  array([[ 0.52116221,  0.47883776]], dtype=float32),
#  array([[  9.11082432e-04,   9.99088883e-01]], dtype=float32),
#  array([[ 0.00337886,  0.99662113]], dtype=float32),
#  array([[ 0.00822083,  0.99177915]], dtype=float32),
#  array([[ 0.0194823 ,  0.98051769]], dtype=float32),
#  array([[ 0.01209506,  0.98790491]], dtype=float32),
#  array([[ 0.01783128,  0.98216873]], dtype=float32),
#  array([[  6.31169765e-04,   9.99368846e-01]], dtype=float32),
#  array([[ 0.00400799,  0.995992  ]], dtype=float32),
#  array([[  3.40144528e-04,   9.99659896e-01]], dtype=float32),
#  array([[  1.79933442e-04,   9.99820054e-01]], dtype=float32),
#  array([[ 0.00247597,  0.99752396]], dtype=float32),
#  array([[  5.04770491e-04,   9.99495268e-01]], dtype=float32),
#  array([[  3.93184309e-05,   9.99960661e-01]], dtype=float32),
#  array([[  4.03438389e-05,   9.99959707e-01]], dtype=float32),
#  array([[  5.15544205e-04,   9.99484420e-01]], dtype=float32),
#  array([[  1.48730430e-06,   9.99998569e-01]], dtype=float32),
#  array([[  3.38808968e-05,   9.99966145e-01]], dtype=float32),
#  array([[  8.52632002e-05,   9.99914765e-01]], dtype=float32),
#  array([[  1.13869328e-06,   9.99998808e-01]], dtype=float32),
#  array([[  1.57105603e-06,   9.99998450e-01]], dtype=float32),
#  array([[  3.90876885e-05,   9.99960899e-01]], dtype=float32),
#  array([[ 0.02869934,  0.97130066]], dtype=float32),
#  array([[ 0.02756081,  0.97243923]], dtype=float32),
#  array([[ 0.1098037 ,  0.89019626]], dtype=float32),
#  array([[ 0.01377474,  0.98622525]], dtype=float32),
#  array([[ 0.02948264,  0.9705174 ]], dtype=float32),
#  array([[  9.56698961e-04,   9.99043286e-01]], dtype=float32),
#  array([[ 0.05664019,  0.94335979]], dtype=float32),
#  array([[ 0.0500894 ,  0.94991058]], dtype=float32),
#  array([[ 0.00511431,  0.99488574]], dtype=float32),
#  array([[ 0.00155475,  0.99844533]], dtype=float32),
#  array([[ 0.03869149,  0.96130854]], dtype=float32),
#  array([[  5.40908950e-04,   9.99459088e-01]], dtype=float32),
#  array([[ 0.00293348,  0.99706656]], dtype=float32),
#  array([[ 0.06381384,  0.93618613]], dtype=float32),
#  array([[ 0.00124433,  0.99875569]], dtype=float32),
#  array([[ 0.00243801,  0.99756205]], dtype=float32),
#  array([[ 0.13843483,  0.86156517]], dtype=float32),
#  array([[ 0.00121846,  0.9987815 ]], dtype=float32),
#  array([[ 0.00219948,  0.99780053]], dtype=float32),
#  array([[  2.04419775e-04,   9.99795616e-01]], dtype=float32),
#  array([[  6.66278589e-04,   9.99333680e-01]], dtype=float32),
#  array([[  3.31409072e-04,   9.99668598e-01]], dtype=float32),
#  array([[  3.56048731e-05,   9.99964356e-01]], dtype=float32),
#  array([[ 0.01471441,  0.98528558]], dtype=float32),
#  array([[  1.11485635e-04,   9.99888539e-01]], dtype=float32),
#  array([[  5.01794566e-05,   9.99949813e-01]], dtype=float32),
#  array([[  9.26951179e-04,   9.99073029e-01]], dtype=float32),
#  array([[  6.06107467e-04,   9.99393940e-01]], dtype=float32),
#  array([[  2.72532111e-06,   9.99997258e-01]], dtype=float32),
#  array([[  5.76154154e-04,   9.99423862e-01]], dtype=float32),
#  array([[ 0.00318306,  0.99681693]], dtype=float32),
#  array([[  4.82482335e-07,   9.99999523e-01]], dtype=float32),
#  array([[  8.10177298e-04,   9.99189794e-01]], dtype=float32),
#  array([[ 0.00246566,  0.99753428]], dtype=float32),
#  array([[  3.98519478e-06,   9.99996066e-01]], dtype=float32),
#  array([[ 0.00978226,  0.99021775]], dtype=float32),
#  array([[  2.11613573e-04,   9.99788344e-01]], dtype=float32),
#  array([[  4.36628354e-04,   9.99563396e-01]], dtype=float32),
#  array([[  8.97117498e-05,   9.99910235e-01]], dtype=float32),
#  array([[ 0.00204698,  0.99795294]], dtype=float32),
#  array([[ 0.0029184 ,  0.99708158]], dtype=float32),
#  array([[  2.92804471e-04,   9.99707162e-01]], dtype=float32),
#  array([[  5.66407165e-04,   9.99433577e-01]], dtype=float32),
#  array([[  4.68469341e-04,   9.99531507e-01]], dtype=float32),
#  array([[ 0.00109979,  0.99890018]], dtype=float32),
#  array([[  1.52613997e-04,   9.99847412e-01]], dtype=float32),
#  array([[  3.52349639e-06,   9.99996424e-01]], dtype=float32),
#  array([[ 0.0012873 ,  0.99871266]], dtype=float32),
#  array([[  1.23269547e-05,   9.99987721e-01]], dtype=float32),
#  array([[  2.19721933e-05,   9.99978065e-01]], dtype=float32),
#  array([[  6.74466486e-04,   9.99325514e-01]], dtype=float32),
#  array([[  1.01649457e-05,   9.99989867e-01]], dtype=float32),
#  array([[  7.90492049e-06,   9.99992132e-01]], dtype=float32),
#  array([[ 0.00267934,  0.99732071]], dtype=float32),
#  array([[ 0.08165313,  0.91834682]], dtype=float32),
#  array([[ 0.4264918 ,  0.57350826]], dtype=float32),
#  array([[ 0.01765263,  0.98234737]], dtype=float32),
#  array([[ 0.58865708,  0.41134295]], dtype=float32),
#  array([[ 0.3638809 ,  0.63611907]], dtype=float32),
#  array([[ 0.18080254,  0.81919742]], dtype=float32),
#  array([[ 0.41291371,  0.58708638]], dtype=float32),
#  array([[ 0.04351731,  0.95648271]], dtype=float32),
#  array([[ 0.24095443,  0.75904554]], dtype=float32),
#  array([[ 0.02732347,  0.97267658]], dtype=float32),
#  array([[ 0.00146819,  0.99853182]], dtype=float32),
#  array([[ 0.39332274,  0.60667729]], dtype=float32),
#  array([[  8.74686230e-05,   9.99912500e-01]], dtype=float32),
#  array([[  1.78320595e-04,   9.99821723e-01]], dtype=float32),
#  array([[ 0.00139326,  0.99860674]], dtype=float32),
#  array([[  6.18046943e-06,   9.99993801e-01]], dtype=float32),
#  array([[  7.26154576e-06,   9.99992728e-01]], dtype=float32),
#  array([[ 0.00191267,  0.99808735]], dtype=float32),
#  array([[ 0.00401275,  0.99598724]], dtype=float32),
#  array([[ 0.00454794,  0.99545211]], dtype=float32),
#  array([[ 0.00101432,  0.99898571]], dtype=float32),
#  array([[ 0.03996404,  0.96003598]], dtype=float32),
#  array([[ 0.03132485,  0.9686752 ]], dtype=float32),
#  array([[ 0.00150095,  0.99849904]], dtype=float32),
#  array([[ 0.05375006,  0.94624996]], dtype=float32),
#  array([[ 0.00836126,  0.99163872]], dtype=float32),
#  array([[ 0.0035876 ,  0.99641246]], dtype=float32),
#  array([[ 0.04490722,  0.95509285]], dtype=float32),
#  array([[ 0.02963098,  0.97036898]], dtype=float32),
#  array([[ 0.07571356,  0.92428643]], dtype=float32),
#  array([[ 0.02675593,  0.97324413]], dtype=float32),
#  array([[ 0.0202442 ,  0.97975576]], dtype=float32),
#  array([[ 0.02499637,  0.97500366]], dtype=float32),
#  array([[ 0.01015069,  0.98984933]], dtype=float32),
#  array([[ 0.01435306,  0.9856469 ]], dtype=float32),
#  array([[ 0.21150002,  0.78849995]], dtype=float32),
#  array([[ 0.0166587 ,  0.98334128]], dtype=float32),
#  array([[ 0.02654975,  0.97345024]], dtype=float32),
#  array([[ 0.07812534,  0.9218747 ]], dtype=float32),
#  array([[ 0.02282436,  0.97717559]], dtype=float32),
#  array([[ 0.02390753,  0.97609246]], dtype=float32),
#  array([[ 0.19519289,  0.80480707]], dtype=float32),
#  array([[ 0.24931906,  0.75068092]], dtype=float32),
#  array([[ 0.06435229,  0.93564779]], dtype=float32),
#  array([[ 0.6056602 ,  0.39433977]], dtype=float32),
#  array([[ 0.02859897,  0.97140098]], dtype=float32),
#  array([[ 0.00104533,  0.99895465]], dtype=float32),
#  array([[  3.05372843e-04,   9.99694705e-01]], dtype=float32),
#  array([[  3.33064963e-05,   9.99966741e-01]], dtype=float32),
#  array([[  9.01077146e-06,   9.99990940e-01]], dtype=float32),
#  array([[  1.03354905e-04,   9.99896646e-01]], dtype=float32),
#  array([[  6.42114901e-04,   9.99357879e-01]], dtype=float32),
#  array([[  2.83513597e-04,   9.99716461e-01]], dtype=float32),
#  array([[  5.41164249e-04,   9.99458849e-01]], dtype=float32),
#  array([[ 0.01339492,  0.98660511]], dtype=float32),
#  array([[ 0.00587346,  0.99412656]], dtype=float32),
#  array([[ 0.00621186,  0.99378806]], dtype=float32),
#  array([[ 0.00114868,  0.9988513 ]], dtype=float32),
#  array([[  9.68759763e-04,   9.99031305e-01]], dtype=float32),
#  array([[ 0.0772905 ,  0.92270952]], dtype=float32),
#  array([[ 0.00221976,  0.99778026]], dtype=float32),
#  array([[  9.52943694e-04,   9.99047101e-01]], dtype=float32),
#  array([[  1.52580978e-04,   9.99847412e-01]], dtype=float32),
#  array([[ 0.00179037,  0.9982096 ]], dtype=float32),
#  array([[  1.62040538e-04,   9.99837875e-01]], dtype=float32)]

# %%
len(file_list_false)
# Out:
# 74902
