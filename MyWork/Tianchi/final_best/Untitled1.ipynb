# %%
from utils.imports import *
# Out:
# Using TensorFlow backend.

# %%
aa = os.listdir('/Volumes/solo/ali/Data/train_mask/nodule')

# %%
def cc(i):
    if i != '.DS_Store':
        lungs = cv2.imread('/Volumes/solo/ali/Data/train_mask/nodule/'+i,cv2.IMREAD_GRAYSCALE).astype('int')
        lungs = int(1)-lungs/255
        cv2.imwrite('/Volumes/solo/ali/Data/train_mask/nodule/'+i,lungs*255)

# %%
Parallel(n_jobs=-1)(delayed(cc)(pat) for pat in tqdm(sorted(aa)))
# Out:
# 100%|██████████| 3712/3712 [00:09<00:00, 379.29it/s]
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
