# %%
from utils.imports import *
# Out:
# Using TensorFlow backend.

# %%
def get_dirfiles(dir):
    file_list = []
    subset_path = os.listdir(dir)
    for _ in range(len(subset_path)):
        if subset_path[_] != '.DS_Store':
            file_list.append(dir + subset_path[_])
    return file_list

def train_generator(output_true,output_false):
    file_list_true = get_dirfiles(output_true)[0:9000]
    file_list_false = get_dirfiles(output_false)[0:9000]
    
    file_list_true = shuffle(file_list_true)
    file_list_false = shuffle(file_list_false)
    
    nb_true = len(file_list_true) + len(file_list_false)
    sample = np.zeros([nb_true,26,40,40])
    labels = np.zeros([nb_true,2])
    for i in tqdm(range(len(file_list_true))):       
        cc= np.load(file_list_true[i])
        sample[i] = cc
        labels[i] = [0.,1.]
    for j in tqdm(range(len(file_list_false))):
        bb= np.load(file_list_false[j])
        sample[j+len(file_list_true)] = bb 
        labels[j+len(file_list_true)] = [1.,0.]
    sample = np.expand_dims(sample, axis=1)        
    return sample,labels

def valid_generator(output_true,output_false):
    file_list_true = get_dirfiles(output_true)[-1000:]
    file_list_false = get_dirfiles(output_false)[-1000:]
    
    file_list_true = shuffle(file_list_true)
    file_list_false = shuffle(file_list_false)

    nb_true = len(file_list_true) + len(file_list_false)
    sample = np.zeros([nb_true,26,40,40])
    labels = np.zeros([nb_true,2])
  
    for i in tqdm(range(len(file_list_true))):       
        cc= np.load(file_list_true[i])
        sample[i] = cc
        labels[i] = [0.,1.]
    for j in tqdm(range(len(file_list_false))):
        bb= np.load(file_list_false[j])
        sample[j+len(file_list_true)] = bb 
        labels[j+len(file_list_true)] = [1.,0.]
    sample = np.expand_dims(sample, axis=1)        
    return sample,labels

def model_40():    

    inputs = Input(shape=(1, 26, 40, 40))
    
    conv1 = Convolution3D(24, 3, 5, 5, activation = 'relu', border_mode='same')(inputs)
    conv1 = BatchNormalization(axis = 1)(conv1)
    conv1 = Convolution3D(24, 2, 2, 2, activation = 'relu', border_mode='same')(conv1)
    conv1 = BatchNormalization(axis = 1)(conv1)
    conv1 = Convolution3D(24, 3, 5, 5, activation = 'relu', border_mode='same')(inputs)
    conv1 = BatchNormalization(axis = 1)(conv1)
    conv1 = Convolution3D(24, 3, 5, 5, activation = 'relu', border_mode='same')(conv1)
    conv1 = BatchNormalization(axis = 1)(conv1)    
    
    output = Flatten(name='flatten')(conv1)
    output = Dense(96)(output)
    output = PReLU()(output)
    output = BatchNormalization()(output)
    output = Dense(2, activation='softmax', name = 'predictions')(output)
    model3d = Model(inputs, output)
    model3d.compile(loss='categorical_crossentropy', optimizer = Adam(lr=1e-5), metrics = ['accuracy'])
    return model3d


def fenlei_fit(name, load_check = False,batch_size=2, epochs=100,check_name = None):

    t = time.time()
    callbacks = [EarlyStopping(monitor='val_loss', patience = 8, verbose = 1),
                 ModelCheckpoint((model_paths + '{}.h5').format(name),
                                 monitor='val_loss',
                                 verbose = 0,
                                 save_best_only = True)]
    if load_check:
        check_model = (model_paths + '{}.h5').format(check_name)
        model = load_model(check_model)
    else:
        model = model_40()
    x,y = train_generator(output_true,output_false)
    model.fit(x=x, y=y, batch_size=batch_size, epochs=epochs,
              validation_data=valid_generator(output_true,output_false),verbose=1, callbacks=callbacks, shuffle=True) 
    return model

# %%
output_path = PATH['cls_train_40']
output_true = PATH['cls_train_40_true']
output_false = PATH['cls_train_40_false']
model_paths = PATH['model_paths']
model_final = PATH['model_final']

# %%
fenlei_fit('Fenge_26_40_40_0617', load_check = False, batch_size=1, epochs=100, check_name = 'Fenge_26_40_40_0617')
# Out:
# 100%|██████████| 9000/9000 [00:15<00:00, 571.48it/s]
# 100%|██████████| 9000/9000 [00:19<00:00, 458.51it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 403.17it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 330.47it/s]
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/100
# 18000/18000 [==============================] - 1366s - loss: 0.4209 - acc: 0.8182 - val_loss: 0.3702 - val_acc: 0.8730
# Epoch 2/100
# 18000/18000 [==============================] - 1361s - loss: 0.2793 - acc: 0.8876 - val_loss: 0.3379 - val_acc: 0.8795
# Epoch 3/100
# 18000/18000 [==============================] - 1348s - loss: 0.2353 - acc: 0.9116 - val_loss: 0.4697 - val_acc: 0.8330
# Epoch 4/100
# 18000/18000 [==============================] - 1353s - loss: 0.1876 - acc: 0.9291 - val_loss: 0.3551 - val_acc: 0.8825
# Epoch 5/100
# 18000/18000 [==============================] - 1358s - loss: 0.1486 - acc: 0.9469 - val_loss: 0.3890 - val_acc: 0.8705
# Epoch 6/100
# 18000/18000 [==============================] - 1354s - loss: 0.1327 - acc: 0.9509 - val_loss: 0.3689 - val_acc: 0.8955
# Epoch 7/100
# 18000/18000 [==============================] - 1357s - loss: 0.1197 - acc: 0.9583 - val_loss: 0.3636 - val_acc: 0.8935
# Epoch 8/100
# 18000/18000 [==============================] - 1364s - loss: 0.1010 - acc: 0.9652 - val_loss: 0.3641 - val_acc: 0.8850
# Epoch 9/100
# 18000/18000 [==============================] - 1365s - loss: 0.1011 - acc: 0.9639 - val_loss: 0.3930 - val_acc: 0.8785
# Epoch 10/100
# 18000/18000 [==============================] - 1362s - loss: 0.0994 - acc: 0.9656 - val_loss: 0.3845 - val_acc: 0.8875
# Epoch 11/100
# 18000/18000 [==============================] - 1357s - loss: 0.0970 - acc: 0.9659 - val_loss: 0.3686 - val_acc: 0.8965
# Epoch 00010: early stopping

# %%
file_list_true = get_dirfiles(output_true)
file_list_false = get_dirfiles(output_false)

# %%
#model_pred = classifier((1, 36, 36, 36), (3, 3, 3), (2, 2, 2))
model_pred = load_model(model_paths + 'Fenge_26_40_40_0617.h5')

# %%
cc = []
for i in file_list_false[0:200]:
    a=np.load(i)
    a=np.expand_dims(a,0)
    a=np.expand_dims(a,0)
    cc.append(model_pred.predict(a))
count = 0
for i in cc:
    if i[0][0] > 0.9:
        count += 1
print count*1.0/len(cc)
# Out:
# 0.78

# %%
cc
# Out:
# [array([[ 0.95507878,  0.04492117]], dtype=float32),
#  array([[ 0.78953469,  0.21046533]], dtype=float32),
#  array([[ 0.98115838,  0.01884155]], dtype=float32),
#  array([[ 0.91804433,  0.08195562]], dtype=float32),
#  array([[ 0.25263128,  0.74736875]], dtype=float32),
#  array([[ 0.97803348,  0.02196653]], dtype=float32),
#  array([[ 0.993608  ,  0.00639199]], dtype=float32),
#  array([[ 0.99645174,  0.00354825]], dtype=float32),
#  array([[ 0.97774029,  0.02225972]], dtype=float32),
#  array([[ 0.16183609,  0.83816385]], dtype=float32),
#  array([[ 0.95343685,  0.04656321]], dtype=float32),
#  array([[ 0.70274049,  0.29725954]], dtype=float32),
#  array([[ 0.87974721,  0.1202528 ]], dtype=float32),
#  array([[ 0.89688772,  0.1031123 ]], dtype=float32),
#  array([[ 0.9517346 ,  0.04826543]], dtype=float32),
#  array([[ 0.89935499,  0.10064503]], dtype=float32),
#  array([[ 0.75651073,  0.24348925]], dtype=float32),
#  array([[ 0.58668095,  0.41331902]], dtype=float32),
#  array([[ 0.99137938,  0.00862068]], dtype=float32),
#  array([[ 0.99757451,  0.00242546]], dtype=float32),
#  array([[ 0.88710088,  0.11289909]], dtype=float32),
#  array([[ 0.88073057,  0.11926939]], dtype=float32),
#  array([[ 0.97412634,  0.02587371]], dtype=float32),
#  array([[ 0.9840315 ,  0.01596848]], dtype=float32),
#  array([[ 0.99077749,  0.00922249]], dtype=float32),
#  array([[ 0.98084635,  0.01915363]], dtype=float32),
#  array([[ 0.92466366,  0.07533631]], dtype=float32),
#  array([[ 0.99826378,  0.00173623]], dtype=float32),
#  array([[ 0.95219427,  0.04780567]], dtype=float32),
#  array([[ 0.60591304,  0.39408696]], dtype=float32),
#  array([[ 0.99320954,  0.00679047]], dtype=float32),
#  array([[ 0.58437955,  0.41562042]], dtype=float32),
#  array([[ 0.99515378,  0.00484621]], dtype=float32),
#  array([[ 0.19344449,  0.80655551]], dtype=float32),
#  array([[ 0.92998046,  0.07001958]], dtype=float32),
#  array([[ 0.95754355,  0.04245643]], dtype=float32),
#  array([[ 0.96087378,  0.03912622]], dtype=float32),
#  array([[ 0.96879435,  0.03120569]], dtype=float32),
#  array([[ 0.9906323 ,  0.00936768]], dtype=float32),
#  array([[ 0.99254817,  0.00745186]], dtype=float32),
#  array([[ 0.9377349 ,  0.06226511]], dtype=float32),
#  array([[ 0.98051411,  0.01948595]], dtype=float32),
#  array([[ 0.98915344,  0.01084654]], dtype=float32),
#  array([[ 0.94625646,  0.05374353]], dtype=float32),
#  array([[ 0.97767329,  0.02232669]], dtype=float32),
#  array([[ 0.90000468,  0.09999532]], dtype=float32),
#  array([[ 0.93960023,  0.06039977]], dtype=float32),
#  array([[ 0.54396826,  0.45603174]], dtype=float32),
#  array([[ 0.91453958,  0.08546036]], dtype=float32),
#  array([[ 0.97565156,  0.0243485 ]], dtype=float32),
#  array([[ 0.96514976,  0.03485021]], dtype=float32),
#  array([[ 0.99375939,  0.00624066]], dtype=float32),
#  array([[ 0.99125987,  0.0087401 ]], dtype=float32),
#  array([[ 0.96172291,  0.03827709]], dtype=float32),
#  array([[ 0.98888528,  0.01111475]], dtype=float32),
#  array([[ 0.95425969,  0.04574024]], dtype=float32),
#  array([[ 0.99552959,  0.00447042]], dtype=float32),
#  array([[ 0.95845705,  0.04154291]], dtype=float32),
#  array([[ 0.98683065,  0.01316938]], dtype=float32),
#  array([[ 0.93015206,  0.06984796]], dtype=float32),
#  array([[ 0.99266547,  0.00733452]], dtype=float32),
#  array([[ 0.99536276,  0.00463718]], dtype=float32),
#  array([[ 0.94266534,  0.05733465]], dtype=float32),
#  array([[ 0.9696694 ,  0.03033056]], dtype=float32),
#  array([[ 0.96547103,  0.03452893]], dtype=float32),
#  array([[ 0.99558061,  0.00441936]], dtype=float32),
#  array([[ 0.94300675,  0.05699329]], dtype=float32),
#  array([[ 0.96208704,  0.03791298]], dtype=float32),
#  array([[ 0.93175304,  0.06824698]], dtype=float32),
#  array([[ 0.93626952,  0.06373052]], dtype=float32),
#  array([[ 0.95764869,  0.04235135]], dtype=float32),
#  array([[ 0.98193067,  0.01806933]], dtype=float32),
#  array([[ 0.99152511,  0.00847486]], dtype=float32),
#  array([[ 0.97692198,  0.02307802]], dtype=float32),
#  array([[ 0.93973529,  0.0602647 ]], dtype=float32),
#  array([[ 0.94849229,  0.0515077 ]], dtype=float32),
#  array([[ 0.78869402,  0.21130602]], dtype=float32),
#  array([[ 0.97409612,  0.02590386]], dtype=float32),
#  array([[ 0.97948688,  0.02051305]], dtype=float32),
#  array([[ 0.99512404,  0.00487599]], dtype=float32),
#  array([[ 0.72493309,  0.27506691]], dtype=float32),
#  array([[ 0.67565793,  0.32434204]], dtype=float32),
#  array([[ 0.19900806,  0.80099189]], dtype=float32),
#  array([[ 0.97001439,  0.02998553]], dtype=float32),
#  array([[ 0.89200658,  0.10799342]], dtype=float32),
#  array([[ 0.70344901,  0.29655093]], dtype=float32),
#  array([[ 0.88540399,  0.11459596]], dtype=float32),
#  array([[  9.99303102e-01,   6.96908101e-04]], dtype=float32),
#  array([[ 0.99333853,  0.00666145]], dtype=float32),
#  array([[ 0.99204433,  0.00795567]], dtype=float32),
#  array([[ 0.95547432,  0.04452568]], dtype=float32),
#  array([[ 0.97288889,  0.02711108]], dtype=float32),
#  array([[ 0.96192741,  0.03807257]], dtype=float32),
#  array([[ 0.99819142,  0.00180857]], dtype=float32),
#  array([[ 0.91232961,  0.08767034]], dtype=float32),
#  array([[ 0.95227253,  0.04772748]], dtype=float32),
#  array([[ 0.99437994,  0.00562003]], dtype=float32),
#  array([[ 0.56065118,  0.43934879]], dtype=float32),
#  array([[ 0.98595339,  0.01404656]], dtype=float32),
#  array([[ 0.95620763,  0.04379237]], dtype=float32),
#  array([[ 0.97973812,  0.02026189]], dtype=float32),
#  array([[ 0.9905048 ,  0.00949522]], dtype=float32),
#  array([[ 0.9916755,  0.0083245]], dtype=float32),
#  array([[ 0.87927169,  0.12072835]], dtype=float32),
#  array([[ 0.95106173,  0.04893824]], dtype=float32),
#  array([[ 0.98107255,  0.01892738]], dtype=float32),
#  array([[ 0.97671789,  0.02328211]], dtype=float32),
#  array([[ 0.94458222,  0.05541773]], dtype=float32),
#  array([[ 0.94349116,  0.05650892]], dtype=float32),
#  array([[ 0.98867828,  0.0113217 ]], dtype=float32),
#  array([[ 0.9926514 ,  0.00734861]], dtype=float32),
#  array([[ 0.94354856,  0.05645144]], dtype=float32),
#  array([[ 0.99671209,  0.0032879 ]], dtype=float32),
#  array([[ 0.71899104,  0.28100899]], dtype=float32),
#  array([[ 0.99414551,  0.00585447]], dtype=float32),
#  array([[ 0.97686517,  0.02313486]], dtype=float32),
#  array([[  9.99945402e-01,   5.45957337e-05]], dtype=float32),
#  array([[  9.99284685e-01,   7.15315575e-04]], dtype=float32),
#  array([[ 0.99143046,  0.00856961]], dtype=float32),
#  array([[ 0.91795373,  0.08204632]], dtype=float32),
#  array([[ 0.99713159,  0.00286844]], dtype=float32),
#  array([[  9.99465644e-01,   5.34372404e-04]], dtype=float32),
#  array([[ 0.74871868,  0.25128129]], dtype=float32),
#  array([[ 0.99192989,  0.00807016]], dtype=float32),
#  array([[ 0.72934049,  0.27065951]], dtype=float32),
#  array([[ 0.99488527,  0.00511469]], dtype=float32),
#  array([[ 0.98848736,  0.01151272]], dtype=float32),
#  array([[ 0.89784896,  0.10215106]], dtype=float32),
#  array([[ 0.24476224,  0.7552377 ]], dtype=float32),
#  array([[ 0.93207979,  0.06792027]], dtype=float32),
#  array([[ 0.98545444,  0.0145456 ]], dtype=float32),
#  array([[ 0.99425596,  0.00574408]], dtype=float32),
#  array([[ 0.96076894,  0.03923105]], dtype=float32),
#  array([[  9.99671102e-01,   3.28964496e-04]], dtype=float32),
#  array([[ 0.93773532,  0.06226471]], dtype=float32),
#  array([[ 0.92705631,  0.07294364]], dtype=float32),
#  array([[ 0.97887975,  0.02112027]], dtype=float32),
#  array([[ 0.92559671,  0.07440332]], dtype=float32),
#  array([[ 0.95534354,  0.04465643]], dtype=float32),
#  array([[ 0.97145396,  0.02854604]], dtype=float32),
#  array([[ 0.39676145,  0.60323852]], dtype=float32),
#  array([[ 0.79954821,  0.20045181]], dtype=float32),
#  array([[ 0.97562349,  0.02437644]], dtype=float32),
#  array([[ 0.99864763,  0.00135234]], dtype=float32),
#  array([[  9.99697089e-01,   3.02904344e-04]], dtype=float32),
#  array([[ 0.85337311,  0.14662695]], dtype=float32),
#  array([[ 0.96832776,  0.03167218]], dtype=float32),
#  array([[ 0.9967795 ,  0.00322051]], dtype=float32),
#  array([[ 0.98809332,  0.01190672]], dtype=float32),
#  array([[ 0.91968685,  0.08031315]], dtype=float32),
#  array([[ 0.94823474,  0.05176529]], dtype=float32),
#  array([[ 0.96996337,  0.03003656]], dtype=float32),
#  array([[ 0.99876851,  0.00123142]], dtype=float32),
#  array([[ 0.99622428,  0.00377574]], dtype=float32),
#  array([[ 0.77013743,  0.22986259]], dtype=float32),
#  array([[ 0.96930236,  0.03069769]], dtype=float32),
#  array([[ 0.81335431,  0.18664572]], dtype=float32),
#  array([[ 0.97881269,  0.02118732]], dtype=float32),
#  array([[ 0.84785092,  0.15214908]], dtype=float32),
#  array([[ 0.95128286,  0.04871722]], dtype=float32),
#  array([[ 0.9674229 ,  0.03257709]], dtype=float32),
#  array([[ 0.96003544,  0.03996464]], dtype=float32),
#  array([[  9.99961019e-01,   3.89569941e-05]], dtype=float32),
#  array([[  9.99451101e-01,   5.48869313e-04]], dtype=float32),
#  array([[ 0.99547309,  0.00452693]], dtype=float32),
#  array([[ 0.89758492,  0.10241511]], dtype=float32),
#  array([[ 0.98340857,  0.01659136]], dtype=float32),
#  array([[ 0.80601239,  0.19398762]], dtype=float32),
#  array([[ 0.9652462 ,  0.03475387]], dtype=float32),
#  array([[ 0.98852032,  0.01147967]], dtype=float32),
#  array([[ 0.95201558,  0.04798444]], dtype=float32),
#  array([[ 0.89635384,  0.10364618]], dtype=float32),
#  array([[ 0.98573744,  0.01426259]], dtype=float32),
#  array([[ 0.97332382,  0.02667619]], dtype=float32),
#  array([[ 0.91286188,  0.08713817]], dtype=float32),
#  array([[ 0.60664964,  0.39335033]], dtype=float32),
#  array([[ 0.94493973,  0.0550603 ]], dtype=float32),
#  array([[ 0.98331958,  0.01668037]], dtype=float32),
#  array([[ 0.78234738,  0.2176526 ]], dtype=float32),
#  array([[  9.99753296e-01,   2.46700714e-04]], dtype=float32),
#  array([[ 0.98422563,  0.01577445]], dtype=float32),
#  array([[ 0.93212557,  0.0678745 ]], dtype=float32),
#  array([[ 0.9953655 ,  0.00463454]], dtype=float32),
#  array([[ 0.94832498,  0.05167497]], dtype=float32),
#  array([[ 0.98072249,  0.01927748]], dtype=float32),
#  array([[ 0.99828231,  0.00171774]], dtype=float32),
#  array([[  9.99079347e-01,   9.20588907e-04]], dtype=float32),
#  array([[ 0.87697357,  0.12302642]], dtype=float32),
#  array([[ 0.79851007,  0.20148993]], dtype=float32),
#  array([[ 0.95342958,  0.04657046]], dtype=float32),
#  array([[ 0.96992493,  0.0300751 ]], dtype=float32),
#  array([[ 0.98023742,  0.01976261]], dtype=float32),
#  array([[ 0.99159747,  0.00840254]], dtype=float32),
#  array([[ 0.81604213,  0.18395782]], dtype=float32),
#  array([[ 0.96211761,  0.0378824 ]], dtype=float32),
#  array([[ 0.99785763,  0.00214239]], dtype=float32),
#  array([[ 0.99689144,  0.00310855]], dtype=float32),
#  array([[ 0.99197245,  0.00802755]], dtype=float32),
#  array([[ 0.88743603,  0.11256393]], dtype=float32),
#  array([[ 0.97301865,  0.02698128]], dtype=float32)]

# %%
cc = []
for i in file_list_true[0:200]:
    a=np.load(i)
    a=np.expand_dims(a,0)
    a=np.expand_dims(a,0)
    cc.append(model_pred.predict(a))
count = 0

# %%
for i in cc:
    if i[0][1] > 0.9:
        count += 1
print count*1.0/len(cc)
# Out:
# 0.615

# %%
cc
# Out:
# [array([[ 0.03677514,  0.96322489]], dtype=float32),
#  array([[ 0.04349786,  0.95650214]], dtype=float32),
#  array([[ 0.00561136,  0.99438864]], dtype=float32),
#  array([[ 0.00795874,  0.99204129]], dtype=float32),
#  array([[ 0.00912778,  0.9908722 ]], dtype=float32),
#  array([[ 0.04031985,  0.95968014]], dtype=float32),
#  array([[  3.67325236e-04,   9.99632716e-01]], dtype=float32),
#  array([[  2.75671249e-04,   9.99724329e-01]], dtype=float32),
#  array([[ 0.05638614,  0.94361383]], dtype=float32),
#  array([[ 0.02625839,  0.97374165]], dtype=float32),
#  array([[ 0.05433248,  0.94566751]], dtype=float32),
#  array([[ 0.0529393,  0.9470607]], dtype=float32),
#  array([[ 0.0831045 ,  0.91689551]], dtype=float32),
#  array([[ 0.06986483,  0.93013513]], dtype=float32),
#  array([[ 0.07091639,  0.92908365]], dtype=float32),
#  array([[ 0.10969967,  0.89030033]], dtype=float32),
#  array([[ 0.15578376,  0.84421623]], dtype=float32),
#  array([[ 0.19935074,  0.80064923]], dtype=float32),
#  array([[ 0.12125502,  0.8787449 ]], dtype=float32),
#  array([[ 0.02557297,  0.97442698]], dtype=float32),
#  array([[ 0.38485086,  0.61514914]], dtype=float32),
#  array([[ 0.01166286,  0.9883371 ]], dtype=float32),
#  array([[ 0.01014932,  0.98985064]], dtype=float32),
#  array([[ 0.10749619,  0.89250374]], dtype=float32),
#  array([[ 0.1634593 ,  0.83654064]], dtype=float32),
#  array([[ 0.14040805,  0.8595919 ]], dtype=float32),
#  array([[ 0.02520419,  0.97479576]], dtype=float32),
#  array([[ 0.35894012,  0.64105988]], dtype=float32),
#  array([[ 0.19346449,  0.80653548]], dtype=float32),
#  array([[ 0.03318607,  0.96681386]], dtype=float32),
#  array([[ 0.0330516 ,  0.96694839]], dtype=float32),
#  array([[ 0.17585976,  0.82414025]], dtype=float32),
#  array([[ 0.420376,  0.579624]], dtype=float32),
#  array([[ 0.01485571,  0.98514426]], dtype=float32),
#  array([[ 0.03010413,  0.96989584]], dtype=float32),
#  array([[ 0.3057501 ,  0.69424993]], dtype=float32),
#  array([[ 0.00576394,  0.99423605]], dtype=float32),
#  array([[ 0.00222236,  0.99777764]], dtype=float32),
#  array([[ 0.00310762,  0.99689239]], dtype=float32),
#  array([[ 0.00310399,  0.99689603]], dtype=float32),
#  array([[ 0.69746768,  0.30253226]], dtype=float32),
#  array([[ 0.00147812,  0.99852186]], dtype=float32),
#  array([[ 0.00191243,  0.99808758]], dtype=float32),
#  array([[ 0.98649198,  0.01350801]], dtype=float32),
#  array([[ 0.00502583,  0.99497414]], dtype=float32),
#  array([[ 0.17618127,  0.82381868]], dtype=float32),
#  array([[ 0.17204973,  0.82795024]], dtype=float32),
#  array([[ 0.22353907,  0.77646089]], dtype=float32),
#  array([[ 0.07280433,  0.92719567]], dtype=float32),
#  array([[ 0.29952601,  0.70047396]], dtype=float32),
#  array([[ 0.24425493,  0.75574499]], dtype=float32),
#  array([[ 0.0486281 ,  0.95137197]], dtype=float32),
#  array([[ 0.07358097,  0.92641908]], dtype=float32),
#  array([[ 0.25689164,  0.74310833]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02397819,  0.97602183]], dtype=float32),
#  array([[ 0.02253742,  0.97746253]], dtype=float32),
#  array([[ 0.05109744,  0.94890255]], dtype=float32),
#  array([[ 0.07383195,  0.92616808]], dtype=float32),
#  array([[ 0.05880393,  0.94119608]], dtype=float32),
#  array([[ 0.1118079 ,  0.88819206]], dtype=float32),
#  array([[ 0.05257856,  0.94742149]], dtype=float32),
#  array([[ 0.04737711,  0.95262295]], dtype=float32),
#  array([[ 0.03884789,  0.96115214]], dtype=float32),
#  array([[ 0.17419432,  0.82580572]], dtype=float32),
#  array([[ 0.0792074 ,  0.92079258]], dtype=float32),
#  array([[ 0.77615225,  0.22384772]], dtype=float32),
#  array([[ 0.13698401,  0.86301601]], dtype=float32),
#  array([[ 0.10694581,  0.89305419]], dtype=float32),
#  array([[ 0.16471349,  0.8352865 ]], dtype=float32),
#  array([[ 0.15772547,  0.84227455]], dtype=float32),
#  array([[ 0.12540877,  0.87459117]], dtype=float32),
#  array([[ 0.05691376,  0.94308627]], dtype=float32),
#  array([[ 0.72571462,  0.27428538]], dtype=float32),
#  array([[ 0.05187133,  0.94812864]], dtype=float32),
#  array([[ 0.17447726,  0.82552272]], dtype=float32),
#  array([[ 0.07556085,  0.92443919]], dtype=float32),
#  array([[ 0.16393545,  0.83606452]], dtype=float32),
#  array([[ 0.41289932,  0.58710068]], dtype=float32),
#  array([[ 0.14424977,  0.8557502 ]], dtype=float32),
#  array([[ 0.12179485,  0.87820506]], dtype=float32),
#  array([[ 0.09409323,  0.9059068 ]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.02552155,  0.97447848]], dtype=float32),
#  array([[ 0.60173774,  0.39826223]], dtype=float32),
#  array([[ 0.21281394,  0.78718603]], dtype=float32),
#  array([[ 0.01861631,  0.98138374]], dtype=float32),
#  array([[ 0.0375523 ,  0.96244776]], dtype=float32),
#  array([[ 0.04434183,  0.9556582 ]], dtype=float32),
#  array([[ 0.12248318,  0.87751681]], dtype=float32),
#  array([[ 0.0375523 ,  0.96244776]], dtype=float32),
#  array([[ 0.04434183,  0.9556582 ]], dtype=float32),
#  array([[ 0.12248318,  0.87751681]], dtype=float32),
#  array([[ 0.00350035,  0.99649966]], dtype=float32),
#  array([[ 0.00684395,  0.99315602]], dtype=float32),
#  array([[ 0.00228442,  0.99771559]], dtype=float32),
#  array([[ 0.02218932,  0.97781074]], dtype=float32),
#  array([[ 0.0092664 ,  0.99073362]], dtype=float32),
#  array([[ 0.03095611,  0.96904391]], dtype=float32),
#  array([[ 0.10022853,  0.89977145]], dtype=float32),
#  array([[ 0.00872233,  0.99127769]], dtype=float32),
#  array([[ 0.02853495,  0.97146499]], dtype=float32),
#  array([[ 0.01647947,  0.98352057]], dtype=float32),
#  array([[ 0.01255446,  0.98744559]], dtype=float32),
#  array([[  3.38095415e-04,   9.99661922e-01]], dtype=float32),
#  array([[ 0.01451718,  0.98548281]], dtype=float32),
#  array([[ 0.05871931,  0.94128072]], dtype=float32),
#  array([[  1.85719866e-04,   9.99814332e-01]], dtype=float32),
#  array([[ 0.00621008,  0.99378997]], dtype=float32),
#  array([[ 0.00615273,  0.99384731]], dtype=float32),
#  array([[  1.72142609e-04,   9.99827862e-01]], dtype=float32),
#  array([[ 0.12397432,  0.87602568]], dtype=float32),
#  array([[ 0.09625598,  0.90374404]], dtype=float32),
#  array([[ 0.16070741,  0.83929265]], dtype=float32),
#  array([[ 0.06457814,  0.93542188]], dtype=float32),
#  array([[ 0.01815351,  0.98184651]], dtype=float32),
#  array([[ 0.16215053,  0.8378495 ]], dtype=float32),
#  array([[ 0.0413874 ,  0.95861262]], dtype=float32),
#  array([[ 0.00844167,  0.99155831]], dtype=float32),
#  array([[ 0.1065999 ,  0.89340013]], dtype=float32),
#  array([[ 0.50726509,  0.49273488]], dtype=float32),
#  array([[ 0.02395152,  0.97604853]], dtype=float32),
#  array([[ 0.06809023,  0.93190974]], dtype=float32),
#  array([[ 0.11451028,  0.8854897 ]], dtype=float32),
#  array([[ 0.18160786,  0.81839216]], dtype=float32),
#  array([[ 0.6657725 ,  0.33422747]], dtype=float32),
#  array([[ 0.2047808 ,  0.79521918]], dtype=float32),
#  array([[ 0.0343085 ,  0.96569157]], dtype=float32),
#  array([[ 0.23000842,  0.76999152]], dtype=float32),
#  array([[ 0.46270472,  0.53729534]], dtype=float32),
#  array([[ 0.49260652,  0.50739348]], dtype=float32),
#  array([[ 0.90968221,  0.09031782]], dtype=float32),
#  array([[ 0.42004716,  0.57995284]], dtype=float32),
#  array([[ 0.19530942,  0.8046906 ]], dtype=float32),
#  array([[ 0.01134527,  0.98865473]], dtype=float32),
#  array([[ 0.12907383,  0.8709262 ]], dtype=float32),
#  array([[ 0.34162986,  0.6583702 ]], dtype=float32),
#  array([[ 0.56057131,  0.43942866]], dtype=float32),
#  array([[ 0.07430519,  0.92569476]], dtype=float32),
#  array([[ 0.176587  ,  0.82341301]], dtype=float32),
#  array([[ 0.01512071,  0.98487931]], dtype=float32),
#  array([[ 0.06033353,  0.93966645]], dtype=float32),
#  array([[ 0.07647034,  0.92352962]], dtype=float32),
#  array([[ 0.02767509,  0.97232497]], dtype=float32),
#  array([[ 0.20238592,  0.7976141 ]], dtype=float32),
#  array([[ 0.05296591,  0.94703406]], dtype=float32),
#  array([[ 0.0638364,  0.9361636]], dtype=float32),
#  array([[  1.73724591e-04,   9.99826252e-01]], dtype=float32),
#  array([[ 0.00730555,  0.9926945 ]], dtype=float32),
#  array([[  8.63562571e-04,   9.99136508e-01]], dtype=float32),
#  array([[  3.37434358e-05,   9.99966264e-01]], dtype=float32),
#  array([[  1.11367379e-04,   9.99888659e-01]], dtype=float32),
#  array([[  5.25603711e-04,   9.99474466e-01]], dtype=float32),
#  array([[  1.71741704e-05,   9.99982834e-01]], dtype=float32),
#  array([[  1.78569026e-04,   9.99821484e-01]], dtype=float32),
#  array([[  3.81859718e-04,   9.99618173e-01]], dtype=float32),
#  array([[ 0.49405497,  0.50594497]], dtype=float32),
#  array([[ 0.56162608,  0.43837389]], dtype=float32),
#  array([[ 0.17756841,  0.82243156]], dtype=float32),
#  array([[ 0.5080803 ,  0.49191964]], dtype=float32),
#  array([[ 0.52754819,  0.47245187]], dtype=float32),
#  array([[ 0.23124821,  0.7687518 ]], dtype=float32),
#  array([[ 0.10833678,  0.89166325]], dtype=float32),
#  array([[ 0.23965724,  0.76034278]], dtype=float32),
#  array([[ 0.09206022,  0.90793979]], dtype=float32),
#  array([[ 0.34308729,  0.65691274]], dtype=float32),
#  array([[ 0.40491763,  0.59508234]], dtype=float32),
#  array([[ 0.05728604,  0.94271392]], dtype=float32),
#  array([[ 0.02133087,  0.97866917]], dtype=float32),
#  array([[ 0.02028527,  0.97971481]], dtype=float32),
#  array([[ 0.32476836,  0.67523164]], dtype=float32),
#  array([[ 0.03419631,  0.96580374]], dtype=float32),
#  array([[ 0.02032449,  0.97967553]], dtype=float32),
#  array([[ 0.02064604,  0.9793539 ]], dtype=float32),
#  array([[ 0.30927369,  0.69072628]], dtype=float32),
#  array([[ 0.12834343,  0.87165654]], dtype=float32),
#  array([[ 0.30899683,  0.6910032 ]], dtype=float32),
#  array([[ 0.09372945,  0.90627056]], dtype=float32),
#  array([[ 0.08571482,  0.91428524]], dtype=float32),
#  array([[ 0.2540772 ,  0.74592286]], dtype=float32),
#  array([[ 0.02905937,  0.97094065]], dtype=float32),
#  array([[ 0.03247234,  0.96752769]], dtype=float32),
#  array([[ 0.01146321,  0.98853672]], dtype=float32),
#  array([[ 0.24766004,  0.7523399 ]], dtype=float32),
#  array([[ 0.16445781,  0.8355422 ]], dtype=float32)]
