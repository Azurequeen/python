# %%
from utils.imports import *
# Out:
# Using TensorFlow backend.

# %%
def get_net(input_shape, load_weight_path=None, features=False, mal=False):
    width = 64
    inputs = Input(shape=(1, 32, 32, 32), name="input_1")
    x = inputs
    x = AveragePooling3D(pool_size=(2, 1, 1), strides=(2, 1, 1), border_mode="same")(x)
    #x = BatchNormalization(axis = 1)(x)
    x = Convolution3D(width, 3, 3, 3, activation='relu', border_mode='same', name='conv1', subsample=(1, 1, 1))(x)
    x = MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2), border_mode='valid', name='pool1')(x)

    # 2nd layer group
    #x = BatchNormalization(axis = 1)(x)
    x = Convolution3D(width*2, 3, 3, 3, activation='relu', border_mode='same', name='conv2', subsample=(1, 1, 1))(x)
    x = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), border_mode='valid', name='pool2')(x)
    x = Dropout(p=0.3)(x)

    # 3rd layer group
    #x = BatchNormalization(axis = 1)(x)
    x = Convolution3D(width*4, 3, 3, 3, activation='relu', border_mode='same', name='conv3a', subsample=(1, 1, 1))(x)
    #x = BatchNormalization(axis = 1)(x)
    x = Convolution3D(width*4, 3, 3, 3, activation='relu', border_mode='same', name='conv3b', subsample=(1, 1, 1))(x)
    x = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), border_mode='valid', name='pool3')(x)
    x = Dropout(p=0.4)(x)

    # 4th layer group
    #x = BatchNormalization(axis = 1)(x)
    x = Convolution3D(width*8, 3, 3, 3, activation='relu', border_mode='same', name='conv4a', subsample=(1, 1, 1))(x)
    #x = BatchNormalization(axis = 1)(x)
    x = Convolution3D(width*8, 3, 3, 3, activation='relu', border_mode='same', name='conv4b', subsample=(1, 1, 1),)(x)
    x = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), border_mode='valid', name='pool4')(x)
    x = Dropout(p=0.5)(x)
       
    last64 = Convolution3D(64, 2, 2, 2, activation="relu", name="last_64")(x)
    out_class = Convolution3D(1, 1, 1, 1, activation="softmax", name="out_class_last")(last64)
    out_class = Flatten(name="out_class")(x)
    
    out_class = Dense(2)(out_class) 
    #out_class = BatchNormalization(axis = 1)(out_class)
    out_class = Activation('softmax')(out_class)
    
    model = Model(input=inputs, output=out_class)
    model.compile(optimizer=SGD(lr=1e-3, momentum=0.9, nesterov=True), loss='categorical_crossentropy', metrics=['accuracy'])
    #model.compile(optimizer=Adam(lr=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])   
    return model

# %%
output_path = PATH['cls_train_cube_30']
output_true = PATH['cls_train_cube_30_true']
output_false = PATH['cls_train_cube_30_false']
model_paths = PATH['model_paths']
model_final = PATH['model_final']

# %%
def get_dirfiles(dir):
    file_list = []
    subset_path = os.listdir(dir)
    for _ in range(len(subset_path)):
        if subset_path[_] != '.DS_Store':
            file_list.append(dir + subset_path[_])
    return file_list

def train_generator(output_true,output_false):
    train_nb = 80000    
    file_list_true = get_dirfiles(output_true)
    file_list_false = get_dirfiles(output_false)        
    file_list_true = np.random.choice(file_list_true, train_nb)
    file_list_false = np.random.choice(file_list_false, train_nb)    
    nb_true = len(file_list_true) + len(file_list_false)    
    sample = np.zeros([nb_true,32, 32, 32])
    labels = np.zeros([nb_true,2])
    for i in tqdm(range(len(file_list_true))):       
        cc= np.load(file_list_true[i])
        sample[i] = cc
        labels[i] = [0.,1.]
    for j in tqdm(range(len(file_list_false))):
        bb= np.load(file_list_false[j])
        sample[j+len(file_list_true)] = bb 
        labels[j+len(file_list_true)] = [1.,0.]
    sample = np.expand_dims(sample, axis=1)        
    return sample,labels


def fenlei_fit(name, load_check = False,batch_size=2, epochs=20,check_name = None):
    t = time.time()
    callbacks = [EarlyStopping(monitor='val_loss', patience = 10, verbose = 1),
                 ModelCheckpoint((model_paths + '{}.h5').format(name),
                                 monitor='val_loss',
                                 verbose = 0,
                                 save_best_only = True)]
    if load_check:
        check_model = (model_paths + '{}.h5').format(check_name)
        model = load_model(check_model)
    else:
        #model = classifier((1, 32, 32, 32),128,(3, 3, 3), (2, 2, 2))
        model = get_net((1, 32, 32, 32))
    x,y = train_generator(output_true,output_false)
    model.fit(x,y, batch_size=batch_size, epochs=epochs,
              validation_split=0.2,verbose=1, callbacks=callbacks, shuffle=True) 
    return model

# %%
fenlei_fit('Fenge_32_32_32_0704', load_check = False, batch_size=8, epochs=200, check_name = 'Fenge_32_32_32_0703')
# Out:
# 100%|██████████| 80000/80000 [38:41<00:00, 34.46it/s]
# 100%|██████████| 80000/80000 [52:25<00:00, 25.43it/s]
# Train on 128000 samples, validate on 32000 samples
# Epoch 1/200
# 128000/128000 [==============================] - 5075s - loss: 0.4070 - acc: 0.7976 - val_loss: 0.1196 - val_acc: 0.9739
# Epoch 2/200
# 128000/128000 [==============================] - 4361s - loss: 0.1541 - acc: 0.9403 - val_loss: 0.1496 - val_acc: 0.9633
# Epoch 3/200
# 128000/128000 [==============================] - 4201s - loss: 0.0965 - acc: 0.9650 - val_loss: 0.0638 - val_acc: 0.9838
# Epoch 4/200
# 128000/128000 [==============================] - 4202s - loss: 0.0678 - acc: 0.9767 - val_loss: 0.1100 - val_acc: 0.9663
# Epoch 5/200
# 128000/128000 [==============================] - 4564s - loss: 0.0509 - acc: 0.9834 - val_loss: 0.0864 - val_acc: 0.9750
# Epoch 6/200
# 128000/128000 [==============================] - 4727s - loss: 0.0407 - acc: 0.9868 - val_loss: 0.0686 - val_acc: 0.9808
# Epoch 7/200
# 128000/128000 [==============================] - 4751s - loss: 0.0325 - acc: 0.9892 - val_loss: 0.0614 - val_acc: 0.9848
# Epoch 8/200
# 128000/128000 [==============================] - 5044s - loss: 0.0283 - acc: 0.9909 - val_loss: 0.0540 - val_acc: 0.9870
# Epoch 9/200
#    552/128000 [..............................] - ETA: 4429s - loss: 0.0347 - acc: 0.9873
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6902e37ed330> in <module>()
# ----> 1 fenlei_fit('Fenge_32_32_32_0704', load_check = False, batch_size=8, epochs=200, check_name = 'Fenge_32_32_32_0703')
#
# <ipython-input-4-f59d2a43bdc4> in fenlei_fit(name, load_check, batch_size, epochs, check_name)
#      43     x,y = train_generator(output_true,output_false)
#      44     model.fit(x,y, batch_size=batch_size, epochs=epochs,
# ---> 45               validation_split=0.2,verbose=1, callbacks=callbacks, shuffle=True)
#      46     return model
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1496                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1497                               callback_metrics=callback_metrics,
# -> 1498                               initial_epoch=initial_epoch)
#    1499
#    1500     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1139                     if isinstance(ins[-1], float):
#    1140                         # Do not slice the training phase flag.
# -> 1141                         ins_batch = _slice_arrays(ins[:-1], batch_ids) + [ins[-1]]
#    1142                     else:
#    1143                         ins_batch = _slice_arrays(ins, batch_ids)
#
# /Users/mahui/anaconda/lib/python2.7/site-packages/keras/engine/training.pyc in _slice_arrays(arrays, start, stop)
#     392             if hasattr(start, 'shape'):
#     393                 start = start.tolist()
# --> 394             return [x[start] for x in arrays]
#     395         else:
#     396             return [x[start:stop] for x in arrays]
#
# KeyboardInterrupt:

# %%
file_list_true = get_dirfiles(output_true)
file_list_false = get_dirfiles(output_false)

# %%
#model_pred = classifier((1, 36, 36, 36), (3, 3, 3), (2, 2, 2))
model_pred = load_model(model_paths + 'Fenge_32_32_32_0704.h5')

# %%
file_list_true = np.random.choice(file_list_true, 1000)
file_list_false = np.random.choice(file_list_false, 1000)

# %%
cc = []
for i in file_list_false[0:200]:
    a=np.load(i)
    a=np.expand_dims(a,0)
    a=np.expand_dims(a,0)
    cc.append(model_pred.predict(a))
count = 0
for i in cc:
    if i[0][0] > 0.9:
        count += 1
print count*1.0/len(cc)
# Out:
# 0.985

# %%
cc
# Out:
# [array([[ 0.99856502,  0.00143498]], dtype=float32),
#  array([[  9.99913096e-01,   8.68837160e-05]], dtype=float32),
#  array([[  9.99999046e-01,   9.01942144e-07]], dtype=float32),
#  array([[  9.99866843e-01,   1.33110327e-04]], dtype=float32),
#  array([[  1.00000000e+00,   4.39493508e-09]], dtype=float32),
#  array([[  1.00000000e+00,   6.12293460e-09]], dtype=float32),
#  array([[  9.99992490e-01,   7.51696325e-06]], dtype=float32),
#  array([[  9.99983191e-01,   1.68623101e-05]], dtype=float32),
#  array([[  9.99999523e-01,   5.32074580e-07]], dtype=float32),
#  array([[  9.99999523e-01,   5.28867190e-07]], dtype=float32),
#  array([[  9.99987364e-01,   1.25941360e-05]], dtype=float32),
#  array([[  9.99538660e-01,   4.61411226e-04]], dtype=float32),
#  array([[  9.99995112e-01,   4.87023863e-06]], dtype=float32),
#  array([[  9.99997735e-01,   2.30652131e-06]], dtype=float32),
#  array([[  9.99929070e-01,   7.09825763e-05]], dtype=float32),
#  array([[  9.99999762e-01,   2.92571741e-07]], dtype=float32),
#  array([[  9.99999046e-01,   9.28928841e-07]], dtype=float32),
#  array([[  9.99957204e-01,   4.28228705e-05]], dtype=float32),
#  array([[  9.99992013e-01,   8.04124193e-06]], dtype=float32),
#  array([[  9.99636054e-01,   3.63921892e-04]], dtype=float32),
#  array([[  9.99999046e-01,   9.69909820e-07]], dtype=float32),
#  array([[  1.00000000e+00,   1.54962780e-08]], dtype=float32),
#  array([[  9.99985695e-01,   1.42765957e-05]], dtype=float32),
#  array([[  9.99636173e-01,   3.63802566e-04]], dtype=float32),
#  array([[  9.99998569e-01,   1.47714786e-06]], dtype=float32),
#  array([[  1.00000000e+00,   1.84244442e-08]], dtype=float32),
#  array([[  9.99973059e-01,   2.69636948e-05]], dtype=float32),
#  array([[  1.00000000e+00,   5.08715958e-09]], dtype=float32),
#  array([[  9.99999523e-01,   5.23096674e-07]], dtype=float32),
#  array([[  1.00000000e+00,   5.68484371e-09]], dtype=float32),
#  array([[  9.99999762e-01,   2.59882654e-07]], dtype=float32),
#  array([[  9.99744594e-01,   2.55448598e-04]], dtype=float32),
#  array([[  9.99972105e-01,   2.79268206e-05]], dtype=float32),
#  array([[  9.99463141e-01,   5.36881213e-04]], dtype=float32),
#  array([[ 0.03901123,  0.9609887 ]], dtype=float32),
#  array([[  9.99998927e-01,   1.06075572e-06]], dtype=float32),
#  array([[  9.99914765e-01,   8.51927325e-05]], dtype=float32),
#  array([[  1.00000000e+00,   3.15762492e-08]], dtype=float32),
#  array([[  9.99956012e-01,   4.39327159e-05]], dtype=float32),
#  array([[  9.99996305e-01,   3.70703742e-06]], dtype=float32),
#  array([[  9.99999881e-01,   1.66296203e-07]], dtype=float32),
#  array([[  9.99996781e-01,   3.21387097e-06]], dtype=float32),
#  array([[  9.99912262e-01,   8.77644052e-05]], dtype=float32),
#  array([[  9.99997139e-01,   2.85900046e-06]], dtype=float32),
#  array([[  9.99629259e-01,   3.70682188e-04]], dtype=float32),
#  array([[  9.99999166e-01,   7.96289157e-07]], dtype=float32),
#  array([[  9.99999642e-01,   3.39766757e-07]], dtype=float32),
#  array([[  9.99996781e-01,   3.17522881e-06]], dtype=float32),
#  array([[  9.99956846e-01,   4.30939835e-05]], dtype=float32),
#  array([[  9.99996066e-01,   3.91356662e-06]], dtype=float32),
#  array([[  1.00000000e+00,   5.07971585e-08]], dtype=float32),
#  array([[  9.99999642e-01,   3.14252929e-07]], dtype=float32),
#  array([[  9.99979019e-01,   2.10002327e-05]], dtype=float32),
#  array([[  9.99996305e-01,   3.72504019e-06]], dtype=float32),
#  array([[  9.99865413e-01,   1.34614602e-04]], dtype=float32),
#  array([[  9.99907017e-01,   9.29743037e-05]], dtype=float32),
#  array([[  9.99998808e-01,   1.14938325e-06]], dtype=float32),
#  array([[  9.99973774e-01,   2.62550348e-05]], dtype=float32),
#  array([[  9.99999881e-01,   1.35346724e-07]], dtype=float32),
#  array([[ 0.99124473,  0.00875524]], dtype=float32),
#  array([[  1.00000000e+00,   1.66432894e-08]], dtype=float32),
#  array([[ 0.99819142,  0.00180864]], dtype=float32),
#  array([[  9.99998927e-01,   1.12877979e-06]], dtype=float32),
#  array([[  9.99999046e-01,   9.39927190e-07]], dtype=float32),
#  array([[  9.99999642e-01,   3.12338614e-07]], dtype=float32),
#  array([[  9.99999881e-01,   8.23290307e-08]], dtype=float32),
#  array([[  9.99744952e-01,   2.55097868e-04]], dtype=float32),
#  array([[  9.99997616e-01,   2.37560403e-06]], dtype=float32),
#  array([[  9.99998927e-01,   1.05518109e-06]], dtype=float32),
#  array([[  9.99999762e-01,   2.66509801e-07]], dtype=float32),
#  array([[  9.99999881e-01,   1.39714089e-07]], dtype=float32),
#  array([[  9.99965191e-01,   3.48479807e-05]], dtype=float32),
#  array([[  9.99999881e-01,   6.23035348e-08]], dtype=float32),
#  array([[  9.99990225e-01,   9.71658119e-06]], dtype=float32),
#  array([[  9.99999285e-01,   7.31303146e-07]], dtype=float32),
#  array([[  9.99999046e-01,   1.00418754e-06]], dtype=float32),
#  array([[  9.99999166e-01,   8.88495038e-07]], dtype=float32),
#  array([[  9.99997258e-01,   2.75955631e-06]], dtype=float32),
#  array([[  9.99977827e-01,   2.21418995e-05]], dtype=float32),
#  array([[  9.99977589e-01,   2.24270316e-05]], dtype=float32),
#  array([[  9.99999762e-01,   2.82999139e-07]], dtype=float32),
#  array([[  9.99985933e-01,   1.40390121e-05]], dtype=float32),
#  array([[  1.00000000e+00,   3.35514239e-09]], dtype=float32),
#  array([[  9.99955773e-01,   4.42307210e-05]], dtype=float32),
#  array([[  1.00000000e+00,   1.38424259e-08]], dtype=float32),
#  array([[  9.99623179e-01,   3.76777374e-04]], dtype=float32),
#  array([[  9.99999881e-01,   8.18624102e-08]], dtype=float32),
#  array([[  9.99996543e-01,   3.45663148e-06]], dtype=float32),
#  array([[  9.99977112e-01,   2.28830104e-05]], dtype=float32),
#  array([[  1.00000000e+00,   1.65897269e-08]], dtype=float32),
#  array([[  9.99999762e-01,   2.97916870e-07]], dtype=float32),
#  array([[  9.99998331e-01,   1.69576572e-06]], dtype=float32),
#  array([[  9.99986291e-01,   1.37326751e-05]], dtype=float32),
#  array([[ 0.99899858,  0.00100143]], dtype=float32),
#  array([[  9.99937654e-01,   6.23115775e-05]], dtype=float32),
#  array([[  9.99999881e-01,   8.39909475e-08]], dtype=float32),
#  array([[  9.99998212e-01,   1.73683225e-06]], dtype=float32),
#  array([[  9.99998569e-01,   1.38388305e-06]], dtype=float32),
#  array([[  1.00000000e+00,   2.32230096e-10]], dtype=float32),
#  array([[  9.99999523e-01,   4.45714107e-07]], dtype=float32),
#  array([[  9.99999881e-01,   1.27414978e-07]], dtype=float32),
#  array([[  9.99585688e-01,   4.14304843e-04]], dtype=float32),
#  array([[  9.99624372e-01,   3.75643751e-04]], dtype=float32),
#  array([[  9.99863625e-01,   1.36308998e-04]], dtype=float32),
#  array([[  9.99906301e-01,   9.36451979e-05]], dtype=float32),
#  array([[  9.99965191e-01,   3.47543864e-05]], dtype=float32),
#  array([[ 0.99308783,  0.00691216]], dtype=float32),
#  array([[  9.99996662e-01,   3.32248010e-06]], dtype=float32),
#  array([[  9.99997616e-01,   2.37932704e-06]], dtype=float32),
#  array([[  9.99997973e-01,   2.07956600e-06]], dtype=float32),
#  array([[  1.00000000e+00,   4.22526192e-09]], dtype=float32),
#  array([[  9.99987841e-01,   1.22014699e-05]], dtype=float32),
#  array([[  9.99982595e-01,   1.74176712e-05]], dtype=float32),
#  array([[  9.99999046e-01,   9.88136435e-07]], dtype=float32),
#  array([[  9.99999881e-01,   1.53180551e-07]], dtype=float32),
#  array([[  9.99999642e-01,   3.11152405e-07]], dtype=float32),
#  array([[  9.99991894e-01,   8.14310806e-06]], dtype=float32),
#  array([[  9.99742568e-01,   2.57467298e-04]], dtype=float32),
#  array([[  9.99999881e-01,   1.75369308e-07]], dtype=float32),
#  array([[  9.99986291e-01,   1.37138295e-05]], dtype=float32),
#  array([[ 0.99438816,  0.00561183]], dtype=float32),
#  array([[  9.99808609e-01,   1.91401559e-04]], dtype=float32),
#  array([[  9.99999762e-01,   2.83147614e-07]], dtype=float32),
#  array([[  9.99952674e-01,   4.73063628e-05]], dtype=float32),
#  array([[  9.99999762e-01,   2.85338729e-07]], dtype=float32),
#  array([[  9.99998927e-01,   1.05448703e-06]], dtype=float32),
#  array([[  9.99999881e-01,   1.64241598e-07]], dtype=float32),
#  array([[  9.99938011e-01,   6.19791754e-05]], dtype=float32),
#  array([[  9.99947548e-01,   5.25047653e-05]], dtype=float32),
#  array([[  9.99429882e-01,   5.70072734e-04]], dtype=float32),
#  array([[  9.99988079e-01,   1.19631577e-05]], dtype=float32),
#  array([[  9.99998927e-01,   1.04323317e-06]], dtype=float32),
#  array([[  9.99911666e-01,   8.83284374e-05]], dtype=float32),
#  array([[ 0.72856808,  0.27143198]], dtype=float32),
#  array([[  9.99800980e-01,   1.99068076e-04]], dtype=float32),
#  array([[  9.99983430e-01,   1.65400488e-05]], dtype=float32),
#  array([[  1.00000000e+00,   2.51720289e-09]], dtype=float32),
#  array([[  9.99999642e-01,   4.14975744e-07]], dtype=float32),
#  array([[  9.99976993e-01,   2.29994876e-05]], dtype=float32),
#  array([[  9.99410033e-01,   5.89926611e-04]], dtype=float32),
#  array([[  9.99999881e-01,   6.98172542e-08]], dtype=float32),
#  array([[  9.99959469e-01,   4.05429673e-05]], dtype=float32),
#  array([[  9.99959350e-01,   4.06002255e-05]], dtype=float32),
#  array([[  9.99630094e-01,   3.69863264e-04]], dtype=float32),
#  array([[  9.99993205e-01,   6.82995278e-06]], dtype=float32),
#  array([[  9.99892831e-01,   1.07174455e-04]], dtype=float32),
#  array([[  9.99998808e-01,   1.14778834e-06]], dtype=float32),
#  array([[  9.99999404e-01,   6.27897919e-07]], dtype=float32),
#  array([[  9.99999166e-01,   7.94956804e-07]], dtype=float32),
#  array([[  9.99998927e-01,   1.08445465e-06]], dtype=float32),
#  array([[  9.99998450e-01,   1.58543139e-06]], dtype=float32),
#  array([[  9.99999762e-01,   2.00755679e-07]], dtype=float32),
#  array([[  9.99999881e-01,   1.42873404e-07]], dtype=float32),
#  array([[  9.99999046e-01,   9.53309609e-07]], dtype=float32),
#  array([[  9.99996901e-01,   3.14705380e-06]], dtype=float32),
#  array([[  9.99999404e-01,   6.30313366e-07]], dtype=float32),
#  array([[  9.99999285e-01,   7.25121652e-07]], dtype=float32),
#  array([[  1.00000000e+00,   1.14396279e-08]], dtype=float32),
#  array([[  9.99999881e-01,   1.16783490e-07]], dtype=float32),
#  array([[  9.99995351e-01,   4.61803847e-06]], dtype=float32),
#  array([[  9.99999762e-01,   1.96466658e-07]], dtype=float32),
#  array([[  9.99997735e-01,   2.28411932e-06]], dtype=float32),
#  array([[  9.99881744e-01,   1.18260956e-04]], dtype=float32),
#  array([[  9.99995112e-01,   4.91627407e-06]], dtype=float32),
#  array([[  9.99961257e-01,   3.87119035e-05]], dtype=float32),
#  array([[ 0.99580258,  0.00419745]], dtype=float32),
#  array([[  9.99754250e-01,   2.45760486e-04]], dtype=float32),
#  array([[ 0.99880445,  0.0011955 ]], dtype=float32),
#  array([[  1.00000000e+00,   1.31284983e-10]], dtype=float32),
#  array([[  9.99853253e-01,   1.46694292e-04]], dtype=float32),
#  array([[  9.99999881e-01,   9.90933842e-08]], dtype=float32),
#  array([[  9.99988675e-01,   1.13147835e-05]], dtype=float32),
#  array([[  9.99720871e-01,   2.79150787e-04]], dtype=float32),
#  array([[ 0.99726164,  0.00273835]], dtype=float32),
#  array([[  9.99997020e-01,   2.96262147e-06]], dtype=float32),
#  array([[ 0.9697901 ,  0.03020991]], dtype=float32),
#  array([[  9.99935746e-01,   6.42455561e-05]], dtype=float32),
#  array([[  9.99917150e-01,   8.27903204e-05]], dtype=float32),
#  array([[  9.99987960e-01,   1.20502145e-05]], dtype=float32),
#  array([[ 0.99054283,  0.00945714]], dtype=float32),
#  array([[  9.99999285e-01,   6.63651633e-07]], dtype=float32),
#  array([[  1.00000000e+00,   4.97955321e-09]], dtype=float32),
#  array([[  9.99999285e-01,   6.86126214e-07]], dtype=float32),
#  array([[  9.99999762e-01,   2.48059337e-07]], dtype=float32),
#  array([[  9.99999881e-01,   1.14801239e-07]], dtype=float32),
#  array([[  9.99994993e-01,   5.04603713e-06]], dtype=float32),
#  array([[  9.99999762e-01,   2.46010416e-07]], dtype=float32),
#  array([[  9.99996662e-01,   3.30457215e-06]], dtype=float32),
#  array([[ 0.99843389,  0.00156612]], dtype=float32),
#  array([[ 0.99814939,  0.00185066]], dtype=float32),
#  array([[  9.99998331e-01,   1.72367299e-06]], dtype=float32),
#  array([[  9.99996901e-01,   3.06188417e-06]], dtype=float32),
#  array([[  9.99999762e-01,   2.26782433e-07]], dtype=float32),
#  array([[  9.99999285e-01,   7.62835498e-07]], dtype=float32),
#  array([[  9.99999404e-01,   5.42026669e-07]], dtype=float32),
#  array([[ 0.1971157 ,  0.80288428]], dtype=float32),
#  array([[  9.99321461e-01,   6.78512035e-04]], dtype=float32),
#  array([[  9.99997497e-01,   2.51180495e-06]], dtype=float32),
#  array([[  9.99991417e-01,   8.56646784e-06]], dtype=float32),
#  array([[  1.00000000e+00,   1.46090229e-09]], dtype=float32)]

# %%
cc = []
for i in file_list_true[0:200]:
    a=np.load(i)
    a=np.expand_dims(a,0)
    a=np.expand_dims(a,0)
    cc.append(model_pred.predict(a))
count = 0

# %%
for i in cc:
    if i[0][1] > 0.9:
        count += 1
print count*1.0/len(cc)
# Out:
# 0.995

# %%
cc
# Out:
# [array([[  8.51626100e-05,   9.99914885e-01]], dtype=float32),
#  array([[  3.76106229e-11,   1.00000000e+00]], dtype=float32),
#  array([[  1.69174555e-07,   9.99999881e-01]], dtype=float32),
#  array([[  7.87350946e-05,   9.99921203e-01]], dtype=float32),
#  array([[  9.70517212e-05,   9.99902964e-01]], dtype=float32),
#  array([[ 0.00236508,  0.99763489]], dtype=float32),
#  array([[  1.68161625e-06,   9.99998331e-01]], dtype=float32),
#  array([[  8.46674553e-08,   9.99999881e-01]], dtype=float32),
#  array([[  2.48743299e-06,   9.99997497e-01]], dtype=float32),
#  array([[  9.35745959e-07,   9.99999046e-01]], dtype=float32),
#  array([[ 0.00331045,  0.99668956]], dtype=float32),
#  array([[ 0.02654075,  0.97345924]], dtype=float32),
#  array([[  2.06154382e-05,   9.99979377e-01]], dtype=float32),
#  array([[  4.96809334e-05,   9.99950290e-01]], dtype=float32),
#  array([[ 0.00832448,  0.9916755 ]], dtype=float32),
#  array([[ 0.00203452,  0.99796546]], dtype=float32),
#  array([[  2.82254099e-04,   9.99717772e-01]], dtype=float32),
#  array([[  2.46727194e-10,   1.00000000e+00]], dtype=float32),
#  array([[  7.94750488e-09,   1.00000000e+00]], dtype=float32),
#  array([[ 0.02919,  0.97081]], dtype=float32),
#  array([[  7.12376088e-04,   9.99287665e-01]], dtype=float32),
#  array([[  4.18939590e-06,   9.99995828e-01]], dtype=float32),
#  array([[  3.33266637e-09,   1.00000000e+00]], dtype=float32),
#  array([[  2.30590246e-07,   9.99999762e-01]], dtype=float32),
#  array([[  1.28397674e-04,   9.99871612e-01]], dtype=float32),
#  array([[ 0.00697631,  0.99302363]], dtype=float32),
#  array([[  1.94918380e-06,   9.99998093e-01]], dtype=float32),
#  array([[  2.72489274e-07,   9.99999762e-01]], dtype=float32),
#  array([[  3.37457300e-06,   9.99996662e-01]], dtype=float32),
#  array([[  1.92522975e-06,   9.99998093e-01]], dtype=float32),
#  array([[  7.55067106e-07,   9.99999285e-01]], dtype=float32),
#  array([[  6.94060698e-04,   9.99305964e-01]], dtype=float32),
#  array([[ 0.00467633,  0.99532372]], dtype=float32),
#  array([[  2.08959978e-08,   1.00000000e+00]], dtype=float32),
#  array([[  8.85176705e-04,   9.99114811e-01]], dtype=float32),
#  array([[  1.45111372e-08,   1.00000000e+00]], dtype=float32),
#  array([[  4.41607390e-10,   1.00000000e+00]], dtype=float32),
#  array([[ 0.00147815,  0.99852186]], dtype=float32),
#  array([[  3.49988881e-07,   9.99999642e-01]], dtype=float32),
#  array([[  1.03983526e-04,   9.99896049e-01]], dtype=float32),
#  array([[ 0.00110752,  0.99889249]], dtype=float32),
#  array([[  2.06419121e-04,   9.99793589e-01]], dtype=float32),
#  array([[  7.88699072e-06,   9.99992132e-01]], dtype=float32),
#  array([[  2.74748909e-05,   9.99972582e-01]], dtype=float32),
#  array([[  3.10696887e-05,   9.99968886e-01]], dtype=float32),
#  array([[  1.06509278e-05,   9.99989390e-01]], dtype=float32),
#  array([[  2.60128898e-11,   1.00000000e+00]], dtype=float32),
#  array([[  6.24155873e-05,   9.99937534e-01]], dtype=float32),
#  array([[  6.45755135e-05,   9.99935389e-01]], dtype=float32),
#  array([[  6.75660776e-05,   9.99932408e-01]], dtype=float32),
#  array([[  2.94698621e-09,   1.00000000e+00]], dtype=float32),
#  array([[ 0.00162581,  0.99837422]], dtype=float32),
#  array([[  4.43724013e-04,   9.99556243e-01]], dtype=float32),
#  array([[  1.67141174e-04,   9.99832869e-01]], dtype=float32),
#  array([[ 0.01415131,  0.98584867]], dtype=float32),
#  array([[  2.26983179e-08,   1.00000000e+00]], dtype=float32),
#  array([[  7.91479549e-10,   1.00000000e+00]], dtype=float32),
#  array([[  1.58927887e-05,   9.99984145e-01]], dtype=float32),
#  array([[  1.00614980e-05,   9.99989986e-01]], dtype=float32),
#  array([[ 0.00317393,  0.99682605]], dtype=float32),
#  array([[  8.07390315e-05,   9.99919295e-01]], dtype=float32),
#  array([[ 0.0051566 ,  0.99484336]], dtype=float32),
#  array([[  2.22219612e-08,   1.00000000e+00]], dtype=float32),
#  array([[  1.69708915e-06,   9.99998331e-01]], dtype=float32),
#  array([[  1.29755529e-09,   1.00000000e+00]], dtype=float32),
#  array([[  6.49202731e-04,   9.99350846e-01]], dtype=float32),
#  array([[  1.15881194e-09,   1.00000000e+00]], dtype=float32),
#  array([[  1.73174863e-04,   9.99826849e-01]], dtype=float32),
#  array([[  8.65121765e-05,   9.99913454e-01]], dtype=float32),
#  array([[ 0.00209698,  0.99790299]], dtype=float32),
#  array([[  4.76698224e-05,   9.99952316e-01]], dtype=float32),
#  array([[  3.77341348e-04,   9.99622583e-01]], dtype=float32),
#  array([[ 0.04906707,  0.95093292]], dtype=float32),
#  array([[  7.97181292e-06,   9.99992013e-01]], dtype=float32),
#  array([[  1.16361887e-04,   9.99883652e-01]], dtype=float32),
#  array([[  8.20340237e-12,   1.00000000e+00]], dtype=float32),
#  array([[  1.34435936e-07,   9.99999881e-01]], dtype=float32),
#  array([[ 0.00120029,  0.99879968]], dtype=float32),
#  array([[  7.25459031e-05,   9.99927402e-01]], dtype=float32),
#  array([[  3.85769643e-04,   9.99614239e-01]], dtype=float32),
#  array([[  9.29928792e-04,   9.99070108e-01]], dtype=float32),
#  array([[  5.95534971e-07,   9.99999404e-01]], dtype=float32),
#  array([[  5.39681878e-07,   9.99999404e-01]], dtype=float32),
#  array([[  8.69495794e-04,   9.99130547e-01]], dtype=float32),
#  array([[  5.89050275e-09,   1.00000000e+00]], dtype=float32),
#  array([[  4.22082347e-04,   9.99577940e-01]], dtype=float32),
#  array([[  2.15848175e-08,   1.00000000e+00]], dtype=float32),
#  array([[ 0.0048227 ,  0.99517727]], dtype=float32),
#  array([[  3.08669172e-07,   9.99999642e-01]], dtype=float32),
#  array([[  9.39523925e-09,   1.00000000e+00]], dtype=float32),
#  array([[  2.68288597e-04,   9.99731719e-01]], dtype=float32),
#  array([[  1.46734125e-10,   1.00000000e+00]], dtype=float32),
#  array([[ 0.00486602,  0.99513394]], dtype=float32),
#  array([[  5.31435471e-05,   9.99946833e-01]], dtype=float32),
#  array([[ 0.00112609,  0.99887389]], dtype=float32),
#  array([[  3.29861388e-04,   9.99670148e-01]], dtype=float32),
#  array([[  1.85035842e-05,   9.99981523e-01]], dtype=float32),
#  array([[  4.71051389e-05,   9.99952912e-01]], dtype=float32),
#  array([[  3.06872820e-08,   1.00000000e+00]], dtype=float32),
#  array([[  1.69640276e-04,   9.99830365e-01]], dtype=float32),
#  array([[ 0.00591678,  0.99408323]], dtype=float32),
#  array([[ 0.002923  ,  0.99707699]], dtype=float32),
#  array([[  1.62872174e-10,   1.00000000e+00]], dtype=float32),
#  array([[  3.72077681e-11,   1.00000000e+00]], dtype=float32),
#  array([[  3.25014494e-11,   1.00000000e+00]], dtype=float32),
#  array([[ 0.00124673,  0.99875331]], dtype=float32),
#  array([[ 0.00127369,  0.99872631]], dtype=float32),
#  array([[  1.04554681e-06,   9.99998927e-01]], dtype=float32),
#  array([[ 0.00224944,  0.99775058]], dtype=float32),
#  array([[ 0.00243167,  0.99756831]], dtype=float32),
#  array([[  3.80937272e-04,   9.99619007e-01]], dtype=float32),
#  array([[  2.33675499e-04,   9.99766290e-01]], dtype=float32),
#  array([[  8.99473962e-05,   9.99909997e-01]], dtype=float32),
#  array([[ 0.00122839,  0.99877161]], dtype=float32),
#  array([[  4.31377091e-04,   9.99568641e-01]], dtype=float32),
#  array([[  4.06211766e-05,   9.99959350e-01]], dtype=float32),
#  array([[  6.62498223e-07,   9.99999285e-01]], dtype=float32),
#  array([[ 0.00781887,  0.99218118]], dtype=float32),
#  array([[  2.07459932e-04,   9.99792516e-01]], dtype=float32),
#  array([[  2.15181746e-04,   9.99784887e-01]], dtype=float32),
#  array([[  3.95869904e-07,   9.99999642e-01]], dtype=float32),
#  array([[ 0.16759835,  0.83240169]], dtype=float32),
#  array([[ 0.00495078,  0.99504918]], dtype=float32),
#  array([[  2.57432530e-05,   9.99974251e-01]], dtype=float32),
#  array([[  5.48975834e-07,   9.99999404e-01]], dtype=float32),
#  array([[  1.00785146e-05,   9.99989867e-01]], dtype=float32),
#  array([[  1.57047941e-09,   1.00000000e+00]], dtype=float32),
#  array([[  3.58451252e-05,   9.99964118e-01]], dtype=float32),
#  array([[  1.46463644e-05,   9.99985337e-01]], dtype=float32),
#  array([[  7.37670634e-05,   9.99926209e-01]], dtype=float32),
#  array([[ 0.00623881,  0.99376112]], dtype=float32),
#  array([[  5.54332451e-04,   9.99445617e-01]], dtype=float32),
#  array([[  5.66740637e-05,   9.99943376e-01]], dtype=float32),
#  array([[ 0.00866243,  0.99133754]], dtype=float32),
#  array([[  4.08359308e-04,   9.99591649e-01]], dtype=float32),
#  array([[  4.36818581e-08,   1.00000000e+00]], dtype=float32),
#  array([[  2.03785312e-05,   9.99979615e-01]], dtype=float32),
#  array([[ 0.00442862,  0.99557143]], dtype=float32),
#  array([[  2.60137967e-10,   1.00000000e+00]], dtype=float32),
#  array([[  2.32690695e-06,   9.99997616e-01]], dtype=float32),
#  array([[  5.59971841e-06,   9.99994397e-01]], dtype=float32),
#  array([[  3.08796295e-08,   1.00000000e+00]], dtype=float32),
#  array([[  2.57535243e-10,   1.00000000e+00]], dtype=float32),
#  array([[ 0.00106104,  0.99893898]], dtype=float32),
#  array([[  1.38383606e-04,   9.99861598e-01]], dtype=float32),
#  array([[  1.03999875e-04,   9.99895930e-01]], dtype=float32),
#  array([[  5.03449769e-07,   9.99999523e-01]], dtype=float32),
#  array([[  8.58607510e-13,   1.00000000e+00]], dtype=float32),
#  array([[  1.69855703e-04,   9.99830127e-01]], dtype=float32),
#  array([[ 0.00262867,  0.99737132]], dtype=float32),
#  array([[  1.77275569e-10,   1.00000000e+00]], dtype=float32),
#  array([[  8.87584974e-08,   9.99999881e-01]], dtype=float32),
#  array([[  2.60591219e-06,   9.99997377e-01]], dtype=float32),
#  array([[  1.35425098e-05,   9.99986410e-01]], dtype=float32),
#  array([[ 0.0046459 ,  0.99535406]], dtype=float32),
#  array([[  1.58337745e-04,   9.99841690e-01]], dtype=float32),
#  array([[  7.84142001e-04,   9.99215841e-01]], dtype=float32),
#  array([[  3.52383904e-06,   9.99996424e-01]], dtype=float32),
#  array([[  1.10157824e-04,   9.99889851e-01]], dtype=float32),
#  array([[  5.09189500e-04,   9.99490738e-01]], dtype=float32),
#  array([[  2.47493904e-06,   9.99997497e-01]], dtype=float32),
#  array([[  4.82963369e-05,   9.99951720e-01]], dtype=float32),
#  array([[  8.89631046e-05,   9.99911070e-01]], dtype=float32),
#  array([[  5.00519993e-04,   9.99499440e-01]], dtype=float32),
#  array([[  1.15932322e-08,   1.00000000e+00]], dtype=float32),
#  array([[ 0.00149605,  0.99850392]], dtype=float32),
#  array([[  4.05514385e-07,   9.99999642e-01]], dtype=float32),
#  array([[ 0.00265263,  0.99734735]], dtype=float32),
#  array([[  7.87116642e-06,   9.99992132e-01]], dtype=float32),
#  array([[  1.80375882e-05,   9.99981999e-01]], dtype=float32),
#  array([[  5.90985292e-04,   9.99409080e-01]], dtype=float32),
#  array([[  7.57720358e-08,   9.99999881e-01]], dtype=float32),
#  array([[ 0.00173047,  0.99826956]], dtype=float32),
#  array([[  6.92643439e-14,   1.00000000e+00]], dtype=float32),
#  array([[  7.72916753e-09,   1.00000000e+00]], dtype=float32),
#  array([[  1.55650720e-04,   9.99844313e-01]], dtype=float32),
#  array([[ 0.00506824,  0.99493176]], dtype=float32),
#  array([[  2.01177754e-05,   9.99979854e-01]], dtype=float32),
#  array([[  2.37247536e-06,   9.99997616e-01]], dtype=float32),
#  array([[ 0.00515979,  0.9948402 ]], dtype=float32),
#  array([[  1.11763538e-05,   9.99988794e-01]], dtype=float32),
#  array([[ 0.02143313,  0.97856688]], dtype=float32),
#  array([[ 0.00902012,  0.99097985]], dtype=float32),
#  array([[  2.27475884e-05,   9.99977231e-01]], dtype=float32),
#  array([[ 0.02422273,  0.97577727]], dtype=float32),
#  array([[  1.48962863e-05,   9.99985099e-01]], dtype=float32),
#  array([[  7.42940003e-08,   9.99999881e-01]], dtype=float32),
#  array([[  3.87053064e-04,   9.99612987e-01]], dtype=float32),
#  array([[  6.14953160e-06,   9.99993801e-01]], dtype=float32),
#  array([[  1.53304627e-05,   9.99984622e-01]], dtype=float32),
#  array([[  4.72287365e-06,   9.99995232e-01]], dtype=float32),
#  array([[  6.58243107e-06,   9.99993443e-01]], dtype=float32),
#  array([[  2.98866155e-07,   9.99999642e-01]], dtype=float32),
#  array([[  2.73748825e-04,   9.99726236e-01]], dtype=float32),
#  array([[  6.67515444e-04,   9.99332488e-01]], dtype=float32),
#  array([[  1.95107751e-13,   1.00000000e+00]], dtype=float32),
#  array([[  1.14981820e-04,   9.99884963e-01]], dtype=float32),
#  array([[  1.32695243e-06,   9.99998689e-01]], dtype=float32),
#  array([[  3.35087890e-07,   9.99999642e-01]], dtype=float32),
#  array([[  1.71736119e-05,   9.99982834e-01]], dtype=float32)]
