# %%
from utils.imports import *
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 训练模型

# %%
src = PATH['model_train']
model_paths = PATH['model_paths']

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def dice_coef_np(y_true,y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return ((2. * intersection + 1) / (np.sum(y_true_f) + np.sum(y_pred_f) + 1))

def unet_model(dropout_rate,learn_rate, width):
    inputs = Input((1, 512, 512))
    conv1 = Convolution2D(width, (3, 3), padding="same", activation="elu")(inputs)
    conv1 = BatchNormalization(axis = 1)(conv1)
    conv1 = Convolution2D(width, (3, 3), padding="same", activation="elu")(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Convolution2D(width*2, (3, 3), padding="same", activation="elu")(pool1)
    conv2 = BatchNormalization(axis = 1)(conv2)
    conv2 = Convolution2D(width*2, (3, 3), padding="same", activation="elu")(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Convolution2D(width*4, (3, 3), padding="same", activation="elu")(pool2)
    conv3 = BatchNormalization(axis = 1)(conv3)
    conv3 = Convolution2D(width*4, (3, 3), padding="same", activation="elu")(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Convolution2D(width*8, (3, 3), padding="same", activation="elu")(pool3)
    conv4 = BatchNormalization(axis = 1)(conv4)
    conv4 = Convolution2D(width*8, (3, 3), padding="same", activation="elu")(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Convolution2D(width*16, (3, 3), padding="same", activation="elu")(pool4)
    conv5 = BatchNormalization(axis = 1)(conv5)
    conv5 = Convolution2D(width*16, (3, 3), padding="same", activation="elu")(conv5)

    up6 = merge([UpSampling2D(size=(2, 2))(conv5), conv4], mode='concat', concat_axis=1)
    conv6 = SpatialDropout2D(dropout_rate)(up6)
    conv6 = Convolution2D(width*8, (3, 3), padding="same", activation="elu")(conv6)
    conv6 = Convolution2D(width*8, (3, 3), padding="same", activation="elu")(conv6)

    up7 = merge([UpSampling2D(size=(2, 2))(conv6), conv3], mode='concat', concat_axis=1)
    conv7 = SpatialDropout2D(dropout_rate)(up7)
    conv7 = Convolution2D(width*4, (3, 3), padding="same", activation="elu")(conv7)
    conv7 = Convolution2D(width*4, (3, 3), padding="same", activation="elu")(conv7)

    up8 = merge([UpSampling2D(size=(2, 2))(conv7), conv2], mode='concat', concat_axis=1)
    conv8 = SpatialDropout2D(dropout_rate)(up8)
    conv8 = Convolution2D(width*2, (3, 3), padding="same", activation="elu")(conv8)
    conv8 = Convolution2D(width*2, (3, 3), padding="same", activation="elu")(conv8)

    up9 = merge([UpSampling2D(size=(2, 2))(conv8), conv1], mode='concat', concat_axis=1)
    conv9 = SpatialDropout2D(dropout_rate)(up9)
    conv9 = Convolution2D(width, (3, 3), padding="same", activation="elu")(conv9)
    conv9 = Convolution2D(width, (3, 3), padding="same", activation="elu")(conv9)
    conv10 = Convolution2D(1, (1, 1), activation="sigmoid")(conv9)

    model = Model(input=inputs, output=conv10)
    #model.summary()
    model.compile(optimizer=Adam(lr=learn_rate), loss=dice_coef_loss, metrics=[dice_coef])
    #model.compile(optimizer=SGD(lr=learn_rate, momentum=0.9, nesterov=True), loss=dice_coef_loss, metrics=[dice_coef])
    
    #plot_model(model, to_file='model1.png',show_shapes=True, show_layer_names=False)
    return model


def unet_fit(name, check_name = None):
    data_gen_args = dict(rotation_range=90.,   
                     width_shift_range=0.3,  
                     height_shift_range=0.3,   
                     horizontal_flip=True,   
                     vertical_flip=True,  
                     )
    from keras.preprocessing.image import ImageDataGenerator
    image_datagen = ImageDataGenerator(**data_gen_args)
    mask_datagen = ImageDataGenerator(**data_gen_args)

    # Provide the same seed and keyword arguments to the fit and flow methods
    seed = 1
    
    image_generator = image_datagen.flow_from_directory(
        src,
        class_mode=None,
        classes=['lung'],
        seed=seed,
        target_size=(512,512),
        color_mode="grayscale",
        batch_size=1)

    mask_generator = mask_datagen.flow_from_directory(
        src,
        class_mode=None,
        classes=['nodule'],
        seed=seed,
        target_size=(512,512),
        color_mode="grayscale",
        batch_size=1) 
    # combine generators into one which yields image and masks
    train_generator = itertools.izip(image_generator, mask_generator)   
    t = time.time()
    callbacks = [EarlyStopping(monitor='val_loss', patience = 40, 
                                   verbose = 1),
    ModelCheckpoint(model_paths + '{}.h5'.format(name), 
                        monitor='val_loss', 
                        verbose = 0, save_best_only = True)]
    
    if check_name is not None:
        check_model = model_paths + '{}.h5'.format(check_name)
        model = load_model(check_model, 
                           custom_objects={'dice_coef_loss': dice_coef_loss, 'dice_coef': dice_coef})
    else:
        model = unet_model(dropout_rate = 0.35, learn_rate = 1e-3, width = 32)
    model.fit_generator(
        train_generator,
        epochs=300,
        verbose =1, 
        callbacks = callbacks,
        steps_per_epoch=256,
        validation_data = train_generator,
        nb_val_samples = 48)
    return

# %%
#unet_fit('final_fenge_170626')
unet_fit('final_fenge_170807')
# Out:
# Found 3711 images belonging to 1 classes.
# Found 3711 images belonging to 1 classes.
# Epoch 1/300
# 256/256 [==============================] - 101s - loss: -1.9866 - dice_coef: 1.9866 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 2/300
# 256/256 [==============================] - 95s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 3/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 4/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 5/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 6/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 7/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 8/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 9/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 10/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 11/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 12/300
# 256/256 [==============================] - 95s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 13/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 14/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 15/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 16/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 17/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 18/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 19/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 20/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 21/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 22/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 23/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 24/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 25/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 26/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 27/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 28/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 29/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 30/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 31/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 32/300
# 256/256 [==============================] - 95s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 33/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 34/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 35/300
# 256/256 [==============================] - 95s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 36/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 37/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 38/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 39/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 40/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 41/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 42/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 43/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 44/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 45/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 46/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 47/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 48/300
# 256/256 [==============================] - 95s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 49/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 50/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 51/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 52/300
# 256/256 [==============================] - 95s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 53/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 54/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 55/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 56/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 57/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 58/300
# 256/256 [==============================] - 95s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 59/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 60/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 61/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 62/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 63/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 64/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 65/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 66/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 67/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 68/300
# 256/256 [==============================] - 93s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 69/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 70/300
# 256/256 [==============================] - 96s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 71/300
# 256/256 [==============================] - 95s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 72/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 73/300
# 256/256 [==============================] - 94s - loss: -1.9922 - dice_coef: 1.9922 - val_loss: -1.9922 - val_dice_coef: 1.9922
# Epoch 00072: early stopping
